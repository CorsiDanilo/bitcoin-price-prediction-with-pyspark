# %% [markdown]
# # **Bitcoin price prediction - Random Forest Regressor (Walk Forward Split)**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author: Corsi Danilo (1742375) - corsi.1742375@studenti.uniroma1.it
#
#
# ---
#
#
# Description: perform model's train / validation with hyperparameter tuning and cross validation based on different methods of splitting the dataset.

# %% [markdown]
# # Global constants, dependencies, libraries and tools

# %%
# Main constants
LOCAL_RUNNING = True
SLOW_OPERATIONS = False # Decide whether or not to use operations that might slow down notebook execution
ROOT_DIR = "D:/Documents/Repository/BDC/project" if LOCAL_RUNNING else "/content/drive"

# %%
if not LOCAL_RUNNING:
    # Point Colaboratory to Google Drive
    from google.colab import drive

    # Define GDrive paths
    drive.mount(ROOT_DIR, force_remount=True)

    # Install Spark and related dependencies
    # !pip install pyspark
    # !pip install -U -q PyDrive -qq
    # !apt install openjdk-8-jdk-headless -qq

# %% [markdown]
# ## Import my utilities

# %%
# Set main dir
MAIN_DIR = ROOT_DIR + "" if LOCAL_RUNNING else ROOT_DIR + "/MyDrive/BDC/project"

# Utilities dir
UTILITIES_DIR = MAIN_DIR + "/utilities"

# Import my utilities
import sys
sys.path.append(UTILITIES_DIR)

from imports import *
import train_validation_utilities
from config import *

importlib.reload(train_validation_utilities)
# Out:
# <module 'train_validation_utilities' from 'D:\\Documents/Repository/BDC/project/utilities\\train_validation_utilities.py'>

# %% [markdown]
# ## Core variables

# %%
# BS = Block Split
# WFS = Walk Forward Split
# SS = Single Split
SPLITTING_METHOD = WFS

# LR = LinearRegression 
# GLR = GeneralizedLinearRegression 
# RF = RandomForestRegressor 
# GBTR = GradientBoostingTreeRegressor
MODEL_NAME = RF

# %%
###################
# --- DATASET --- #
###################

# Datasets dirs
DATASET_OUTPUT_DIR = MAIN_DIR + "/datasets/output"

# Datasets paths
DATASET_TRAIN_VALID  = DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

####################
# --- FEATURES --- #
####################

# Features dir
FEATURES_DIR = MAIN_DIR + "/features"

# Features paths
FEATURES_CORRELATION = FEATURES_DIR + "/" + FEATURES_CORRELATION_LABEL + ".json"
BASE_FEATURES = FEATURES_DIR + "/" + BASE_FEATURES_LABEL + ".json"
BASE_AND_MOST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_MOST_CORR_FEATURES_LABEL + ".json"
BASE_AND_LEAST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_LEAST_CORR_FEATURES_LABEL + ".json"

##################
# --- MODELS --- #
##################

# Model dir
MODELS_DIR = MAIN_DIR + "/models"

# Model path
MODEL = MODELS_DIR + "/" + MODEL_NAME

###################
# --- RESULTS --- #
###################

# Results dir
RESULTS_DIR = MAIN_DIR + "/results/" + SPLITTING_METHOD

# Results path
ALL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_all.csv"
REL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_rel.csv"

MODEL_ACCURACY_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_accuracy.csv"

# %%
# Importing useful libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pio.renderers.default = 'vscode+colab' # To correctly render plotly plots

# %% [markdown]
# # Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '12G').\
                set('spark.driver.memory', '12G').\
                set('spark.driver.maxResultSize', '109G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPricePrediction").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Loading dataset

# %%
# Load train / validation set into pyspark dataset objects
df = spark.read.load(DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
train_validation_utilities.dataset_info(df)
# Out:
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |          timestamp| id|     market-price|    opening-price|    highest-price|     lowest-price|    closing-price|  trade-volume-btc|   total-bitcoins|          market-cap|    trade-volume-usd|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|          hash-rate|        difficulty|      miners-revenue|transaction-fees-usd|n-unique-addresses|n-transactions|estimated-transaction-volume-usd|       sma-5-days|       sma-7-days|      sma-10-days|      sma-20-days|      sma-50-days|     sma-100-days|next-market-price|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |2019-11-16 00:00:00|  0|          8457.69|          8463.79|          8528.44|          8430.77|          8484.07|         50.607771|     1.80514375E7|  1.5313937003125E11|      1.0234650669E8|     249372.424907|  1.17150405405405|         4.7506956E8|        1915.32432432432| 9.35826039467827E7|1.2720005267391E13|  1.58643792041146E7|     194291.70411461|          495077.0|      283468.0|              4.61834641876112E8|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|8457.950520833334|
# |2019-11-16 00:15:00|  1|8457.950520833334|8464.019583333335|        8529.4725|8430.178229166668|8484.321979166667| 51.01141038541667|1.8051455859375E7|1.531540059538411...|1.0156392265666667E8| 249374.2310199896|1.1708478397463982| 4.750724999895833E8|       1913.255199192695|9.362212362750347E7|1.2720005267391E13|1.5871859392603226E7|  194137.97333240334|          494408.0|   283269.0625|               4.6059488883908E8|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8458.211041666667|
# |2019-11-16 00:30:00|  2|8458.211041666667|8464.249166666668|8530.505000000001|8429.586458333333|8484.573958333332|51.415049770833335| 1.805147421875E7|1.531686418764322...|1.0078133862333333E8|249376.03713297917|1.1701916254387466| 4.750754399791667E8|      1911.1860740610698|9.366164330822423E7|1.2720005267391E13|1.5879339581091853E7|  193984.24255019668|          493739.0|    283070.125|            4.5935513580204797E8|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|     8458.4715625|
# |2019-11-16 00:45:00|  3|     8458.4715625|       8464.47875|        8531.5375|     8428.9946875|     8484.8259375|    51.81868915625|1.8051492578125E7|1.531832777990234...|       9.999875459E7|249377.84324596875|1.1695354111310947|   4.7507837996875E8|      1909.1169489294448|  9.3701162988945E7|1.2720005267391E13| 1.588681976958048E7|     193830.51176799|          493070.0|   282871.1875|            4.5811538276501596E8|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|8458.732083333334|
# |2019-11-16 01:00:00|  4|8458.732083333334|8464.708333333334|          8532.57|8428.402916666668|8485.077916666667| 52.22232854166667|  1.80515109375E7|1.531979137216146E11| 9.921617055666666E7|249379.64935895836|1.1688791968234429| 4.750813199583333E8|      1907.0478237978195|9.374068266966577E7|1.2720005267391E13|1.5894299958069108E7|  193676.78098578335|          492401.0|     282672.25|            4.5687562972798395E8|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.992604166668|
# |2019-11-16 01:15:00|  5|8458.992604166668|8464.937916666668|        8533.6025|8427.811145833333|8485.329895833333| 52.62596792708333|1.8051529296875E7|1.532125496442057...| 9.843358652333333E7|249381.45547194793| 1.168222982515791| 4.750842599479167E8|      1904.9786986661945|9.378020235038655E7|1.2720005267391E13|1.5901780146557735E7|  193523.05020357668|          491732.0|   282473.3125|            4.5563587669095194E8|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8459.253125000001|
# |2019-11-16 01:30:00|  6|8459.253125000001|8465.167500000001|         8534.635|      8427.219375|      8485.581875|     53.0296073125| 1.805154765625E7|1.532271855667968...|       9.765100249E7| 249383.2615849375|1.1675667682081394|    4.750871999375E8|      1902.9095735345695| 9.38197220311073E7|1.2720005267391E13|1.5909260335046362E7|  193369.31942137002|          491063.0|    282274.375|            4.5439612365391994E8|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|8459.513645833335|
# |2019-11-16 01:45:00|  7|8459.513645833335|8465.397083333333|        8535.6675|8426.627604166668|8485.833854166667|53.433246697916665|1.8051566015625E7|1.532418214893880...| 9.686841845666666E7| 249385.0676979271|1.1669105539004876| 4.750901399270833E8|      1900.8404484029443|9.385924171182808E7|1.2720005267391E13|1.5916740523534989E7|  193215.58863916335|          490394.0|   282075.4375|             4.531563706168879E8|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8459.774166666668|
# |2019-11-16 02:00:00|  8|8459.774166666668|8465.626666666667|           8536.7|8426.035833333333|8486.085833333333| 53.83688608333333|   1.8051584375E7|1.532564574119791...| 9.608583442333333E7|249386.87381091667|1.1662543395928358| 4.750930799166667E8|      1898.7713232713193|9.389876139254886E7|1.2720005267391E13|1.5924220712023616E7|  193061.85785695666|          489725.0|      281876.5|             4.519166175798559E8|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8460.034687500001|
# |2019-11-16 02:15:00|  9|8460.034687500001|       8465.85625|        8537.7325|     8425.4440625|     8486.3378125|    54.24052546875|1.8051602734375E7|1.532710933345703E11|       9.530325039E7|249388.67992390625|1.1655981252851841|   4.7509601990625E8|       1896.702198139694|9.393828107326962E7|1.2720005267391E13|1.5931700900512243E7|     192908.12707475|          489056.0|   281677.5625|             4.506768645428239E8|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8460.295208333333|
# |2019-11-16 02:30:00| 10|8460.295208333333|8466.085833333334|8538.765000000001|8424.852291666666|8486.589791666667| 54.64416485416667| 1.805162109375E7|1.532857292571614...| 9.452066635666667E7|249390.48603689583|1.1649419109775323| 4.750989598958333E8|       1894.633073008069| 9.39778007539904E7|1.2720005267391E13| 1.593918108900087E7|  192754.39629254333|          488387.0|    281478.625|             4.494371115057919E8|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8460.555729166666|
# |2019-11-16 02:45:00| 11|8460.555729166666|8466.315416666668|        8539.7975|8424.260520833333|8486.841770833333|55.047804239583336|1.8051639453125E7|1.533003651797526E11| 9.373808232333332E7| 249392.2921498854|1.1642856966698805| 4.751018998854167E8|       1892.563947876444|9.401732043471116E7|1.2720005267391E13|1.5946661277489496E7|  192600.66551033666|          487718.0|   281279.6875|             4.481973584687599E8|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|       8460.81625|
# |2019-11-16 03:00:00| 12|       8460.81625|         8466.545|          8540.83|       8423.66875|       8487.09375|55.451443624999996|  1.80516578125E7|1.533150011023437...| 9.295549828999999E7|  249394.098262875|1.1636294823622286|     4.75104839875E8|      1890.4948227448187|9.405684011543193E7|1.2720005267391E13|1.5954141465978123E7|     192446.93472813|          487049.0|     281080.75|             4.469576054317279E8|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8461.076770833333|
# |2019-11-16 03:15:00| 13|8461.076770833333|8466.774583333334|8541.862500000001|8423.076979166666|8487.345729166667|55.855083010416664|1.8051676171875E7|1.533296370249349E11| 9.217291425666666E7| 249395.9043758646| 1.162973268054577| 4.751077798645833E8|      1888.4256976131937| 9.40963597961527E7|1.2720005267391E13|1.5961621654466752E7|  192293.20394592333|          486380.0|   280881.8125|             4.457178523946959E8|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8461.337291666667|
# |2019-11-16 03:30:00| 14|8461.337291666667|8467.004166666668|         8542.895|8422.485208333334|8487.597708333333| 56.25872239583333| 1.805169453125E7|1.533442729475260...| 9.139033022333333E7|249397.71048885418|1.1623170537469252| 4.751107198541667E8|      1886.3565724815685|9.413587947687347E7|1.2720005267391E13|1.5969101842955379E7|  192139.47316371667|          485711.0|    280682.875|            4.4447809935766387E8|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|     8461.5978125|
# |2019-11-16 03:45:00| 15|     8461.5978125|8467.233750000001|        8543.9275|     8421.8934375|     8487.8496875|    56.66236178125|1.8051712890625E7|1.533589088701172E11|       9.060774619E7|249399.51660184376|1.1616608394392733|   4.7511365984375E8|      1884.2874473499435|9.417539915759423E7|1.2720005267391E13|1.5976582031444006E7|     191985.74238151|          485042.0|   280483.9375|            4.4323834632063186E8|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8461.858333333334|
# |2019-11-16 04:00:00| 16|8461.858333333334|8467.463333333333|8544.960000000001|8421.301666666666|8488.101666666666|57.066001166666666|    1.805173125E7|1.533735447927083...| 8.982516215666667E7|249401.32271483334|1.1610046251316217| 4.751165998333333E8|      1882.2183222183185|9.421491883831501E7|1.2720005267391E13|1.5984062219932633E7|  191832.01159930334|          484373.0|      280285.0|            4.4199859328359985E8|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8462.118854166667|
# |2019-11-16 04:15:00| 17|8462.118854166667|8467.692916666667|        8545.9925|8420.709895833334|8488.353645833333|57.469640552083334|1.8051749609375E7|1.533881807152994...| 8.904257812333333E7|249403.12882782292|  1.16034841082397| 4.751195398229167E8|      1880.1491970866932|9.425443851903579E7|1.2720005267391E13| 1.599154240842126E7|  191678.28081709667|          483704.0|   280086.0625|            4.4075884024656785E8|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|      8462.379375|
# |2019-11-16 04:30:00| 18|      8462.379375|        8467.9225|         8547.025|      8420.118125|      8488.605625|     57.8732799375| 1.805176796875E7|1.534028166378906...|       8.825999409E7| 249404.9349408125| 1.159692196516318|    4.751224798125E8|      1878.0800719550682|9.429395819975655E7|1.2720005267391E13|1.5999022596909886E7|     191524.55003489|          483035.0|    279887.125|             4.395190872095358E8|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8462.639895833334|
# |2019-11-16 04:45:00| 19|8462.639895833334|8468.152083333334|        8548.0575|8419.526354166666|8488.857604166666| 58.27691932291667|1.8051786328125E7|1.534174525604817...| 8.747741005666667E7|249406.74105380208|1.1590359822086664| 4.751254198020833E8|       1876.010946823443|9.433347788047732E7|1.2720005267391E13|1.6006502785398513E7|  191370.81925268334|          482366.0|   279688.1875|            4.3827933417250377E8|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8462.900416666667|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# only showing top 20 rows
#
# Shape: (131136, 29)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- opening-price: double (nullable = true)
#  |-- highest-price: double (nullable = true)
#  |-- lowest-price: double (nullable = true)
#  |-- closing-price: double (nullable = true)
#  |-- trade-volume-btc: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume-usd: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# # Loading features

# %%
# Loading base features
with open(BASE_FEATURES, "r") as f:
    BASE_FEATURES = json.load(f)
print(BASE_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd']

# %%
# Loading currency and additional most correlated features
with open(BASE_AND_MOST_CORR_FEATURES, "r") as f:
    BASE_AND_MOST_CORR_FEATURES = json.load(f)
print(BASE_AND_MOST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'sma-20-days']

# %%
# Loading currency and additional least correlated features
with open(BASE_AND_LEAST_CORR_FEATURES, "r") as f:
    BASE_AND_LEAST_CORR_FEATURES = json.load(f)
print(BASE_AND_LEAST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'sma-100-days', 'transaction-fees-usd', 'n-unique-addresses', 'sma-50-days', 'n-transactions-total', 'blocks-size', 'hash-rate', 'difficulty', 'avg-block-size', 'n-transactions-per-block', 'n-transactions']

# %% [markdown]
# # Model train / validation
# In order to train and validate the model I'll try several approaches:
# - `Default without normalization:` make predictions using the base model
# - `Default with normalization:` like the previous one but features are normalized
#
# Then the features that gave on average the most satisfactory results (for each model) are chosen and proceeded with:
# - `Hyperparameter tuning:` finding the best parameters to use.
# - `Cross Validation:` validate the performance of the model with the chosen parameters (also here using Block split / Walk forward split)
#
# If the final results are satisfactory, the model will be trained on the whole train / validation set and saved in order to make predictions on the test set.
#
# For each approach the train / validation set will be split according to the chosen splitting method (in order to figure out which one works best for our problem). In this case the `Walk forward time series splits` method will be used: involves using a sliding window approach to create the training and validation sets for each fold. The model is trained on a fixed window of historical data, and then validated on the next observation in the time series. This process is repeated for each subsequent observation, with the window sliding forward one step at a time.
#
# <img src="https://github.com/CorsiDanilo/bitcoin-price-prediction-with-pyspark/blob/main/notebooks/images/walk-forward-splits.png?raw=1">

# %%
# Get splitting parameters based on the choosen splitting method
splitting_info = train_validation_utilities.get_splitting_params(SPLITTING_METHOD)
splitting_info
# Out:
# {'split_type': 'walk_forward_splits',
#  'min_obser': 20000,
#  'sliding_window': 5000}

# %% [markdown]
# ## Default
# The train / validation set will be splitted based on the splitting method chosen so that the model performance can be seen without any tuning by using different features (normalized and non)

# %%
# Get default parameters
params = train_validation_utilities.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'numTrees': [20], 'maxDepth': [5], 'seed': [42]}

# %% [markdown]
# ### Without normalization

# %%
# Define model and features type
MODEL_TYPE = "default"
FEATURES_NORMALIZATION = False

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_train_results_base_features, default_valid_results_base_features, default_train_pred_base_features, default_valid_pred_base_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:04<00:00,  4.03s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.62s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:02<00:00,  2.02s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]

# %%
default_train_results_base_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   train  walk_forward_splits
# 1   RandomForestRegressor  default   train  walk_forward_splits
# 2   RandomForestRegressor  default   train  walk_forward_splits
# 3   RandomForestRegressor  default   train  walk_forward_splits
# 4   RandomForestRegressor  default   train  walk_forward_splits
# 5   RandomForestRegressor  default   train  walk_forward_splits
# 6   RandomForestRegressor  default   train  walk_forward_splits
# 7   RandomForestRegressor  default   train  walk_forward_splits
# 8   RandomForestRegressor  default   train  walk_forward_splits
# 9   RandomForestRegressor  default   train  walk_forward_splits
# 10  RandomForestRegressor  default   train  walk_forward_splits
# 11  RandomForestRegressor  default   train  walk_forward_splits
# 12  RandomForestRegressor  default   train  walk_forward_splits
# 13  RandomForestRegressor  default   train  walk_forward_splits
# 14  RandomForestRegressor  default   train  walk_forward_splits
# 15  RandomForestRegressor  default   train  walk_forward_splits
# 16  RandomForestRegressor  default   train  walk_forward_splits
# 17  RandomForestRegressor  default   train  walk_forward_splits
# 18  RandomForestRegressor  default   train  walk_forward_splits
# 19  RandomForestRegressor  default   train  walk_forward_splits
# 20  RandomForestRegressor  default   train  walk_forward_splits
# 21  RandomForestRegressor  default   train  walk_forward_splits
#
#          Features  Splits Train / Validation   Parameters        RMSE  \
# 0   base_features       1      (20000, 5000)  [20, 5, 42]   54.324828
# 1   base_features       2      (20000, 5000)  [20, 5, 42]   67.275716
# 2   base_features       3      (20000, 5000)  [20, 5, 42]   68.267176
# 3   base_features       4      (20000, 5000)  [20, 5, 42]  101.332426
# 4   base_features       5      (20000, 5000)  [20, 5, 42]  245.803556
# 5   base_features       6      (20000, 5000)  [20, 5, 42]  474.640394
# 6   base_features       7      (20000, 5000)  [20, 5, 42]  453.399154
# 7   base_features       8      (20000, 5000)  [20, 5, 42]  454.302951
# 8   base_features       9      (20000, 5000)  [20, 5, 42]  345.221745
# 9   base_features      10      (20000, 5000)  [20, 5, 42]  331.128187
# 10  base_features      11      (20000, 5000)  [20, 5, 42]  372.919494
# 11  base_features      12      (20000, 5000)  [20, 5, 42]  355.183722
# 12  base_features      13      (20000, 5000)  [20, 5, 42]  336.093028
# 13  base_features      14      (20000, 5000)  [20, 5, 42]  319.064368
# 14  base_features      15      (20000, 5000)  [20, 5, 42]  348.907796
# 15  base_features      16      (20000, 5000)  [20, 5, 42]  272.084910
# 16  base_features      17      (20000, 5000)  [20, 5, 42]  249.966050
# 17  base_features      18      (20000, 5000)  [20, 5, 42]  238.851797
# 18  base_features      19      (20000, 5000)  [20, 5, 42]  111.543800
# 19  base_features      20      (20000, 5000)  [20, 5, 42]   97.130514
# 20  base_features      21      (20000, 5000)  [20, 5, 42]  143.186270
# 21  base_features      22      (20000, 5000)  [20, 5, 42]  122.386525
#
#               MSE         MAE      MAPE        R2  Adjusted_R2      Time
# 0     2951.186967   40.463460  0.005271  0.998088     0.998088  2.124227
# 1     4526.021944   43.766245  0.005333  0.997262     0.997261  1.000664
# 2     4660.407379   48.790814  0.005713  0.998392     0.998392  0.911856
# 3    10268.260658   63.657083  0.006096  0.996683     0.996682  0.781034
# 4    60419.387956  134.788525  0.008653  0.997781     0.997781  0.754985
# 5   225283.503611  286.217603  0.012909  0.998573     0.998572  0.713389
# 6   205570.793236  332.765242  0.012473  0.999334     0.999334  0.717053
# 7   206391.171739  300.855322  0.008288  0.998973     0.998973  0.807583
# 8   119178.052938  244.867106  0.005562  0.998812     0.998812  0.753515
# 9   109645.876060  246.937555  0.005445  0.998698     0.998698  0.730999
# 10  139068.948925  279.546119  0.006132  0.998596     0.998596  0.759004
# 11  126155.476614  260.822470  0.005719  0.998649     0.998649  0.780001
# 12  112958.523218  236.612182  0.004876  0.998204     0.998204  0.807002
# 13  101802.071100  224.954112  0.004716  0.998583     0.998582  0.752001
# 14  121736.650391  235.275620  0.005475  0.997999     0.997999  0.793000
# 15   74030.198038  184.146388  0.005823  0.999008     0.999008  0.717997
# 16   62483.025988  176.676700  0.006212  0.999249     0.999249  0.719521
# 17   57050.180927  151.375719  0.006118  0.998441     0.998441  0.753041
# 18   12442.019371   75.098651  0.003728  0.997882     0.997881  0.796124
# 19    9434.336749   68.977977  0.003461  0.998526     0.998526  0.726518
# 20   20502.307814   87.983576  0.004099  0.998732     0.998732  0.729520
# 21   14978.461612   88.991997  0.003826  0.999315     0.999315  0.741046

# %%
default_valid_results_base_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   valid  walk_forward_splits
# 1   RandomForestRegressor  default   valid  walk_forward_splits
# 2   RandomForestRegressor  default   valid  walk_forward_splits
# 3   RandomForestRegressor  default   valid  walk_forward_splits
# 4   RandomForestRegressor  default   valid  walk_forward_splits
# 5   RandomForestRegressor  default   valid  walk_forward_splits
# 6   RandomForestRegressor  default   valid  walk_forward_splits
# 7   RandomForestRegressor  default   valid  walk_forward_splits
# 8   RandomForestRegressor  default   valid  walk_forward_splits
# 9   RandomForestRegressor  default   valid  walk_forward_splits
# 10  RandomForestRegressor  default   valid  walk_forward_splits
# 11  RandomForestRegressor  default   valid  walk_forward_splits
# 12  RandomForestRegressor  default   valid  walk_forward_splits
# 13  RandomForestRegressor  default   valid  walk_forward_splits
# 14  RandomForestRegressor  default   valid  walk_forward_splits
# 15  RandomForestRegressor  default   valid  walk_forward_splits
# 16  RandomForestRegressor  default   valid  walk_forward_splits
# 17  RandomForestRegressor  default   valid  walk_forward_splits
# 18  RandomForestRegressor  default   valid  walk_forward_splits
# 19  RandomForestRegressor  default   valid  walk_forward_splits
# 20  RandomForestRegressor  default   valid  walk_forward_splits
# 21  RandomForestRegressor  default   valid  walk_forward_splits
#
#          Features  Splits Train / Validation   Parameters          RMSE  \
# 0   base_features       1      (20000, 5000)  [20, 5, 42]    341.014059
# 1   base_features       2      (20000, 5000)  [20, 5, 42]    451.926817
# 2   base_features       3      (20000, 5000)  [20, 5, 42]   1775.458383
# 3   base_features       4      (20000, 5000)  [20, 5, 42]   7215.715807
# 4   base_features       5      (20000, 5000)  [20, 5, 42]  12913.689053
# 5   base_features       6      (20000, 5000)  [20, 5, 42]   3023.558357
# 6   base_features       7      (20000, 5000)  [20, 5, 42]   1810.830679
# 7   base_features       8      (20000, 5000)  [20, 5, 42]    596.276765
# 8   base_features       9      (20000, 5000)  [20, 5, 42]    710.370482
# 9   base_features      10      (20000, 5000)  [20, 5, 42]   1708.787772
# 10  base_features      11      (20000, 5000)  [20, 5, 42]    704.542033
# 11  base_features      12      (20000, 5000)  [20, 5, 42]    610.707760
# 12  base_features      13      (20000, 5000)  [20, 5, 42]    394.971386
# 13  base_features      14      (20000, 5000)  [20, 5, 42]   5476.107162
# 14  base_features      15      (20000, 5000)  [20, 5, 42]   7807.975736
# 15  base_features      16      (20000, 5000)  [20, 5, 42]    359.799992
# 16  base_features      17      (20000, 5000)  [20, 5, 42]    752.901408
# 17  base_features      18      (20000, 5000)  [20, 5, 42]    402.969140
# 18  base_features      19      (20000, 5000)  [20, 5, 42]    274.532982
# 19  base_features      20      (20000, 5000)  [20, 5, 42]   3262.889155
# 20  base_features      21      (20000, 5000)  [20, 5, 42]    577.862333
# 21  base_features      22      (20000, 5000)  [20, 5, 42]    978.552082
#
#              MSE           MAE      MAPE         R2  Adjusted_R2      Time
# 0   1.162906e+05    142.833086  0.013294   0.703295     0.703057  2.124227
# 1   2.042378e+05    388.396665  0.034183   0.425514     0.425054  1.000664
# 2   3.152252e+06   1134.296754  0.078325   0.030501     0.029725  0.911856
# 3   5.206655e+07   5621.445609  0.233791  -1.598331    -1.600412  0.781034
# 4   1.667634e+08  10528.753877  0.235727  -2.051569    -2.054013  0.754985
# 5   9.141905e+06   2332.379703  0.040161   0.516360     0.515973  0.713389
# 6   3.279108e+06   1406.283847  0.035560   0.957918     0.957885  0.717053
# 7   3.555460e+05    448.545050  0.012828   0.958328     0.958295  0.807583
# 8   5.046262e+05    523.555803  0.011474   0.940783     0.940735  0.753515
# 9   2.919956e+06   1010.541397  0.016595   0.950629     0.950590  0.730999
# 10  4.963795e+05    571.715346  0.011302   0.981339     0.981324  0.759004
# 11  3.729640e+05    462.410862  0.011757   0.946683     0.946640  0.780001
# 12  1.560024e+05    294.339527  0.007143   0.978989     0.978973  0.807002
# 13  2.998775e+07   4415.263900  0.146960  -0.538799    -0.540032  0.752001
# 14  6.096449e+07   7545.828805  0.358777 -14.037055   -14.049097  0.793000
# 15  1.294560e+05    279.558085  0.013342   0.955935     0.955900  0.717997
# 16  5.668605e+05    350.972056  0.019740   0.453849     0.453411  0.719521
# 17  1.623841e+05    326.404208  0.019607  -0.368002    -0.369097  0.753041
# 18  7.536836e+04    166.237173  0.007357   0.985592     0.985580  0.796124
# 19  1.064645e+07   2542.002912  0.088992  -0.196627    -0.197585  0.726518
# 20  3.339249e+05    486.434971  0.017745   0.616531     0.616224  0.729520
# 21  9.575642e+05    742.069467  0.024859   0.662582     0.662312  0.741046

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_train_results_base_and_most_corr_features, default_valid_results_base_and_most_corr_features, default_train_pred_base_and_most_corr_features, default_valid_pred_base_and_most_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.90s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.87s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]

# %%
default_train_results_base_and_most_corr_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   train  walk_forward_splits
# 1   RandomForestRegressor  default   train  walk_forward_splits
# 2   RandomForestRegressor  default   train  walk_forward_splits
# 3   RandomForestRegressor  default   train  walk_forward_splits
# 4   RandomForestRegressor  default   train  walk_forward_splits
# 5   RandomForestRegressor  default   train  walk_forward_splits
# 6   RandomForestRegressor  default   train  walk_forward_splits
# 7   RandomForestRegressor  default   train  walk_forward_splits
# 8   RandomForestRegressor  default   train  walk_forward_splits
# 9   RandomForestRegressor  default   train  walk_forward_splits
# 10  RandomForestRegressor  default   train  walk_forward_splits
# 11  RandomForestRegressor  default   train  walk_forward_splits
# 12  RandomForestRegressor  default   train  walk_forward_splits
# 13  RandomForestRegressor  default   train  walk_forward_splits
# 14  RandomForestRegressor  default   train  walk_forward_splits
# 15  RandomForestRegressor  default   train  walk_forward_splits
# 16  RandomForestRegressor  default   train  walk_forward_splits
# 17  RandomForestRegressor  default   train  walk_forward_splits
# 18  RandomForestRegressor  default   train  walk_forward_splits
# 19  RandomForestRegressor  default   train  walk_forward_splits
# 20  RandomForestRegressor  default   train  walk_forward_splits
# 21  RandomForestRegressor  default   train  walk_forward_splits
#
#                        Features  Splits Train / Validation   Parameters  \
# 0   base_and_most_corr_features       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_most_corr_features       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_most_corr_features       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_most_corr_features       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_most_corr_features       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_most_corr_features       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_most_corr_features       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_most_corr_features       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_most_corr_features       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_most_corr_features      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_most_corr_features      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_most_corr_features      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_most_corr_features      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_most_corr_features      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_most_corr_features      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_most_corr_features      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_most_corr_features      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_most_corr_features      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_most_corr_features      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_most_corr_features      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_most_corr_features      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_most_corr_features      22      (20000, 5000)  [20, 5, 42]
#
#           RMSE            MSE         MAE      MAPE        R2  Adjusted_R2  \
# 0    55.884373    3123.063151   42.855391  0.005617  0.997977     0.997977
# 1    54.077732    2924.401054   38.347669  0.004709  0.998231     0.998230
# 2    65.590702    4302.140213   46.501029  0.005458  0.998516     0.998515
# 3    87.214075    7606.294795   56.646746  0.005313  0.997543     0.997542
# 4   208.425711   43441.277030  120.940702  0.008069  0.998405     0.998404
# 5   421.601079  177747.469841  273.053898  0.012779  0.998874     0.998874
# 6   435.040829  189260.522983  315.295167  0.011953  0.999387     0.999387
# 7   445.454478  198429.691872  303.619560  0.008393  0.999013     0.999012
# 8   334.790056  112084.381733  243.431235  0.005631  0.998883     0.998883
# 9   316.341216  100071.764904  236.004004  0.005233  0.998812     0.998811
# 10  352.047189  123937.223598  260.814960  0.005748  0.998749     0.998748
# 11  344.777583  118871.581696  250.459137  0.005512  0.998727     0.998727
# 12  332.752479  110724.212501  231.801276  0.004777  0.998240     0.998239
# 13  308.646406   95262.603782  221.496979  0.004666  0.998674     0.998673
# 14  310.518645   96421.828878  222.728334  0.005320  0.998415     0.998415
# 15  213.831491   45723.906607  163.214724  0.005074  0.999387     0.999387
# 16  216.904707   47047.651923  161.879652  0.005791  0.999434     0.999434
# 17  204.181663   41690.151598  136.274905  0.005668  0.998861     0.998861
# 18  102.846610   10577.425179   71.490870  0.003553  0.998199     0.998199
# 19   98.869487    9775.175548   69.564742  0.003531  0.998473     0.998473
# 20  115.380441   13312.646191   81.209091  0.003845  0.999177     0.999177
# 21  120.197973   14447.552742   89.488188  0.003818  0.999339     0.999339
#
#         Time
# 0   0.800778
# 1   0.755819
# 2   0.735129
# 3   0.799385
# 4   0.741255
# 5   0.765357
# 6   0.731522
# 7   0.763512
# 8   0.804514
# 9   0.752996
# 10  0.775998
# 11  0.804513
# 12  0.752513
# 13  0.756518
# 14  0.780098
# 15  0.754511
# 16  0.769515
# 17  0.774359
# 18  0.796187
# 19  0.787520
# 20  0.772001
# 21  0.779520

# %%
default_valid_results_base_and_most_corr_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   valid  walk_forward_splits
# 1   RandomForestRegressor  default   valid  walk_forward_splits
# 2   RandomForestRegressor  default   valid  walk_forward_splits
# 3   RandomForestRegressor  default   valid  walk_forward_splits
# 4   RandomForestRegressor  default   valid  walk_forward_splits
# 5   RandomForestRegressor  default   valid  walk_forward_splits
# 6   RandomForestRegressor  default   valid  walk_forward_splits
# 7   RandomForestRegressor  default   valid  walk_forward_splits
# 8   RandomForestRegressor  default   valid  walk_forward_splits
# 9   RandomForestRegressor  default   valid  walk_forward_splits
# 10  RandomForestRegressor  default   valid  walk_forward_splits
# 11  RandomForestRegressor  default   valid  walk_forward_splits
# 12  RandomForestRegressor  default   valid  walk_forward_splits
# 13  RandomForestRegressor  default   valid  walk_forward_splits
# 14  RandomForestRegressor  default   valid  walk_forward_splits
# 15  RandomForestRegressor  default   valid  walk_forward_splits
# 16  RandomForestRegressor  default   valid  walk_forward_splits
# 17  RandomForestRegressor  default   valid  walk_forward_splits
# 18  RandomForestRegressor  default   valid  walk_forward_splits
# 19  RandomForestRegressor  default   valid  walk_forward_splits
# 20  RandomForestRegressor  default   valid  walk_forward_splits
# 21  RandomForestRegressor  default   valid  walk_forward_splits
#
#                        Features  Splits Train / Validation   Parameters  \
# 0   base_and_most_corr_features       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_most_corr_features       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_most_corr_features       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_most_corr_features       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_most_corr_features       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_most_corr_features       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_most_corr_features       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_most_corr_features       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_most_corr_features       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_most_corr_features      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_most_corr_features      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_most_corr_features      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_most_corr_features      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_most_corr_features      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_most_corr_features      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_most_corr_features      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_most_corr_features      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_most_corr_features      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_most_corr_features      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_most_corr_features      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_most_corr_features      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_most_corr_features      22      (20000, 5000)  [20, 5, 42]
#
#             RMSE           MSE           MAE      MAPE         R2  \
# 0     380.676138  1.449143e+05    164.197890  0.015358   0.630264
# 1     491.449652  2.415228e+05    401.108825  0.036253   0.320638
# 2    1812.134802  3.283833e+06   1169.295549  0.080938  -0.009967
# 3    7247.268773  5.252290e+07   5663.362098  0.235824  -1.621105
# 4   12716.236660  1.617027e+08  10410.077041  0.233592  -1.958965
# 5    2754.285142  7.586087e+06   2098.132145  0.036213   0.598669
# 6    2630.659771  6.920371e+06   1944.358582  0.050280   0.911189
# 7     605.009533  3.660365e+05    442.072271  0.012520   0.957098
# 8     568.970865  3.237278e+05    430.923664  0.009418   0.962011
# 9    2004.584149  4.018358e+06   1201.484097  0.019509   0.932057
# 10    970.102549  9.410990e+05    818.035613  0.016252   0.964621
# 11    676.766579  4.580130e+05    496.741522  0.012674   0.934525
# 12    414.987269  1.722144e+05    321.306555  0.007731   0.976806
# 13   5491.124959  3.015245e+07   4432.170645  0.147496  -0.547251
# 14   7946.491512  6.314673e+07   7690.400016  0.365485 -14.575311
# 15    400.791093  1.606335e+05    312.593967  0.014713   0.945323
# 16    746.211940  5.568323e+05    339.298266  0.019135   0.463511
# 17    391.497646  1.532704e+05    312.911949  0.018801  -0.291224
# 18    661.210585  4.371994e+05    585.415626  0.025647   0.916419
# 19   3300.404517  1.089267e+07   2577.212075  0.090273  -0.224302
# 20   1289.074531  1.661713e+06   1178.797601  0.043028  -0.908262
# 21   1023.661034  1.047882e+06    799.948940  0.026704   0.630757
#
#     Adjusted_R2      Time
# 0      0.629968  0.800778
# 1      0.320094  0.755819
# 2     -0.010776  0.735129
# 3     -1.623204  0.799385
# 4     -1.961334  0.741255
# 5      0.598347  0.765357
# 6      0.911118  0.731522
# 7      0.957064  0.763512
# 8      0.961980  0.804514
# 9      0.932003  0.752996
# 10     0.964592  0.775998
# 11     0.934473  0.804513
# 12     0.976787  0.752513
# 13    -0.548490  0.756518
# 14   -14.587784  0.780098
# 15     0.945279  0.754511
# 16     0.463081  0.769515
# 17    -0.292258  0.774359
# 18     0.916353  0.796187
# 19    -0.225282  0.787520
# 20    -0.909790  0.772001
# 21     0.630461  0.779520

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_train_results_base_and_least_corr_features, default_valid_results_base_and_least_corr_features, default_train_pred_base_and_least_corr_features, default_valid_pred_base_and_least_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:02<00:00,  2.18s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:02<00:00,  2.02s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]

# %%
default_train_results_base_and_least_corr_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   train  walk_forward_splits
# 1   RandomForestRegressor  default   train  walk_forward_splits
# 2   RandomForestRegressor  default   train  walk_forward_splits
# 3   RandomForestRegressor  default   train  walk_forward_splits
# 4   RandomForestRegressor  default   train  walk_forward_splits
# 5   RandomForestRegressor  default   train  walk_forward_splits
# 6   RandomForestRegressor  default   train  walk_forward_splits
# 7   RandomForestRegressor  default   train  walk_forward_splits
# 8   RandomForestRegressor  default   train  walk_forward_splits
# 9   RandomForestRegressor  default   train  walk_forward_splits
# 10  RandomForestRegressor  default   train  walk_forward_splits
# 11  RandomForestRegressor  default   train  walk_forward_splits
# 12  RandomForestRegressor  default   train  walk_forward_splits
# 13  RandomForestRegressor  default   train  walk_forward_splits
# 14  RandomForestRegressor  default   train  walk_forward_splits
# 15  RandomForestRegressor  default   train  walk_forward_splits
# 16  RandomForestRegressor  default   train  walk_forward_splits
# 17  RandomForestRegressor  default   train  walk_forward_splits
# 18  RandomForestRegressor  default   train  walk_forward_splits
# 19  RandomForestRegressor  default   train  walk_forward_splits
# 20  RandomForestRegressor  default   train  walk_forward_splits
# 21  RandomForestRegressor  default   train  walk_forward_splits
#
#                         Features  Splits Train / Validation   Parameters  \
# 0   base_and_least_corr_features       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_least_corr_features       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_least_corr_features       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_least_corr_features       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_least_corr_features       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_least_corr_features       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_least_corr_features       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_least_corr_features       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_least_corr_features       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_least_corr_features      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_least_corr_features      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_least_corr_features      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_least_corr_features      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_least_corr_features      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_least_corr_features      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_least_corr_features      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_least_corr_features      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_least_corr_features      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_least_corr_features      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_least_corr_features      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_least_corr_features      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_least_corr_features      22      (20000, 5000)  [20, 5, 42]
#
#           RMSE            MSE         MAE      MAPE        R2  Adjusted_R2  \
# 0    55.536725    3084.327784   40.765889  0.005364  0.998002     0.998002
# 1    53.499846    2862.233507   37.313675  0.004631  0.998268     0.998268
# 2    64.840827    4204.332807   47.165961  0.005495  0.998549     0.998549
# 3    79.373063    6300.083141   51.674075  0.004946  0.997965     0.997964
# 4   157.170225   24702.479639  103.755659  0.007309  0.999093     0.999093
# 5   376.797037  141976.007101  252.283889  0.012051  0.999101     0.999100
# 6   424.936019  180570.619959  304.753420  0.011261  0.999415     0.999415
# 7   428.810983  183878.859499  290.086866  0.007889  0.999085     0.999085
# 8   334.172402  111671.194392  234.756466  0.005423  0.998887     0.998887
# 9   305.888803   93567.959527  229.348511  0.005102  0.998889     0.998889
# 10  355.259973  126209.648663  267.435533  0.005950  0.998726     0.998725
# 11  351.151431  123307.327452  259.762719  0.005718  0.998680     0.998680
# 12  316.203487   99984.645281  218.987131  0.004478  0.998410     0.998410
# 13  307.630534   94636.545534  214.198970  0.004508  0.998682     0.998682
# 14  323.165614  104436.014022  220.174275  0.005290  0.998284     0.998283
# 15  220.516245   48627.414425  165.333415  0.005101  0.999348     0.999348
# 16  233.843076   54682.584103  174.661299  0.006403  0.999343     0.999342
# 17  191.206757   36560.023893  132.621177  0.005594  0.999001     0.999001
# 18  110.730327   12261.205232   73.182857  0.003637  0.997913     0.997912
# 19   95.993182    9214.690977   68.197756  0.003469  0.998561     0.998560
# 20  121.316034   14717.580019   84.533653  0.004051  0.999090     0.999090
# 21  114.758255   13169.457056   83.362001  0.003516  0.999398     0.999397
#
#         Time
# 0   0.909670
# 1   0.845103
# 2   0.871024
# 3   0.948189
# 4   0.817850
# 5   0.913142
# 6   0.903635
# 7   0.865193
# 8   0.894993
# 9   0.914337
# 10  0.953367
# 11  0.907361
# 12  0.929383
# 13  0.896302
# 14  0.889496
# 15  0.845803
# 16  0.916698
# 17  0.889510
# 18  0.866558
# 19  0.875508
# 20  0.859447
# 21  0.830514

# %%
default_valid_results_base_and_least_corr_features
# Out:
#                     Model     Type Dataset            Splitting  \
# 0   RandomForestRegressor  default   valid  walk_forward_splits
# 1   RandomForestRegressor  default   valid  walk_forward_splits
# 2   RandomForestRegressor  default   valid  walk_forward_splits
# 3   RandomForestRegressor  default   valid  walk_forward_splits
# 4   RandomForestRegressor  default   valid  walk_forward_splits
# 5   RandomForestRegressor  default   valid  walk_forward_splits
# 6   RandomForestRegressor  default   valid  walk_forward_splits
# 7   RandomForestRegressor  default   valid  walk_forward_splits
# 8   RandomForestRegressor  default   valid  walk_forward_splits
# 9   RandomForestRegressor  default   valid  walk_forward_splits
# 10  RandomForestRegressor  default   valid  walk_forward_splits
# 11  RandomForestRegressor  default   valid  walk_forward_splits
# 12  RandomForestRegressor  default   valid  walk_forward_splits
# 13  RandomForestRegressor  default   valid  walk_forward_splits
# 14  RandomForestRegressor  default   valid  walk_forward_splits
# 15  RandomForestRegressor  default   valid  walk_forward_splits
# 16  RandomForestRegressor  default   valid  walk_forward_splits
# 17  RandomForestRegressor  default   valid  walk_forward_splits
# 18  RandomForestRegressor  default   valid  walk_forward_splits
# 19  RandomForestRegressor  default   valid  walk_forward_splits
# 20  RandomForestRegressor  default   valid  walk_forward_splits
# 21  RandomForestRegressor  default   valid  walk_forward_splits
#
#                         Features  Splits Train / Validation   Parameters  \
# 0   base_and_least_corr_features       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_least_corr_features       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_least_corr_features       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_least_corr_features       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_least_corr_features       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_least_corr_features       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_least_corr_features       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_least_corr_features       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_least_corr_features       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_least_corr_features      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_least_corr_features      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_least_corr_features      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_least_corr_features      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_least_corr_features      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_least_corr_features      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_least_corr_features      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_least_corr_features      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_least_corr_features      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_least_corr_features      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_least_corr_features      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_least_corr_features      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_least_corr_features      22      (20000, 5000)  [20, 5, 42]
#
#             RMSE           MSE           MAE      MAPE         R2  \
# 0     350.633123  1.229436e+05    146.548859  0.013642   0.686320
# 1     520.840849  2.712752e+05    429.487927  0.038004   0.236950
# 2    1792.313674  3.212388e+06   1136.756930  0.078282   0.012006
# 3    7810.503835  6.100397e+07   6357.850351  0.269305  -2.044344
# 4   12507.577521  1.564395e+08  10026.930335  0.223138  -1.862655
# 5    3288.721000  1.081569e+07   2640.325653  0.045472   0.427812
# 6    3163.783466  1.000953e+07   2262.212466  0.059233   0.871545
# 7     653.560038  4.271407e+05    443.057026  0.012306   0.949937
# 8     786.144424  6.180231e+05    666.370743  0.014147   0.927476
# 9    2584.241012  6.678302e+06   1780.736451  0.028774   0.887083
# 10   1278.076518  1.633480e+06   1148.208553  0.022918   0.938592
# 11    985.128428  9.704780e+05    744.039690  0.019251   0.861266
# 12    481.585536  2.319246e+05    374.983053  0.008994   0.968764
# 13   5926.836865  3.512740e+07   4807.142806  0.159815  -0.802537
# 14   9087.857553  8.258915e+07   8801.350035  0.417785 -19.370838
# 15    352.181170  1.240316e+05    267.443586  0.012539   0.957781
# 16    806.629203  6.506507e+05    411.648037  0.022904   0.373120
# 17    439.494627  1.931555e+05    358.253691  0.021531  -0.627235
# 18    244.185851  5.962673e+04    196.293819  0.008829   0.988601
# 19   3287.122105  1.080517e+07   2565.732614  0.089869  -0.214467
# 20   1076.837321  1.159579e+06    910.344591  0.033196  -0.331626
# 21    833.994228  6.955464e+05    652.566535  0.021930   0.754909
#
#     Adjusted_R2      Time
# 0      0.686069  0.909670
# 1      0.236339  0.845103
# 2      0.011215  0.871024
# 3     -2.046782  0.948189
# 4     -1.864947  0.817850
# 5      0.427353  0.913142
# 6      0.871442  0.903635
# 7      0.949896  0.865193
# 8      0.927417  0.894993
# 9      0.886992  0.914337
# 10     0.938543  0.953367
# 11     0.861155  0.907361
# 12     0.968739  0.929383
# 13    -0.803980  0.896302
# 14   -19.387151  0.889496
# 15     0.957748  0.845803
# 16     0.372618  0.916698
# 17    -0.628538  0.889510
# 18     0.988592  0.866558
# 19    -0.215440  0.875508
# 20    -0.332692  0.859447
# 21     0.754713  0.830514

# %% [markdown]
# ### With normalization

# %%
# Define model and features type
MODEL_TYPE = "default_norm"
FEATURES_NORMALIZATION = True

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_norm_train_results_base_features, default_norm_valid_results_base_features, default_norm_train_pred_base_features, default_norm_valid_pred_base_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:02<00:00,  2.10s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:02<00:00,  2.02s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]

# %%
default_norm_train_results_base_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   train  walk_forward_splits
# 1   RandomForestRegressor  default_norm   train  walk_forward_splits
# 2   RandomForestRegressor  default_norm   train  walk_forward_splits
# 3   RandomForestRegressor  default_norm   train  walk_forward_splits
# 4   RandomForestRegressor  default_norm   train  walk_forward_splits
# 5   RandomForestRegressor  default_norm   train  walk_forward_splits
# 6   RandomForestRegressor  default_norm   train  walk_forward_splits
# 7   RandomForestRegressor  default_norm   train  walk_forward_splits
# 8   RandomForestRegressor  default_norm   train  walk_forward_splits
# 9   RandomForestRegressor  default_norm   train  walk_forward_splits
# 10  RandomForestRegressor  default_norm   train  walk_forward_splits
# 11  RandomForestRegressor  default_norm   train  walk_forward_splits
# 12  RandomForestRegressor  default_norm   train  walk_forward_splits
# 13  RandomForestRegressor  default_norm   train  walk_forward_splits
# 14  RandomForestRegressor  default_norm   train  walk_forward_splits
# 15  RandomForestRegressor  default_norm   train  walk_forward_splits
# 16  RandomForestRegressor  default_norm   train  walk_forward_splits
# 17  RandomForestRegressor  default_norm   train  walk_forward_splits
# 18  RandomForestRegressor  default_norm   train  walk_forward_splits
# 19  RandomForestRegressor  default_norm   train  walk_forward_splits
# 20  RandomForestRegressor  default_norm   train  walk_forward_splits
# 21  RandomForestRegressor  default_norm   train  walk_forward_splits
#
#               Features  Splits Train / Validation   Parameters         RMSE  \
# 0   base_features_norm       1      (20000, 5000)  [20, 5, 42]   262.475778
# 1   base_features_norm       2      (20000, 5000)  [20, 5, 42]   268.133114
# 2   base_features_norm       3      (20000, 5000)  [20, 5, 42]   313.707297
# 3   base_features_norm       4      (20000, 5000)  [20, 5, 42]   376.201026
# 4   base_features_norm       5      (20000, 5000)  [20, 5, 42]   787.265667
# 5   base_features_norm       6      (20000, 5000)  [20, 5, 42]  1594.855164
# 6   base_features_norm       7      (20000, 5000)  [20, 5, 42]  2087.725793
# 7   base_features_norm       8      (20000, 5000)  [20, 5, 42]  2296.707285
# 8   base_features_norm       9      (20000, 5000)  [20, 5, 42]  1626.790707
# 9   base_features_norm      10      (20000, 5000)  [20, 5, 42]  1488.242263
# 10  base_features_norm      11      (20000, 5000)  [20, 5, 42]  1733.917160
# 11  base_features_norm      12      (20000, 5000)  [20, 5, 42]  1828.222785
# 12  base_features_norm      13      (20000, 5000)  [20, 5, 42]  1693.500064
# 13  base_features_norm      14      (20000, 5000)  [20, 5, 42]  1805.387606
# 14  base_features_norm      15      (20000, 5000)  [20, 5, 42]  1536.009032
# 15  base_features_norm      16      (20000, 5000)  [20, 5, 42]  1128.141244
# 16  base_features_norm      17      (20000, 5000)  [20, 5, 42]  1009.718602
# 17  base_features_norm      18      (20000, 5000)  [20, 5, 42]   739.627026
# 18  base_features_norm      19      (20000, 5000)  [20, 5, 42]   555.579717
# 19  base_features_norm      20      (20000, 5000)  [20, 5, 42]   516.715207
# 20  base_features_norm      21      (20000, 5000)  [20, 5, 42]   757.291144
# 21  base_features_norm      22      (20000, 5000)  [20, 5, 42]   839.582629
#
#              MSE          MAE      MAPE        R2  Adjusted_R2      Time
# 0   6.889353e+04   207.602294  0.025876  0.955373     0.955364  0.723095
# 1   7.189537e+04   197.585347  0.023598  0.956503     0.956495  0.796232
# 2   9.841227e+04   236.576907  0.027473  0.966044     0.966037  0.707100
# 3   1.415272e+05   278.469729  0.027531  0.954277     0.954268  0.708658
# 4   6.197872e+05   612.104458  0.047886  0.977240     0.977235  0.762123
# 5   2.543563e+06  1175.594148  0.063857  0.983885     0.983882  0.808950
# 6   4.358599e+06  1595.527515  0.067536  0.985887     0.985884  0.738198
# 7   5.274864e+06  1813.232405  0.057877  0.973753     0.973748  0.797259
# 8   2.646448e+06  1219.785241  0.028649  0.973623     0.973617  0.776791
# 9   2.214865e+06  1120.080895  0.025976  0.973699     0.973693  0.762012
# 10  3.006469e+06  1257.276831  0.029194  0.969646     0.969640  0.814613
# 11  3.342399e+06  1355.458328  0.030571  0.964217     0.964210  0.724170
# 12  2.867942e+06  1287.130785  0.027467  0.954406     0.954397  0.744225
# 13  3.259424e+06  1425.283227  0.030980  0.954617     0.954608  0.739198
# 14  2.359324e+06  1125.860308  0.027321  0.961223     0.961215  0.731085
# 15  1.272703e+06   856.346902  0.025671  0.982949     0.982945  0.738078
# 16  1.019532e+06   791.852442  0.027727  0.987743     0.987741  0.731978
# 17  5.470481e+05   575.531934  0.025141  0.985053     0.985050  0.795009
# 18  3.086688e+05   398.537131  0.020106  0.947449     0.947439  0.739614
# 19  2.669946e+05   392.580009  0.020114  0.958296     0.958288  0.735251
# 20  5.734899e+05   546.885569  0.025782  0.964537     0.964530  0.723749
# 21  7.048990e+05   625.050676  0.027888  0.967752     0.967746  0.708983

# %%
default_norm_valid_results_base_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 1   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 2   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 3   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 4   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 5   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 6   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 7   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 8   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 9   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 10  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 11  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 12  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 13  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 14  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 15  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 16  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 17  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 18  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 19  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 20  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 21  RandomForestRegressor  default_norm   valid  walk_forward_splits
#
#               Features  Splits Train / Validation   Parameters          RMSE  \
# 0   base_features_norm       1      (20000, 5000)  [20, 5, 42]    645.698275
# 1   base_features_norm       2      (20000, 5000)  [20, 5, 42]   1268.262192
# 2   base_features_norm       3      (20000, 5000)  [20, 5, 42]   2280.163967
# 3   base_features_norm       4      (20000, 5000)  [20, 5, 42]   8288.886669
# 4   base_features_norm       5      (20000, 5000)  [20, 5, 42]  16184.718790
# 5   base_features_norm       6      (20000, 5000)  [20, 5, 42]  12100.744230
# 6   base_features_norm       7      (20000, 5000)  [20, 5, 42]   3169.035368
# 7   base_features_norm       8      (20000, 5000)  [20, 5, 42]   3191.031908
# 8   base_features_norm       9      (20000, 5000)  [20, 5, 42]   2994.384779
# 9   base_features_norm      10      (20000, 5000)  [20, 5, 42]   5681.285322
# 10  base_features_norm      11      (20000, 5000)  [20, 5, 42]   1907.834167
# 11  base_features_norm      12      (20000, 5000)  [20, 5, 42]   1860.711728
# 12  base_features_norm      13      (20000, 5000)  [20, 5, 42]   2130.608481
# 13  base_features_norm      14      (20000, 5000)  [20, 5, 42]   8160.847089
# 14  base_features_norm      15      (20000, 5000)  [20, 5, 42]   8968.464451
# 15  base_features_norm      16      (20000, 5000)  [20, 5, 42]   1454.864137
# 16  base_features_norm      17      (20000, 5000)  [20, 5, 42]   1806.292383
# 17  base_features_norm      18      (20000, 5000)  [20, 5, 42]   2849.762788
# 18  base_features_norm      19      (20000, 5000)  [20, 5, 42]   1140.412784
# 19  base_features_norm      20      (20000, 5000)  [20, 5, 42]   4708.653245
# 20  base_features_norm      21      (20000, 5000)  [20, 5, 42]   2168.801547
# 21  base_features_norm      22      (20000, 5000)  [20, 5, 42]   1889.644817
#
#              MSE           MAE      MAPE         R2  Adjusted_R2      Time
# 0   4.169263e+05    340.093045  0.032686  -0.063751    -0.064603  0.723095
# 1   1.608489e+06   1170.996230  0.102545  -3.524401    -3.528024  0.796232
# 2   5.199148e+06   1526.211225  0.106598  -0.599037    -0.600317  0.707100
# 3   6.870564e+07   7013.733126  0.302384  -2.428689    -2.431434  0.708658
# 4   2.619451e+08  13697.566024  0.312613  -3.793281    -3.797120  0.762123
# 5   1.464280e+08  11064.020676  0.193054  -6.746566    -6.752769  0.808950
# 6   1.004279e+07   2429.132392  0.052804   0.871118     0.871015  0.738198
# 7   1.018268e+07   2673.191752  0.075565  -0.193472    -0.194427  0.797259
# 8   8.966340e+06   2575.890230  0.056045  -0.052192    -0.053035  0.776791
# 9   3.227700e+07   4629.849051  0.076541   0.454257     0.453820  0.762012
# 10  3.639831e+06   1535.292147  0.029506   0.863166     0.863056  0.814613
# 11  3.462248e+06   1489.688038  0.037318   0.505056     0.504660  0.724170
# 12  4.539492e+06   1706.566671  0.042300   0.388613     0.388124  0.744225
# 13  6.659943e+07   7269.914386  0.235687  -2.417501    -2.420237  0.739198
# 14  8.043335e+07   8729.022081  0.413711 -18.839104   -18.854992  0.731085
# 15  2.116630e+06   1227.510239  0.059306   0.279529     0.278952  0.738078
# 16  3.262692e+06   1476.392033  0.078955  -2.143495    -2.146012  0.731978
# 17  8.121148e+06   2825.669148  0.168902 -67.416453   -67.471241  0.795009
# 18  1.300541e+06    930.299464  0.040842   0.751372     0.751173  0.739614
# 19  2.217142e+07   3988.434328  0.142540  -1.491997    -1.493993  0.735251
# 20  4.703700e+06   1775.207891  0.064757  -4.401589    -4.405915  0.723749
# 21  3.570758e+06   1712.943512  0.057208  -0.258232    -0.259240  0.708983

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_norm_train_results_base_and_most_corr_features, default_norm_valid_results_base_and_most_corr_features, default_norm_train_pred_base_and_most_corr_features, default_norm_valid_pred_base_and_most_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:02<00:00,  2.02s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]

# %%
default_norm_train_results_base_and_most_corr_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   train  walk_forward_splits
# 1   RandomForestRegressor  default_norm   train  walk_forward_splits
# 2   RandomForestRegressor  default_norm   train  walk_forward_splits
# 3   RandomForestRegressor  default_norm   train  walk_forward_splits
# 4   RandomForestRegressor  default_norm   train  walk_forward_splits
# 5   RandomForestRegressor  default_norm   train  walk_forward_splits
# 6   RandomForestRegressor  default_norm   train  walk_forward_splits
# 7   RandomForestRegressor  default_norm   train  walk_forward_splits
# 8   RandomForestRegressor  default_norm   train  walk_forward_splits
# 9   RandomForestRegressor  default_norm   train  walk_forward_splits
# 10  RandomForestRegressor  default_norm   train  walk_forward_splits
# 11  RandomForestRegressor  default_norm   train  walk_forward_splits
# 12  RandomForestRegressor  default_norm   train  walk_forward_splits
# 13  RandomForestRegressor  default_norm   train  walk_forward_splits
# 14  RandomForestRegressor  default_norm   train  walk_forward_splits
# 15  RandomForestRegressor  default_norm   train  walk_forward_splits
# 16  RandomForestRegressor  default_norm   train  walk_forward_splits
# 17  RandomForestRegressor  default_norm   train  walk_forward_splits
# 18  RandomForestRegressor  default_norm   train  walk_forward_splits
# 19  RandomForestRegressor  default_norm   train  walk_forward_splits
# 20  RandomForestRegressor  default_norm   train  walk_forward_splits
# 21  RandomForestRegressor  default_norm   train  walk_forward_splits
#
#                             Features  Splits Train / Validation   Parameters  \
# 0   base_and_most_corr_features_norm       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_most_corr_features_norm       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_most_corr_features_norm       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_most_corr_features_norm       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_most_corr_features_norm       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_most_corr_features_norm       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_most_corr_features_norm       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_most_corr_features_norm       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_most_corr_features_norm       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_most_corr_features_norm      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_most_corr_features_norm      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_most_corr_features_norm      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_most_corr_features_norm      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_most_corr_features_norm      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_most_corr_features_norm      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_most_corr_features_norm      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_most_corr_features_norm      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_most_corr_features_norm      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_most_corr_features_norm      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_most_corr_features_norm      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_most_corr_features_norm      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_most_corr_features_norm      22      (20000, 5000)  [20, 5, 42]
#
#            RMSE           MSE          MAE      MAPE        R2  Adjusted_R2  \
# 0    133.823537  1.790874e+04   105.771006  0.013438  0.988399     0.988397
# 1    126.055437  1.588997e+04    93.034999  0.011111  0.990387     0.990385
# 2    132.213744  1.748047e+04    97.114165  0.010986  0.993969     0.993967
# 3    149.643573  2.239320e+04   111.716320  0.010658  0.992766     0.992764
# 4    230.734680  5.323849e+04   171.969806  0.013055  0.998045     0.998045
# 5    669.018263  4.475854e+05   429.028190  0.018437  0.997164     0.997164
# 6   1334.676854  1.781362e+06   908.951745  0.025937  0.994232     0.994231
# 7   1460.559295  2.133233e+06  1094.549316  0.026977  0.989385     0.989383
# 8   1398.660409  1.956251e+06  1020.451118  0.022555  0.980502     0.980498
# 9    905.110383  8.192248e+05   630.109988  0.013553  0.990272     0.990270
# 10   758.534377  5.753744e+05   555.807018  0.012362  0.994191     0.994190
# 11   862.978297  7.447315e+05   663.641235  0.014266  0.992027     0.992026
# 12   767.804350  5.895235e+05   593.228712  0.012293  0.990628     0.990626
# 13   657.076485  4.317495e+05   504.775235  0.010774  0.993988     0.993987
# 14   628.158405  3.945830e+05   475.478863  0.011589  0.993515     0.993514
# 15   517.123804  2.674170e+05   378.772100  0.011272  0.996417     0.996416
# 16   540.368195  2.919978e+05   410.196314  0.015245  0.996490     0.996489
# 17   473.454253  2.241589e+05   334.286024  0.014961  0.993875     0.993874
# 18   303.102009  9.187083e+04   225.386386  0.011383  0.984359     0.984356
# 19   277.346863  7.692128e+04   201.960606  0.010292  0.987985     0.987983
# 20   240.165327  5.767938e+04   177.172561  0.008595  0.996433     0.996433
# 21   255.602328  6.533255e+04   189.419228  0.007876  0.997011     0.997011
#
#         Time
# 0   0.850189
# 1   0.786912
# 2   0.778359
# 3   0.780360
# 4   0.873467
# 5   0.790060
# 6   0.846836
# 7   0.802643
# 8   0.812807
# 9   0.828047
# 10  0.844014
# 11  0.819683
# 12  0.818244
# 13  0.804994
# 14  0.807891
# 15  0.807239
# 16  0.869038
# 17  0.832051
# 18  0.868839
# 19  0.828599
# 20  0.836593
# 21  0.879760

# %%
default_norm_valid_results_base_and_most_corr_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 1   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 2   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 3   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 4   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 5   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 6   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 7   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 8   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 9   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 10  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 11  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 12  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 13  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 14  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 15  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 16  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 17  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 18  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 19  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 20  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 21  RandomForestRegressor  default_norm   valid  walk_forward_splits
#
#                             Features  Splits Train / Validation   Parameters  \
# 0   base_and_most_corr_features_norm       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_most_corr_features_norm       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_most_corr_features_norm       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_most_corr_features_norm       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_most_corr_features_norm       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_most_corr_features_norm       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_most_corr_features_norm       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_most_corr_features_norm       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_most_corr_features_norm       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_most_corr_features_norm      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_most_corr_features_norm      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_most_corr_features_norm      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_most_corr_features_norm      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_most_corr_features_norm      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_most_corr_features_norm      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_most_corr_features_norm      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_most_corr_features_norm      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_most_corr_features_norm      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_most_corr_features_norm      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_most_corr_features_norm      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_most_corr_features_norm      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_most_corr_features_norm      22      (20000, 5000)  [20, 5, 42]
#
#             RMSE           MSE           MAE      MAPE         R2  \
# 0     498.661324  2.486631e+05    366.323439  0.036887   0.365558
# 1     900.539437  8.109713e+05    828.730599  0.074939  -1.281122
# 2    1928.848100  3.720455e+06   1380.997394  0.098427  -0.144254
# 3    7472.753002  5.584204e+07   5964.020865  0.250578  -1.786743
# 4   13859.523958  1.920864e+08  12133.741289  0.281560  -2.514951
# 5   16840.501343  2.836025e+08  15041.548512  0.261823 -14.003587
# 6   20929.369196  4.380385e+08  20409.192624  0.450357  -4.621465
# 7    2944.021169  8.667261e+06   2495.188468  0.074172  -0.015855
# 8    1449.845986  2.102053e+06   1135.865548  0.024664   0.753326
# 9    5762.090387  3.320169e+07   4577.339607  0.073955   0.438622
# 10   5523.320893  3.050707e+07   5375.771073  0.103874  -0.146868
# 11   2316.335593  5.365411e+06   2031.605269  0.051022   0.232990
# 12   1211.199056  1.467003e+06    971.616325  0.023740   0.802421
# 13   6468.412995  4.184037e+07   5597.792384  0.183104  -1.147008
# 14   8176.236389  6.685084e+07   7966.560738  0.377448 -15.488941
# 15   2574.371910  6.627391e+06   2135.057503  0.104119  -1.255871
# 16   3206.613673  1.028237e+07   2437.525806  0.125754  -8.906721
# 17   2652.706324  7.036851e+06   2609.494330  0.155803 -58.281813
# 18   1064.759902  1.133714e+06    902.914968  0.040390   0.783265
# 19   3413.619975  1.165280e+07   2760.064601  0.097531  -0.309738
# 20   3428.477235  1.175446e+07   3288.748070  0.119925 -12.498468
# 21   1463.227459  2.141035e+06   1343.079263  0.044946   0.245561
#
#     Adjusted_R2      Time
# 0      0.365050  0.850189
# 1     -1.282948  0.786912
# 2     -0.145170  0.778359
# 3     -1.788975  0.780360
# 4     -2.517765  0.873467
# 5    -14.015601  0.790060
# 6     -4.625966  0.846836
# 7     -0.016668  0.802643
# 8      0.753128  0.812807
# 9      0.438173  0.828047
# 10    -0.147787  0.844014
# 11     0.232376  0.819683
# 12     0.802263  0.818244
# 13    -1.148727  0.804994
# 14   -15.502145  0.807891
# 15    -1.257677  0.807239
# 16    -8.914654  0.869038
# 17   -58.329286  0.832051
# 18     0.783091  0.868839
# 19    -0.310787  0.828599
# 20   -12.509277  0.836593
# 21     0.244957  0.879760

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_norm_train_results_base_and_least_corr_features, default_norm_valid_results_base_and_least_corr_features, default_norm_train_pred_base_and_least_corr_features, default_norm_valid_pred_base_and_least_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:02<00:00,  2.31s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:02<00:00,  2.32s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:02<00:00,  2.28s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]

# %%
default_norm_train_results_base_and_least_corr_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   train  walk_forward_splits
# 1   RandomForestRegressor  default_norm   train  walk_forward_splits
# 2   RandomForestRegressor  default_norm   train  walk_forward_splits
# 3   RandomForestRegressor  default_norm   train  walk_forward_splits
# 4   RandomForestRegressor  default_norm   train  walk_forward_splits
# 5   RandomForestRegressor  default_norm   train  walk_forward_splits
# 6   RandomForestRegressor  default_norm   train  walk_forward_splits
# 7   RandomForestRegressor  default_norm   train  walk_forward_splits
# 8   RandomForestRegressor  default_norm   train  walk_forward_splits
# 9   RandomForestRegressor  default_norm   train  walk_forward_splits
# 10  RandomForestRegressor  default_norm   train  walk_forward_splits
# 11  RandomForestRegressor  default_norm   train  walk_forward_splits
# 12  RandomForestRegressor  default_norm   train  walk_forward_splits
# 13  RandomForestRegressor  default_norm   train  walk_forward_splits
# 14  RandomForestRegressor  default_norm   train  walk_forward_splits
# 15  RandomForestRegressor  default_norm   train  walk_forward_splits
# 16  RandomForestRegressor  default_norm   train  walk_forward_splits
# 17  RandomForestRegressor  default_norm   train  walk_forward_splits
# 18  RandomForestRegressor  default_norm   train  walk_forward_splits
# 19  RandomForestRegressor  default_norm   train  walk_forward_splits
# 20  RandomForestRegressor  default_norm   train  walk_forward_splits
# 21  RandomForestRegressor  default_norm   train  walk_forward_splits
#
#                              Features  Splits Train / Validation   Parameters  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_least_corr_features_norm       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_least_corr_features_norm       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_least_corr_features_norm       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_least_corr_features_norm       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_least_corr_features_norm       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_least_corr_features_norm       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_least_corr_features_norm       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_least_corr_features_norm       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_least_corr_features_norm      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_least_corr_features_norm      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_least_corr_features_norm      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_least_corr_features_norm      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_least_corr_features_norm      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_least_corr_features_norm      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_least_corr_features_norm      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_least_corr_features_norm      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_least_corr_features_norm      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_least_corr_features_norm      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_least_corr_features_norm      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_least_corr_features_norm      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_least_corr_features_norm      22      (20000, 5000)  [20, 5, 42]
#
#            RMSE           MSE         MAE      MAPE        R2  Adjusted_R2  \
# 0    135.667828  1.840576e+04  103.343535  0.012910  0.988077     0.988075
# 1    154.204799  2.377912e+04  115.978371  0.013532  0.985614     0.985611
# 2    135.086438  1.824835e+04  102.512346  0.011572  0.993704     0.993702
# 3    187.466690  3.514376e+04  145.382442  0.014159  0.988646     0.988644
# 4    242.319576  5.871878e+04  174.952606  0.013133  0.997844     0.997843
# 5    478.254366  2.287272e+05  340.985050  0.017531  0.998551     0.998551
# 6    595.259813  3.543342e+05  429.044815  0.014656  0.998853     0.998852
# 7    846.222812  7.160930e+05  608.391226  0.015726  0.996437     0.996436
# 8    813.140450  6.611974e+05  609.222383  0.014284  0.993410     0.993408
# 9   1198.666481  1.436801e+06  838.938954  0.019304  0.982938     0.982935
# 10  1035.594419  1.072456e+06  763.001149  0.017318  0.989172     0.989170
# 11   880.484258  7.752525e+05  663.014604  0.014198  0.991700     0.991699
# 12   832.338791  6.927879e+05  613.223242  0.012273  0.988986     0.988984
# 13   715.506136  5.119490e+05  545.948452  0.011379  0.992872     0.992870
# 14   690.704144  4.770722e+05  502.258934  0.012144  0.992159     0.992157
# 15   519.961174  2.703596e+05  374.719241  0.010671  0.996378     0.996377
# 16   376.425208  1.416959e+05  290.556030  0.010987  0.998297     0.998296
# 17   380.583617  1.448439e+05  294.527832  0.013272  0.996043     0.996042
# 18   262.053130  6.867184e+04  189.719536  0.009477  0.988309     0.988306
# 19   319.990341  1.023938e+05  222.652142  0.011125  0.984006     0.984003
# 20   303.920918  9.236792e+04  204.541918  0.009624  0.994288     0.994287
# 21   293.607195  8.620519e+04  214.869442  0.009185  0.996056     0.996055
#
#         Time
# 0   0.859265
# 1   0.911677
# 2   0.873301
# 3   0.860543
# 4   0.837170
# 5   0.906071
# 6   0.864639
# 7   0.925980
# 8   0.877642
# 9   0.866321
# 10  0.980524
# 11  0.998032
# 12  1.011699
# 13  0.863987
# 14  0.994252
# 15  0.919242
# 16  0.903246
# 17  0.884830
# 18  0.904878
# 19  0.908157
# 20  0.895794
# 21  0.888421

# %%
default_norm_valid_results_base_and_least_corr_features
# Out:
#                     Model          Type Dataset            Splitting  \
# 0   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 1   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 2   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 3   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 4   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 5   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 6   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 7   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 8   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 9   RandomForestRegressor  default_norm   valid  walk_forward_splits
# 10  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 11  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 12  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 13  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 14  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 15  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 16  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 17  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 18  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 19  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 20  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 21  RandomForestRegressor  default_norm   valid  walk_forward_splits
#
#                              Features  Splits Train / Validation   Parameters  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)  [20, 5, 42]
# 1   base_and_least_corr_features_norm       2      (20000, 5000)  [20, 5, 42]
# 2   base_and_least_corr_features_norm       3      (20000, 5000)  [20, 5, 42]
# 3   base_and_least_corr_features_norm       4      (20000, 5000)  [20, 5, 42]
# 4   base_and_least_corr_features_norm       5      (20000, 5000)  [20, 5, 42]
# 5   base_and_least_corr_features_norm       6      (20000, 5000)  [20, 5, 42]
# 6   base_and_least_corr_features_norm       7      (20000, 5000)  [20, 5, 42]
# 7   base_and_least_corr_features_norm       8      (20000, 5000)  [20, 5, 42]
# 8   base_and_least_corr_features_norm       9      (20000, 5000)  [20, 5, 42]
# 9   base_and_least_corr_features_norm      10      (20000, 5000)  [20, 5, 42]
# 10  base_and_least_corr_features_norm      11      (20000, 5000)  [20, 5, 42]
# 11  base_and_least_corr_features_norm      12      (20000, 5000)  [20, 5, 42]
# 12  base_and_least_corr_features_norm      13      (20000, 5000)  [20, 5, 42]
# 13  base_and_least_corr_features_norm      14      (20000, 5000)  [20, 5, 42]
# 14  base_and_least_corr_features_norm      15      (20000, 5000)  [20, 5, 42]
# 15  base_and_least_corr_features_norm      16      (20000, 5000)  [20, 5, 42]
# 16  base_and_least_corr_features_norm      17      (20000, 5000)  [20, 5, 42]
# 17  base_and_least_corr_features_norm      18      (20000, 5000)  [20, 5, 42]
# 18  base_and_least_corr_features_norm      19      (20000, 5000)  [20, 5, 42]
# 19  base_and_least_corr_features_norm      20      (20000, 5000)  [20, 5, 42]
# 20  base_and_least_corr_features_norm      21      (20000, 5000)  [20, 5, 42]
# 21  base_and_least_corr_features_norm      22      (20000, 5000)  [20, 5, 42]
#
#             RMSE           MSE           MAE      MAPE         R2  \
# 0     589.168097  3.471190e+05    464.543445  0.047113   0.114356
# 1    1016.644694  1.033566e+06    919.521954  0.082223  -1.907243
# 2    2776.829342  7.710781e+06   1932.292582  0.137083  -1.371508
# 3    7415.759641  5.499349e+07   5818.047383  0.242650  -1.744397
# 4   14074.210412  1.980834e+08  11937.351065  0.271767  -2.624688
# 5    3680.961508  1.354948e+07   3078.028630  0.053385   0.283184
# 6    3631.305471  1.318638e+07   3029.355049  0.070345   0.830776
# 7   12880.966405  1.659193e+08  10018.946810  0.289909 -18.446735
# 8    8888.313186  7.900211e+07   8198.500781  0.174457  -8.270830
# 9   11070.929504  1.225655e+08  10030.519608  0.168531  -1.072351
# 10   3187.069368  1.015741e+07   2812.441655  0.052490   0.618147
# 11   6000.285265  3.600342e+07   5453.822875  0.139006  -4.146852
# 12   1672.208095  2.796280e+06   1256.227861  0.028592   0.623392
# 13   6775.715683  4.591032e+07   5621.087832  0.185821  -1.355855
# 14   7947.088528  6.315622e+07   7695.446738  0.365657 -14.577651
# 15    635.596381  4.039828e+05    497.784169  0.023255   0.862490
# 16   1022.633871  1.045780e+06    724.102210  0.038398  -0.007574
# 17    692.944887  4.801726e+05    597.981604  0.036029  -3.045205
# 18   2271.854114  5.161321e+06   1956.725754  0.084793   0.013297
# 19   4032.965418  1.626481e+07   3684.362675  0.136137  -0.828114
# 20   1137.909609  1.294838e+06    995.106273  0.036645  -0.486954
# 21   2165.576777  4.689723e+06   2001.077138  0.067124  -0.652523
#
#     Adjusted_R2      Time
# 0      0.113647  0.859265
# 1     -1.909571  0.911677
# 2     -1.373407  0.873301
# 3     -1.746595  0.860543
# 4     -2.627591  0.837170
# 5      0.282610  0.906071
# 6      0.830640  0.864639
# 7    -18.462308  0.925980
# 8     -8.278254  0.877642
# 9     -1.074011  0.866321
# 10     0.617841  0.980524
# 11    -4.150973  0.998032
# 12     0.623091  1.011699
# 13    -1.357741  0.863987
# 14   -14.590126  0.994252
# 15     0.862380  0.919242
# 16    -0.008381  0.903246
# 17    -3.048444  0.884830
# 18     0.012506  0.904878
# 19    -0.829577  0.908157
# 20    -0.488145  0.895794
# 21    -0.653847  0.888421

# %%
# Define model information and evaluators to show
model_info = ['Model', 'Type', 'Dataset', 'Splitting', 'Features', 'Parameters']
evaluator_lst = ['RMSE', 'MSE', 'MAE', 'MAPE', 'R2', 'Adjusted_R2', 'Time']

# %%
# Define the results to show
default_comparison_lst = [default_valid_results_base_features, default_valid_results_base_and_most_corr_features, default_valid_results_base_and_least_corr_features, default_norm_valid_results_base_features, default_norm_valid_results_base_and_most_corr_features, default_norm_valid_results_base_and_least_corr_features]

# Show the comparison table
default_comparison_lst_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in default_comparison_lst])
default_comparison_lst_df
# Out:
#                    Model          Type Dataset            Splitting  \
# 0  RandomForestRegressor       default   valid  walk_forward_splits
# 0  RandomForestRegressor       default   valid  walk_forward_splits
# 0  RandomForestRegressor       default   valid  walk_forward_splits
# 0  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 0  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 0  RandomForestRegressor  default_norm   valid  walk_forward_splits
#
#                             Features   Parameters         RMSE           MSE  \
# 0                      base_features  [20, 5, 42]  2370.519970  1.560697e+07
# 0        base_and_most_corr_features  [20, 5, 42]  2478.345441  1.576778e+07
# 0       base_and_least_corr_features  [20, 5, 42]  2648.102198  1.744722e+07
# 0                 base_features_norm  [20, 5, 42]  4311.414051  3.407697e+07
# 0   base_and_most_corr_features_norm  [20, 5, 42]  5185.701605  5.522636e+07
# 0  base_and_least_corr_features_norm  [20, 5, 42]  4707.588012  3.835252e+07
#
#            MAE      MAPE        R2  Adjusted_R2      Time
# 0  1896.375868  0.065433 -0.305707    -0.306753  0.835004
# 0  1990.447497  0.068993 -0.408750    -0.409878  0.770615
# 0  2142.194716  0.073721 -0.655070    -0.656395  0.888322
# 0  3717.619259  0.121903 -5.011666    -5.016480  0.750290
# 0  4625.144485  0.138864 -5.399166    -5.404291  0.825756
# 0  4032.876095  0.124155 -2.599675    -2.602557  0.906167

# %%
# Save the best default model results and predicitons
best_default_results = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in [default_valid_results_base_features]])
best_default_predictions = default_valid_pred_base_features
best_default_results
# Out:
#                    Model     Type Dataset            Splitting       Features  \
# 0  RandomForestRegressor  default   valid  walk_forward_splits  base_features
#
#     Parameters        RMSE           MSE          MAE      MAPE        R2  \
# 0  [20, 5, 42]  2370.51997  1.560697e+07  1896.375868  0.065433 -0.305707
#
#    Adjusted_R2      Time
# 0    -0.306753  0.835004

# %%
# Define the choosen features
FEATURES_NORMALIZATION = False
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %% [markdown]
# ## Tuned
# Once the features and execution method are selected, the model will undergo hyperparameter tuning and cross validation to find the best configuration.

# %%
# Get model grid parameters
params = train_validation_utilities.get_model_grid_params(MODEL_NAME)
params
# Out:
# {'numTrees': [3, 5, 10, 20, 30], 'maxDepth': [3, 5, 10], 'seed': [42]}

# %% [markdown]
# ### Hyperparameter tuning

# %%
# Select the type of feature to be used
MODEL_TYPE = "hyp_tuning"

# %%
# Perform hyperparameter tuning
hyp_res = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
hyp_res
# Out:
# Split: [1/22]: 100%|██████████| 15/15 [00:25<00:00,  1.71s/it]
# Best parameters chosen for split [1/22]: [3, 10, 42]
# Split: [2/22]: 100%|██████████| 15/15 [00:26<00:00,  1.76s/it]
# Best parameters chosen for split [2/22]: [3, 10, 42]
# Split: [3/22]: 100%|██████████| 15/15 [00:25<00:00,  1.67s/it]
# Best parameters chosen for split [3/22]: [3, 10, 42]
# Split: [4/22]: 100%|██████████| 15/15 [00:24<00:00,  1.64s/it]
# Best parameters chosen for split [4/22]: [3, 10, 42]
# Split: [5/22]: 100%|██████████| 15/15 [00:24<00:00,  1.62s/it]
# Best parameters chosen for split [5/22]: [20, 3, 42]
# Split: [6/22]: 100%|██████████| 15/15 [00:23<00:00,  1.60s/it]
# Best parameters chosen for split [6/22]: [3, 10, 42]
# Split: [7/22]: 100%|██████████| 15/15 [00:24<00:00,  1.63s/it]
# Best parameters chosen for split [7/22]: [10, 10, 42]
# Split: [8/22]: 100%|██████████| 15/15 [00:24<00:00,  1.65s/it]
# Best parameters chosen for split [8/22]: [5, 10, 42]
# Split: [9/22]: 100%|██████████| 15/15 [00:25<00:00,  1.71s/it]
# Best parameters chosen for split [9/22]: [30, 10, 42]
# Split: [10/22]: 100%|██████████| 15/15 [00:25<00:00,  1.71s/it]
# Best parameters chosen for split [10/22]: [5, 5, 42]
# Split: [11/22]: 100%|██████████| 15/15 [00:25<00:00,  1.67s/it]
# Best parameters chosen for split [11/22]: [5, 10, 42]
# Split: [12/22]: 100%|██████████| 15/15 [00:24<00:00,  1.66s/it]
# Best parameters chosen for split [12/22]: [10, 10, 42]
# Split: [13/22]: 100%|██████████| 15/15 [00:25<00:00,  1.67s/it]
# Best parameters chosen for split [13/22]: [30, 10, 42]
# Split: [14/22]: 100%|██████████| 15/15 [00:24<00:00,  1.66s/it]
# Best parameters chosen for split [14/22]: [5, 5, 42]
# Split: [15/22]: 100%|██████████| 15/15 [00:25<00:00,  1.67s/it]
# Best parameters chosen for split [15/22]: [5, 10, 42]
# Split: [16/22]: 100%|██████████| 15/15 [00:24<00:00,  1.66s/it]
# Best parameters chosen for split [16/22]: [30, 5, 42]
# Split: [17/22]: 100%|██████████| 15/15 [00:24<00:00,  1.63s/it]
# Best parameters chosen for split [17/22]: [10, 10, 42]
# Split: [18/22]: 100%|██████████| 15/15 [00:24<00:00,  1.63s/it]
# Best parameters chosen for split [18/22]: [3, 10, 42]
# Split: [19/22]: 100%|██████████| 15/15 [00:24<00:00,  1.65s/it]
# Best parameters chosen for split [19/22]: [30, 10, 42]
# Split: [20/22]: 100%|██████████| 15/15 [00:25<00:00,  1.69s/it]
# Best parameters chosen for split [20/22]: [10, 10, 42]
# Split: [21/22]: 100%|██████████| 15/15 [00:24<00:00,  1.66s/it]
# Best parameters chosen for split [21/22]: [20, 5, 42]
# Split: [22/22]: 100%|██████████| 15/15 [00:24<00:00,  1.64s/it]
# Best parameters chosen for split [22/22]: [10, 10, 42]
#                     Model        Type Dataset            Splitting  \
# 0   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 1   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 2   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 3   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 4   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 5   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 6   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 7   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 8   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 9   RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 10  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 11  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 12  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 13  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 14  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 15  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 16  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 17  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 18  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 19  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 20  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
# 21  RandomForestRegressor  hyp_tuning   valid  walk_forward_splits
#
#          Features  Splits Train / Validation    Parameters          RMSE  \
# 0   base_features       1      (20000, 5000)   [3, 10, 42]    314.768648
# 1   base_features       2      (20000, 5000)   [3, 10, 42]    400.353365
# 2   base_features       3      (20000, 5000)   [3, 10, 42]   1629.767381
# 3   base_features       4      (20000, 5000)   [3, 10, 42]   7036.130720
# 4   base_features       5      (20000, 5000)   [20, 3, 42]  12363.714181
# 5   base_features       6      (20000, 5000)   [3, 10, 42]   2553.021163
# 6   base_features       7      (20000, 5000)  [10, 10, 42]   1372.244856
# 7   base_features       8      (20000, 5000)   [5, 10, 42]    482.778963
# 8   base_features       9      (20000, 5000)  [30, 10, 42]    577.376055
# 9   base_features      10      (20000, 5000)    [5, 5, 42]   1529.544155
# 10  base_features      11      (20000, 5000)   [5, 10, 42]    573.346975
# 11  base_features      12      (20000, 5000)  [10, 10, 42]    483.770726
# 12  base_features      13      (20000, 5000)  [30, 10, 42]    261.185701
# 13  base_features      14      (20000, 5000)    [5, 5, 42]   5263.998883
# 14  base_features      15      (20000, 5000)   [5, 10, 42]   7587.288872
# 15  base_features      16      (20000, 5000)   [30, 5, 42]    298.882334
# 16  base_features      17      (20000, 5000)  [10, 10, 42]    608.776104
# 17  base_features      18      (20000, 5000)   [3, 10, 42]    358.606315
# 18  base_features      19      (20000, 5000)  [30, 10, 42]    251.261513
# 19  base_features      20      (20000, 5000)  [10, 10, 42]   3155.770891
# 20  base_features      21      (20000, 5000)   [20, 5, 42]    577.862333
# 21  base_features      22      (20000, 5000)  [10, 10, 42]    794.489298
#
#              MSE          MAE      MAPE         R2  Adjusted_R2      Time
# 0   9.907930e+04   132.938768  0.012410   0.747208     0.747005  0.695701
# 1   1.602828e+05   334.683212  0.029451   0.549152     0.548791  0.757241
# 2   2.656142e+06  1009.015574  0.069176   0.183084     0.182430  0.685774
# 3   4.950714e+07  5458.946267  0.226675  -1.470606    -1.472584  0.706308
# 4   1.528614e+08  9911.776051  0.220214  -1.797181    -1.799421  0.397253
# 5   6.517917e+06  1913.161875  0.033209   0.655179     0.654903  0.685237
# 6   1.883056e+06  1077.118627  0.026814   0.975834     0.975815  0.974319
# 7   2.330755e+05   348.615921  0.009799   0.972682     0.972660  0.730780
# 8   3.333631e+05   431.779274  0.009469   0.960880     0.960849  2.379147
# 9   2.339505e+06   994.824313  0.016614   0.960443     0.960412  0.369313
# 10  3.287268e+05   366.831212  0.006795   0.987642     0.987632  0.771682
# 11  2.340341e+05   378.843666  0.009474   0.966544     0.966517  1.054179
# 12  6.821797e+04   194.150274  0.004712   0.990812     0.990805  2.458084
# 13  2.770968e+07  4244.948131  0.141263  -0.421902    -0.423041  0.376279
# 14  5.756695e+07  7320.166209  0.348235 -13.199044   -13.210415  1.054486
# 15  8.933065e+04   224.587465  0.010580   0.969593     0.969569  0.670023
# 16  3.706083e+05   260.865530  0.014778   0.642931     0.642645  1.005332
# 17  1.285985e+05   272.868913  0.016322  -0.083375    -0.084243  0.646537
# 18  6.313235e+04   152.903262  0.006724   0.987931     0.987921  2.200009
# 19  9.958890e+06  2447.550789  0.085638  -0.119348    -0.120244  1.014839
# 20  3.339249e+05   486.434971  0.017745   0.616531     0.616224  0.501049
# 21  6.312132e+05   595.833416  0.019936   0.777579     0.777400  1.044808

# %% [markdown]
# ---
# Since during this stage will be used the Block split / Walk forward split method of the dataset I compute a score for each parameter chosen by each split, assigning weights based on:
#    * Their `frequency` for each split (if the same parameters are chosen from several splits, these will have greater weight)
#    * The `split` they belong to (the closer the split is to today's date the more weight they will have)
#    * Their `RMSE value` for each split (the lower this is, the more weight they will have)
#
#    Then, the overall score will be calculated by putting together these three weights for each parameter and the one with the best score will be the chosen parameter.

# %%
# Show parameters score
grouped_scores, best_params = train_validation_utilities.choose_best_params(hyp_res)
grouped_scores
# Out:
#               Split weight  RMSE weight  Frequency weight  Final score
# Parameters
# (10, 10, 42)      0.709091     0.896228          0.833333     0.529589
# (30, 10, 42)      0.621212     0.970618          0.500000     0.301480
# (3, 10, 42)       0.257576     0.834291          1.000000     0.214893
# (5, 10, 42)       0.515152     0.766968          0.500000     0.197552
# (20, 5, 42)       0.954545     0.953261          0.166667     0.151655
# (5, 5, 42)        0.545455     0.725263          0.333333     0.131866
# (30, 5, 42)       0.727273     0.975826          0.166667     0.118282
# (20, 3, 42)       0.227273     0.000000          0.166667     0.000000

# %%
# Print best parameters
print(f"Best parameters: {best_params}")
# Out:
# Best parameters: (10, 10, 42)

# %% [markdown]
# ### Cross validation

# %%
MODEL_TYPE = "cross_val"

# %%
# Get tuned parameters
params = train_validation_utilities.get_best_model_params(best_params, MODEL_NAME)
params
# Out:
# {'numTrees': [10], 'maxDepth': [10], 'seed': [42]}

# %%
# Perform cross validation
cv_train_result, cv_valid_result, cv_train_pred, cv_valid_pred = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:02<00:00,  2.34s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:02<00:00,  2.28s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]

# %%
cv_train_result
# Out:
#                     Model       Type Dataset            Splitting  \
# 0   RandomForestRegressor  cross_val   train  walk_forward_splits
# 1   RandomForestRegressor  cross_val   train  walk_forward_splits
# 2   RandomForestRegressor  cross_val   train  walk_forward_splits
# 3   RandomForestRegressor  cross_val   train  walk_forward_splits
# 4   RandomForestRegressor  cross_val   train  walk_forward_splits
# 5   RandomForestRegressor  cross_val   train  walk_forward_splits
# 6   RandomForestRegressor  cross_val   train  walk_forward_splits
# 7   RandomForestRegressor  cross_val   train  walk_forward_splits
# 8   RandomForestRegressor  cross_val   train  walk_forward_splits
# 9   RandomForestRegressor  cross_val   train  walk_forward_splits
# 10  RandomForestRegressor  cross_val   train  walk_forward_splits
# 11  RandomForestRegressor  cross_val   train  walk_forward_splits
# 12  RandomForestRegressor  cross_val   train  walk_forward_splits
# 13  RandomForestRegressor  cross_val   train  walk_forward_splits
# 14  RandomForestRegressor  cross_val   train  walk_forward_splits
# 15  RandomForestRegressor  cross_val   train  walk_forward_splits
# 16  RandomForestRegressor  cross_val   train  walk_forward_splits
# 17  RandomForestRegressor  cross_val   train  walk_forward_splits
# 18  RandomForestRegressor  cross_val   train  walk_forward_splits
# 19  RandomForestRegressor  cross_val   train  walk_forward_splits
# 20  RandomForestRegressor  cross_val   train  walk_forward_splits
# 21  RandomForestRegressor  cross_val   train  walk_forward_splits
#
#          Features  Splits Train / Validation    Parameters        RMSE  \
# 0   base_features       1      (20000, 5000)  [10, 10, 42]   21.875971
# 1   base_features       2      (20000, 5000)  [10, 10, 42]   35.190901
# 2   base_features       3      (20000, 5000)  [10, 10, 42]   23.111129
# 3   base_features       4      (20000, 5000)  [10, 10, 42]   43.173344
# 4   base_features       5      (20000, 5000)  [10, 10, 42]  219.615814
# 5   base_features       6      (20000, 5000)  [10, 10, 42]  165.758818
# 6   base_features       7      (20000, 5000)  [10, 10, 42]  175.088428
# 7   base_features       8      (20000, 5000)  [10, 10, 42]  171.150362
# 8   base_features       9      (20000, 5000)  [10, 10, 42]  123.333297
# 9   base_features      10      (20000, 5000)  [10, 10, 42]  124.283867
# 10  base_features      11      (20000, 5000)  [10, 10, 42]  124.177519
# 11  base_features      12      (20000, 5000)  [10, 10, 42]  119.901127
# 12  base_features      13      (20000, 5000)  [10, 10, 42]  110.284463
# 13  base_features      14      (20000, 5000)  [10, 10, 42]  115.299493
# 14  base_features      15      (20000, 5000)  [10, 10, 42]  118.448123
# 15  base_features      16      (20000, 5000)  [10, 10, 42]   84.792908
# 16  base_features      17      (20000, 5000)  [10, 10, 42]   88.304791
# 17  base_features      18      (20000, 5000)  [10, 10, 42]  109.458523
# 18  base_features      19      (20000, 5000)  [10, 10, 42]   49.588332
# 19  base_features      20      (20000, 5000)  [10, 10, 42]   31.622126
# 20  base_features      21      (20000, 5000)  [10, 10, 42]   54.789744
# 21  base_features      22      (20000, 5000)  [10, 10, 42]   48.594700
#
#              MSE         MAE      MAPE        R2  Adjusted_R2      Time
# 0     478.558112   13.902996  0.001820  0.999690     0.999690  1.156645
# 1    1238.399515   16.934609  0.002011  0.999251     0.999251  1.262350
# 2     534.124297   15.144886  0.001814  0.999816     0.999816  1.141181
# 3    1863.937610   21.559442  0.002114  0.999398     0.999398  1.125212
# 4   48231.105873   70.126146  0.003423  0.998229     0.998228  1.040986
# 5   27475.985828   80.621651  0.003169  0.999826     0.999826  1.084377
# 6   30655.957631  105.529485  0.003770  0.999901     0.999901  1.104608
# 7   29292.446274  111.487959  0.003133  0.999854     0.999854  1.114029
# 8   15211.102061   86.282186  0.001952  0.999848     0.999848  1.241316
# 9   15446.479693   87.685026  0.001928  0.999817     0.999817  1.154617
# 10  15420.056322   89.486275  0.001976  0.999844     0.999844  1.176823
# 11  14376.280360   84.418287  0.001834  0.999846     0.999846  1.191418
# 12  12162.662756   75.999332  0.001567  0.999807     0.999807  1.146835
# 13  13293.973158   77.766559  0.001642  0.999815     0.999815  1.197321
# 14  14029.957753   75.315984  0.001772  0.999769     0.999769  1.143854
# 15   7189.837267   58.949238  0.001800  0.999904     0.999904  1.127867
# 16   7797.736198   56.579488  0.001931  0.999906     0.999906  1.173095
# 17  11981.168252   51.068235  0.002085  0.999673     0.999673  1.101023
# 18   2459.002708   25.393610  0.001219  0.999581     0.999581  1.244197
# 19    999.958830   21.385059  0.001069  0.999844     0.999844  1.180600
# 20   3001.915996   30.221877  0.001374  0.999814     0.999814  1.189685
# 21   2361.444871   28.469666  0.001230  0.999892     0.999892  1.200775

# %%
cv_valid_result
# Out:
#                     Model       Type Dataset            Splitting  \
# 0   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 1   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 2   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 3   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 4   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 5   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 6   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 7   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 8   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 9   RandomForestRegressor  cross_val   valid  walk_forward_splits
# 10  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 11  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 12  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 13  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 14  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 15  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 16  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 17  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 18  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 19  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 20  RandomForestRegressor  cross_val   valid  walk_forward_splits
# 21  RandomForestRegressor  cross_val   valid  walk_forward_splits
#
#          Features  Splits Train / Validation    Parameters          RMSE  \
# 0   base_features       1      (20000, 5000)  [10, 10, 42]    333.069181
# 1   base_features       2      (20000, 5000)  [10, 10, 42]    446.991482
# 2   base_features       3      (20000, 5000)  [10, 10, 42]   1727.544555
# 3   base_features       4      (20000, 5000)  [10, 10, 42]   7139.300111
# 4   base_features       5      (20000, 5000)  [10, 10, 42]  12705.285413
# 5   base_features       6      (20000, 5000)  [10, 10, 42]   2632.163736
# 6   base_features       7      (20000, 5000)  [10, 10, 42]   1372.244856
# 7   base_features       8      (20000, 5000)  [10, 10, 42]    486.717468
# 8   base_features       9      (20000, 5000)  [10, 10, 42]    628.248750
# 9   base_features      10      (20000, 5000)  [10, 10, 42]   1699.787041
# 10  base_features      11      (20000, 5000)  [10, 10, 42]   1342.760041
# 11  base_features      12      (20000, 5000)  [10, 10, 42]    483.770726
# 12  base_features      13      (20000, 5000)  [10, 10, 42]    307.232246
# 13  base_features      14      (20000, 5000)  [10, 10, 42]   5533.181794
# 14  base_features      15      (20000, 5000)  [10, 10, 42]   7666.850859
# 15  base_features      16      (20000, 5000)  [10, 10, 42]    385.177533
# 16  base_features      17      (20000, 5000)  [10, 10, 42]    608.776104
# 17  base_features      18      (20000, 5000)  [10, 10, 42]    381.438493
# 18  base_features      19      (20000, 5000)  [10, 10, 42]    513.418138
# 19  base_features      20      (20000, 5000)  [10, 10, 42]   3155.770891
# 20  base_features      21      (20000, 5000)  [10, 10, 42]    645.638858
# 21  base_features      22      (20000, 5000)  [10, 10, 42]    794.489298
#
#              MSE           MAE      MAPE         R2  Adjusted_R2      Time
# 0   1.109351e+05    140.156597  0.013068   0.716959     0.716732  1.156645
# 1   1.998014e+05    383.543477  0.033719   0.437993     0.437543  1.262350
# 2   2.984410e+06   1094.237776  0.075346   0.082122     0.081387  1.141181
# 3   5.096961e+07   5545.183098  0.230357  -1.543589    -1.545626  1.125212
# 4   1.614243e+08  10298.659686  0.229923  -1.953870    -1.956236  1.040986
# 5   6.928286e+06   2018.818808  0.034966   0.633469     0.633175  1.084377
# 6   1.883056e+06   1077.118627  0.026814   0.975834     0.975815  1.104608
# 7   2.368939e+05    362.779097  0.010312   0.972235     0.972212  1.114029
# 8   3.946965e+05    475.903588  0.010424   0.953683     0.953646  1.241316
# 9   2.889276e+06   1001.000410  0.016379   0.951148     0.951109  1.154617
# 10  1.803005e+06   1186.307855  0.023321   0.932219     0.932164  1.176823
# 11  2.340341e+05    378.843666  0.009474   0.966544     0.966517  1.191418
# 12  9.439165e+04    225.278611  0.005471   0.987287     0.987277  1.146835
# 13  3.061610e+07   4454.586791  0.148337  -0.571043    -0.572301  1.197321
# 14  5.878060e+07   7401.394177  0.352030 -13.498394   -13.510005  1.143854
# 15  1.483617e+05    266.353728  0.012369   0.949500     0.949459  1.127867
# 16  3.706083e+05    260.865530  0.014778   0.642931     0.642645  1.173095
# 17  1.454953e+05    299.726891  0.017990  -0.225723    -0.226704  1.101023
# 18  2.635982e+05    448.751180  0.019699   0.949607     0.949567  1.244197
# 19  9.958890e+06   2447.550789  0.085638  -0.119348    -0.120244  1.180600
# 20  4.168495e+05    563.547377  0.020394   0.521302     0.520919  1.189685
# 21  6.312132e+05    595.833416  0.019936   0.777579     0.777400  1.200775

# %%
# Define the results to show
tuned_comparison_lst = [cv_valid_result]

# Show the comparison table
tuned_comparison_lst_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in tuned_comparison_lst])
tuned_comparison_lst_df
# Out:
#                    Model       Type Dataset            Splitting  \
# 0  RandomForestRegressor  cross_val   valid  walk_forward_splits
#
#         Features    Parameters         RMSE           MSE          MAE  \
# 0  base_features  [10, 10, 42]  2317.720799  1.506747e+07  1860.292781
#
#        MAPE        R2  Adjusted_R2      Time
# 0  0.064125 -0.248253    -0.249252  1.159037

# %% [markdown]
# # Comparison table
# Visualization of model performance at various stages of train / validation

# %%
# Concatenate final results into Pandas dataset
final_comparison_lst_df = pd.DataFrame(pd.concat([default_comparison_lst_df, tuned_comparison_lst_df], ignore_index=True))
final_comparison_lst_df
# Out:
#                    Model          Type Dataset            Splitting  \
# 0  RandomForestRegressor       default   valid  walk_forward_splits
# 1  RandomForestRegressor       default   valid  walk_forward_splits
# 2  RandomForestRegressor       default   valid  walk_forward_splits
# 3  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 4  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 5  RandomForestRegressor  default_norm   valid  walk_forward_splits
# 6  RandomForestRegressor     cross_val   valid  walk_forward_splits
#
#                             Features    Parameters         RMSE           MSE  \
# 0                      base_features   [20, 5, 42]  2370.519970  1.560697e+07
# 1        base_and_most_corr_features   [20, 5, 42]  2478.345441  1.576778e+07
# 2       base_and_least_corr_features   [20, 5, 42]  2648.102198  1.744722e+07
# 3                 base_features_norm   [20, 5, 42]  4311.414051  3.407697e+07
# 4   base_and_most_corr_features_norm   [20, 5, 42]  5185.701605  5.522636e+07
# 5  base_and_least_corr_features_norm   [20, 5, 42]  4707.588012  3.835252e+07
# 6                      base_features  [10, 10, 42]  2317.720799  1.506747e+07
#
#            MAE      MAPE        R2  Adjusted_R2      Time
# 0  1896.375868  0.065433 -0.305707    -0.306753  0.835004
# 1  1990.447497  0.068993 -0.408750    -0.409878  0.770615
# 2  2142.194716  0.073721 -0.655070    -0.656395  0.888322
# 3  3717.619259  0.121903 -5.011666    -5.016480  0.750290
# 4  4625.144485  0.138864 -5.399166    -5.404291  0.825756
# 5  4032.876095  0.124155 -2.599675    -2.602557  0.906167
# 6  1860.292781  0.064125 -0.248253    -0.249252  1.159037

# %% [markdown]
# # Model accuracy
#
# Since predicting the price accurately is very difficult I also saw how good the models are at predicting whether the price will go up or down in this way:
#
# For each prediction let's consider the actual market-price, next-market-price and our predicted next-market-price (prediction).
# I compute whether the current prediction is correct (1) or not (0):
#
# $$
# prediction\_is\_correct
# =
# \begin{cases}
# 0 \text{ if [(market-price > next-market-price) and (market-price < prediction)] or [(market-price < next-market-price) and (market-price > prediction)]} \\
# 1 \text{ if [(market-price > next-market-price) and (market-price > prediction)] or [(market-price < next-market-price) and (market-price < prediction)]}
# \end{cases}
# $$
#
# After that I count the number of correct prediction:
# $$
# correct\_predictions
# =
# \sum_{i=0}^{total\_rows} prediction\_is\_correct
# $$
#
# Finally I compute the percentage of accuracy of the model:
# $$
# \\
# accuracy
# =
# (correct\_predictions / total\_rows)
# * 100
# $$

# %%
# Convert the pandas dataset to a PySpark dataset
best_default_pred_spark = spark.createDataFrame(best_default_predictions)
validated_pred_spark = spark.createDataFrame(cv_valid_pred)

# Compute model accuracy
default_accuracy = train_validation_utilities.model_accuracy(best_default_pred_spark)
validated_accuracy = train_validation_utilities.model_accuracy(validated_pred_spark)

# Shows whether features are normalised or not
if FEATURES_NORMALIZATION:
    NEW_CHOSEN_FEATURES_LABEL = CHOSEN_FEATURES_LABEL + "_norm"
    CHOSEN_FEATURES_LABEL = NEW_CHOSEN_FEATURES_LABEL
    
# Saving accuracy data into dataframe
accuracy_data = {
    'Model': MODEL_NAME,
    'Features': CHOSEN_FEATURES_LABEL,
    'Splitting': SPLITTING_METHOD,
    'Accuracy (default)': default_accuracy,
    'Accuracy (tuned)': validated_accuracy
}
accuracy_data_df = pd.DataFrame(accuracy_data, index=['Model'])

print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (default): {default_accuracy:.2f}%")
print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (tuned): {validated_accuracy:.2f}%")
# Out:
# Percentage of correct predictions for RandomForestRegressor with base_features and walk_forward_splits (default): 50.99%
# Percentage of correct predictions for RandomForestRegressor with base_features and walk_forward_splits (tuned): 51.54%

# %%
# Concatenate default and tuned results
default_tuned_results = [best_default_results, cv_valid_result]
default_tuned_results_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in default_tuned_results])
default_tuned_results_df
# Out:
#                    Model       Type Dataset            Splitting  \
# 0  RandomForestRegressor    default   valid  walk_forward_splits
# 0  RandomForestRegressor  cross_val   valid  walk_forward_splits
#
#         Features    Parameters         RMSE           MSE          MAE  \
# 0  base_features   [20, 5, 42]  2370.519970  1.560697e+07  1896.375868
# 0  base_features  [10, 10, 42]  2317.720799  1.506747e+07  1860.292781
#
#        MAPE        R2  Adjusted_R2      Time
# 0  0.065433 -0.305707    -0.306753  0.835004
# 0  0.064125 -0.248253    -0.249252  1.159037

# %% [markdown]
# # Saving final results

# %%
# Save all final comparison results
final_comparison_lst_df.to_csv(ALL_MODEL_RESULTS, index=False)

# %%
# Save relevant results (default and tuned results)
default_tuned_results_df.to_csv(REL_MODEL_RESULTS, index=False)

# %%
# Saving accuracy results
accuracy_data_df.to_csv(MODEL_ACCURACY_RESULTS, index=False)

# %%
# Export notebook in html format (remember to save the notebook and change the model name)
if LOCAL_RUNNING:
    # !jupyter nbconvert --to html 4-walk-forward-split_{MODEL_NAME}.ipynb --output 4-walk-forward-split_{MODEL_NAME} --output-dir='./exports'
# Out:
# d:\Documents\Repository\BDC\project\.bdc\Lib\site-packages\traitlets\traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use './exports' instead of "'./exports'" if you require traitlets >=5.
#   warn(
# [NbConvertApp] Converting notebook 4-walk-forward-split_RandomForestRegressor.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 541210 bytes to exports\4-walk-forward-split_RandomForestRegressor.html
