# %% [markdown]
# # **Bitcoin price prediction - Walk Forward Split**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author: Corsi Danilo (1742375) - corsi.1742375@studenti.uniroma1.it
#
#
# ---
#
#
# Description: executing the chosen model, first with default values, then by choosing the best parameters by performing hyperparameter tuning with cross validation and performance evaluation.

# %% [markdown]
# # Global constants, dependencies, libraries and tools

# %%
# Main constants
LOCAL_RUNNING = True
SLOW_OPERATIONS = False # Decide whether or not to use operations that might slow down notebook execution
ROOT_DIR = "D:/Documents/Repository/BDC/project" if LOCAL_RUNNING else "/content/drive"

# %%
if not LOCAL_RUNNING:
    # Point Colaboratory to Google Drive
    from google.colab import drive

    # Define GDrive paths
    drive.mount(ROOT_DIR, force_remount=True)

    # Install Spark and related dependencies
    # !pip install pyspark
    # !pip install -U -q PyDrive -qq
    # !apt install openjdk-8-jdk-headless -qq

# %% [markdown]
# ## Import my utilities

# %%
# Set main dir
MAIN_DIR = ROOT_DIR + "" if LOCAL_RUNNING else ROOT_DIR + "/MyDrive/BDC/project"

# Utilities dir
UTILITIES_DIR = MAIN_DIR + "/utilities"

# Import my utilities
import sys
sys.path.append(UTILITIES_DIR)

from imports import *
import utilities, parameters

importlib.reload(utilities)
importlib.reload(parameters)
# Out:
# <module 'parameters' from 'D:\\Documents/Repository/BDC/project/utilities\\parameters.py'>

# %% [markdown]
# ## Core variables

# %%
# BS = Block Split
# WFS = Walk Forward Split
# SS = Single Split
SPLITTING_METHOD = parameters.WFS

# LR = LinearRegression 
# GLR = GeneralizedLinearRegression 
# RF = RandomForestRegressor 
# GBTR = GradientBoostingTreeRegressor
MODEL_NAME = parameters.GBTR

# %%
###################
# --- DATASET --- #
###################

# Datasets dirs
DATASET_OUTPUT_DIR = MAIN_DIR + "/datasets/output"

# Datasets names
DATASET_TRAIN_VALID_NAME = "bitcoin_blockchain_data_15min_train_valid"

# Datasets paths
DATASET_TRAIN_VALID  = DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

####################
# --- FEATURES --- #
####################

# Features dir
FEATURES_DIR = MAIN_DIR + "/features"

# Features labels
FEATURES_LABEL = "features"
TARGET_LABEL = "next-market-price"

# Features names
FEATURES_CORRELATION_LABEL = "features_correlation"
BASE_FEATURES_LABEL = "base_features"
BASE_AND_MOST_CORR_FEATURES_LABEL = "base_and_most_corr_features"
BASE_AND_LEAST_CORR_FEATURES_LABEL = "base_and_least_corr_features"

# Features paths
FEATURES_CORRELATION = FEATURES_DIR + "/" + FEATURES_CORRELATION_LABEL + ".json"
BASE_FEATURES = FEATURES_DIR + "/" + BASE_FEATURES_LABEL + ".json"
BASE_AND_MOST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_MOST_CORR_FEATURES_LABEL + ".json"
BASE_AND_LEAST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_LEAST_CORR_FEATURES_LABEL + ".json"

##################
# --- MODELS --- #
##################

# Model dir
MODELS_DIR = MAIN_DIR + "/models"

# Model path
MODEL = MODELS_DIR + "/" + MODEL_NAME

###################
# --- RESULTS --- #
###################

# Results dir
RESULTS_DIR = MAIN_DIR + "/results/" + SPLITTING_METHOD

# Results path
ALL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_all.csv"
REL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_rel.csv"

MODEL_ACCURACY_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_accuracy.csv"

# %%
# Importing useful libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

if LOCAL_RUNNING: pio.renderers.default='notebook' # To correctly export the notebook in html format

# %% [markdown]
# # Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '12G').\
                set('spark.driver.memory', '12G').\
                set('spark.driver.maxResultSize', '109G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPricePrediction").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Loading dataset

# %%
# Load train / validation set into pyspark dataset objects
df = spark.read.load(DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  # Print dataset
  dataset.show(20)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
dataset_info(df)
# Out:
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |          timestamp| id|     market-price|    opening-price|    highest-price|     lowest-price|    closing-price|  trade-volume-btc|   total-bitcoins|          market-cap|    trade-volume-usd|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|          hash-rate|        difficulty|      miners-revenue|transaction-fees-usd|n-unique-addresses|n-transactions|estimated-transaction-volume-usd|       sma-5-days|       sma-7-days|      sma-10-days|      sma-20-days|      sma-50-days|     sma-100-days|next-market-price|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |2019-11-16 00:00:00|  0|          8457.69|          8463.79|          8528.44|          8430.77|          8484.07|         50.607771|     1.80514375E7|  1.5313937003125E11|      1.0234650669E8|     249372.424907|  1.17150405405405|         4.7506956E8|        1915.32432432432| 9.35826039467827E7|1.2720005267391E13|  1.58643792041146E7|     194291.70411461|          495077.0|      283468.0|              4.61834641876112E8|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|8457.950520833334|
# |2019-11-16 00:15:00|  1|8457.950520833334|8464.019583333335|        8529.4725|8430.178229166668|8484.321979166667| 51.01141038541667|1.8051455859375E7|1.531540059538411...|1.0156392265666667E8| 249374.2310199896|1.1708478397463982| 4.750724999895833E8|       1913.255199192695|9.362212362750347E7|1.2720005267391E13|1.5871859392603226E7|  194137.97333240334|          494408.0|   283269.0625|               4.6059488883908E8|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8458.211041666667|
# |2019-11-16 00:30:00|  2|8458.211041666667|8464.249166666668|8530.505000000001|8429.586458333333|8484.573958333332|51.415049770833335| 1.805147421875E7|1.531686418764322...|1.0078133862333333E8|249376.03713297917|1.1701916254387466| 4.750754399791667E8|      1911.1860740610698|9.366164330822423E7|1.2720005267391E13|1.5879339581091853E7|  193984.24255019668|          493739.0|    283070.125|            4.5935513580204797E8|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|     8458.4715625|
# |2019-11-16 00:45:00|  3|     8458.4715625|       8464.47875|        8531.5375|     8428.9946875|     8484.8259375|    51.81868915625|1.8051492578125E7|1.531832777990234...|       9.999875459E7|249377.84324596875|1.1695354111310947|   4.7507837996875E8|      1909.1169489294448|  9.3701162988945E7|1.2720005267391E13| 1.588681976958048E7|     193830.51176799|          493070.0|   282871.1875|            4.5811538276501596E8|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|8458.732083333334|
# |2019-11-16 01:00:00|  4|8458.732083333334|8464.708333333334|          8532.57|8428.402916666668|8485.077916666667| 52.22232854166667|  1.80515109375E7|1.531979137216146E11| 9.921617055666666E7|249379.64935895836|1.1688791968234429| 4.750813199583333E8|      1907.0478237978195|9.374068266966577E7|1.2720005267391E13|1.5894299958069108E7|  193676.78098578335|          492401.0|     282672.25|            4.5687562972798395E8|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.992604166668|
# |2019-11-16 01:15:00|  5|8458.992604166668|8464.937916666668|        8533.6025|8427.811145833333|8485.329895833333| 52.62596792708333|1.8051529296875E7|1.532125496442057...| 9.843358652333333E7|249381.45547194793| 1.168222982515791| 4.750842599479167E8|      1904.9786986661945|9.378020235038655E7|1.2720005267391E13|1.5901780146557735E7|  193523.05020357668|          491732.0|   282473.3125|            4.5563587669095194E8|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8459.253125000001|
# |2019-11-16 01:30:00|  6|8459.253125000001|8465.167500000001|         8534.635|      8427.219375|      8485.581875|     53.0296073125| 1.805154765625E7|1.532271855667968...|       9.765100249E7| 249383.2615849375|1.1675667682081394|    4.750871999375E8|      1902.9095735345695| 9.38197220311073E7|1.2720005267391E13|1.5909260335046362E7|  193369.31942137002|          491063.0|    282274.375|            4.5439612365391994E8|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|8459.513645833335|
# |2019-11-16 01:45:00|  7|8459.513645833335|8465.397083333333|        8535.6675|8426.627604166668|8485.833854166667|53.433246697916665|1.8051566015625E7|1.532418214893880...| 9.686841845666666E7| 249385.0676979271|1.1669105539004876| 4.750901399270833E8|      1900.8404484029443|9.385924171182808E7|1.2720005267391E13|1.5916740523534989E7|  193215.58863916335|          490394.0|   282075.4375|             4.531563706168879E8|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8459.774166666668|
# |2019-11-16 02:00:00|  8|8459.774166666668|8465.626666666667|           8536.7|8426.035833333333|8486.085833333333| 53.83688608333333|   1.8051584375E7|1.532564574119791...| 9.608583442333333E7|249386.87381091667|1.1662543395928358| 4.750930799166667E8|      1898.7713232713193|9.389876139254886E7|1.2720005267391E13|1.5924220712023616E7|  193061.85785695666|          489725.0|      281876.5|             4.519166175798559E8|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8460.034687500001|
# |2019-11-16 02:15:00|  9|8460.034687500001|       8465.85625|        8537.7325|     8425.4440625|     8486.3378125|    54.24052546875|1.8051602734375E7|1.532710933345703E11|       9.530325039E7|249388.67992390625|1.1655981252851841|   4.7509601990625E8|       1896.702198139694|9.393828107326962E7|1.2720005267391E13|1.5931700900512243E7|     192908.12707475|          489056.0|   281677.5625|             4.506768645428239E8|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8460.295208333333|
# |2019-11-16 02:30:00| 10|8460.295208333333|8466.085833333334|8538.765000000001|8424.852291666666|8486.589791666667| 54.64416485416667| 1.805162109375E7|1.532857292571614...| 9.452066635666667E7|249390.48603689583|1.1649419109775323| 4.750989598958333E8|       1894.633073008069| 9.39778007539904E7|1.2720005267391E13| 1.593918108900087E7|  192754.39629254333|          488387.0|    281478.625|             4.494371115057919E8|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8460.555729166666|
# |2019-11-16 02:45:00| 11|8460.555729166666|8466.315416666668|        8539.7975|8424.260520833333|8486.841770833333|55.047804239583336|1.8051639453125E7|1.533003651797526E11| 9.373808232333332E7| 249392.2921498854|1.1642856966698805| 4.751018998854167E8|       1892.563947876444|9.401732043471116E7|1.2720005267391E13|1.5946661277489496E7|  192600.66551033666|          487718.0|   281279.6875|             4.481973584687599E8|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|       8460.81625|
# |2019-11-16 03:00:00| 12|       8460.81625|         8466.545|          8540.83|       8423.66875|       8487.09375|55.451443624999996|  1.80516578125E7|1.533150011023437...| 9.295549828999999E7|  249394.098262875|1.1636294823622286|     4.75104839875E8|      1890.4948227448187|9.405684011543193E7|1.2720005267391E13|1.5954141465978123E7|     192446.93472813|          487049.0|     281080.75|             4.469576054317279E8|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8461.076770833333|
# |2019-11-16 03:15:00| 13|8461.076770833333|8466.774583333334|8541.862500000001|8423.076979166666|8487.345729166667|55.855083010416664|1.8051676171875E7|1.533296370249349E11| 9.217291425666666E7| 249395.9043758646| 1.162973268054577| 4.751077798645833E8|      1888.4256976131937| 9.40963597961527E7|1.2720005267391E13|1.5961621654466752E7|  192293.20394592333|          486380.0|   280881.8125|             4.457178523946959E8|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8461.337291666667|
# |2019-11-16 03:30:00| 14|8461.337291666667|8467.004166666668|         8542.895|8422.485208333334|8487.597708333333| 56.25872239583333| 1.805169453125E7|1.533442729475260...| 9.139033022333333E7|249397.71048885418|1.1623170537469252| 4.751107198541667E8|      1886.3565724815685|9.413587947687347E7|1.2720005267391E13|1.5969101842955379E7|  192139.47316371667|          485711.0|    280682.875|            4.4447809935766387E8|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|     8461.5978125|
# |2019-11-16 03:45:00| 15|     8461.5978125|8467.233750000001|        8543.9275|     8421.8934375|     8487.8496875|    56.66236178125|1.8051712890625E7|1.533589088701172E11|       9.060774619E7|249399.51660184376|1.1616608394392733|   4.7511365984375E8|      1884.2874473499435|9.417539915759423E7|1.2720005267391E13|1.5976582031444006E7|     191985.74238151|          485042.0|   280483.9375|            4.4323834632063186E8|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8461.858333333334|
# |2019-11-16 04:00:00| 16|8461.858333333334|8467.463333333333|8544.960000000001|8421.301666666666|8488.101666666666|57.066001166666666|    1.805173125E7|1.533735447927083...| 8.982516215666667E7|249401.32271483334|1.1610046251316217| 4.751165998333333E8|      1882.2183222183185|9.421491883831501E7|1.2720005267391E13|1.5984062219932633E7|  191832.01159930334|          484373.0|      280285.0|            4.4199859328359985E8|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8462.118854166667|
# |2019-11-16 04:15:00| 17|8462.118854166667|8467.692916666667|        8545.9925|8420.709895833334|8488.353645833333|57.469640552083334|1.8051749609375E7|1.533881807152994...| 8.904257812333333E7|249403.12882782292|  1.16034841082397| 4.751195398229167E8|      1880.1491970866932|9.425443851903579E7|1.2720005267391E13| 1.599154240842126E7|  191678.28081709667|          483704.0|   280086.0625|            4.4075884024656785E8|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|      8462.379375|
# |2019-11-16 04:30:00| 18|      8462.379375|        8467.9225|         8547.025|      8420.118125|      8488.605625|     57.8732799375| 1.805176796875E7|1.534028166378906...|       8.825999409E7| 249404.9349408125| 1.159692196516318|    4.751224798125E8|      1878.0800719550682|9.429395819975655E7|1.2720005267391E13|1.5999022596909886E7|     191524.55003489|          483035.0|    279887.125|             4.395190872095358E8|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8462.639895833334|
# |2019-11-16 04:45:00| 19|8462.639895833334|8468.152083333334|        8548.0575|8419.526354166666|8488.857604166666| 58.27691932291667|1.8051786328125E7|1.534174525604817...| 8.747741005666667E7|249406.74105380208|1.1590359822086664| 4.751254198020833E8|       1876.010946823443|9.433347788047732E7|1.2720005267391E13|1.6006502785398513E7|  191370.81925268334|          482366.0|   279688.1875|            4.3827933417250377E8|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8462.900416666667|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# only showing top 20 rows
#
# Shape: (131136, 29)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- opening-price: double (nullable = true)
#  |-- highest-price: double (nullable = true)
#  |-- lowest-price: double (nullable = true)
#  |-- closing-price: double (nullable = true)
#  |-- trade-volume-btc: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume-usd: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# # Loading features

# %%
# Loading base features
with open(BASE_FEATURES, "r") as f:
    BASE_FEATURES = json.load(f)
print(BASE_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd']

# %%
# Loading currency and additional most correlated features
with open(BASE_AND_MOST_CORR_FEATURES, "r") as f:
    BASE_AND_MOST_CORR_FEATURES = json.load(f)
print(BASE_AND_MOST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'sma-20-days']

# %%
# Loading currency and additional least correlated features
with open(BASE_AND_LEAST_CORR_FEATURES, "r") as f:
    BASE_AND_LEAST_CORR_FEATURES = json.load(f)
print(BASE_AND_LEAST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'sma-100-days', 'transaction-fees-usd', 'n-unique-addresses', 'sma-50-days', 'n-transactions-total', 'blocks-size', 'hash-rate', 'difficulty', 'avg-block-size', 'n-transactions-per-block', 'n-transactions']

# %% [markdown]
# # Model train / validation
# In order to train and validate the model I'll try several approaches:
# - **Default without normalization:** Make predictions using the chosen base model
# - **Default with normalization:** Like the previous one but features are normalized
#
# At this point, the features that gave on average the most satisfactory results (for each model) are chosen and proceeded with:
#
# - **Hyperparameter tuning:** Researching the best parameters to use
# - **Cross Validation:** Validate the performance of the model with the chosen parameters
#
# If the final results are satisfactory, the model will be trained on the whole train / validation set and saved to later make predictions on the test set.
#
# For each approach the train / validation set will be split according to the chosen splitting method (in order to figure out which one works best for our problem). In this case the **Walk forward time series splits** method will be used: involves using a sliding window approach to create the training and validation sets for each fold. The model is trained on a fixed window of historical data, and then validated on the next observation in the time series. This process is repeated for each subsequent observation, with the window sliding forward one step at a time.
#
# ![walk-forward-splits.png](https://drive.google.com/uc?id=1SNdq-kjbv4MXtdBj3EOJ2dmQpbbPStJi)

# %%
# Get splitting parameters based on the choosen splitting method
splitting_info = parameters.get_splitting_params(SPLITTING_METHOD)
splitting_info
# Out:
# {'split_type': 'walk_forward_splits',
#  'min_obser': 20000,
#  'sliding_window': 5000}

# %% [markdown]
# ## Default
# The train / validation set will be splitted based on the splitting method chosen so that the model performance can be seen without any tuning by using different features (normalized and non)

# %%
# Get default parameters
params = parameters.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [20], 'maxDepth': [5], 'stepSize': [0.1], 'seed': [42]}

# %% [markdown]
# ### Without normalization

# %%
# Define model and features type
MODEL_TYPE = "default"
FEATURES_NORMALIZATION = False

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_train_results_base_features, default_valid_results_base_features, default_train_pred_base_features, default_valid_pred_base_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)

# %%
default_train_results_base_features
# Out:
#                             Model     Type Dataset            Splitting  \
# 0   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 1   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 2   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 3   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 4   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 5   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 6   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 7   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 8   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 9   GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 10  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 11  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 12  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 13  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 14  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 15  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 16  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 17  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 18  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 19  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 20  GradientBoostingTreeRegressor  default   train  walk_forward_splits
# 21  GradientBoostingTreeRegressor  default   train  walk_forward_splits
#
#          Features  Splits Train / Validation        Parameters        RMSE  \
# 0   base_features       1      (20000, 5000)  [20, 5, 0.1, 42]   38.025608
# 1   base_features       2      (20000, 5000)  [20, 5, 0.1, 42]   41.580552
# 2   base_features       3      (20000, 5000)  [20, 5, 0.1, 42]   50.991889
# 3   base_features       4      (20000, 5000)  [20, 5, 0.1, 42]   59.080724
# 4   base_features       5      (20000, 5000)  [20, 5, 0.1, 42]  154.340786
# 5   base_features       6      (20000, 5000)  [20, 5, 0.1, 42]  299.777239
# 6   base_features       7      (20000, 5000)  [20, 5, 0.1, 42]  334.162830
# 7   base_features       8      (20000, 5000)  [20, 5, 0.1, 42]  309.491807
# 8   base_features       9      (20000, 5000)  [20, 5, 0.1, 42]  250.451316
# 9   base_features      10      (20000, 5000)  [20, 5, 0.1, 42]  244.020333
# 10  base_features      11      (20000, 5000)  [20, 5, 0.1, 42]  277.697800
# 11  base_features      12      (20000, 5000)  [20, 5, 0.1, 42]  275.688371
# 12  base_features      13      (20000, 5000)  [20, 5, 0.1, 42]  238.840607
# 13  base_features      14      (20000, 5000)  [20, 5, 0.1, 42]  251.990214
# 14  base_features      15      (20000, 5000)  [20, 5, 0.1, 42]  229.099520
# 15  base_features      16      (20000, 5000)  [20, 5, 0.1, 42]  185.083119
# 16  base_features      17      (20000, 5000)  [20, 5, 0.1, 42]  180.966096
# 17  base_features      18      (20000, 5000)  [20, 5, 0.1, 42]  168.451479
# 18  base_features      19      (20000, 5000)  [20, 5, 0.1, 42]   73.070637
# 19  base_features      20      (20000, 5000)  [20, 5, 0.1, 42]   64.574778
# 20  base_features      21      (20000, 5000)  [20, 5, 0.1, 42]  104.697999
# 21  base_features      22      (20000, 5000)  [20, 5, 0.1, 42]   92.437602
#
#               MSE         MAE      MAPE        R2  Adjusted_R2      Time
# 0     1445.946891   28.187303  0.003617  0.999063     0.999063  7.953128
# 1     1728.942264   29.993176  0.003680  0.998954     0.998954  5.806709
# 2     2600.172722   38.027498  0.004421  0.999103     0.999103  5.529161
# 3     3490.531977   40.001244  0.003891  0.998872     0.998872  5.395158
# 4    23821.078368   84.117335  0.005476  0.999125     0.999125  5.257649
# 5    89866.392727  194.098198  0.008886  0.999431     0.999431  5.230885
# 6   111664.797032  240.903323  0.009152  0.999638     0.999638  5.330364
# 7    95785.178443  231.094857  0.006329  0.999523     0.999523  5.100798
# 8    62725.861613  189.369944  0.004366  0.999375     0.999375  5.101252
# 9    59545.923104  189.007307  0.004283  0.999293     0.999293  5.259725
# 10   77116.067973  212.385143  0.004782  0.999221     0.999221  5.053396
# 11   76004.077953  208.860714  0.004498  0.999186     0.999186  5.141325
# 12   57044.835406  186.125533  0.003844  0.999093     0.999093  5.132200
# 13   63499.067890  189.427694  0.003961  0.999116     0.999116  5.145062
# 14   52486.590038  168.148990  0.003957  0.999137     0.999137  4.983361
# 15   34255.760799  132.075640  0.004206  0.999541     0.999541  4.903127
# 16   32748.727787  123.264168  0.004216  0.999606     0.999606  4.934021
# 17   28375.900723  105.210037  0.004345  0.999225     0.999225  4.789259
# 18    5339.318007   50.679935  0.002522  0.999091     0.999091  4.873832
# 19    4169.901895   47.078237  0.002356  0.999349     0.999349  4.934354
# 20   10961.670963   69.259893  0.003248  0.999322     0.999322  4.880916
# 21    8544.710242   64.496291  0.002834  0.999609     0.999609  4.920304

# %%
default_valid_results_base_features
# Out:
#                             Model     Type Dataset            Splitting  \
# 0   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 1   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 2   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 3   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 4   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 5   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 6   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 7   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 8   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 9   GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 10  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 11  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 12  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 13  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 14  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 15  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 16  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 17  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 18  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 19  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 20  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
# 21  GradientBoostingTreeRegressor  default   valid  walk_forward_splits
#
#          Features  Splits Train / Validation        Parameters          RMSE  \
# 0   base_features       1      (20000, 5000)  [20, 5, 0.1, 42]    314.366864
# 1   base_features       2      (20000, 5000)  [20, 5, 0.1, 42]    476.790953
# 2   base_features       3      (20000, 5000)  [20, 5, 0.1, 42]   1686.544411
# 3   base_features       4      (20000, 5000)  [20, 5, 0.1, 42]   7211.854850
# 4   base_features       5      (20000, 5000)  [20, 5, 0.1, 42]  13389.352236
# 5   base_features       6      (20000, 5000)  [20, 5, 0.1, 42]   2934.082137
# 6   base_features       7      (20000, 5000)  [20, 5, 0.1, 42]    845.258912
# 7   base_features       8      (20000, 5000)  [20, 5, 0.1, 42]    756.502006
# 8   base_features       9      (20000, 5000)  [20, 5, 0.1, 42]    688.210692
# 9   base_features      10      (20000, 5000)  [20, 5, 0.1, 42]   2252.006206
# 10  base_features      11      (20000, 5000)  [20, 5, 0.1, 42]    544.264041
# 11  base_features      12      (20000, 5000)  [20, 5, 0.1, 42]    505.840857
# 12  base_features      13      (20000, 5000)  [20, 5, 0.1, 42]    281.954184
# 13  base_features      14      (20000, 5000)  [20, 5, 0.1, 42]   5482.877134
# 14  base_features      15      (20000, 5000)  [20, 5, 0.1, 42]   7709.027654
# 15  base_features      16      (20000, 5000)  [20, 5, 0.1, 42]    290.346196
# 16  base_features      17      (20000, 5000)  [20, 5, 0.1, 42]    610.309646
# 17  base_features      18      (20000, 5000)  [20, 5, 0.1, 42]    355.833451
# 18  base_features      19      (20000, 5000)  [20, 5, 0.1, 42]    535.252532
# 19  base_features      20      (20000, 5000)  [20, 5, 0.1, 42]   3209.945531
# 20  base_features      21      (20000, 5000)  [20, 5, 0.1, 42]   1021.339584
# 21  base_features      22      (20000, 5000)  [20, 5, 0.1, 42]    909.581503
#
#              MSE           MAE      MAPE         R2  Adjusted_R2      Time
# 0   9.882653e+04    135.121327  0.012654   0.747853     0.747651  7.953128
# 1   2.273296e+05    397.198468  0.035126   0.360561     0.360049  5.806709
# 2   2.844432e+06   1068.660435  0.073695   0.125174     0.124473  5.529161
# 3   5.201085e+07   5610.942378  0.233261  -1.595551    -1.597630  5.395158
# 4   1.792748e+08  10996.909526  0.247336  -2.280513    -2.283140  5.257649
# 5   8.608838e+06   2219.921972  0.038546   0.544562     0.544197  5.230885
# 6   7.144626e+05    532.668255  0.012067   0.990831     0.990824  5.330364
# 7   5.722953e+05    534.680763  0.015478   0.932924     0.932870  5.100798
# 8   4.736340e+05    495.689252  0.010913   0.944419     0.944375  5.101252
# 9   5.071532e+06   1447.219444  0.023305   0.914250     0.914181  5.259725
# 10  2.962233e+05    441.563852  0.008358   0.988864     0.988855  5.053396
# 11  2.558750e+05    436.976203  0.010876   0.963422     0.963392  5.141325
# 12  7.949816e+04    230.176324  0.005517   0.989293     0.989284  5.132200
# 13  3.006194e+07   4443.173791  0.147708  -0.542607    -0.543842  5.145062
# 14  5.942911e+07   7441.762780  0.353952 -13.658350   -13.670088  4.983361
# 15  8.430091e+04    221.741818  0.010301   0.971305     0.971282  4.903127
# 16  3.724779e+05    265.992089  0.015013   0.641130     0.640843  4.934021
# 17  1.266174e+05    272.987445  0.016258  -0.066686    -0.067540  4.789259
# 18  2.864953e+05    234.251666  0.010335   0.945230     0.945186  4.873832
# 19  1.030375e+07   2500.330257  0.087546  -0.158109    -0.159037  4.934354
# 20  1.043135e+06    941.848095  0.034360  -0.197905    -0.198864  4.880916
# 21  8.273385e+05    740.974102  0.025368   0.708470     0.708236  4.920304

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_train_results_base_and_most_corr_features, default_valid_results_base_and_most_corr_features, default_train_pred_base_and_most_corr_features, default_valid_pred_base_and_most_corr_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
default_train_results_base_and_most_corr_features

# %%
default_valid_results_base_and_most_corr_features

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_train_results_base_and_least_corr_features, default_valid_results_base_and_least_corr_features, default_train_pred_base_and_least_corr_features, default_valid_pred_base_and_least_corr_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
default_train_results_base_and_least_corr_features

# %%
default_valid_results_base_and_least_corr_features

# %% [markdown]
# ### With normalization

# %%
# Define model and features type
MODEL_TYPE = "default_norm"
FEATURES_NORMALIZATION = True

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_norm_train_results_base_features, default_norm_valid_results_base_features, default_norm_train_pred_base_features, default_norm_valid_pred_base_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
default_norm_train_results_base_features

# %%
default_norm_valid_results_base_features

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_norm_train_results_base_and_most_corr_features, default_norm_valid_results_base_and_most_corr_features, default_norm_train_pred_base_and_most_corr_features, default_norm_valid_pred_base_and_most_corr_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
default_norm_train_results_base_and_most_corr_features

# %%
default_norm_valid_results_base_and_most_corr_features

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_norm_train_results_base_and_least_corr_features, default_norm_valid_results_base_and_least_corr_features, default_norm_train_pred_base_and_least_corr_features, default_norm_valid_pred_base_and_least_corr_features = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
default_norm_train_results_base_and_least_corr_features

# %%
default_norm_valid_results_base_and_least_corr_features

# %%
# Define model information and evaluators to show
model_info = ['Model', 'Type', 'Dataset', 'Splitting', 'Features', 'Parameters']
evaluator_lst = ['RMSE', 'MSE', 'MAE', 'MAPE', 'R2', 'Adjusted_R2', 'Time']

# %%
# Define the results to show
default_comparison_lst = [default_valid_results_base_features, default_valid_results_base_and_most_corr_features, default_valid_results_base_and_least_corr_features, default_norm_valid_results_base_features, default_norm_valid_results_base_and_most_corr_features, default_norm_valid_results_base_and_least_corr_features]

# Show the comparison table
default_comparison_lst_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in default_comparison_lst])
default_comparison_lst_df

# %%
# Save the best default model results and predicitons
best_default_results = 
best_default_predictions = 
best_default_results

# %%
# Define the choosen features
FEATURES_NORMALIZATION = 
CHOSEN_FEATURES = 
CHOSEN_FEATURES_LABEL =

# %% [markdown]
# ## Tuned
# Once the features and execution method are selected, the model will undergo hyperparameter tuning and cross validation to find the best configuration.

# %%
# Get model grid parameters
params = parameters.get_model_grid_params(MODEL_NAME)
params

# %% [markdown]
# ### Hyperparameter tuning

# %%
# Select the type of feature to be used
MODEL_TYPE = "hyp_tuning"

# %%
# Perform hyperparameter tuning
hyp_res = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)
hyp_res

# %% [markdown]
# ---
# Since I will use the Walking forward splitting method during this phase I compute a score for each parameter chosen by each split assigning weights based on:
# * Their frequency for each split (if the same parameters are chosen from several splits, these will have greater weight)
# * The split they belong to (the closer the split is to today's date the more weight they will have)
# * Their RMSE value for each split (the lower this is, the more weight they will have)
#
# Finally, the overall score will be calculated by putting together these weights for each parameter and the one with the best score will be the chosen parameter

# %%
# Show parameters score
grouped_scores, best_params = parameters.choose_best_params(hyp_res)
grouped_scores

# %%
# Print best parameters
print(f"Best parameters: {best_params}")

# %% [markdown]
# ### Cross validation

# %%
MODEL_TYPE = "cross_val"

# %%
# Get tuned parameters
params = parameters.get_best_model_params(best_params, MODEL_NAME)
params

# %%
# Perform cross validation
cv_train_result, cv_valid_result, cv_train_pred, cv_valid_pred = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, LOCAL_RUNNING)

# %%
cv_train_result

# %%
cv_valid_result

# %%
# Define the results to show
tuned_comparison_lst = [cv_valid_result]

# Show the comparison table
tuned_comparison_lst_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in tuned_comparison_lst])
tuned_comparison_lst_df

# %% [markdown]
# # Comparison table
# Visualization of model performance at various stages of train / validation

# %%
# Concatenate final results into Pandas dataset
final_comparison_lst_df = pd.DataFrame(pd.concat([default_comparison_lst_df, tuned_comparison_lst_df], ignore_index=True))
final_comparison_lst_df

# %% [markdown]
# # Model accuracy
#
# Since predicting the price accurately is very difficult let's se how good the model is at predicting whether the price will go up or down.
#
# For each row in our predictions let's consider the actual market-price, next-market-price and our predicted next-market-price (prediction).
# We compute whether the current prediction is correct (1) or not (0):
#
# $$
# prediction\_is\_correct
# =
# \begin{cases}
# 0 \text{ if [(market-price > next-market-price) and (market-price < prediction)] or [(market-price < next-market-price) and (market-price > prediction)]} \\
# 1 \text{ if [(market-price > next-market-price) and (market-price > prediction)] or [(market-price < next-market-price) and (market-price < prediction)]}
# \end{cases}
# $$
#
# After that I count the number of correct prediction:
# $$
# correct\_predictions
# =
# \sum_{i=0}^{total\_rows} prediction\_is\_correct
# $$
#
# Finally I compute the percentage of accuracy of the model:
# $$
# \\
# accuracy
# =
# (correct\_predictions / total\_rows)
# * 100
# $$

# %%
# Convert the pandas dataset to a PySpark dataset
best_default_pred_spark = spark.createDataFrame(best_default_predictions)
validated_pred_spark = spark.createDataFrame(cv_valid_pred)

# Compute model accuracy
default_accuracy = utilities.model_accuracy(best_default_pred_spark)
validated_accuracy = utilities.model_accuracy(validated_pred_spark)

# Shows whether features are normalised or not
if FEATURES_NORMALIZATION:
    NEW_CHOSEN_FEATURES_LABEL = CHOSEN_FEATURES_LABEL + "_norm"
    CHOSEN_FEATURES_LABEL = NEW_CHOSEN_FEATURES_LABEL
    
# Saving accuracy data into dataframe
accuracy_data = {
    'Model': MODEL_NAME,
    'Features': CHOSEN_FEATURES_LABEL,
    'Splitting': SPLITTING_METHOD,
    'Accuracy (default)': default_accuracy,
    'Accuracy (tuned)': validated_accuracy
}
accuracy_data_df = pd.DataFrame(accuracy_data, index=['Model'])

print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (default): {default_accuracy:.2f}%")
print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (tuned): {validated_accuracy:.2f}%")

# %%
# Concatenate default and tuned results
default_tuned_results = [best_default_results, cv_valid_result]
default_tuned_results_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in default_tuned_results])
default_tuned_results_df

# %% [markdown]
# # Saving final results

# %%
# Save all final comparison results
final_comparison_lst_df.to_csv(ALL_MODEL_RESULTS, index=False)

# %%
# Save relevant results (default and tuned results)
default_tuned_results_df.to_csv(REL_MODEL_RESULTS, index=False)

# %%
# Saving accuracy results
accuracy_data_df.to_csv(MODEL_ACCURACY_RESULTS, index=False)

# %%
# Export notebook in html format (remember to save the notebook and change the model name)
if LOCAL_RUNNING:
    # !jupyter nbconvert --to html 4-walk-forward-split.ipynb --output 4-walk-forward-split_{MODEL_NAME} --output-dir='./exports'
