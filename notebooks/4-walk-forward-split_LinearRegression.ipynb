# %% [markdown]
# # **Bitcoin price prediction - Walk Forward Split**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author: Corsi Danilo (1742375) - corsi.1742375@studenti.uniroma1.it
#
#
# ---
#
#
# Description: perform model's train / validation with hyperparameter tuning and cross validation based on different methods of splitting the dataset.

# %% [markdown]
# # Global constants, dependencies, libraries and tools

# %%
# Main constants
LOCAL_RUNNING = True
SLOW_OPERATIONS = False # Decide whether or not to use operations that might slow down notebook execution
ROOT_DIR = "D:/Documents/Repository/BDC/project" if LOCAL_RUNNING else "/content/drive"

# %%
if not LOCAL_RUNNING:
    # Point Colaboratory to Google Drive
    from google.colab import drive

    # Define GDrive paths
    drive.mount(ROOT_DIR, force_remount=True)

    # Install Spark and related dependencies
    # !pip install pyspark
    # !pip install -U -q PyDrive -qq
    # !apt install openjdk-8-jdk-headless -qq

# %% [markdown]
# ## Import my utilities

# %%
# Set main dir
MAIN_DIR = ROOT_DIR + "" if LOCAL_RUNNING else ROOT_DIR + "/MyDrive/BDC/project"

# Utilities dir
UTILITIES_DIR = MAIN_DIR + "/utilities"

# Import my utilities
import sys
sys.path.append(UTILITIES_DIR)

from imports import *
import train_validation_utilities
from config import *

importlib.reload(train_validation_utilities)
# Out:
# <module 'train_validation_utilities' from 'D:\\Documents/Repository/BDC/project/utilities\\train_validation_utilities.py'>

# %% [markdown]
# ## Core variables

# %%
# BS = Block Split
# WFS = Walk Forward Split
# SS = Single Split
SPLITTING_METHOD = WFS

# LR = LinearRegression 
# GLR = GeneralizedLinearRegression 
# RF = RandomForestRegressor 
# GBTR = GradientBoostingTreeRegressor
MODEL_NAME = LR

# %%
###################
# --- DATASET --- #
###################

# Datasets dirs
DATASET_OUTPUT_DIR = MAIN_DIR + "/datasets/output"

# Datasets paths
DATASET_TRAIN_VALID  = DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

####################
# --- FEATURES --- #
####################

# Features dir
FEATURES_DIR = MAIN_DIR + "/features"

# Features paths
FEATURES_CORRELATION = FEATURES_DIR + "/" + FEATURES_CORRELATION_LABEL + ".json"
BASE_FEATURES = FEATURES_DIR + "/" + BASE_FEATURES_LABEL + ".json"
BASE_AND_MOST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_MOST_CORR_FEATURES_LABEL + ".json"
BASE_AND_LEAST_CORR_FEATURES = FEATURES_DIR + "/" + BASE_AND_LEAST_CORR_FEATURES_LABEL + ".json"

##################
# --- MODELS --- #
##################

# Model dir
MODELS_DIR = MAIN_DIR + "/models"

# Model path
MODEL = MODELS_DIR + "/" + MODEL_NAME

###################
# --- RESULTS --- #
###################

# Results dir
RESULTS_DIR = MAIN_DIR + "/results/" + SPLITTING_METHOD

# Results path
ALL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_all.csv"
REL_MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_rel.csv"

MODEL_ACCURACY_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_accuracy.csv"

# %%
# Importing useful libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pio.renderers.default = 'vscode+colab' # To correctly render plotly plots

# %% [markdown]
# # Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '12G').\
                set('spark.driver.memory', '12G').\
                set('spark.driver.maxResultSize', '109G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPricePrediction").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Loading dataset

# %%
# Load train / validation set into pyspark dataset objects
df = spark.read.load(DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
train_validation_utilities.dataset_info(df)
# Out:
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |          timestamp| id|     market-price|    opening-price|    highest-price|     lowest-price|    closing-price|  trade-volume-btc|   total-bitcoins|          market-cap|    trade-volume-usd|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|          hash-rate|        difficulty|      miners-revenue|transaction-fees-usd|n-unique-addresses|n-transactions|estimated-transaction-volume-usd|       sma-5-days|       sma-7-days|      sma-10-days|      sma-20-days|      sma-50-days|     sma-100-days|next-market-price|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |2019-11-16 00:00:00|  0|          8457.69|          8463.79|          8528.44|          8430.77|          8484.07|         50.607771|     1.80514375E7|  1.5313937003125E11|      1.0234650669E8|     249372.424907|  1.17150405405405|         4.7506956E8|        1915.32432432432| 9.35826039467827E7|1.2720005267391E13|  1.58643792041146E7|     194291.70411461|          495077.0|      283468.0|              4.61834641876112E8|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|          8457.69|8457.950520833334|
# |2019-11-16 00:15:00|  1|8457.950520833334|8464.019583333335|        8529.4725|8430.178229166668|8484.321979166667| 51.01141038541667|1.8051455859375E7|1.531540059538411...|1.0156392265666667E8| 249374.2310199896|1.1708478397463982| 4.750724999895833E8|       1913.255199192695|9.362212362750347E7|1.2720005267391E13|1.5871859392603226E7|  194137.97333240334|          494408.0|   283269.0625|               4.6059488883908E8|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8457.820260416667|8458.211041666667|
# |2019-11-16 00:30:00|  2|8458.211041666667|8464.249166666668|8530.505000000001|8429.586458333333|8484.573958333332|51.415049770833335| 1.805147421875E7|1.531686418764322...|1.0078133862333333E8|249376.03713297917|1.1701916254387466| 4.750754399791667E8|      1911.1860740610698|9.366164330822423E7|1.2720005267391E13|1.5879339581091853E7|  193984.24255019668|          493739.0|    283070.125|            4.5935513580204797E8|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|8457.950520833334|     8458.4715625|
# |2019-11-16 00:45:00|  3|     8458.4715625|       8464.47875|        8531.5375|     8428.9946875|     8484.8259375|    51.81868915625|1.8051492578125E7|1.531832777990234...|       9.999875459E7|249377.84324596875|1.1695354111310947|   4.7507837996875E8|      1909.1169489294448|  9.3701162988945E7|1.2720005267391E13| 1.588681976958048E7|     193830.51176799|          493070.0|   282871.1875|            4.5811538276501596E8|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|    8458.08078125|8458.732083333334|
# |2019-11-16 01:00:00|  4|8458.732083333334|8464.708333333334|          8532.57|8428.402916666668|8485.077916666667| 52.22232854166667|  1.80515109375E7|1.531979137216146E11| 9.921617055666666E7|249379.64935895836|1.1688791968234429| 4.750813199583333E8|      1907.0478237978195|9.374068266966577E7|1.2720005267391E13|1.5894299958069108E7|  193676.78098578335|          492401.0|     282672.25|            4.5687562972798395E8|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.211041666667|8458.992604166668|
# |2019-11-16 01:15:00|  5|8458.992604166668|8464.937916666668|        8533.6025|8427.811145833333|8485.329895833333| 52.62596792708333|1.8051529296875E7|1.532125496442057...| 9.843358652333333E7|249381.45547194793| 1.168222982515791| 4.750842599479167E8|      1904.9786986661945|9.378020235038655E7|1.2720005267391E13|1.5901780146557735E7|  193523.05020357668|          491732.0|   282473.3125|            4.5563587669095194E8|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8458.341302083334|8459.253125000001|
# |2019-11-16 01:30:00|  6|8459.253125000001|8465.167500000001|         8534.635|      8427.219375|      8485.581875|     53.0296073125| 1.805154765625E7|1.532271855667968...|       9.765100249E7| 249383.2615849375|1.1675667682081394|    4.750871999375E8|      1902.9095735345695| 9.38197220311073E7|1.2720005267391E13|1.5909260335046362E7|  193369.31942137002|          491063.0|    282274.375|            4.5439612365391994E8|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|     8458.4715625|8459.513645833335|
# |2019-11-16 01:45:00|  7|8459.513645833335|8465.397083333333|        8535.6675|8426.627604166668|8485.833854166667|53.433246697916665|1.8051566015625E7|1.532418214893880...| 9.686841845666666E7| 249385.0676979271|1.1669105539004876| 4.750901399270833E8|      1900.8404484029443|9.385924171182808E7|1.2720005267391E13|1.5916740523534989E7|  193215.58863916335|          490394.0|   282075.4375|             4.531563706168879E8|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8458.601822916668|8459.774166666668|
# |2019-11-16 02:00:00|  8|8459.774166666668|8465.626666666667|           8536.7|8426.035833333333|8486.085833333333| 53.83688608333333|   1.8051584375E7|1.532564574119791...| 9.608583442333333E7|249386.87381091667|1.1662543395928358| 4.750930799166667E8|      1898.7713232713193|9.389876139254886E7|1.2720005267391E13|1.5924220712023616E7|  193061.85785695666|          489725.0|      281876.5|             4.519166175798559E8|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8458.732083333334|8460.034687500001|
# |2019-11-16 02:15:00|  9|8460.034687500001|       8465.85625|        8537.7325|     8425.4440625|     8486.3378125|    54.24052546875|1.8051602734375E7|1.532710933345703E11|       9.530325039E7|249388.67992390625|1.1655981252851841|   4.7509601990625E8|       1896.702198139694|9.393828107326962E7|1.2720005267391E13|1.5931700900512243E7|     192908.12707475|          489056.0|   281677.5625|             4.506768645428239E8|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8458.862343750001|8460.295208333333|
# |2019-11-16 02:30:00| 10|8460.295208333333|8466.085833333334|8538.765000000001|8424.852291666666|8486.589791666667| 54.64416485416667| 1.805162109375E7|1.532857292571614...| 9.452066635666667E7|249390.48603689583|1.1649419109775323| 4.750989598958333E8|       1894.633073008069| 9.39778007539904E7|1.2720005267391E13| 1.593918108900087E7|  192754.39629254333|          488387.0|    281478.625|             4.494371115057919E8|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8458.992604166668|8460.555729166666|
# |2019-11-16 02:45:00| 11|8460.555729166666|8466.315416666668|        8539.7975|8424.260520833333|8486.841770833333|55.047804239583336|1.8051639453125E7|1.533003651797526E11| 9.373808232333332E7| 249392.2921498854|1.1642856966698805| 4.751018998854167E8|       1892.563947876444|9.401732043471116E7|1.2720005267391E13|1.5946661277489496E7|  192600.66551033666|          487718.0|   281279.6875|             4.481973584687599E8|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|8459.122864583334|       8460.81625|
# |2019-11-16 03:00:00| 12|       8460.81625|         8466.545|          8540.83|       8423.66875|       8487.09375|55.451443624999996|  1.80516578125E7|1.533150011023437...| 9.295549828999999E7|  249394.098262875|1.1636294823622286|     4.75104839875E8|      1890.4948227448187|9.405684011543193E7|1.2720005267391E13|1.5954141465978123E7|     192446.93472813|          487049.0|     281080.75|             4.469576054317279E8|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8459.253125000001|8461.076770833333|
# |2019-11-16 03:15:00| 13|8461.076770833333|8466.774583333334|8541.862500000001|8423.076979166666|8487.345729166667|55.855083010416664|1.8051676171875E7|1.533296370249349E11| 9.217291425666666E7| 249395.9043758646| 1.162973268054577| 4.751077798645833E8|      1888.4256976131937| 9.40963597961527E7|1.2720005267391E13|1.5961621654466752E7|  192293.20394592333|          486380.0|   280881.8125|             4.457178523946959E8|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8459.383385416668|8461.337291666667|
# |2019-11-16 03:30:00| 14|8461.337291666667|8467.004166666668|         8542.895|8422.485208333334|8487.597708333333| 56.25872239583333| 1.805169453125E7|1.533442729475260...| 9.139033022333333E7|249397.71048885418|1.1623170537469252| 4.751107198541667E8|      1886.3565724815685|9.413587947687347E7|1.2720005267391E13|1.5969101842955379E7|  192139.47316371667|          485711.0|    280682.875|            4.4447809935766387E8|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|8459.513645833335|     8461.5978125|
# |2019-11-16 03:45:00| 15|     8461.5978125|8467.233750000001|        8543.9275|     8421.8934375|     8487.8496875|    56.66236178125|1.8051712890625E7|1.533589088701172E11|       9.060774619E7|249399.51660184376|1.1616608394392733|   4.7511365984375E8|      1884.2874473499435|9.417539915759423E7|1.2720005267391E13|1.5976582031444006E7|     191985.74238151|          485042.0|   280483.9375|            4.4323834632063186E8|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8459.643906250001|8461.858333333334|
# |2019-11-16 04:00:00| 16|8461.858333333334|8467.463333333333|8544.960000000001|8421.301666666666|8488.101666666666|57.066001166666666|    1.805173125E7|1.533735447927083...| 8.982516215666667E7|249401.32271483334|1.1610046251316217| 4.751165998333333E8|      1882.2183222183185|9.421491883831501E7|1.2720005267391E13|1.5984062219932633E7|  191832.01159930334|          484373.0|      280285.0|            4.4199859328359985E8|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8459.774166666668|8462.118854166667|
# |2019-11-16 04:15:00| 17|8462.118854166667|8467.692916666667|        8545.9925|8420.709895833334|8488.353645833333|57.469640552083334|1.8051749609375E7|1.533881807152994...| 8.904257812333333E7|249403.12882782292|  1.16034841082397| 4.751195398229167E8|      1880.1491970866932|9.425443851903579E7|1.2720005267391E13| 1.599154240842126E7|  191678.28081709667|          483704.0|   280086.0625|            4.4075884024656785E8|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|8459.904427083335|      8462.379375|
# |2019-11-16 04:30:00| 18|      8462.379375|        8467.9225|         8547.025|      8420.118125|      8488.605625|     57.8732799375| 1.805176796875E7|1.534028166378906...|       8.825999409E7| 249404.9349408125| 1.159692196516318|    4.751224798125E8|      1878.0800719550682|9.429395819975655E7|1.2720005267391E13|1.5999022596909886E7|     191524.55003489|          483035.0|    279887.125|             4.395190872095358E8|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8460.034687500001|8462.639895833334|
# |2019-11-16 04:45:00| 19|8462.639895833334|8468.152083333334|        8548.0575|8419.526354166666|8488.857604166666| 58.27691932291667|1.8051786328125E7|1.534174525604817...| 8.747741005666667E7|249406.74105380208|1.1590359822086664| 4.751254198020833E8|       1876.010946823443|9.433347788047732E7|1.2720005267391E13|1.6006502785398513E7|  191370.81925268334|          482366.0|   279688.1875|            4.3827933417250377E8|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8460.164947916668|8462.900416666667|
# +-------------------+---+-----------------+-----------------+-----------------+-----------------+-----------------+------------------+-----------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+--------------+--------------------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# only showing top 20 rows
#
# Shape: (131136, 29)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- opening-price: double (nullable = true)
#  |-- highest-price: double (nullable = true)
#  |-- lowest-price: double (nullable = true)
#  |-- closing-price: double (nullable = true)
#  |-- trade-volume-btc: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume-usd: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# # Loading features

# %%
# Loading base features
with open(BASE_FEATURES, "r") as f:
    BASE_FEATURES = json.load(f)
print(BASE_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd']

# %%
# Loading currency and additional most correlated features
with open(BASE_AND_MOST_CORR_FEATURES, "r") as f:
    BASE_AND_MOST_CORR_FEATURES = json.load(f)
print(BASE_AND_MOST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'sma-20-days']

# %%
# Loading currency and additional least correlated features
with open(BASE_AND_LEAST_CORR_FEATURES, "r") as f:
    BASE_AND_LEAST_CORR_FEATURES = json.load(f)
print(BASE_AND_LEAST_CORR_FEATURES)
# Out:
# ['opening-price', 'highest-price', 'lowest-price', 'closing-price', 'trade-volume-btc', 'market-price', 'market-cap', 'total-bitcoins', 'trade-volume-usd', 'sma-100-days', 'transaction-fees-usd', 'n-unique-addresses', 'sma-50-days', 'n-transactions-total', 'blocks-size', 'hash-rate', 'difficulty', 'avg-block-size', 'n-transactions-per-block', 'n-transactions']

# %% [markdown]
# # Model train / validation
# In order to train and validate the model I'll try several approaches:
# - `Default without normalization:` make predictions using the base model
# - `Default with normalization:` like the previous one but features are normalized
#
# Then the features that gave on average the most satisfactory results (for each model) are chosen and proceeded with:
# - `Hyperparameter tuning:` finding the best parameters to use.
# - `Cross Validation:` validate the performance of the model with the chosen parameters (also here using Block split / Walk forward split)
#
# If the final results are satisfactory, the model will be trained on the whole train / validation set and saved in order to make predictions on the test set.
#
# For each approach the train / validation set will be split according to the chosen splitting method (in order to figure out which one works best for our problem). In this case the `Walk forward time series splits` method will be used: involves using a sliding window approach to create the training and validation sets for each fold. The model is trained on a fixed window of historical data, and then validated on the next observation in the time series. This process is repeated for each subsequent observation, with the window sliding forward one step at a time.
#
# <img src="https://github.com/CorsiDanilo/big-data-computing-project/blob/main/notebooks/images/walk-forward-splits.png?raw=1">

# %%
# Get splitting parameters based on the choosen splitting method
splitting_info = train_validation_utilities.get_splitting_params(SPLITTING_METHOD)
splitting_info
# Out:
# {'split_type': 'walk_forward_splits',
#  'min_obser': 20000,
#  'sliding_window': 5000}

# %% [markdown]
# ## Default
# The train / validation set will be splitted based on the splitting method chosen so that the model performance can be seen without any tuning by using different features (normalized and non)

# %%
# Get default parameters
params = train_validation_utilities.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [100], 'regParam': [0.0], 'elasticNetParam': [0.0]}

# %% [markdown]
# ### Without normalization

# %%
# Define model and features type
MODEL_TYPE = "default"
FEATURES_NORMALIZATION = False

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_train_results_base_features, default_valid_results_base_features, default_train_pred_base_features, default_valid_pred_base_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:02<00:00,  2.99s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.79s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]

# %%
default_train_results_base_features
# Out:
#                Model     Type Dataset            Splitting       Features  \
# 0   LinearRegression  default   train  walk_forward_splits  base_features
# 1   LinearRegression  default   train  walk_forward_splits  base_features
# 2   LinearRegression  default   train  walk_forward_splits  base_features
# 3   LinearRegression  default   train  walk_forward_splits  base_features
# 4   LinearRegression  default   train  walk_forward_splits  base_features
# 5   LinearRegression  default   train  walk_forward_splits  base_features
# 6   LinearRegression  default   train  walk_forward_splits  base_features
# 7   LinearRegression  default   train  walk_forward_splits  base_features
# 8   LinearRegression  default   train  walk_forward_splits  base_features
# 9   LinearRegression  default   train  walk_forward_splits  base_features
# 10  LinearRegression  default   train  walk_forward_splits  base_features
# 11  LinearRegression  default   train  walk_forward_splits  base_features
# 12  LinearRegression  default   train  walk_forward_splits  base_features
# 13  LinearRegression  default   train  walk_forward_splits  base_features
# 14  LinearRegression  default   train  walk_forward_splits  base_features
# 15  LinearRegression  default   train  walk_forward_splits  base_features
# 16  LinearRegression  default   train  walk_forward_splits  base_features
# 17  LinearRegression  default   train  walk_forward_splits  base_features
# 18  LinearRegression  default   train  walk_forward_splits  base_features
# 19  LinearRegression  default   train  walk_forward_splits  base_features
# 20  LinearRegression  default   train  walk_forward_splits  base_features
# 21  LinearRegression  default   train  walk_forward_splits  base_features
#
#     Splits Train / Validation       Parameters       RMSE         MSE  \
# 0        1      (20000, 5000)  [100, 0.0, 0.0]   2.435528    5.931795
# 1        2      (20000, 5000)  [100, 0.0, 0.0]   2.475028    6.125762
# 2        3      (20000, 5000)  [100, 0.0, 0.0]   2.501137    6.255685
# 3        4      (20000, 5000)  [100, 0.0, 0.0]   2.453739    6.020836
# 4        5      (20000, 5000)  [100, 0.0, 0.0]   3.709999   13.764096
# 5        6      (20000, 5000)  [100, 0.0, 0.0]   9.638562   92.901869
# 6        7      (20000, 5000)  [100, 0.0, 0.0]  12.194722  148.711252
# 7        8      (20000, 5000)  [100, 0.0, 0.0]  15.897169  252.719991
# 8        9      (20000, 5000)  [100, 0.0, 0.0]  16.404645  269.112368
# 9       10      (20000, 5000)  [100, 0.0, 0.0]  15.268518  233.127637
# 10      11      (20000, 5000)  [100, 0.0, 0.0]  15.155735  229.696312
# 11      12      (20000, 5000)  [100, 0.0, 0.0]  13.412414  179.892862
# 12      13      (20000, 5000)  [100, 0.0, 0.0]  13.215041  174.637296
# 13      14      (20000, 5000)  [100, 0.0, 0.0]  12.898535  166.372212
# 14      15      (20000, 5000)  [100, 0.0, 0.0]  11.966487  143.196817
# 15      16      (20000, 5000)  [100, 0.0, 0.0]  10.114252  102.298094
# 16      17      (20000, 5000)  [100, 0.0, 0.0]   9.193243   84.515724
# 17      18      (20000, 5000)  [100, 0.0, 0.0]   7.398190   54.733219
# 18      19      (20000, 5000)  [100, 0.0, 0.0]   5.134895   26.367150
# 19      20      (20000, 5000)  [100, 0.0, 0.0]   4.519632   20.427072
# 20      21      (20000, 5000)  [100, 0.0, 0.0]   4.613640   21.285674
# 21      22      (20000, 5000)  [100, 0.0, 0.0]   4.682997   21.930459
#
#           MAE      MAPE        R2  Adjusted_R2      Time
# 0    1.775203  0.000222  0.999996     0.999996  1.345970
# 1    1.772700  0.000211  0.999996     0.999996  0.409629
# 2    1.802832  0.000205  0.999998     0.999998  0.383702
# 3    1.733474  0.000163  0.999998     0.999998  0.344082
# 4    2.449029  0.000166  0.999999     0.999999  0.330220
# 5    5.483164  0.000218  0.999999     0.999999  0.334105
# 6    7.983527  0.000236  1.000000     1.000000  0.333746
# 7   11.076743  0.000272  0.999999     0.999999  0.318145
# 8   11.976985  0.000277  0.999997     0.999997  0.339401
# 9   11.170710  0.000249  0.999997     0.999997  0.339045
# 10  11.072854  0.000246  0.999998     0.999998  0.332692
# 11  10.119369  0.000216  0.999998     0.999998  0.337106
# 12   9.713685  0.000198  0.999997     0.999997  0.327046
# 13   9.247437  0.000194  0.999998     0.999998  0.341121
# 14   8.653656  0.000210  0.999998     0.999998  0.318936
# 15   6.976818  0.000209  0.999999     0.999999  0.321024
# 16   6.200583  0.000211  0.999999     0.999999  0.311076
# 17   4.819576  0.000197  0.999999     0.999999  0.322597
# 18   3.248051  0.000161  0.999996     0.999996  0.330671
# 19   2.843344  0.000141  0.999997     0.999997  0.313222
# 20   2.915151  0.000135  0.999999     0.999999  0.338939
# 21   3.195962  0.000133  0.999999     0.999999  0.302653

# %%
default_valid_results_base_features
# Out:
#                Model     Type Dataset            Splitting       Features  \
# 0   LinearRegression  default   valid  walk_forward_splits  base_features
# 1   LinearRegression  default   valid  walk_forward_splits  base_features
# 2   LinearRegression  default   valid  walk_forward_splits  base_features
# 3   LinearRegression  default   valid  walk_forward_splits  base_features
# 4   LinearRegression  default   valid  walk_forward_splits  base_features
# 5   LinearRegression  default   valid  walk_forward_splits  base_features
# 6   LinearRegression  default   valid  walk_forward_splits  base_features
# 7   LinearRegression  default   valid  walk_forward_splits  base_features
# 8   LinearRegression  default   valid  walk_forward_splits  base_features
# 9   LinearRegression  default   valid  walk_forward_splits  base_features
# 10  LinearRegression  default   valid  walk_forward_splits  base_features
# 11  LinearRegression  default   valid  walk_forward_splits  base_features
# 12  LinearRegression  default   valid  walk_forward_splits  base_features
# 13  LinearRegression  default   valid  walk_forward_splits  base_features
# 14  LinearRegression  default   valid  walk_forward_splits  base_features
# 15  LinearRegression  default   valid  walk_forward_splits  base_features
# 16  LinearRegression  default   valid  walk_forward_splits  base_features
# 17  LinearRegression  default   valid  walk_forward_splits  base_features
# 18  LinearRegression  default   valid  walk_forward_splits  base_features
# 19  LinearRegression  default   valid  walk_forward_splits  base_features
# 20  LinearRegression  default   valid  walk_forward_splits  base_features
# 21  LinearRegression  default   valid  walk_forward_splits  base_features
#
#     Splits Train / Validation       Parameters       RMSE         MSE  \
# 0        1      (20000, 5000)  [100, 0.0, 0.0]   1.967400    3.870664
# 1        2      (20000, 5000)  [100, 0.0, 0.0]   2.605017    6.786111
# 2        3      (20000, 5000)  [100, 0.0, 0.0]   2.724320    7.421920
# 3        4      (20000, 5000)  [100, 0.0, 0.0]   6.471575   41.881283
# 4        5      (20000, 5000)  [100, 0.0, 0.0]  18.771401  352.365482
# 5        6      (20000, 5000)  [100, 0.0, 0.0]  16.145362  260.672702
# 6        7      (20000, 5000)  [100, 0.0, 0.0]  22.168812  491.456224
# 7        8      (20000, 5000)  [100, 0.0, 0.0]  11.347899  128.774810
# 8        9      (20000, 5000)  [100, 0.0, 0.0]  14.330402  205.360409
# 9       10      (20000, 5000)  [100, 0.0, 0.0]  24.800043  615.042153
# 10      11      (20000, 5000)  [100, 0.0, 0.0]  14.907110  222.221921
# 11      12      (20000, 5000)  [100, 0.0, 0.0]  10.189462  103.825141
# 12      13      (20000, 5000)  [100, 0.0, 0.0]  12.396027  153.661497
# 13      14      (20000, 5000)  [100, 0.0, 0.0]  10.999633  120.991920
# 14      15      (20000, 5000)  [100, 0.0, 0.0]  13.235425  175.176470
# 15      16      (20000, 5000)  [100, 0.0, 0.0]   5.815023   33.814498
# 16      17      (20000, 5000)  [100, 0.0, 0.0]   5.188175   26.917161
# 17      18      (20000, 5000)  [100, 0.0, 0.0]   2.324007    5.401007
# 18      19      (20000, 5000)  [100, 0.0, 0.0]   4.895850   23.969348
# 19      20      (20000, 5000)  [100, 0.0, 0.0]   6.058534   36.705832
# 20      21      (20000, 5000)  [100, 0.0, 0.0]  11.815526  139.606643
# 21      22      (20000, 5000)  [100, 0.0, 0.0]   4.138742   17.129184
#
#           MAE      MAPE        R2  Adjusted_R2      Time
# 0    1.244890  0.000127  0.999990     0.999990  1.345970
# 1    1.925979  0.000172  0.999981     0.999981  0.409629
# 2    1.846456  0.000142  0.999998     0.999998  0.383702
# 3    5.010823  0.000230  0.999998     0.999998  0.344082
# 4   13.769709  0.000338  0.999994     0.999994  0.330220
# 5   12.597670  0.000228  0.999986     0.999986  0.334105
# 6   16.149503  0.000362  0.999994     0.999994  0.333746
# 7    9.291584  0.000266  0.999985     0.999985  0.318145
# 8   10.656071  0.000230  0.999976     0.999976  0.339401
# 9   13.522523  0.000233  0.999990     0.999990  0.339045
# 10  10.851963  0.000206  0.999992     0.999992  0.332692
# 11   7.552378  0.000189  0.999985     0.999985  0.337106
# 12   8.641235  0.000209  0.999979     0.999979  0.327046
# 13   8.220294  0.000250  0.999994     0.999994  0.341121
# 14  11.241598  0.000525  0.999957     0.999957  0.318936
# 15   4.108232  0.000194  0.999988     0.999988  0.321024
# 16   2.970004  0.000158  0.999974     0.999974  0.311076
# 17   1.662315  0.000099  0.999954     0.999954  0.322597
# 18   3.366594  0.000150  0.999995     0.999995  0.330671
# 19   4.436293  0.000168  0.999996     0.999996  0.313222
# 20   6.772705  0.000247  0.999840     0.999840  0.338939
# 21   3.119415  0.000107  0.999994     0.999994  0.302653

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_train_results_base_and_most_corr_features, default_valid_results_base_and_most_corr_features, default_train_pred_base_and_most_corr_features, default_valid_pred_base_and_most_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]

# %%
default_train_results_base_and_most_corr_features
# Out:
#                Model     Type Dataset            Splitting  \
# 0   LinearRegression  default   train  walk_forward_splits
# 1   LinearRegression  default   train  walk_forward_splits
# 2   LinearRegression  default   train  walk_forward_splits
# 3   LinearRegression  default   train  walk_forward_splits
# 4   LinearRegression  default   train  walk_forward_splits
# 5   LinearRegression  default   train  walk_forward_splits
# 6   LinearRegression  default   train  walk_forward_splits
# 7   LinearRegression  default   train  walk_forward_splits
# 8   LinearRegression  default   train  walk_forward_splits
# 9   LinearRegression  default   train  walk_forward_splits
# 10  LinearRegression  default   train  walk_forward_splits
# 11  LinearRegression  default   train  walk_forward_splits
# 12  LinearRegression  default   train  walk_forward_splits
# 13  LinearRegression  default   train  walk_forward_splits
# 14  LinearRegression  default   train  walk_forward_splits
# 15  LinearRegression  default   train  walk_forward_splits
# 16  LinearRegression  default   train  walk_forward_splits
# 17  LinearRegression  default   train  walk_forward_splits
# 18  LinearRegression  default   train  walk_forward_splits
# 19  LinearRegression  default   train  walk_forward_splits
# 20  LinearRegression  default   train  walk_forward_splits
# 21  LinearRegression  default   train  walk_forward_splits
#
#                        Features  Splits Train / Validation       Parameters  \
# 0   base_and_most_corr_features       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_and_most_corr_features       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_and_most_corr_features       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_and_most_corr_features       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_and_most_corr_features       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_and_most_corr_features       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_and_most_corr_features       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_and_most_corr_features       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_and_most_corr_features       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_and_most_corr_features      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_and_most_corr_features      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_and_most_corr_features      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_and_most_corr_features      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_and_most_corr_features      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_and_most_corr_features      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_and_most_corr_features      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_and_most_corr_features      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_and_most_corr_features      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_and_most_corr_features      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_and_most_corr_features      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_and_most_corr_features      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_and_most_corr_features      22      (20000, 5000)  [100, 0.0, 0.0]
#
#          RMSE         MSE        MAE      MAPE        R2  Adjusted_R2  \
# 0    2.394387    5.733089   1.764614  0.000221  0.999996     0.999996
# 1    2.429342    5.901701   1.761104  0.000209  0.999996     0.999996
# 2    2.460705    6.055071   1.791034  0.000203  0.999998     0.999998
# 3    2.424943    5.880348   1.736340  0.000164  0.999998     0.999998
# 4    3.622242   13.120634   2.458340  0.000168  1.000000     1.000000
# 5    9.281299   86.142503   5.468560  0.000224  0.999999     0.999999
# 6   11.978819  143.492113   7.818047  0.000223  1.000000     1.000000
# 7   15.637570  244.533607  11.058752  0.000271  0.999999     0.999999
# 8   16.231205  263.452010  11.871252  0.000273  0.999997     0.999997
# 9   15.202700  231.122095  11.136229  0.000248  0.999997     0.999997
# 10  15.099271  227.987975  10.961829  0.000244  0.999998     0.999998
# 11  13.203350  174.328440  10.056755  0.000215  0.999998     0.999998
# 12  13.038138  169.993036   9.644806  0.000197  0.999997     0.999997
# 13  12.746130  162.463829   9.355411  0.000197  0.999998     0.999998
# 14  11.912321  141.903400   8.612255  0.000209  0.999998     0.999998
# 15  10.058882  101.181115   6.988803  0.000209  0.999999     0.999999
# 16   9.104289   82.888075   6.208731  0.000212  0.999999     0.999999
# 17   7.321795   53.608678   4.829906  0.000198  0.999999     0.999999
# 18   5.105499   26.066118   3.240330  0.000161  0.999996     0.999996
# 19   4.473885   20.015645   2.836917  0.000141  0.999997     0.999997
# 20   4.584385   21.016586   2.924695  0.000135  0.999999     0.999999
# 21   4.654911   21.668192   3.209380  0.000134  0.999999     0.999999
#
#         Time
# 0   0.327357
# 1   0.385321
# 2   0.325584
# 3   0.352011
# 4   0.335872
# 5   0.351151
# 6   0.340696
# 7   0.339713
# 8   0.348331
# 9   0.346121
# 10  0.342032
# 11  0.341676
# 12  0.371513
# 13  0.352445
# 14  0.363971
# 15  0.352712
# 16  0.348310
# 17  0.348723
# 18  0.350243
# 19  0.362933
# 20  0.369731
# 21  0.355561

# %%
default_valid_results_base_and_most_corr_features
# Out:
#                Model     Type Dataset            Splitting  \
# 0   LinearRegression  default   valid  walk_forward_splits
# 1   LinearRegression  default   valid  walk_forward_splits
# 2   LinearRegression  default   valid  walk_forward_splits
# 3   LinearRegression  default   valid  walk_forward_splits
# 4   LinearRegression  default   valid  walk_forward_splits
# 5   LinearRegression  default   valid  walk_forward_splits
# 6   LinearRegression  default   valid  walk_forward_splits
# 7   LinearRegression  default   valid  walk_forward_splits
# 8   LinearRegression  default   valid  walk_forward_splits
# 9   LinearRegression  default   valid  walk_forward_splits
# 10  LinearRegression  default   valid  walk_forward_splits
# 11  LinearRegression  default   valid  walk_forward_splits
# 12  LinearRegression  default   valid  walk_forward_splits
# 13  LinearRegression  default   valid  walk_forward_splits
# 14  LinearRegression  default   valid  walk_forward_splits
# 15  LinearRegression  default   valid  walk_forward_splits
# 16  LinearRegression  default   valid  walk_forward_splits
# 17  LinearRegression  default   valid  walk_forward_splits
# 18  LinearRegression  default   valid  walk_forward_splits
# 19  LinearRegression  default   valid  walk_forward_splits
# 20  LinearRegression  default   valid  walk_forward_splits
# 21  LinearRegression  default   valid  walk_forward_splits
#
#                        Features  Splits Train / Validation       Parameters  \
# 0   base_and_most_corr_features       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_and_most_corr_features       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_and_most_corr_features       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_and_most_corr_features       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_and_most_corr_features       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_and_most_corr_features       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_and_most_corr_features       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_and_most_corr_features       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_and_most_corr_features       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_and_most_corr_features      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_and_most_corr_features      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_and_most_corr_features      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_and_most_corr_features      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_and_most_corr_features      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_and_most_corr_features      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_and_most_corr_features      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_and_most_corr_features      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_and_most_corr_features      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_and_most_corr_features      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_and_most_corr_features      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_and_most_corr_features      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_and_most_corr_features      22      (20000, 5000)  [100, 0.0, 0.0]
#
#          RMSE          MSE        MAE      MAPE        R2  Adjusted_R2  \
# 0    5.066869    25.673165   4.174077  0.000431  0.999934     0.999934
# 1   16.524886   273.071854  14.425821  0.001317  0.999232     0.999231
# 2    3.501878    12.263152   2.648493  0.000207  0.999996     0.999996
# 3    6.674011    44.542422   5.167971  0.000236  0.999998     0.999998
# 4   32.616080  1063.808683  26.151445  0.000633  0.999981     0.999981
# 5   36.323552  1319.400439  31.427627  0.000554  0.999930     0.999930
# 6   23.676308   560.567578  18.478149  0.000418  0.999993     0.999993
# 7   31.043815   963.718439  27.908732  0.000804  0.999887     0.999887
# 8   28.033908   785.899984  21.927642  0.000469  0.999908     0.999908
# 9   25.555276   653.072120  14.461111  0.000250  0.999989     0.999989
# 10  23.483409   551.470484  20.443120  0.000402  0.999979     0.999979
# 11  16.070598   258.264131  13.250067  0.000330  0.999963     0.999963
# 12  14.727536   216.900304  11.436935  0.000275  0.999971     0.999971
# 13  14.634810   214.177661  11.953661  0.000373  0.999989     0.999989
# 14   8.544112    73.001854   6.417279  0.000300  0.999982     0.999982
# 15   8.885697    78.955614   7.105937  0.000341  0.999973     0.999973
# 16   9.443581    89.181216   7.627020  0.000396  0.999914     0.999914
# 17   9.844231    96.908880   9.098773  0.000541  0.999184     0.999183
# 18   5.332711    28.437807   3.921999  0.000175  0.999995     0.999995
# 19   6.647795    44.193183   4.936393  0.000188  0.999995     0.999995
# 20  11.172864   124.832883   6.638873  0.000242  0.999857     0.999857
# 21   5.844311    34.155966   4.691637  0.000160  0.999988     0.999988
#
#         Time
# 0   0.327357
# 1   0.385321
# 2   0.325584
# 3   0.352011
# 4   0.335872
# 5   0.351151
# 6   0.340696
# 7   0.339713
# 8   0.348331
# 9   0.346121
# 10  0.342032
# 11  0.341676
# 12  0.371513
# 13  0.352445
# 14  0.363971
# 15  0.352712
# 16  0.348310
# 17  0.348723
# 18  0.350243
# 19  0.362933
# 20  0.369731
# 21  0.355561

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_train_results_base_and_least_corr_features, default_valid_results_base_and_least_corr_features, default_train_pred_base_and_least_corr_features, default_valid_pred_base_and_least_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:02<00:00,  2.37s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.55s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]

# %%
default_train_results_base_and_least_corr_features
# Out:
#                Model     Type Dataset            Splitting  \
# 0   LinearRegression  default   train  walk_forward_splits
# 1   LinearRegression  default   train  walk_forward_splits
# 2   LinearRegression  default   train  walk_forward_splits
# 3   LinearRegression  default   train  walk_forward_splits
# 4   LinearRegression  default   train  walk_forward_splits
# 5   LinearRegression  default   train  walk_forward_splits
# 6   LinearRegression  default   train  walk_forward_splits
# 7   LinearRegression  default   train  walk_forward_splits
# 8   LinearRegression  default   train  walk_forward_splits
# 9   LinearRegression  default   train  walk_forward_splits
# 10  LinearRegression  default   train  walk_forward_splits
# 11  LinearRegression  default   train  walk_forward_splits
# 12  LinearRegression  default   train  walk_forward_splits
# 13  LinearRegression  default   train  walk_forward_splits
# 14  LinearRegression  default   train  walk_forward_splits
# 15  LinearRegression  default   train  walk_forward_splits
# 16  LinearRegression  default   train  walk_forward_splits
# 17  LinearRegression  default   train  walk_forward_splits
# 18  LinearRegression  default   train  walk_forward_splits
# 19  LinearRegression  default   train  walk_forward_splits
# 20  LinearRegression  default   train  walk_forward_splits
# 21  LinearRegression  default   train  walk_forward_splits
#
#                         Features  Splits Train / Validation       Parameters  \
# 0   base_and_least_corr_features       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_and_least_corr_features       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_and_least_corr_features       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_and_least_corr_features       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_and_least_corr_features       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_and_least_corr_features       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_and_least_corr_features       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_and_least_corr_features       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_and_least_corr_features       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_and_least_corr_features      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_and_least_corr_features      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_and_least_corr_features      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_and_least_corr_features      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_and_least_corr_features      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_and_least_corr_features      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_and_least_corr_features      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_and_least_corr_features      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_and_least_corr_features      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_and_least_corr_features      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_and_least_corr_features      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_and_least_corr_features      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_and_least_corr_features      22      (20000, 5000)  [100, 0.0, 0.0]
#
#          RMSE          MSE        MAE      MAPE        R2  Adjusted_R2  \
# 0    2.404372     5.781006   1.771638  0.000222  0.999996     0.999996
# 1    4.239158    17.970458   3.081568  0.000374  0.999989     0.999989
# 2    4.511198    20.350910   3.265560  0.000380  0.999993     0.999993
# 3    2.424511     5.878255   1.743085  0.000165  0.999998     0.999998
# 4    7.986730    63.787854   5.541164  0.000383  0.999998     0.999998
# 5    9.215036    84.916880   5.365513  0.000219  0.999999     0.999999
# 6   33.097532  1095.446652  20.492264  0.000645  0.999996     0.999996
# 7   36.868850  1359.312072  21.069773  0.000523  0.999993     0.999993
# 8   36.653543  1343.482181  21.943948  0.000501  0.999987     0.999987
# 9   29.266226   856.511964  20.348322  0.000454  0.999990     0.999990
# 10  28.026462   785.482576  19.393254  0.000432  0.999992     0.999992
# 11  13.055512   170.446389   9.941622  0.000213  0.999998     0.999998
# 12  12.831281   164.641774   9.461246  0.000193  0.999997     0.999997
# 13  12.648417   159.982443   9.234414  0.000194  0.999998     0.999998
# 14  11.823946   139.805710   8.580601  0.000208  0.999998     0.999998
# 15  10.007542   100.150897   6.947280  0.000209  0.999999     0.999999
# 16   9.085638    82.548816   6.206168  0.000212  0.999999     0.999999
# 17   7.347685    53.988472   4.811585  0.000197  0.999999     0.999999
# 18   5.083704    25.844042   3.237703  0.000161  0.999996     0.999996
# 19   4.428656    19.612993   2.825892  0.000141  0.999997     0.999997
# 20   4.571820    20.901536   2.917819  0.000135  0.999999     0.999999
# 21   4.619005    21.335209   3.205308  0.000134  0.999999     0.999999
#
#         Time
# 0   0.363024
# 1   1.269894
# 2   0.380172
# 3   0.371039
# 4   0.360383
# 5   0.377893
# 6   0.391188
# 7   0.385530
# 8   0.381859
# 9   0.390714
# 10  0.409865
# 11  0.393627
# 12  0.411874
# 13  0.394118
# 14  0.402242
# 15  0.432280
# 16  0.416286
# 17  0.431877
# 18  0.406068
# 19  0.397267
# 20  0.405731
# 21  0.424512

# %%
default_valid_results_base_and_least_corr_features
# Out:
#                Model     Type Dataset            Splitting  \
# 0   LinearRegression  default   valid  walk_forward_splits
# 1   LinearRegression  default   valid  walk_forward_splits
# 2   LinearRegression  default   valid  walk_forward_splits
# 3   LinearRegression  default   valid  walk_forward_splits
# 4   LinearRegression  default   valid  walk_forward_splits
# 5   LinearRegression  default   valid  walk_forward_splits
# 6   LinearRegression  default   valid  walk_forward_splits
# 7   LinearRegression  default   valid  walk_forward_splits
# 8   LinearRegression  default   valid  walk_forward_splits
# 9   LinearRegression  default   valid  walk_forward_splits
# 10  LinearRegression  default   valid  walk_forward_splits
# 11  LinearRegression  default   valid  walk_forward_splits
# 12  LinearRegression  default   valid  walk_forward_splits
# 13  LinearRegression  default   valid  walk_forward_splits
# 14  LinearRegression  default   valid  walk_forward_splits
# 15  LinearRegression  default   valid  walk_forward_splits
# 16  LinearRegression  default   valid  walk_forward_splits
# 17  LinearRegression  default   valid  walk_forward_splits
# 18  LinearRegression  default   valid  walk_forward_splits
# 19  LinearRegression  default   valid  walk_forward_splits
# 20  LinearRegression  default   valid  walk_forward_splits
# 21  LinearRegression  default   valid  walk_forward_splits
#
#                         Features  Splits Train / Validation       Parameters  \
# 0   base_and_least_corr_features       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_and_least_corr_features       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_and_least_corr_features       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_and_least_corr_features       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_and_least_corr_features       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_and_least_corr_features       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_and_least_corr_features       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_and_least_corr_features       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_and_least_corr_features       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_and_least_corr_features      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_and_least_corr_features      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_and_least_corr_features      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_and_least_corr_features      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_and_least_corr_features      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_and_least_corr_features      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_and_least_corr_features      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_and_least_corr_features      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_and_least_corr_features      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_and_least_corr_features      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_and_least_corr_features      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_and_least_corr_features      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_and_least_corr_features      22      (20000, 5000)  [100, 0.0, 0.0]
#
#          RMSE          MSE        MAE      MAPE        R2  Adjusted_R2  \
# 0    2.791788     7.794079   2.211872  0.000228  0.999980     0.999980
# 1    4.197800    17.621527   3.237724  0.000291  0.999950     0.999950
# 2    5.307284    28.167260   4.239820  0.000330  0.999991     0.999991
# 3    6.550041    42.903044   5.067042  0.000232  0.999998     0.999998
# 4   51.312083  2632.929909  31.370695  0.000774  0.999952     0.999952
# 5   21.708625   471.264410  17.842189  0.000323  0.999975     0.999975
# 6   81.513730  6644.488246  64.418107  0.001523  0.999915     0.999915
# 7   33.357450  1112.719503  27.193701  0.000792  0.999870     0.999869
# 8   48.830129  2384.381478  38.410888  0.000829  0.999720     0.999720
# 9   66.688928  4447.413141  34.237775  0.000587  0.999925     0.999925
# 10  26.195713   686.215383  17.961882  0.000343  0.999974     0.999974
# 11  10.419510   108.566197   7.594904  0.000189  0.999984     0.999984
# 12  17.310233   299.644155  14.163635  0.000338  0.999960     0.999960
# 13  11.344315   128.693483   8.481933  0.000256  0.999993     0.999993
# 14  16.737856   280.155825  14.502541  0.000675  0.999931     0.999931
# 15   8.050617    64.812430   6.647577  0.000318  0.999978     0.999978
# 16   5.948409    35.383567   3.927627  0.000208  0.999966     0.999966
# 17   3.557027    12.652438   2.990304  0.000179  0.999893     0.999893
# 18  19.712897   388.598297  13.707686  0.000593  0.999926     0.999926
# 19  10.909637   119.020175   9.080781  0.000338  0.999987     0.999987
# 20  13.254828   175.690478   8.792063  0.000320  0.999798     0.999798
# 21   8.218087    67.536960   7.129985  0.000241  0.999976     0.999976
#
#         Time
# 0   0.363024
# 1   1.269894
# 2   0.380172
# 3   0.371039
# 4   0.360383
# 5   0.377893
# 6   0.391188
# 7   0.385530
# 8   0.381859
# 9   0.390714
# 10  0.409865
# 11  0.393627
# 12  0.411874
# 13  0.394118
# 14  0.402242
# 15  0.432280
# 16  0.416286
# 17  0.431877
# 18  0.406068
# 19  0.397267
# 20  0.405731
# 21  0.424512

# %% [markdown]
# ### With normalization

# %%
# Define model and features type
MODEL_TYPE = "default_norm"
FEATURES_NORMALIZATION = True

# %%
# Choose base features
CHOSEN_FEATURES = BASE_FEATURES
CHOSEN_FEATURES_LABEL = BASE_FEATURES_LABEL

# %%
# Make predictions by using base features
default_norm_train_results_base_features, default_norm_valid_results_base_features, default_norm_train_pred_base_features, default_norm_valid_pred_base_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]

# %%
default_norm_train_results_base_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   train  walk_forward_splits
# 1   LinearRegression  default_norm   train  walk_forward_splits
# 2   LinearRegression  default_norm   train  walk_forward_splits
# 3   LinearRegression  default_norm   train  walk_forward_splits
# 4   LinearRegression  default_norm   train  walk_forward_splits
# 5   LinearRegression  default_norm   train  walk_forward_splits
# 6   LinearRegression  default_norm   train  walk_forward_splits
# 7   LinearRegression  default_norm   train  walk_forward_splits
# 8   LinearRegression  default_norm   train  walk_forward_splits
# 9   LinearRegression  default_norm   train  walk_forward_splits
# 10  LinearRegression  default_norm   train  walk_forward_splits
# 11  LinearRegression  default_norm   train  walk_forward_splits
# 12  LinearRegression  default_norm   train  walk_forward_splits
# 13  LinearRegression  default_norm   train  walk_forward_splits
# 14  LinearRegression  default_norm   train  walk_forward_splits
# 15  LinearRegression  default_norm   train  walk_forward_splits
# 16  LinearRegression  default_norm   train  walk_forward_splits
# 17  LinearRegression  default_norm   train  walk_forward_splits
# 18  LinearRegression  default_norm   train  walk_forward_splits
# 19  LinearRegression  default_norm   train  walk_forward_splits
# 20  LinearRegression  default_norm   train  walk_forward_splits
# 21  LinearRegression  default_norm   train  walk_forward_splits
#
#               Features  Splits Train / Validation       Parameters  \
# 0   base_features_norm       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_features_norm       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_features_norm       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_features_norm       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_features_norm       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_features_norm       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_features_norm       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_features_norm       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_features_norm       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_features_norm      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_features_norm      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_features_norm      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_features_norm      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_features_norm      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_features_norm      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_features_norm      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_features_norm      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_features_norm      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_features_norm      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_features_norm      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_features_norm      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_features_norm      22      (20000, 5000)  [100, 0.0, 0.0]
#
#            RMSE           MSE          MAE      MAPE        R2  Adjusted_R2  \
# 0    172.449465  2.973882e+04   125.967961  0.016061  0.980736     0.980732
# 1    199.359256  3.974411e+04   137.223589  0.016516  0.975955     0.975950
# 2    339.923359  1.155479e+05   281.786687  0.031511  0.960132     0.960124
# 3    383.592607  1.471433e+05   243.133474  0.023506  0.952463     0.952454
# 4   1539.228214  2.369223e+06  1178.304354  0.086934  0.912996     0.912979
# 5   4300.165140  1.849142e+07  3350.967567  0.170925  0.882848     0.882825
# 6   5531.850165  3.060137e+07  4603.175821  0.201905  0.900913     0.900893
# 7   3601.173407  1.296845e+07  2975.002965  0.089996  0.935471     0.935458
# 8   1313.048981  1.724098e+06  1061.084232  0.024961  0.982816     0.982812
# 9   1400.508285  1.961423e+06  1163.720643  0.025762  0.976708     0.976703
# 10  1877.216842  3.523943e+06  1565.651110  0.034444  0.964421     0.964414
# 11  1992.267912  3.969131e+06  1759.808006  0.038207  0.957508     0.957499
# 12  1340.413246  1.796708e+06  1101.583329  0.023086  0.971436     0.971431
# 13  1739.545628  3.026019e+06  1233.068646  0.026763  0.957867     0.957859
# 14  1731.257022  2.997251e+06  1341.608950  0.033285  0.950738     0.950729
# 15  1617.033363  2.614797e+06  1336.935052  0.043807  0.964967     0.964960
# 16  1644.454946  2.704232e+06  1343.338958  0.048811  0.967490     0.967484
# 17  1233.217300  1.520825e+06   946.973223  0.038284  0.958447     0.958439
# 18   343.979867  1.183221e+05   248.503348  0.012300  0.979856     0.979852
# 19   254.237185  6.463655e+04   203.744280  0.010186  0.989904     0.989902
# 20  1826.217183  3.335069e+06  1234.260988  0.061131  0.793767     0.793725
# 21   640.584941  4.103491e+05   520.687359  0.022956  0.981227     0.981224
#
#         Time
# 0   0.310572
# 1   0.265240
# 2   0.260122
# 3   0.268987
# 4   0.269374
# 5   0.274162
# 6   0.276675
# 7   0.288966
# 8   0.287053
# 9   0.278277
# 10  0.286582
# 11  0.285628
# 12  0.277375
# 13  0.295214
# 14  0.286058
# 15  0.290624
# 16  0.289136
# 17  0.289557
# 18  0.296996
# 19  0.294964
# 20  0.287775
# 21  0.292032

# %%
default_norm_valid_results_base_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   valid  walk_forward_splits
# 1   LinearRegression  default_norm   valid  walk_forward_splits
# 2   LinearRegression  default_norm   valid  walk_forward_splits
# 3   LinearRegression  default_norm   valid  walk_forward_splits
# 4   LinearRegression  default_norm   valid  walk_forward_splits
# 5   LinearRegression  default_norm   valid  walk_forward_splits
# 6   LinearRegression  default_norm   valid  walk_forward_splits
# 7   LinearRegression  default_norm   valid  walk_forward_splits
# 8   LinearRegression  default_norm   valid  walk_forward_splits
# 9   LinearRegression  default_norm   valid  walk_forward_splits
# 10  LinearRegression  default_norm   valid  walk_forward_splits
# 11  LinearRegression  default_norm   valid  walk_forward_splits
# 12  LinearRegression  default_norm   valid  walk_forward_splits
# 13  LinearRegression  default_norm   valid  walk_forward_splits
# 14  LinearRegression  default_norm   valid  walk_forward_splits
# 15  LinearRegression  default_norm   valid  walk_forward_splits
# 16  LinearRegression  default_norm   valid  walk_forward_splits
# 17  LinearRegression  default_norm   valid  walk_forward_splits
# 18  LinearRegression  default_norm   valid  walk_forward_splits
# 19  LinearRegression  default_norm   valid  walk_forward_splits
# 20  LinearRegression  default_norm   valid  walk_forward_splits
# 21  LinearRegression  default_norm   valid  walk_forward_splits
#
#               Features  Splits Train / Validation       Parameters  \
# 0   base_features_norm       1      (20000, 5000)  [100, 0.0, 0.0]
# 1   base_features_norm       2      (20000, 5000)  [100, 0.0, 0.0]
# 2   base_features_norm       3      (20000, 5000)  [100, 0.0, 0.0]
# 3   base_features_norm       4      (20000, 5000)  [100, 0.0, 0.0]
# 4   base_features_norm       5      (20000, 5000)  [100, 0.0, 0.0]
# 5   base_features_norm       6      (20000, 5000)  [100, 0.0, 0.0]
# 6   base_features_norm       7      (20000, 5000)  [100, 0.0, 0.0]
# 7   base_features_norm       8      (20000, 5000)  [100, 0.0, 0.0]
# 8   base_features_norm       9      (20000, 5000)  [100, 0.0, 0.0]
# 9   base_features_norm      10      (20000, 5000)  [100, 0.0, 0.0]
# 10  base_features_norm      11      (20000, 5000)  [100, 0.0, 0.0]
# 11  base_features_norm      12      (20000, 5000)  [100, 0.0, 0.0]
# 12  base_features_norm      13      (20000, 5000)  [100, 0.0, 0.0]
# 13  base_features_norm      14      (20000, 5000)  [100, 0.0, 0.0]
# 14  base_features_norm      15      (20000, 5000)  [100, 0.0, 0.0]
# 15  base_features_norm      16      (20000, 5000)  [100, 0.0, 0.0]
# 16  base_features_norm      17      (20000, 5000)  [100, 0.0, 0.0]
# 17  base_features_norm      18      (20000, 5000)  [100, 0.0, 0.0]
# 18  base_features_norm      19      (20000, 5000)  [100, 0.0, 0.0]
# 19  base_features_norm      20      (20000, 5000)  [100, 0.0, 0.0]
# 20  base_features_norm      21      (20000, 5000)  [100, 0.0, 0.0]
# 21  base_features_norm      22      (20000, 5000)  [100, 0.0, 0.0]
#
#             RMSE           MSE           MAE      MAPE          R2  \
# 0     264.307943  6.985869e+04    158.822298  0.015516    0.821762
# 1     797.245095  6.355997e+05    741.327145  0.064909   -0.787832
# 2    1430.948083  2.047612e+06   1065.667243  0.076648    0.370242
# 3    6201.314710  3.845630e+07   5179.856522  0.222014   -0.919125
# 4   15598.618764  2.433169e+08  13763.119202  0.319465   -3.452407
# 5   15616.929439  2.438885e+08  15087.307380  0.265730  -11.902574
# 6    5155.734711  2.658160e+07   4321.196705  0.096414    0.658871
# 7    7218.817557  5.211133e+07   6592.658222  0.193099   -5.107760
# 8    2169.076227  4.704892e+06   2144.720314  0.046414    0.447885
# 9    3506.617620  1.229637e+07   3066.896252  0.051809    0.792092
# 10   1726.120738  2.979493e+06   1555.710594  0.030084    0.887990
# 11   1449.664417  2.101527e+06   1298.581026  0.031237    0.699577
# 12    921.091845  8.484102e+05    784.071535  0.019097    0.885735
# 13  10711.461203  1.147354e+08   7179.169800  0.238146   -4.887563
# 14   9730.029002  9.467346e+07   7428.461212  0.350577  -22.351466
# 15   1448.070397  2.096908e+06   1257.837751  0.058501    0.286242
# 16   2393.759939  5.730087e+06   1748.325821  0.094053   -4.520747
# 17   3943.925775  1.555455e+07   3913.236705  0.233925 -130.039008
# 18    366.647634  1.344305e+05    297.093025  0.013110    0.974301
# 19   2058.457795  4.237248e+06   1690.926005  0.059859    0.523747
# 20   1475.082026  2.175867e+06   1143.676609  0.041183   -1.498701
# 21   2086.218487  4.352308e+06   1732.181259  0.057722   -0.533628
#
#     Adjusted_R2      Time
# 0      0.821619  0.310572
# 1     -0.789264  0.265240
# 2      0.369737  0.260122
# 3     -0.920662  0.268987
# 4     -3.455973  0.269374
# 5    -11.912906  0.274162
# 6      0.658598  0.276675
# 7     -5.112651  0.288966
# 8      0.447443  0.287053
# 9      0.791925  0.278277
# 10     0.887901  0.286582
# 11     0.699337  0.285628
# 12     0.885643  0.277375
# 13    -4.892278  0.295214
# 14   -22.370166  0.286058
# 15     0.285670  0.290624
# 16    -4.525168  0.289136
# 17  -130.143944  0.289557
# 18     0.974280  0.296996
# 19     0.523365  0.294964
# 20    -1.500702  0.287775
# 21    -0.534856  0.292032

# %%
# Choose base and most additional correlated features
CHOSEN_FEATURES = BASE_AND_MOST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_MOST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and most additional correlated features
default_norm_train_results_base_and_most_corr_features, default_norm_valid_results_base_and_most_corr_features, default_norm_train_pred_base_and_most_corr_features, default_norm_valid_pred_base_and_most_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]

# %%
default_norm_train_results_base_and_most_corr_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   train  walk_forward_splits
# 1   LinearRegression  default_norm   train  walk_forward_splits
# 2   LinearRegression  default_norm   train  walk_forward_splits
# 3   LinearRegression  default_norm   train  walk_forward_splits
# 4   LinearRegression  default_norm   train  walk_forward_splits
# 5   LinearRegression  default_norm   train  walk_forward_splits
# 6   LinearRegression  default_norm   train  walk_forward_splits
# 7   LinearRegression  default_norm   train  walk_forward_splits
# 8   LinearRegression  default_norm   train  walk_forward_splits
# 9   LinearRegression  default_norm   train  walk_forward_splits
# 10  LinearRegression  default_norm   train  walk_forward_splits
# 11  LinearRegression  default_norm   train  walk_forward_splits
# 12  LinearRegression  default_norm   train  walk_forward_splits
# 13  LinearRegression  default_norm   train  walk_forward_splits
# 14  LinearRegression  default_norm   train  walk_forward_splits
# 15  LinearRegression  default_norm   train  walk_forward_splits
# 16  LinearRegression  default_norm   train  walk_forward_splits
# 17  LinearRegression  default_norm   train  walk_forward_splits
# 18  LinearRegression  default_norm   train  walk_forward_splits
# 19  LinearRegression  default_norm   train  walk_forward_splits
# 20  LinearRegression  default_norm   train  walk_forward_splits
# 21  LinearRegression  default_norm   train  walk_forward_splits
#
#                             Features  Splits Train / Validation  \
# 0   base_and_most_corr_features_norm       1      (20000, 5000)
# 1   base_and_most_corr_features_norm       2      (20000, 5000)
# 2   base_and_most_corr_features_norm       3      (20000, 5000)
# 3   base_and_most_corr_features_norm       4      (20000, 5000)
# 4   base_and_most_corr_features_norm       5      (20000, 5000)
# 5   base_and_most_corr_features_norm       6      (20000, 5000)
# 6   base_and_most_corr_features_norm       7      (20000, 5000)
# 7   base_and_most_corr_features_norm       8      (20000, 5000)
# 8   base_and_most_corr_features_norm       9      (20000, 5000)
# 9   base_and_most_corr_features_norm      10      (20000, 5000)
# 10  base_and_most_corr_features_norm      11      (20000, 5000)
# 11  base_and_most_corr_features_norm      12      (20000, 5000)
# 12  base_and_most_corr_features_norm      13      (20000, 5000)
# 13  base_and_most_corr_features_norm      14      (20000, 5000)
# 14  base_and_most_corr_features_norm      15      (20000, 5000)
# 15  base_and_most_corr_features_norm      16      (20000, 5000)
# 16  base_and_most_corr_features_norm      17      (20000, 5000)
# 17  base_and_most_corr_features_norm      18      (20000, 5000)
# 18  base_and_most_corr_features_norm      19      (20000, 5000)
# 19  base_and_most_corr_features_norm      20      (20000, 5000)
# 20  base_and_most_corr_features_norm      21      (20000, 5000)
# 21  base_and_most_corr_features_norm      22      (20000, 5000)
#
#          Parameters         RMSE           MSE          MAE      MAPE  \
# 0   [100, 0.0, 0.0]   141.567250  2.004129e+04   104.019283  0.013299
# 1   [100, 0.0, 0.0]   160.588821  2.578877e+04   119.642965  0.014321
# 2   [100, 0.0, 0.0]   234.181954  5.484119e+04   185.870612  0.020492
# 3   [100, 0.0, 0.0]   288.198946  8.305863e+04   198.890697  0.019033
# 4   [100, 0.0, 0.0]   767.339216  5.888095e+05   578.971967  0.042743
# 5   [100, 0.0, 0.0]  3072.492074  9.440208e+06  2459.702885  0.131297
# 6   [100, 0.0, 0.0]  3081.815639  9.497588e+06  2564.857466  0.105676
# 7   [100, 0.0, 0.0]  2706.646835  7.325937e+06  2250.175187  0.066399
# 8   [100, 0.0, 0.0]  1303.031170  1.697890e+06  1079.839392  0.025299
# 9   [100, 0.0, 0.0]  1094.476554  1.197879e+06   847.603451  0.019704
# 10  [100, 0.0, 0.0]  1077.081734  1.160105e+06   845.941633  0.019857
# 11  [100, 0.0, 0.0]  1159.232296  1.343820e+06   920.780776  0.020592
# 12  [100, 0.0, 0.0]   856.045953  7.328147e+05   649.109651  0.013575
# 13  [100, 0.0, 0.0]   955.823875  9.135993e+05   753.286592  0.016146
# 14  [100, 0.0, 0.0]   814.527551  6.634551e+05   644.220734  0.016270
# 15  [100, 0.0, 0.0]  1472.512967  2.168294e+06  1243.988006  0.039604
# 16  [100, 0.0, 0.0]  1284.750548  1.650584e+06  1042.984932  0.036003
# 17  [100, 0.0, 0.0]   717.323898  5.145536e+05   546.098760  0.022016
# 18  [100, 0.0, 0.0]   267.667810  7.164606e+04   177.557129  0.008946
# 19  [100, 0.0, 0.0]   180.379609  3.253680e+04   132.613334  0.006472
# 20  [100, 0.0, 0.0]   474.771551  2.254080e+05   368.320945  0.017377
# 21  [100, 0.0, 0.0]   439.926930  1.935357e+05   365.679958  0.016796
#
#           R2  Adjusted_R2      Time
# 0   0.987018     0.987015  0.302403
# 1   0.984398     0.984395  0.317935
# 2   0.981078     0.981074  0.302867
# 3   0.973167     0.973161  0.301665
# 4   0.978378     0.978373  0.317937
# 5   0.940192     0.940180  0.315096
# 6   0.969247     0.969241  0.324187
# 7   0.963547     0.963540  0.314900
# 8   0.983077     0.983074  0.335481
# 9   0.985775     0.985772  0.321324
# 10  0.988287     0.988285  0.321493
# 11  0.985613     0.985611  0.332107
# 12  0.988350     0.988348  0.332909
# 13  0.987279     0.987277  0.340065
# 14  0.989096     0.989094  0.347044
# 15  0.970950     0.970944  0.329399
# 16  0.980157     0.980153  0.343496
# 17  0.985941     0.985938  0.341100
# 18  0.987802     0.987800  0.336584
# 19  0.994918     0.994917  0.336034
# 20  0.986061     0.986058  0.338103
# 21  0.991146     0.991144  0.334032

# %%
default_norm_valid_results_base_and_most_corr_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   valid  walk_forward_splits
# 1   LinearRegression  default_norm   valid  walk_forward_splits
# 2   LinearRegression  default_norm   valid  walk_forward_splits
# 3   LinearRegression  default_norm   valid  walk_forward_splits
# 4   LinearRegression  default_norm   valid  walk_forward_splits
# 5   LinearRegression  default_norm   valid  walk_forward_splits
# 6   LinearRegression  default_norm   valid  walk_forward_splits
# 7   LinearRegression  default_norm   valid  walk_forward_splits
# 8   LinearRegression  default_norm   valid  walk_forward_splits
# 9   LinearRegression  default_norm   valid  walk_forward_splits
# 10  LinearRegression  default_norm   valid  walk_forward_splits
# 11  LinearRegression  default_norm   valid  walk_forward_splits
# 12  LinearRegression  default_norm   valid  walk_forward_splits
# 13  LinearRegression  default_norm   valid  walk_forward_splits
# 14  LinearRegression  default_norm   valid  walk_forward_splits
# 15  LinearRegression  default_norm   valid  walk_forward_splits
# 16  LinearRegression  default_norm   valid  walk_forward_splits
# 17  LinearRegression  default_norm   valid  walk_forward_splits
# 18  LinearRegression  default_norm   valid  walk_forward_splits
# 19  LinearRegression  default_norm   valid  walk_forward_splits
# 20  LinearRegression  default_norm   valid  walk_forward_splits
# 21  LinearRegression  default_norm   valid  walk_forward_splits
#
#                             Features  Splits Train / Validation  \
# 0   base_and_most_corr_features_norm       1      (20000, 5000)
# 1   base_and_most_corr_features_norm       2      (20000, 5000)
# 2   base_and_most_corr_features_norm       3      (20000, 5000)
# 3   base_and_most_corr_features_norm       4      (20000, 5000)
# 4   base_and_most_corr_features_norm       5      (20000, 5000)
# 5   base_and_most_corr_features_norm       6      (20000, 5000)
# 6   base_and_most_corr_features_norm       7      (20000, 5000)
# 7   base_and_most_corr_features_norm       8      (20000, 5000)
# 8   base_and_most_corr_features_norm       9      (20000, 5000)
# 9   base_and_most_corr_features_norm      10      (20000, 5000)
# 10  base_and_most_corr_features_norm      11      (20000, 5000)
# 11  base_and_most_corr_features_norm      12      (20000, 5000)
# 12  base_and_most_corr_features_norm      13      (20000, 5000)
# 13  base_and_most_corr_features_norm      14      (20000, 5000)
# 14  base_and_most_corr_features_norm      15      (20000, 5000)
# 15  base_and_most_corr_features_norm      16      (20000, 5000)
# 16  base_and_most_corr_features_norm      17      (20000, 5000)
# 17  base_and_most_corr_features_norm      18      (20000, 5000)
# 18  base_and_most_corr_features_norm      19      (20000, 5000)
# 19  base_and_most_corr_features_norm      20      (20000, 5000)
# 20  base_and_most_corr_features_norm      21      (20000, 5000)
# 21  base_and_most_corr_features_norm      22      (20000, 5000)
#
#          Parameters          RMSE           MSE           MAE      MAPE  \
# 0   [100, 0.0, 0.0]    367.699700  1.352031e+05    348.666542  0.037065
# 1   [100, 0.0, 0.0]    648.688850  4.207972e+05    587.932183  0.051294
# 2   [100, 0.0, 0.0]   1310.927911  1.718532e+06    903.251923  0.063510
# 3   [100, 0.0, 0.0]   6680.537409  4.462958e+07   5471.637005  0.232418
# 4   [100, 0.0, 0.0]  12991.859489  1.687884e+08  11033.910516  0.251353
# 5   [100, 0.0, 0.0]   8229.028267  6.771691e+07   7530.807177  0.131103
# 6   [100, 0.0, 0.0]  35447.012833  1.256491e+09  27481.852300  0.695214
# 7   [100, 0.0, 0.0]  35118.036412  1.233276e+09  30034.089234  0.870320
# 8   [100, 0.0, 0.0]   1852.292055  3.430986e+06   1721.438745  0.037360
# 9   [100, 0.0, 0.0]   1914.271168  3.664434e+06   1311.146254  0.022683
# 10  [100, 0.0, 0.0]   4526.903362  2.049285e+07   4354.579622  0.086041
# 11  [100, 0.0, 0.0]   3346.011162  1.119579e+07   2978.483722  0.073080
# 12  [100, 0.0, 0.0]   1246.023681  1.552575e+06   1000.907613  0.024573
# 13  [100, 0.0, 0.0]   6725.489429  4.523221e+07   5607.474042  0.183556
# 14  [100, 0.0, 0.0]   6128.394431  3.755722e+07   5284.020875  0.250361
# 15  [100, 0.0, 0.0]   1838.511999  3.380126e+06   1593.730505  0.075972
# 16  [100, 0.0, 0.0]   5692.611384  3.240582e+07   4882.309681  0.249152
# 17  [100, 0.0, 0.0]   4550.353141  2.070571e+07   3878.472625  0.230183
# 18  [100, 0.0, 0.0]    983.017267  9.663229e+05    910.324589  0.040746
# 19  [100, 0.0, 0.0]   1439.106630  2.071028e+06   1270.626171  0.046653
# 20  [100, 0.0, 0.0]   3441.850636  1.184634e+07   3136.331069  0.115024
# 21  [100, 0.0, 0.0]   2088.006761  4.359772e+06   1851.082546  0.061571
#
#             R2  Adjusted_R2      Time
# 0     0.655041     0.654765  0.302403
# 1    -0.183630    -0.184577  0.317935
# 2     0.471453     0.471029  0.302867
# 3    -1.227196    -1.228980  0.301665
# 4    -2.088625    -2.091099  0.317937
# 5    -2.582467    -2.585336  0.315096
# 6   -15.124880   -15.137793  0.324187
# 7  -143.547392  -143.663146  0.314900
# 8     0.597377     0.597054  0.335481
# 9     0.938041     0.937992  0.321324
# 10    0.229601     0.228984  0.321493
# 11   -0.600489    -0.601770  0.332107
# 12    0.790897     0.790729  0.332909
# 13   -1.321058    -1.322916  0.340065
# 14   -8.263589    -8.271008  0.347044
# 15   -0.150547    -0.151469  0.329399
# 16  -30.221929   -30.246932  0.343496
# 17 -173.434882  -173.574570  0.341100
# 18    0.815265     0.815118  0.336584
# 19    0.767223     0.767037  0.336034
# 20  -12.603980   -12.614874  0.338103
# 21   -0.536258    -0.537489  0.334032

# %%
# Choose base and least additional correlated features
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %%
# Make predictions by using base and least additional correlated features
default_norm_train_results_base_and_least_corr_features, default_norm_valid_results_base_and_least_corr_features, default_norm_train_pred_base_and_least_corr_features, default_norm_valid_pred_base_and_least_corr_features = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.55s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]

# %%
default_norm_train_results_base_and_least_corr_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   train  walk_forward_splits
# 1   LinearRegression  default_norm   train  walk_forward_splits
# 2   LinearRegression  default_norm   train  walk_forward_splits
# 3   LinearRegression  default_norm   train  walk_forward_splits
# 4   LinearRegression  default_norm   train  walk_forward_splits
# 5   LinearRegression  default_norm   train  walk_forward_splits
# 6   LinearRegression  default_norm   train  walk_forward_splits
# 7   LinearRegression  default_norm   train  walk_forward_splits
# 8   LinearRegression  default_norm   train  walk_forward_splits
# 9   LinearRegression  default_norm   train  walk_forward_splits
# 10  LinearRegression  default_norm   train  walk_forward_splits
# 11  LinearRegression  default_norm   train  walk_forward_splits
# 12  LinearRegression  default_norm   train  walk_forward_splits
# 13  LinearRegression  default_norm   train  walk_forward_splits
# 14  LinearRegression  default_norm   train  walk_forward_splits
# 15  LinearRegression  default_norm   train  walk_forward_splits
# 16  LinearRegression  default_norm   train  walk_forward_splits
# 17  LinearRegression  default_norm   train  walk_forward_splits
# 18  LinearRegression  default_norm   train  walk_forward_splits
# 19  LinearRegression  default_norm   train  walk_forward_splits
# 20  LinearRegression  default_norm   train  walk_forward_splits
# 21  LinearRegression  default_norm   train  walk_forward_splits
#
#                              Features  Splits Train / Validation  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)
# 1   base_and_least_corr_features_norm       2      (20000, 5000)
# 2   base_and_least_corr_features_norm       3      (20000, 5000)
# 3   base_and_least_corr_features_norm       4      (20000, 5000)
# 4   base_and_least_corr_features_norm       5      (20000, 5000)
# 5   base_and_least_corr_features_norm       6      (20000, 5000)
# 6   base_and_least_corr_features_norm       7      (20000, 5000)
# 7   base_and_least_corr_features_norm       8      (20000, 5000)
# 8   base_and_least_corr_features_norm       9      (20000, 5000)
# 9   base_and_least_corr_features_norm      10      (20000, 5000)
# 10  base_and_least_corr_features_norm      11      (20000, 5000)
# 11  base_and_least_corr_features_norm      12      (20000, 5000)
# 12  base_and_least_corr_features_norm      13      (20000, 5000)
# 13  base_and_least_corr_features_norm      14      (20000, 5000)
# 14  base_and_least_corr_features_norm      15      (20000, 5000)
# 15  base_and_least_corr_features_norm      16      (20000, 5000)
# 16  base_and_least_corr_features_norm      17      (20000, 5000)
# 17  base_and_least_corr_features_norm      18      (20000, 5000)
# 18  base_and_least_corr_features_norm      19      (20000, 5000)
# 19  base_and_least_corr_features_norm      20      (20000, 5000)
# 20  base_and_least_corr_features_norm      21      (20000, 5000)
# 21  base_and_least_corr_features_norm      22      (20000, 5000)
#
#          Parameters        RMSE            MSE         MAE      MAPE  \
# 0   [100, 0.0, 0.0]   46.775858    2187.980904   36.789900  0.004593
# 1   [100, 0.0, 0.0]   58.359949    3405.883590   44.785131  0.005310
# 2   [100, 0.0, 0.0]   85.924301    7382.985433   68.274485  0.007807
# 3   [100, 0.0, 0.0]   79.020024    6244.164114   59.178084  0.005548
# 4   [100, 0.0, 0.0]  101.742433   10351.522705   79.533996  0.006228
# 5   [100, 0.0, 0.0]  265.644271   70566.878601  199.327453  0.010041
# 6   [100, 0.0, 0.0]  423.833075  179634.475354  345.303284  0.012438
# 7   [100, 0.0, 0.0]  464.127898  215414.705768  377.009728  0.010959
# 8   [100, 0.0, 0.0]  686.845447  471756.668342  518.619391  0.012263
# 9   [100, 0.0, 0.0]  734.188296  539032.453459  581.739895  0.013189
# 10  [100, 0.0, 0.0]  742.580631  551425.993906  600.856941  0.013678
# 11  [100, 0.0, 0.0]  832.373863  692846.247036  659.198144  0.014315
# 12  [100, 0.0, 0.0]  447.053753  199857.058405  332.875577  0.006869
# 13  [100, 0.0, 0.0]  221.065892   48870.128445  155.644957  0.003235
# 14  [100, 0.0, 0.0]  155.320585   24124.484081  111.454390  0.002820
# 15  [100, 0.0, 0.0]  118.842838   14123.620133  100.323370  0.003188
# 16  [100, 0.0, 0.0]  136.741773   18698.312414  107.597511  0.003686
# 17  [100, 0.0, 0.0]  121.752732   14823.727644   89.759958  0.003771
# 18  [100, 0.0, 0.0]   57.951383    3358.362775   41.543932  0.002090
# 19  [100, 0.0, 0.0]   54.796135    3002.616384   40.042592  0.001997
# 20  [100, 0.0, 0.0]  185.258129   34320.574261  130.376960  0.006077
# 21  [100, 0.0, 0.0]  137.680814   18956.006666  108.856047  0.004744
#
#           R2  Adjusted_R2      Time
# 0   0.998583     0.998582  0.348100
# 1   0.997939     0.997939  0.332849
# 2   0.997453     0.997452  0.345104
# 3   0.997983     0.997982  0.351021
# 4   0.999620     0.999620  0.354113
# 5   0.999553     0.999553  0.391699
# 6   0.999418     0.999418  0.389941
# 7   0.998928     0.998928  0.385397
# 8   0.995298     0.995297  0.373013
# 9   0.993599     0.993598  0.366832
# 10  0.994433     0.994431  0.403560
# 11  0.992583     0.992581  0.404772
# 12  0.996823     0.996822  0.408195
# 13  0.999320     0.999319  0.406038
# 14  0.999604     0.999603  0.387498
# 15  0.999811     0.999811  0.398719
# 16  0.999775     0.999775  0.386976
# 17  0.999595     0.999595  0.386044
# 18  0.999428     0.999428  0.391201
# 19  0.999531     0.999531  0.388581
# 20  0.997878     0.997877  0.382039
# 21  0.999133     0.999133  0.383594

# %%
default_norm_valid_results_base_and_least_corr_features
# Out:
#                Model          Type Dataset            Splitting  \
# 0   LinearRegression  default_norm   valid  walk_forward_splits
# 1   LinearRegression  default_norm   valid  walk_forward_splits
# 2   LinearRegression  default_norm   valid  walk_forward_splits
# 3   LinearRegression  default_norm   valid  walk_forward_splits
# 4   LinearRegression  default_norm   valid  walk_forward_splits
# 5   LinearRegression  default_norm   valid  walk_forward_splits
# 6   LinearRegression  default_norm   valid  walk_forward_splits
# 7   LinearRegression  default_norm   valid  walk_forward_splits
# 8   LinearRegression  default_norm   valid  walk_forward_splits
# 9   LinearRegression  default_norm   valid  walk_forward_splits
# 10  LinearRegression  default_norm   valid  walk_forward_splits
# 11  LinearRegression  default_norm   valid  walk_forward_splits
# 12  LinearRegression  default_norm   valid  walk_forward_splits
# 13  LinearRegression  default_norm   valid  walk_forward_splits
# 14  LinearRegression  default_norm   valid  walk_forward_splits
# 15  LinearRegression  default_norm   valid  walk_forward_splits
# 16  LinearRegression  default_norm   valid  walk_forward_splits
# 17  LinearRegression  default_norm   valid  walk_forward_splits
# 18  LinearRegression  default_norm   valid  walk_forward_splits
# 19  LinearRegression  default_norm   valid  walk_forward_splits
# 20  LinearRegression  default_norm   valid  walk_forward_splits
# 21  LinearRegression  default_norm   valid  walk_forward_splits
#
#                              Features  Splits Train / Validation  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)
# 1   base_and_least_corr_features_norm       2      (20000, 5000)
# 2   base_and_least_corr_features_norm       3      (20000, 5000)
# 3   base_and_least_corr_features_norm       4      (20000, 5000)
# 4   base_and_least_corr_features_norm       5      (20000, 5000)
# 5   base_and_least_corr_features_norm       6      (20000, 5000)
# 6   base_and_least_corr_features_norm       7      (20000, 5000)
# 7   base_and_least_corr_features_norm       8      (20000, 5000)
# 8   base_and_least_corr_features_norm       9      (20000, 5000)
# 9   base_and_least_corr_features_norm      10      (20000, 5000)
# 10  base_and_least_corr_features_norm      11      (20000, 5000)
# 11  base_and_least_corr_features_norm      12      (20000, 5000)
# 12  base_and_least_corr_features_norm      13      (20000, 5000)
# 13  base_and_least_corr_features_norm      14      (20000, 5000)
# 14  base_and_least_corr_features_norm      15      (20000, 5000)
# 15  base_and_least_corr_features_norm      16      (20000, 5000)
# 16  base_and_least_corr_features_norm      17      (20000, 5000)
# 17  base_and_least_corr_features_norm      18      (20000, 5000)
# 18  base_and_least_corr_features_norm      19      (20000, 5000)
# 19  base_and_least_corr_features_norm      20      (20000, 5000)
# 20  base_and_least_corr_features_norm      21      (20000, 5000)
# 21  base_and_least_corr_features_norm      22      (20000, 5000)
#
#          Parameters         RMSE           MSE          MAE      MAPE  \
# 0   [100, 0.0, 0.0]   151.429406  2.293087e+04   104.902314  0.010443
# 1   [100, 0.0, 0.0]   264.081218  6.973889e+04   234.853585  0.020507
# 2   [100, 0.0, 0.0]   449.883773  2.023954e+05   372.570671  0.028047
# 3   [100, 0.0, 0.0]  1554.349606  2.416003e+06  1144.631145  0.046924
# 4   [100, 0.0, 0.0]  2550.349753  6.504284e+06  2113.359180  0.047900
# 5   [100, 0.0, 0.0]  1127.199169  1.270578e+06   908.863665  0.016300
# 6   [100, 0.0, 0.0]  5392.702134  2.908124e+07  4546.555216  0.106833
# 7   [100, 0.0, 0.0]  4834.891534  2.337618e+07  4097.027458  0.121293
# 8   [100, 0.0, 0.0]  2212.921675  4.897022e+06  2128.964333  0.045467
# 9   [100, 0.0, 0.0]  3532.458849  1.247827e+07  2994.222933  0.048972
# 10  [100, 0.0, 0.0]  3565.620346  1.271365e+07  3360.576260  0.066749
# 11  [100, 0.0, 0.0]  3080.291418  9.488195e+06  2605.315941  0.064605
# 12  [100, 0.0, 0.0]   367.592978  1.351246e+05   292.457693  0.007004
# 13  [100, 0.0, 0.0]   394.079775  1.552989e+05   299.493230  0.009632
# 14  [100, 0.0, 0.0]  1449.159444  2.100063e+06  1341.979744  0.062619
# 15  [100, 0.0, 0.0]  2057.214004  4.232129e+06  1713.458908  0.083567
# 16  [100, 0.0, 0.0]   398.767065  1.590152e+05   348.840525  0.018294
# 17  [100, 0.0, 0.0]   253.619781  6.432299e+04   227.214240  0.013533
# 18  [100, 0.0, 0.0]    97.784359  9.561781e+03    74.006487  0.003457
# 19  [100, 0.0, 0.0]   776.273239  6.026001e+05   659.263399  0.023892
# 20  [100, 0.0, 0.0]  1707.599133  2.915895e+06  1478.154083  0.054241
# 21  [100, 0.0, 0.0]  2141.488953  4.585975e+06  1882.984943  0.062991
#
#           R2  Adjusted_R2      Time
# 0   0.941494     0.941447  0.348100
# 1   0.803837     0.803680  0.332849
# 2   0.937752     0.937702  0.345104
# 3   0.879432     0.879335  0.351021
# 4   0.880979     0.880884  0.354113
# 5   0.932782     0.932728  0.391699
# 6   0.626793     0.626494  0.389941
# 7  -1.739828    -1.742022  0.385397
# 8   0.425339     0.424878  0.373013
# 9   0.789016     0.788847  0.366832
# 10  0.522049     0.521666  0.403560
# 11 -0.356380    -0.357466  0.404772
# 12  0.981801     0.981787  0.408195
# 13  0.992031     0.992025  0.406038
# 14  0.482014     0.481599  0.387498
# 15 -0.440557    -0.441711  0.398719
# 16  0.846794     0.846672  0.386976
# 17  0.458112     0.457678  0.386044
# 18  0.998172     0.998171  0.391201
# 19  0.932270     0.932215  0.388581
# 20 -2.348527    -2.351208  0.382039
# 21 -0.615966    -0.617260  0.383594

# %%
# Define model information and evaluators to show
model_info = ['Model', 'Type', 'Dataset', 'Splitting', 'Features', 'Parameters']
evaluator_lst = ['RMSE', 'MSE', 'MAE', 'MAPE', 'R2', 'Adjusted_R2', 'Time']

# %%
# Define the results to show
default_comparison_lst = [default_valid_results_base_features, default_valid_results_base_and_most_corr_features, default_valid_results_base_and_least_corr_features, default_norm_valid_results_base_features, default_norm_valid_results_base_and_most_corr_features, default_norm_valid_results_base_and_least_corr_features]

# Show the comparison table
default_comparison_lst_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in default_comparison_lst])
default_comparison_lst_df
# Out:
#               Model          Type Dataset            Splitting  \
# 0  LinearRegression       default   valid  walk_forward_splits
# 0  LinearRegression       default   valid  walk_forward_splits
# 0  LinearRegression       default   valid  walk_forward_splits
# 0  LinearRegression  default_norm   valid  walk_forward_splits
# 0  LinearRegression  default_norm   valid  walk_forward_splits
# 0  LinearRegression  default_norm   valid  walk_forward_splits
#
#                             Features       Parameters         RMSE  \
# 0                      base_features  [100, 0.0, 0.0]    10.149807
# 0        base_and_most_corr_features  [100, 0.0, 0.0]    15.620374
# 0       base_and_least_corr_features  [100, 0.0, 0.0]    21.541681
# 0                 base_features_norm  [100, 0.0, 0.0]  4375.915428
# 0   base_and_most_corr_features_norm  [100, 0.0, 0.0]  6662.119726
# 0  base_and_least_corr_features_norm  [100, 0.0, 0.0]  1743.625346
#
#             MSE          MAE      MAPE         R2  Adjusted_R2      Time
# 0  1.442297e+02     7.225374  0.000220   0.999979     0.999979  0.380688
# 0  3.414772e+02    12.467853  0.000411   0.999893     0.999892  0.350546
# 0  9.162115e+02    15.600488  0.000450   0.999938     0.999938  0.436247
# 0  3.971494e+07  3734.129210  0.117251  -8.120562    -8.127866  0.284153
# 0  1.350926e+08  5598.776134  0.174056 -17.573728   -17.588602  0.326644
# 0  5.340021e+06  1496.804362  0.043785   0.360428     0.359915  0.380240

# %%
# Save the best default model results and predicitons
best_default_results = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in [default_norm_valid_results_base_and_least_corr_features]])
best_default_predictions = default_norm_valid_pred_base_and_least_corr_features
best_default_results
# Out:
#               Model          Type Dataset            Splitting  \
# 0  LinearRegression  default_norm   valid  walk_forward_splits
#
#                             Features       Parameters         RMSE  \
# 0  base_and_least_corr_features_norm  [100, 0.0, 0.0]  1743.625346
#
#             MSE          MAE      MAPE        R2  Adjusted_R2     Time
# 0  5.340021e+06  1496.804362  0.043785  0.360428     0.359915  0.38024

# %%
# Define the choosen features
FEATURES_NORMALIZATION = True
CHOSEN_FEATURES = BASE_AND_LEAST_CORR_FEATURES
CHOSEN_FEATURES_LABEL = BASE_AND_LEAST_CORR_FEATURES_LABEL

# %% [markdown]
# ## Tuned
# Once the features and execution method are selected, the model will undergo hyperparameter tuning and cross validation to find the best configuration.

# %%
# Get model grid parameters
params = train_validation_utilities.get_model_grid_params(MODEL_NAME)
params
# Out:
# {'maxIter': [5, 10, 50, 80, 100],
#  'regParam': array([0. , 0.2, 0.4, 0.6, 0.8]),
#  'elasticNetParam': array([0. , 0.2, 0.4, 0.6, 0.8])}

# %% [markdown]
# ### Hyperparameter tuning

# %%
# Select the type of feature to be used
MODEL_TYPE = "hyp_tuning"

# %%
# Perform hyperparameter tuning
hyp_res = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
hyp_res
# Out:
# Split: [1/22]: 100%|██████████| 125/125 [01:54<00:00,  1.09it/s]
# Best parameters chosen for split [1/22]: [50, 0.0, 0.0]
# Split: [2/22]: 100%|██████████| 125/125 [01:52<00:00,  1.11it/s]
# Best parameters chosen for split [2/22]: [10, 0.6, 0.8]
# Split: [3/22]: 100%|██████████| 125/125 [01:52<00:00,  1.11it/s]
# Best parameters chosen for split [3/22]: [50, 0.8, 0.4]
# Split: [4/22]: 100%|██████████| 125/125 [01:51<00:00,  1.12it/s]
# Best parameters chosen for split [4/22]: [10, 0.0, 0.0]
# Split: [5/22]: 100%|██████████| 125/125 [01:58<00:00,  1.05it/s]
# Best parameters chosen for split [5/22]: [50, 0.0, 0.0]
# Split: [6/22]: 100%|██████████| 125/125 [02:00<00:00,  1.04it/s]
# Best parameters chosen for split [6/22]: [80, 0.8, 0.4]
# Split: [7/22]: 100%|██████████| 125/125 [02:00<00:00,  1.04it/s]
# Best parameters chosen for split [7/22]: [50, 0.6, 0.2]
# Split: [8/22]: 100%|██████████| 125/125 [02:00<00:00,  1.04it/s]
# Best parameters chosen for split [8/22]: [80, 0.8, 0.8]
# Split: [9/22]: 100%|██████████| 125/125 [02:00<00:00,  1.04it/s]
# Best parameters chosen for split [9/22]: [5, 0.2, 0.0]
# Split: [10/22]: 100%|██████████| 125/125 [02:01<00:00,  1.03it/s]
# Best parameters chosen for split [10/22]: [10, 0.0, 0.0]
# Split: [11/22]: 100%|██████████| 125/125 [02:02<00:00,  1.02it/s]
# Best parameters chosen for split [11/22]: [100, 0.6, 0.6]
# Split: [12/22]: 100%|██████████| 125/125 [02:08<00:00,  1.02s/it]
# Best parameters chosen for split [12/22]: [5, 0.2, 0.4]
# Split: [13/22]: 100%|██████████| 125/125 [02:06<00:00,  1.01s/it]
# Best parameters chosen for split [13/22]: [5, 0.0, 0.0]
# Split: [14/22]: 100%|██████████| 125/125 [02:05<00:00,  1.01s/it]
# Best parameters chosen for split [14/22]: [5, 0.0, 0.0]
# Split: [15/22]: 100%|██████████| 125/125 [02:06<00:00,  1.01s/it]
# Best parameters chosen for split [15/22]: [100, 0.8, 0.8]
# Split: [16/22]: 100%|██████████| 125/125 [02:05<00:00,  1.01s/it]
# Best parameters chosen for split [16/22]: [50, 0.2, 0.4]
# Split: [17/22]: 100%|██████████| 125/125 [02:00<00:00,  1.04it/s]
# Best parameters chosen for split [17/22]: [80, 0.4, 0.2]
# Split: [18/22]: 100%|██████████| 125/125 [01:59<00:00,  1.05it/s]
# Best parameters chosen for split [18/22]: [100, 0.6, 0.2]
# Split: [19/22]: 100%|██████████| 125/125 [01:59<00:00,  1.05it/s]
# Best parameters chosen for split [19/22]: [5, 0.0, 0.0]
# Split: [20/22]: 100%|██████████| 125/125 [01:58<00:00,  1.05it/s]
# Best parameters chosen for split [20/22]: [5, 0.0, 0.0]
# Split: [21/22]: 100%|██████████| 125/125 [01:59<00:00,  1.05it/s]
# Best parameters chosen for split [21/22]: [5, 0.2, 0.0]
# Split: [22/22]: 100%|██████████| 125/125 [01:58<00:00,  1.05it/s]
# Best parameters chosen for split [22/22]: [5, 0.8, 0.0]
#                Model        Type Dataset            Splitting  \
# 0   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 1   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 2   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 3   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 4   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 5   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 6   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 7   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 8   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 9   LinearRegression  hyp_tuning   valid  walk_forward_splits
# 10  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 11  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 12  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 13  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 14  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 15  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 16  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 17  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 18  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 19  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 20  LinearRegression  hyp_tuning   valid  walk_forward_splits
# 21  LinearRegression  hyp_tuning   valid  walk_forward_splits
#
#                              Features  Splits Train / Validation  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)
# 1   base_and_least_corr_features_norm       2      (20000, 5000)
# 2   base_and_least_corr_features_norm       3      (20000, 5000)
# 3   base_and_least_corr_features_norm       4      (20000, 5000)
# 4   base_and_least_corr_features_norm       5      (20000, 5000)
# 5   base_and_least_corr_features_norm       6      (20000, 5000)
# 6   base_and_least_corr_features_norm       7      (20000, 5000)
# 7   base_and_least_corr_features_norm       8      (20000, 5000)
# 8   base_and_least_corr_features_norm       9      (20000, 5000)
# 9   base_and_least_corr_features_norm      10      (20000, 5000)
# 10  base_and_least_corr_features_norm      11      (20000, 5000)
# 11  base_and_least_corr_features_norm      12      (20000, 5000)
# 12  base_and_least_corr_features_norm      13      (20000, 5000)
# 13  base_and_least_corr_features_norm      14      (20000, 5000)
# 14  base_and_least_corr_features_norm      15      (20000, 5000)
# 15  base_and_least_corr_features_norm      16      (20000, 5000)
# 16  base_and_least_corr_features_norm      17      (20000, 5000)
# 17  base_and_least_corr_features_norm      18      (20000, 5000)
# 18  base_and_least_corr_features_norm      19      (20000, 5000)
# 19  base_and_least_corr_features_norm      20      (20000, 5000)
# 20  base_and_least_corr_features_norm      21      (20000, 5000)
# 21  base_and_least_corr_features_norm      22      (20000, 5000)
#
#          Parameters         RMSE           MSE          MAE      MAPE  \
# 0    [50, 0.0, 0.0]   138.583590  1.920541e+04    99.124021  0.009912
# 1    [10, 0.6, 0.8]   206.652903  4.270542e+04   172.557994  0.015330
# 2    [50, 0.8, 0.4]   295.645265  8.740612e+04   243.992502  0.019007
# 3    [10, 0.0, 0.0]   413.019396  1.705850e+05   339.192700  0.016350
# 4    [50, 0.0, 0.0]  2463.702791  6.069831e+06  2050.230192  0.046547
# 5    [80, 0.8, 0.4]   822.956571  6.772575e+05   751.562096  0.013284
# 6    [50, 0.6, 0.2]  4274.384347  1.827036e+07  3562.382243  0.082129
# 7    [80, 0.8, 0.8]  1139.036491  1.297404e+06   816.359351  0.023013
# 8     [5, 0.2, 0.0]  1788.213930  3.197709e+06  1664.784733  0.035519
# 9    [10, 0.0, 0.0]  2834.693231  8.035486e+06  2335.760116  0.038232
# 10  [100, 0.6, 0.6]  1051.321692  1.105277e+06   785.343591  0.014243
# 11    [5, 0.2, 0.4]  1210.635927  1.465639e+06  1039.293462  0.026247
# 12    [5, 0.0, 0.0]   367.592978  1.351246e+05   292.457693  0.007004
# 13    [5, 0.0, 0.0]   394.079775  1.552989e+05   299.493230  0.009632
# 14  [100, 0.8, 0.8]   522.948829  2.734755e+05   395.668256  0.017951
# 15   [50, 0.2, 0.4]   303.508045  9.211713e+04   246.736497  0.011812
# 16   [80, 0.4, 0.2]   292.348859  8.546786e+04   238.458040  0.012595
# 17  [100, 0.6, 0.2]   167.055370  2.790750e+04   146.784398  0.008781
# 18    [5, 0.0, 0.0]    97.784359  9.561781e+03    74.006487  0.003457
# 19    [5, 0.0, 0.0]   776.273239  6.026001e+05   659.263399  0.023892
# 20    [5, 0.2, 0.0]   802.085808  6.433416e+05   653.649626  0.023873
# 21    [5, 0.8, 0.0]   751.321972  5.644847e+05   673.572827  0.022596
#
#           R2  Adjusted_R2      Time
# 0   0.950999     0.950960  0.137468
# 1   0.879877     0.879781  0.105858
# 2   0.973118     0.973096  0.110059
# 3   0.991487     0.991480  0.114259
# 4   0.888929     0.888840  0.122635
# 5   0.964171     0.964142  0.139826
# 6   0.765532     0.765344  0.119112
# 7   0.847936     0.847815  0.174224
# 8   0.624752     0.624451  0.117112
# 9   0.864135     0.864026  0.136261
# 10  0.958449     0.958415  0.126889
# 11  0.790480     0.790312  0.115870
# 12  0.981801     0.981787  0.442955
# 13  0.992031     0.992025  0.460090
# 14  0.932547     0.932493  0.132678
# 15  0.968645     0.968620  0.141856
# 16  0.917655     0.917589  0.119999
# 17  0.764894     0.764706  0.119998
# 18  0.998172     0.998171  0.328998
# 19  0.932270     0.932215  0.307998
# 20  0.261206     0.260614  0.123004
# 21  0.801092     0.800933  0.124998

# %% [markdown]
# ---
# Since during this stage will be used the Block split / Walk forward split method of the dataset I compute a score for each parameter chosen by each split, assigning weights based on:
#    * Their `frequency` for each split (if the same parameters are chosen from several splits, these will have greater weight)
#    * The `split` they belong to (the closer the split is to today's date the more weight they will have)
#    * Their `RMSE value` for each split (the lower this is, the more weight they will have)
#
#    Then, the overall score will be calculated by putting together these three weights for each parameter and the one with the best score will be the chosen parameter.

# %%
# Show parameters score
grouped_scores, best_params = train_validation_utilities.choose_best_params(hyp_res)
grouped_scores
# Out:
#                  Split weight  RMSE weight  Frequency weight  Final score
# Parameters
# (5, 0.0, 0.0)        0.750000     0.904329              1.00     0.678247
# (5, 0.2, 0.0)        0.681818     0.696997              0.50     0.237613
# (5, 0.8, 0.0)        1.000000     0.824227              0.25     0.206057
# (100, 0.6, 0.2)      0.818182     0.960917              0.25     0.196551
# (80, 0.4, 0.2)       0.772727     0.931604              0.25     0.179969
# (50, 0.2, 0.4)       0.727273     0.928994              0.25     0.168908
# (100, 0.8, 0.8)      0.681818     0.877655              0.25     0.149600
# (10, 0.0, 0.0)       0.318182     0.620096              0.50     0.098652
# (5, 0.2, 0.4)        0.545455     0.716770              0.25     0.097741
# (100, 0.6, 0.6)      0.500000     0.754041              0.25     0.094255
# (80, 0.8, 0.8)       0.363636     0.733520              0.25     0.066684
# (80, 0.8, 0.4)       0.272727     0.807468              0.25     0.055055
# (50, 0.0, 0.0)       0.136364     0.695595              0.50     0.047427
# (50, 0.8, 0.4)       0.136364     0.930833              0.25     0.031733
# (10, 0.6, 0.8)       0.090909     0.951653              0.25     0.021628
# (50, 0.6, 0.2)       0.318182     0.000000              0.25     0.000000

# %%
# Print best parameters
print(f"Best parameters: {best_params}")
# Out:
# Best parameters: (5, 0.0, 0.0)

# %% [markdown]
# ### Cross validation

# %%
MODEL_TYPE = "cross_val"

# %%
# Get tuned parameters
params = train_validation_utilities.get_best_model_params(best_params, MODEL_NAME)
params
# Out:
# {'maxIter': [5], 'regParam': [0.0], 'elasticNetParam': [0.0]}

# %%
# Perform cross validation
cv_train_result, cv_valid_result, cv_train_pred, cv_valid_pred = train_validation_utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL, SLOW_OPERATIONS)
# Out:
# Split: [1/22]: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Split: [2/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [3/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [4/22]: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Split: [5/22]: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Split: [6/22]: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Split: [7/22]: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Split: [8/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [9/22]: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Split: [10/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [11/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [12/22]: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Split: [13/22]: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Split: [14/22]: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Split: [15/22]: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Split: [16/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [17/22]: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Split: [18/22]: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Split: [19/22]: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Split: [20/22]: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Split: [21/22]: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Split: [22/22]: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]

# %%
cv_train_result
# Out:
#                Model       Type Dataset            Splitting  \
# 0   LinearRegression  cross_val   train  walk_forward_splits
# 1   LinearRegression  cross_val   train  walk_forward_splits
# 2   LinearRegression  cross_val   train  walk_forward_splits
# 3   LinearRegression  cross_val   train  walk_forward_splits
# 4   LinearRegression  cross_val   train  walk_forward_splits
# 5   LinearRegression  cross_val   train  walk_forward_splits
# 6   LinearRegression  cross_val   train  walk_forward_splits
# 7   LinearRegression  cross_val   train  walk_forward_splits
# 8   LinearRegression  cross_val   train  walk_forward_splits
# 9   LinearRegression  cross_val   train  walk_forward_splits
# 10  LinearRegression  cross_val   train  walk_forward_splits
# 11  LinearRegression  cross_val   train  walk_forward_splits
# 12  LinearRegression  cross_val   train  walk_forward_splits
# 13  LinearRegression  cross_val   train  walk_forward_splits
# 14  LinearRegression  cross_val   train  walk_forward_splits
# 15  LinearRegression  cross_val   train  walk_forward_splits
# 16  LinearRegression  cross_val   train  walk_forward_splits
# 17  LinearRegression  cross_val   train  walk_forward_splits
# 18  LinearRegression  cross_val   train  walk_forward_splits
# 19  LinearRegression  cross_val   train  walk_forward_splits
# 20  LinearRegression  cross_val   train  walk_forward_splits
# 21  LinearRegression  cross_val   train  walk_forward_splits
#
#                              Features  Splits Train / Validation  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)
# 1   base_and_least_corr_features_norm       2      (20000, 5000)
# 2   base_and_least_corr_features_norm       3      (20000, 5000)
# 3   base_and_least_corr_features_norm       4      (20000, 5000)
# 4   base_and_least_corr_features_norm       5      (20000, 5000)
# 5   base_and_least_corr_features_norm       6      (20000, 5000)
# 6   base_and_least_corr_features_norm       7      (20000, 5000)
# 7   base_and_least_corr_features_norm       8      (20000, 5000)
# 8   base_and_least_corr_features_norm       9      (20000, 5000)
# 9   base_and_least_corr_features_norm      10      (20000, 5000)
# 10  base_and_least_corr_features_norm      11      (20000, 5000)
# 11  base_and_least_corr_features_norm      12      (20000, 5000)
# 12  base_and_least_corr_features_norm      13      (20000, 5000)
# 13  base_and_least_corr_features_norm      14      (20000, 5000)
# 14  base_and_least_corr_features_norm      15      (20000, 5000)
# 15  base_and_least_corr_features_norm      16      (20000, 5000)
# 16  base_and_least_corr_features_norm      17      (20000, 5000)
# 17  base_and_least_corr_features_norm      18      (20000, 5000)
# 18  base_and_least_corr_features_norm      19      (20000, 5000)
# 19  base_and_least_corr_features_norm      20      (20000, 5000)
# 20  base_and_least_corr_features_norm      21      (20000, 5000)
# 21  base_and_least_corr_features_norm      22      (20000, 5000)
#
#        Parameters         RMSE           MSE          MAE      MAPE        R2  \
# 0   [5, 0.0, 0.0]   177.094036  3.136230e+04   139.201168  0.018013  0.979685
# 1   [5, 0.0, 0.0]    58.359949  3.405884e+03    44.785131  0.005310  0.997939
# 2   [5, 0.0, 0.0]   221.883325  4.923221e+04   169.177916  0.020057  0.983013
# 3   [5, 0.0, 0.0]   185.920828  3.456655e+04   145.231786  0.013918  0.988833
# 4   [5, 0.0, 0.0]   313.581443  9.833332e+04   234.019197  0.017863  0.996389
# 5   [5, 0.0, 0.0]   716.745917  5.137247e+05   467.784399  0.020712  0.996745
# 6   [5, 0.0, 0.0]   423.833075  1.796345e+05   345.303284  0.012438  0.999418
# 7   [5, 0.0, 0.0]  1138.303241  1.295734e+06   879.109472  0.024180  0.993553
# 8   [5, 0.0, 0.0]  1425.755060  2.032777e+06  1093.884680  0.025694  0.979739
# 9   [5, 0.0, 0.0]  1308.468466  1.712090e+06  1049.544758  0.023216  0.979669
# 10  [5, 0.0, 0.0]   742.580631  5.514260e+05   600.856941  0.013678  0.994433
# 11  [5, 0.0, 0.0]   832.373863  6.928462e+05   659.198144  0.014315  0.992583
# 12  [5, 0.0, 0.0]   447.053753  1.998571e+05   332.875577  0.006869  0.996823
# 13  [5, 0.0, 0.0]   221.065892  4.887013e+04   155.644957  0.003235  0.999320
# 14  [5, 0.0, 0.0]   155.320585  2.412448e+04   111.454390  0.002820  0.999604
# 15  [5, 0.0, 0.0]   118.842838  1.412362e+04   100.323370  0.003188  0.999811
# 16  [5, 0.0, 0.0]   136.741773  1.869831e+04   107.597511  0.003686  0.999775
# 17  [5, 0.0, 0.0]   121.752732  1.482373e+04    89.759958  0.003771  0.999595
# 18  [5, 0.0, 0.0]    57.951383  3.358363e+03    41.543932  0.002090  0.999428
# 19  [5, 0.0, 0.0]    54.796135  3.002616e+03    40.042592  0.001997  0.999531
# 20  [5, 0.0, 0.0]   185.258129  3.432057e+04   130.376960  0.006077  0.997878
# 21  [5, 0.0, 0.0]   137.680814  1.895601e+04   108.856047  0.004744  0.999133
#
#     Adjusted_R2      Time
# 0      0.979681  0.271000
# 1      0.997939  0.246999
# 2      0.983010  0.245997
# 3      0.988830  0.251999
# 4      0.996388  0.305519
# 5      0.996745  0.374996
# 6      0.999418  0.245999
# 7      0.993551  0.267000
# 8      0.979735  0.319514
# 9      0.979665  0.285000
# 10     0.994431  0.280000
# 11     0.992581  0.279998
# 12     0.996822  0.313995
# 13     0.999319  0.305516
# 14     0.999603  0.281000
# 15     0.999811  0.273000
# 16     0.999775  0.251999
# 17     0.999595  0.262002
# 18     0.999428  0.262511
# 19     0.999531  0.267999
# 20     0.997877  0.263999
# 21     0.999133  0.237998

# %%
cv_valid_result
# Out:
#                Model       Type Dataset            Splitting  \
# 0   LinearRegression  cross_val   valid  walk_forward_splits
# 1   LinearRegression  cross_val   valid  walk_forward_splits
# 2   LinearRegression  cross_val   valid  walk_forward_splits
# 3   LinearRegression  cross_val   valid  walk_forward_splits
# 4   LinearRegression  cross_val   valid  walk_forward_splits
# 5   LinearRegression  cross_val   valid  walk_forward_splits
# 6   LinearRegression  cross_val   valid  walk_forward_splits
# 7   LinearRegression  cross_val   valid  walk_forward_splits
# 8   LinearRegression  cross_val   valid  walk_forward_splits
# 9   LinearRegression  cross_val   valid  walk_forward_splits
# 10  LinearRegression  cross_val   valid  walk_forward_splits
# 11  LinearRegression  cross_val   valid  walk_forward_splits
# 12  LinearRegression  cross_val   valid  walk_forward_splits
# 13  LinearRegression  cross_val   valid  walk_forward_splits
# 14  LinearRegression  cross_val   valid  walk_forward_splits
# 15  LinearRegression  cross_val   valid  walk_forward_splits
# 16  LinearRegression  cross_val   valid  walk_forward_splits
# 17  LinearRegression  cross_val   valid  walk_forward_splits
# 18  LinearRegression  cross_val   valid  walk_forward_splits
# 19  LinearRegression  cross_val   valid  walk_forward_splits
# 20  LinearRegression  cross_val   valid  walk_forward_splits
# 21  LinearRegression  cross_val   valid  walk_forward_splits
#
#                              Features  Splits Train / Validation  \
# 0   base_and_least_corr_features_norm       1      (20000, 5000)
# 1   base_and_least_corr_features_norm       2      (20000, 5000)
# 2   base_and_least_corr_features_norm       3      (20000, 5000)
# 3   base_and_least_corr_features_norm       4      (20000, 5000)
# 4   base_and_least_corr_features_norm       5      (20000, 5000)
# 5   base_and_least_corr_features_norm       6      (20000, 5000)
# 6   base_and_least_corr_features_norm       7      (20000, 5000)
# 7   base_and_least_corr_features_norm       8      (20000, 5000)
# 8   base_and_least_corr_features_norm       9      (20000, 5000)
# 9   base_and_least_corr_features_norm      10      (20000, 5000)
# 10  base_and_least_corr_features_norm      11      (20000, 5000)
# 11  base_and_least_corr_features_norm      12      (20000, 5000)
# 12  base_and_least_corr_features_norm      13      (20000, 5000)
# 13  base_and_least_corr_features_norm      14      (20000, 5000)
# 14  base_and_least_corr_features_norm      15      (20000, 5000)
# 15  base_and_least_corr_features_norm      16      (20000, 5000)
# 16  base_and_least_corr_features_norm      17      (20000, 5000)
# 17  base_and_least_corr_features_norm      18      (20000, 5000)
# 18  base_and_least_corr_features_norm      19      (20000, 5000)
# 19  base_and_least_corr_features_norm      20      (20000, 5000)
# 20  base_and_least_corr_features_norm      21      (20000, 5000)
# 21  base_and_least_corr_features_norm      22      (20000, 5000)
#
#        Parameters         RMSE           MSE          MAE      MAPE        R2  \
# 0   [5, 0.0, 0.0]   333.608862  1.112949e+05   310.266234  0.032890  0.716041
# 1   [5, 0.0, 0.0]   264.081218  6.973889e+04   234.853585  0.020507  0.803837
# 2   [5, 0.0, 0.0]   412.091039  1.698190e+05   357.970182  0.028800  0.947771
# 3   [5, 0.0, 0.0]   654.065548  4.278017e+05   521.174311  0.025413  0.978651
# 4   [5, 0.0, 0.0]  2584.448146  6.679372e+06  2236.527957  0.053393  0.877776
# 5   [5, 0.0, 0.0]  1734.613457  3.008884e+06  1468.287322  0.026414  0.840819
# 6   [5, 0.0, 0.0]  5392.702134  2.908124e+07  4546.555216  0.106833  0.626793
# 7   [5, 0.0, 0.0]  1622.484166  2.632455e+06  1238.353940  0.036633  0.691461
# 8   [5, 0.0, 0.0]  2945.785810  8.677654e+06  2390.200841  0.051264 -0.018315
# 9   [5, 0.0, 0.0]  4383.778097  1.921751e+07  3882.496923  0.065357  0.675068
# 10  [5, 0.0, 0.0]  3565.620346  1.271365e+07  3360.576260  0.066749  0.522049
# 11  [5, 0.0, 0.0]  3080.291418  9.488195e+06  2605.315941  0.064605 -0.356380
# 12  [5, 0.0, 0.0]   367.592978  1.351246e+05   292.457693  0.007004  0.981801
# 13  [5, 0.0, 0.0]   394.079775  1.552989e+05   299.493230  0.009632  0.992031
# 14  [5, 0.0, 0.0]  1449.159444  2.100063e+06  1341.979744  0.062619  0.482014
# 15  [5, 0.0, 0.0]  2057.214004  4.232129e+06  1713.458908  0.083567 -0.440557
# 16  [5, 0.0, 0.0]   398.767065  1.590152e+05   348.840525  0.018294  0.846794
# 17  [5, 0.0, 0.0]   253.619781  6.432299e+04   227.214240  0.013533  0.458112
# 18  [5, 0.0, 0.0]    97.784359  9.561781e+03    74.006487  0.003457  0.998172
# 19  [5, 0.0, 0.0]   776.273239  6.026001e+05   659.263399  0.023892  0.932270
# 20  [5, 0.0, 0.0]  1707.599133  2.915895e+06  1478.154083  0.054241 -2.348527
# 21  [5, 0.0, 0.0]  2141.488953  4.585975e+06  1882.984943  0.062991 -0.615966
#
#     Adjusted_R2      Time
# 0      0.715813  0.271000
# 1      0.803680  0.246999
# 2      0.947729  0.245997
# 3      0.978634  0.251999
# 4      0.877678  0.305519
# 5      0.840692  0.374996
# 6      0.626494  0.245999
# 7      0.691213  0.267000
# 8     -0.019131  0.319514
# 9      0.674808  0.285000
# 10     0.521666  0.280000
# 11    -0.357466  0.279998
# 12     0.981787  0.313995
# 13     0.992025  0.305516
# 14     0.481599  0.281000
# 15    -0.441711  0.273000
# 16     0.846672  0.251999
# 17     0.457678  0.262002
# 18     0.998171  0.262511
# 19     0.932215  0.267999
# 20    -2.351208  0.263999
# 21    -0.617260  0.237998

# %%
# Define the results to show
tuned_comparison_lst = [cv_valid_result]

# Show the comparison table
tuned_comparison_lst_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in tuned_comparison_lst])
tuned_comparison_lst_df
# Out:
#               Model       Type Dataset            Splitting  \
# 0  LinearRegression  cross_val   valid  walk_forward_splits
#
#                             Features     Parameters         RMSE  \
# 0  base_and_least_corr_features_norm  [5, 0.0, 0.0]  1664.415862
#
#             MSE         MAE      MAPE        R2  Adjusted_R2      Time
# 0  4.874436e+06  1430.47418  0.041731  0.435987     0.435535  0.277002

# %% [markdown]
# # Comparison table
# Visualization of model performance at various stages of train / validation

# %%
# Concatenate final results into Pandas dataset
final_comparison_lst_df = pd.DataFrame(pd.concat([default_comparison_lst_df, tuned_comparison_lst_df], ignore_index=True))
final_comparison_lst_df
# Out:
#               Model          Type Dataset            Splitting  \
# 0  LinearRegression       default   valid  walk_forward_splits
# 1  LinearRegression       default   valid  walk_forward_splits
# 2  LinearRegression       default   valid  walk_forward_splits
# 3  LinearRegression  default_norm   valid  walk_forward_splits
# 4  LinearRegression  default_norm   valid  walk_forward_splits
# 5  LinearRegression  default_norm   valid  walk_forward_splits
# 6  LinearRegression     cross_val   valid  walk_forward_splits
#
#                             Features       Parameters         RMSE  \
# 0                      base_features  [100, 0.0, 0.0]    10.149807
# 1        base_and_most_corr_features  [100, 0.0, 0.0]    15.620374
# 2       base_and_least_corr_features  [100, 0.0, 0.0]    21.541681
# 3                 base_features_norm  [100, 0.0, 0.0]  4375.915428
# 4   base_and_most_corr_features_norm  [100, 0.0, 0.0]  6662.119726
# 5  base_and_least_corr_features_norm  [100, 0.0, 0.0]  1743.625346
# 6  base_and_least_corr_features_norm    [5, 0.0, 0.0]  1664.415862
#
#             MSE          MAE      MAPE         R2  Adjusted_R2      Time
# 0  1.442297e+02     7.225374  0.000220   0.999979     0.999979  0.380688
# 1  3.414772e+02    12.467853  0.000411   0.999893     0.999892  0.350546
# 2  9.162115e+02    15.600488  0.000450   0.999938     0.999938  0.436247
# 3  3.971494e+07  3734.129210  0.117251  -8.120562    -8.127866  0.284153
# 4  1.350926e+08  5598.776134  0.174056 -17.573728   -17.588602  0.326644
# 5  5.340021e+06  1496.804362  0.043785   0.360428     0.359915  0.380240
# 6  4.874436e+06  1430.474180  0.041731   0.435987     0.435535  0.277002

# %% [markdown]
# # Model accuracy
#
# Since predicting the price accurately is very difficult I also saw how good the models are at predicting whether the price will go up or down in this way:
#
# For each prediction let's consider the actual market-price, next-market-price and our predicted next-market-price (prediction).
# I compute whether the current prediction is correct (1) or not (0):
#
# $$
# prediction\_is\_correct
# =
# \begin{cases}
# 0 \text{ if [(market-price > next-market-price) and (market-price < prediction)] or [(market-price < next-market-price) and (market-price > prediction)]} \\
# 1 \text{ if [(market-price > next-market-price) and (market-price > prediction)] or [(market-price < next-market-price) and (market-price < prediction)]}
# \end{cases}
# $$
#
# After that I count the number of correct prediction:
# $$
# correct\_predictions
# =
# \sum_{i=0}^{total\_rows} prediction\_is\_correct
# $$
#
# Finally I compute the percentage of accuracy of the model:
# $$
# \\
# accuracy
# =
# (correct\_predictions / total\_rows)
# * 100
# $$

# %%
# Convert the pandas dataset to a PySpark dataset
best_default_pred_spark = spark.createDataFrame(best_default_predictions)
validated_pred_spark = spark.createDataFrame(cv_valid_pred)

# Compute model accuracy
default_accuracy = train_validation_utilities.model_accuracy(best_default_pred_spark)
validated_accuracy = train_validation_utilities.model_accuracy(validated_pred_spark)

# Shows whether features are normalised or not
if FEATURES_NORMALIZATION:
    NEW_CHOSEN_FEATURES_LABEL = CHOSEN_FEATURES_LABEL + "_norm"
    CHOSEN_FEATURES_LABEL = NEW_CHOSEN_FEATURES_LABEL
    
# Saving accuracy data into dataframe
accuracy_data = {
    'Model': MODEL_NAME,
    'Features': CHOSEN_FEATURES_LABEL,
    'Splitting': SPLITTING_METHOD,
    'Accuracy (default)': default_accuracy,
    'Accuracy (tuned)': validated_accuracy
}
accuracy_data_df = pd.DataFrame(accuracy_data, index=['Model'])

print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (default): {default_accuracy:.2f}%")
print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (tuned): {validated_accuracy:.2f}%")
# Out:
# Percentage of correct predictions for LinearRegression with base_and_least_corr_features_norm and walk_forward_splits (default): 48.02%
# Percentage of correct predictions for LinearRegression with base_and_least_corr_features_norm and walk_forward_splits (tuned): 50.31%

# %%
# Concatenate default and tuned results
default_tuned_results = [best_default_results, cv_valid_result]
default_tuned_results_df = pd.concat([train_validation_utilities.model_comparison(results, model_info, evaluator_lst) for results in default_tuned_results])
default_tuned_results_df
# Out:
#               Model          Type Dataset            Splitting  \
# 0  LinearRegression  default_norm   valid  walk_forward_splits
# 0  LinearRegression     cross_val   valid  walk_forward_splits
#
#                             Features       Parameters         RMSE  \
# 0  base_and_least_corr_features_norm  [100, 0.0, 0.0]  1743.625346
# 0  base_and_least_corr_features_norm    [5, 0.0, 0.0]  1664.415862
#
#             MSE          MAE      MAPE        R2  Adjusted_R2      Time
# 0  5.340021e+06  1496.804362  0.043785  0.360428     0.359915  0.380240
# 0  4.874436e+06  1430.474180  0.041731  0.435987     0.435535  0.277002

# %% [markdown]
# # Saving final results

# %%
# Save all final comparison results
final_comparison_lst_df.to_csv(ALL_MODEL_RESULTS, index=False)

# %%
# Save relevant results (default and tuned results)
default_tuned_results_df.to_csv(REL_MODEL_RESULTS, index=False)

# %%
# Saving accuracy results
accuracy_data_df.to_csv(MODEL_ACCURACY_RESULTS, index=False)

# %%
# Export notebook in html format (remember to save the notebook and change the model name)
if LOCAL_RUNNING:
    # !jupyter nbconvert --to html 4-walk-forward-split_{MODEL_NAME}.ipynb --output 4-walk-forward-split_{MODEL_NAME} --output-dir='./exports'
# Out:
# d:\Documents\Repository\BDC\project\.bdc\Lib\site-packages\traitlets\traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use './exports' instead of "'./exports'" if you require traitlets >=5.
#   warn(
# [NbConvertApp] Converting notebook 4-walk-forward-split_LinearRegression.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 542301 bytes to exports\4-walk-forward-split_LinearRegression.html
