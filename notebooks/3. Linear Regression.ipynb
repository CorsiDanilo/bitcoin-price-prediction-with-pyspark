# %% [markdown]
# # **Bitcoin price forecasting - Linear Regression**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author
# Corsi Danilo - corsi.1742375@studenti.uniroma1.it

# %% [markdown]
# ## Global constants, dependencies, libraries and tools

# %%
# GDrive root
GDRIVE_DIR = "/content/drive"

# Dataset
GDRIVE_DATASET_OUTPUT_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/datasets/output"
GDRIVE_DATASET_NAME = "bitcoin_blockchain_data_30min"
GDRIVE_DATASET_NAME_ENG = GDRIVE_DATASET_NAME + "train_valid"
GDRIVE_DATASET_NAME_EXT_ENG  = "/" + GDRIVE_DATASET_NAME_ENG + ".parquet"
GDRIVE_DATASET_NAME_ENG = GDRIVE_DATASET_OUTPUT_DIR + GDRIVE_DATASET_NAME_EXT_ENG

# Features
GDRIVE_FEATURES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/features"
GDRIVE_ALL_FEATURES_NAME = "all_features"
GDRIVE_MORE_REL_FEATURES_NAME = "more_rel_features"
GDRIVE_LESS_REL_FEATURES_NAME = "less_rel_features"
GDRIVE_ALL_FEATURES_NAME_EXT = "/" + GDRIVE_ALL_FEATURES_NAME + ".json"
GDRIVE_MORE_REL_FEATURES_NAME_EXT = "/" + GDRIVE_MORE_REL_FEATURES_NAME + ".json"
GDRIVE_LESS_REL_FEATURES_NAME_EXT = "/" + GDRIVE_LESS_REL_FEATURES_NAME + ".json"
GDRIVE_ALL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_ALL_FEATURES_NAME_EXT
GDRIVE_MORE_REL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_MORE_REL_FEATURES_NAME_EXT
GDRIVE_LESS_REL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_LESS_REL_FEATURES_NAME_EXT

# Others
JAVA_HOME = "/usr/lib/jvm/java-8-openjdk-amd64"
MODEL_NAME = "LinearRegression"
SLOW_OPERATION = True

# %%
# Point Colaboratory to our Google Drive
from google.colab import drive

# Define GDrive paths
drive.mount(GDRIVE_DIR, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Install Spark and related dependencies
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285388 sha256=dd3696ba22a8457b1f2f1a7e1aa122c7fd3d134768e0aeccb8f7fd7d706b1433
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %% [markdown]
# ## Import files

# %%
GDRIVE_UTILITIES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/utilities"

import sys
sys.path.append(GDRIVE_UTILITIES_DIR)

from imports import *
import utilities, parameters

importlib.reload(utilities)
importlib.reload(parameters)
# Out:
# <module 'parameters' from '/content/drive/MyDrive/BDC/project/utilities/parameters.py'>

# %% [markdown]
# ## Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '4G').\
                set('spark.driver.memory', '45G').\
                set('spark.driver.maxResultSize', '10G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPriceForecasting").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Loading dataset

# %%
# Load datasets into pyspark dataframe objects
df = spark.read.load(GDRIVE_DATASET_NAME_ENG,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the DataFrame
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the DataFrame
  dataset.printSchema()

# %%
if SLOW_OPERATION:
  dataset_info(df)
# Out:
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |          timestamp| id|      market-price|total-bitcoins|         market-cap|  trade-volume|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|        hash-rate|         difficulty|    miners-revenue|transaction-fees-usd|n-unique-addresses|    n-transactions|estimated-transaction-volume-usd|      rate-of-change|        sma-5-days|        sma-7-days|       sma-10-days|       sma-20-days|       sma-50-days|      sma-100-days| next-market-price|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |2016-01-01 00:00:00|  0|            430.89|   1.5029575E7|      6.474139727E9|  2860153.0242|      54604.791735| 0.493407133333333|        1.01155706E8|                   919.2| 697129.166405808|1.03880340815456E11|  1554768.75755142|    8783.06385149973|          263121.0|          124092.0|              5.83462646538702E7| 0.01866292247827417|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|
# |2016-01-01 00:30:00|  1|430.97041666666667|1.5029690625E7|6.474671910552083E9|2834859.039425|54606.164985937496|0.4952058123084288|1.0115826085416667E8|       921.4635057471265|697344.3297287727|1.03880340815456E11|1557198.9846382332|    8887.55143320559|       264578.9375|124611.70833333333|             5.818972467025057E7|0.018659440081436607|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|431.05083333333334|
# |2016-01-01 01:00:00|  2|431.05083333333334| 1.502980625E7|6.475204094104167E9| 2809565.05465|   54607.538236875|0.4970044912835246|1.0116081570833333E8|        923.727011494253|697559.4930517374|1.03880340815456E11|1559629.2117250462|    8992.03901491145|        266036.875|125131.41666666667|             5.803318468663094E7| 0.01865595898393746| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333|431.13124999999997|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 3 rows
#
# Shape: (131424, 25)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- rate-of-change: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# ## Loading features

# %%
# Set the features label
FEATURES_LABEL = "features"

# Set the target variable
TARGET_VAL = 'market-price'

# %%
# Loading correlation matrix features
with open(GDRIVE_ALL_FEATURES, "r") as f:
    all_features = json.load(f)
print(all_features)
# Out:
# ['total-bitcoins', 'market-cap', 'trade-volume', 'blocks-size', 'avg-block-size', 'n-transactions-total', 'n-transactions-per-block', 'hash-rate', 'difficulty', 'miners-revenue', 'transaction-fees-usd', 'n-unique-addresses', 'n-transactions', 'estimated-transaction-volume-usd', 'rate-of-change', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'sma-20-days', 'sma-50-days', 'sma-100-days']

# %%
# Loading correlation matrix features
with open(GDRIVE_MORE_REL_FEATURES, "r") as f:
    more_rel_features = json.load(f)
print(more_rel_features)
# Out:
# ['market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'estimated-transaction-volume-usd', 'sma-10-days', 'n-transactions-total', 'blocks-size', 'sma-100-days', 'total-bitcoins']

# %%
# Loading correlation matrix features
with open(GDRIVE_LESS_REL_FEATURES, "r") as f:
    less_rel_features = json.load(f)
print(less_rel_features)
# Out:
# ['sma-20-days', 'sma-50-days', 'n-unique-addresses', 'difficulty', 'hash-rate', 'avg-block-size', 'transaction-fees-usd', 'trade-volume', 'n-transactions-per-block', 'n-transactions', 'rate-of-change']

# %% [markdown]
# ## Evaluate simple model

# %%
# Get default params
params = parameters.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [100], 'regParam': [0.0], 'elasticNetParam': [0.0]}

# %%
# Valid performances with all the features
simple_res_all, simple_pred_all = utilities.evaluate_simple_model(df, all_features, params, GDRIVE_ALL_FEATURES_NAME, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
simple_res_all
# Out:
#               Model    Type      Features       Parameters         RMSE  \
# 0  LinearRegression  simple  all_features  [100, 0.0, 0.0]  6328.114969
#
#        MAPE          MAE      Variance        R2  Adjusted_R2      Time
# 0  0.191128  4912.677774  9.049858e+07  0.474349     0.474229  7.484958

# %%
utilities.show_results(simple_pred_all, MODEL_NAME, TARGET_VAL)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Valid performances with the corr matrix features
simple_res_more_rel, simple_pred_more_rel = utilities.evaluate_simple_model(df, more_rel_features, params, GDRIVE_MORE_REL_FEATURES_NAME, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
simple_res_more_rel
# Out:
#               Model    Type           Features       Parameters         RMSE  \
# 0  LinearRegression  simple  more_rel_features  [100, 0.0, 0.0]  7352.156437
#
#        MAPE          MAE      Variance        R2  Adjusted_R2      Time
# 0  0.260539  5907.680003  5.361845e+07  0.290458     0.290296  4.432118

# %%
utilities.show_results(simple_pred_more_rel, MODEL_NAME, TARGET_VAL)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Valid performances with the corr matrix features
simple_res_less_rel, simple_pred_less_rel = utilities.evaluate_simple_model(df, less_rel_features, params, GDRIVE_LESS_REL_FEATURES_NAME, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
simple_res_less_rel
# Out:
#               Model    Type           Features       Parameters          RMSE  \
# 0  LinearRegression  simple  less_rel_features  [100, 0.0, 0.0]  11109.834435
#
#        MAPE          MAE      Variance        R2  Adjusted_R2      Time
# 0  0.399404  9927.127534  9.481255e+07 -0.620182    -0.620552  2.252941

# %%
utilities.show_results(simple_pred_less_rel, MODEL_NAME, TARGET_VAL)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Hyperparameter tuning

# %%
choosen_features = more_rel_features
CHOSEN_FEATURES_LABEL = GDRIVE_MORE_REL_FEATURES_NAME

# %%
# Split proportion list
PORTION_LIST = [0.6, 0.7, 0.8, 0.9]

# %%
# Get simple params
params = parameters.get_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [5, 10, 50, 80, 100],
#  'regParam': array([0. , 0.2, 0.4, 0.6, 0.8]),
#  'elasticNetParam': array([0. , 0.2, 0.4, 0.6, 0.8])}

# %%
hyp_res = utilities.autoTuning(df, choosen_features, params, CHOSEN_FEATURES_LABEL, PORTION_LIST, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
hyp_res
# Out:
#               Model        Type           Features  Proportion     Parameters  \
# 0  LinearRegression  autotuning  more_rel_features         0.9  [5, 0.8, 0.8]
#
#           RMSE      MAPE          MAE      Variance        R2  Adjusted_R2  \
# 0  1604.378022  0.057455  1252.913471  2.178731e+07  0.878357     0.878302
#
#        Time
# 0  0.325904

# %% [markdown]
# ## Cross validation

# %%
# Get tuned params
params = parameters.get_tuned_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [5], 'regParam': [0.8], 'elasticNetParam': [0.8]}

# %%
## Cross Validation Parameter
# Multiple Splits Time Series Cross Validation
mul_cv = {'cv_type':'mulTs',
          'kSplits': 5}

# Blocked Time Series Cross Validation
blk_cv = {'cv_type':'blkTs',
          'kSplits': 10}

# %%
mul_cv_res, trained_models_mul_cv = utilities.tsCrossValidation(df, choosen_features, params, mul_cv, CHOSEN_FEATURES_LABEL, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
mul_cv_res
# Out:
#               Model   Type           Features  Splits Train&Validation  \
# 0  LinearRegression  mulTs  more_rel_features       1   (21904, 21904)
# 1  LinearRegression  mulTs  more_rel_features       2   (43808, 21904)
# 2  LinearRegression  mulTs  more_rel_features       3   (65712, 21904)
# 3  LinearRegression  mulTs  more_rel_features       4   (87616, 21904)
# 4  LinearRegression  mulTs  more_rel_features       5  (109520, 21904)
#
#       Parameters          RMSE      MAPE           MAE      Variance  \
# 0  [5, 0.8, 0.8]   6424.133797  0.663416   5097.303390  2.601065e+07
# 1  [5, 0.8, 0.8]   1893.799915  0.226327   1492.591611  9.684955e+05
# 2  [5, 0.8, 0.8]   5291.410710  0.340122   4023.949427  1.656210e+07
# 3  [5, 0.8, 0.8]  35532.696579  0.737162  34416.762023  1.184971e+09
# 4  [5, 0.8, 0.8]   4727.433265  0.145719   3753.996555  3.716347e+07
#
#           R2  Adjusted_R2      Time
# 0  -1.531820    -1.532513  1.362415
# 1   0.429375     0.429219  0.903342
# 2  -0.880495    -0.881011  1.087136
# 3 -13.799956   -13.804011  0.984310
# 4   0.472838     0.472694  1.165217

# %%
blk_cv_res, trained_models_mul_cv = utilities.tsCrossValidation(df, choosen_features, params, blk_cv, CHOSEN_FEATURES_LABEL, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)
blk_cv_res
# Out:
#               Model   Type           Features  Splits Train&Validation  \
# 0  LinearRegression  blkTs  more_rel_features       1    (10513, 2629)
# 1  LinearRegression  blkTs  more_rel_features       2    (10513, 2629)
# 2  LinearRegression  blkTs  more_rel_features       3    (10513, 2629)
# 3  LinearRegression  blkTs  more_rel_features       4    (10513, 2629)
# 4  LinearRegression  blkTs  more_rel_features       5    (10513, 2629)
# 5  LinearRegression  blkTs  more_rel_features       6    (10513, 2629)
# 6  LinearRegression  blkTs  more_rel_features       7    (10513, 2629)
# 7  LinearRegression  blkTs  more_rel_features       8    (10513, 2629)
# 8  LinearRegression  blkTs  more_rel_features       9    (10513, 2629)
# 9  LinearRegression  blkTs  more_rel_features      10    (10513, 2629)
#
#       Parameters          RMSE      MAPE           MAE      Variance  \
# 0  [5, 0.8, 0.8]     41.387775  0.067585     40.151226  1.777808e+03
# 1  [5, 0.8, 0.8]    789.702713  0.301556    732.235307  5.419033e+05
# 2  [5, 0.8, 0.8]   2514.093590  0.267695   2441.441951  7.716504e+06
# 3  [5, 0.8, 0.8]   2707.762928  0.611596   2314.723272  1.123479e+07
# 4  [5, 0.8, 0.8]    620.674916  0.050310    523.611444  3.763737e+05
# 5  [5, 0.8, 0.8]    211.034082  0.016889    159.246674  4.636766e+04
# 6  [5, 0.8, 0.8]  19288.181570  0.354457  18582.097561  3.461891e+08
# 7  [5, 0.8, 0.8]   3031.181616  0.044736   2575.552551  3.105992e+07
# 8  [5, 0.8, 0.8]   2122.135356  0.080682   1749.012856  1.077796e+07
# 9  [5, 0.8, 0.8]   1295.713185  0.039223   1104.938939  2.013716e+06
#
#           R2  Adjusted_R2      Time
# 0  -6.298358    -6.315060  0.575574
# 1  -3.605597    -3.616136  1.168731
# 2  -3.283181    -3.292982  0.577143
# 3  -6.004338    -6.020367  0.594536
# 4   0.501554     0.500413  0.616366
# 5   0.392908     0.391519  0.611802
# 6 -11.228947   -11.256931  0.630353
# 7   0.770982     0.770458  0.612054
# 8  -0.447593    -0.450906  0.500620
# 9   0.201720     0.199894  0.498347

# %% [markdown]
# ## Comparison table

# %%
# Define what model_info and evaluators in the Model Comparison Table
model_info = ['Model','Type', 'Features', 'Parameters']
evaluator_lst = ['RMSE','MAPE','MAE','Variance','R2','Adjusted_R2','Time']

# The the Cross Validation results would like to compare
comparison_lst = [simple_res_all, simple_res_more_rel, simple_res_less_rel, hyp_res, mul_cv_res, blk_cv_res]

# %%
# Show the Comparison Table
pd.concat([utilities.modelComparison(cv_result, model_info, evaluator_lst) for cv_result in comparison_lst])
# Out:
#               Model        Type           Features       Parameters  \
# 0  LinearRegression      simple       all_features  [100, 0.0, 0.0]
# 0  LinearRegression      simple  more_rel_features  [100, 0.0, 0.0]
# 0  LinearRegression      simple  less_rel_features  [100, 0.0, 0.0]
# 0  LinearRegression  autotuning  more_rel_features    [5, 0.8, 0.8]
# 0  LinearRegression       mulTs  more_rel_features    [5, 0.8, 0.8]
# 0  LinearRegression       blkTs  more_rel_features    [5, 0.8, 0.8]
#
#            RMSE      MAPE          MAE      Variance        R2  Adjusted_R2  \
# 0   6328.114969  0.191128  4912.677774  9.049858e+07  0.474349     0.474229
# 0   7352.156437  0.260539  5907.680003  5.361845e+07  0.290458     0.290296
# 0  11109.834435  0.399404  9927.127534  9.481255e+07 -0.620182    -0.620552
# 0   1604.378022  0.057455  1252.913471  2.178731e+07  0.878357     0.878302
# 0  10773.894853  0.422549  9756.920601  2.531352e+08 -3.062011    -3.063124
# 0   3262.186773  0.183473  3022.301178  4.099584e+07 -2.900085    -2.909010
#
#        Time
# 0  7.484958
# 0  4.432118
# 0  2.252941
# 0  0.325904
# 0  1.100484
# 0  0.638553

# %% [markdown]
# ## Training the final model

# %%
model = utilities.train_final_model(df, more_rel_features, params, MODEL_NAME, FEATURES_LABEL, TARGET_VAL)

# %%
GDRIVE_MODELS_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/models"
GDRIVE_MODEL_NAME_EXT = GDRIVE_MODELS_DIR + "/" + MODEL_NAME

# %%
# Save the trained model
model.write().overwrite().save(GDRIVE_MODEL_NAME_EXT)
