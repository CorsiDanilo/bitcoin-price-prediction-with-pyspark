# %% [markdown]
# # **Bitcoin price forecasting - GBTRegressor**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author
# Corsi Danilo - corsi.1742375@studenti.uniroma1.it

# %% [markdown]
# ## Global constants, dependencies, libraries and tools

# %%
# Main constants
GDRIVE_DIR = "/content/drive"
MODEL_NAME = "LinearRegression"
SLOW_OPERATIONS = True

# %%
# Datasets dirs
GDRIVE_DATASET_OUTPUT_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/datasets/output"

# Datasets names
DATASET_TRAIN_VALID_NAME = "bitcoin_blockchain_data_30min_train_valid"

# Datasets paths
GDRIVE_DATASET_TRAIN_VALID  = GDRIVE_DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

# --------------------------------------------- #

# Features dir
GDRIVE_FEATURES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/features"

# Features names
ALL_FEATURES_NAME = "all_features"
MORE_REL_FEATURES_NAME = "more_rel_features"
LESS_REL_FEATURES_NAME = "less_rel_features"

# Features labels
FEATURES_LABEL = "features"
TARGET_LABEL = "next-market-price"

# Features paths
GDRIVE_ALL_FEATURES = GDRIVE_FEATURES_DIR + "/" + ALL_FEATURES_NAME + ".json"
GDRIVE_MORE_REL_FEATURES = GDRIVE_FEATURES_DIR + "/" + MORE_REL_FEATURES_NAME + ".json"
GDRIVE_LESS_REL_FEATURES = GDRIVE_FEATURES_DIR + "/" + LESS_REL_FEATURES_NAME + ".json"

# --------------------------------------------- #

# Model dir
GDRIVE_MODELS_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/models"

# Model path
GDRIVE_MODEL = GDRIVE_MODELS_DIR + "/" + MODEL_NAME

# --------------------------------------------- #

# Utilities dir
GDRIVE_UTILITIES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/utilities"

# %%
# Point Colaboratory to our Google Drive
from google.colab import drive

# Define GDrive paths
drive.mount(GDRIVE_DIR, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Install Spark and related dependencies
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285387 sha256=fc641814102f5700c832fc1c8c31a41ea818b0b287b74e687b1b0de0d457576e
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %% [markdown]
# ## Import files

# %%
import sys
sys.path.append(GDRIVE_UTILITIES_DIR)

from imports import *
import utilities, parameters

importlib.reload(utilities)
importlib.reload(parameters)
# Out:
# <module 'parameters' from '/content/drive/MyDrive/BDC/project/utilities/parameters.py'>

# %% [markdown]
# ## Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '4G').\
                set('spark.driver.memory', '45G').\
                set('spark.driver.maxResultSize', '10G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPriceForecasting").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Loading dataset

# %%
# Load datasets into pyspark dataset objects
df = spark.read.load(GDRIVE_DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
if SLOW_OPERATIONS:
  dataset_info(df)
# Out:
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |          timestamp| id|      market-price|total-bitcoins|         market-cap|  trade-volume|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|        hash-rate|         difficulty|    miners-revenue|transaction-fees-usd|n-unique-addresses|    n-transactions|estimated-transaction-volume-usd|      rate-of-change|        sma-5-days|        sma-7-days|       sma-10-days|       sma-20-days|       sma-50-days|      sma-100-days| next-market-price|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |2016-01-01 00:00:00|  0|            430.89|   1.5029575E7|      6.474139727E9|  2860153.0242|      54604.791735| 0.493407133333333|        1.01155706E8|                   919.2| 697129.166405808|1.03880340815456E11|  1554768.75755142|    8783.06385149973|          263121.0|          124092.0|              5.83462646538702E7| 0.01866292247827417|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|
# |2016-01-01 00:30:00|  1|430.97041666666667|1.5029690625E7|6.474671910552083E9|2834859.039425|54606.164985937496|0.4952058123084288|1.0115826085416667E8|       921.4635057471265|697344.3297287727|1.03880340815456E11|1557198.9846382332|    8887.55143320559|       264578.9375|124611.70833333333|             5.818972467025057E7|0.018659440081436607|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|431.05083333333334|
# |2016-01-01 01:00:00|  2|431.05083333333334| 1.502980625E7|6.475204094104167E9| 2809565.05465|   54607.538236875|0.4970044912835246|1.0116081570833333E8|        923.727011494253|697559.4930517374|1.03880340815456E11|1559629.2117250462|    8992.03901491145|        266036.875|125131.41666666667|             5.803318468663094E7| 0.01865595898393746| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333|431.13124999999997|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 3 rows
#
# Shape: (129600, 25)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- rate-of-change: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# ## Loading features

# %%
# Loading correlation matrix features
with open(GDRIVE_ALL_FEATURES, "r") as f:
    all_features = json.load(f)
print(all_features)
# Out:
# ['market-price', 'total-bitcoins', 'market-cap', 'trade-volume', 'blocks-size', 'avg-block-size', 'n-transactions-total', 'n-transactions-per-block', 'hash-rate', 'difficulty', 'miners-revenue', 'transaction-fees-usd', 'n-unique-addresses', 'n-transactions', 'estimated-transaction-volume-usd', 'rate-of-change', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'sma-20-days', 'sma-50-days', 'sma-100-days']

# %%
# Loading correlation matrix features
with open(GDRIVE_MORE_REL_FEATURES, "r") as f:
    more_rel_features = json.load(f)
print(more_rel_features)
# Out:
# ['market-price', 'market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'n-transactions-total', 'blocks-size', 'sma-100-days', 'total-bitcoins']

# %%
# Loading correlation matrix features
with open(GDRIVE_LESS_REL_FEATURES, "r") as f:
    less_rel_features = json.load(f)
print(less_rel_features)
# Out:
# ['sma-20-days', 'sma-50-days', 'n-unique-addresses', 'difficulty', 'hash-rate', 'avg-block-size', 'transaction-fees-usd', 'trade-volume', 'n-transactions-per-block', 'n-transactions', 'rate-of-change']

# %% [markdown]
# ## [TOFIX] Shared functions ❗

# %%
from itertools import product
from dateutil.relativedelta import relativedelta

##########
# SHARED #
##########

# Return the dataset with the selected features
def select_features(dataset, features, features_label, target_label):
  vectorAssembler = VectorAssembler(inputCols = features, outputCol = features_label)

  dataset = vectorAssembler.transform(dataset).select("timestamp", "id", features_label, target_label)

  return dataset

# Normalized / standardized features selection
def select_normalized_features(dataset, features, features_label, target_label):
    # Assemble the columns into a vector column
    assembler = VectorAssembler(inputCols = features, outputCol = "raw_features")
    df_vector  = assembler.transform(dataset).select("timestamp", "id", "raw_features", target_label)

    # Create a Normalizer instance
    normalizer = Normalizer(inputCol="raw_features", outputCol=features_label)

    # Fit and transform the data
    normalized_data = normalizer.transform(df_vector).select("timestamp", "id", features_label, target_label)

    return normalized_data

def dataset_split(dataset):
    # Retrieve the last value of the column
    last_value = dataset.agg(last("timestamp")).collect()[0][0]

    # Sottrai un mese dalla data di partenza
    split_date = last_value - relativedelta(months=1)

    # Split the dataset based on the desired date
    train_data = dataset[dataset['timestamp'] <= split_date]
    valid_data = dataset[dataset['timestamp'] > split_date]

    return train_data, valid_data

def show_results(results, ml_model):
  trace1 = go.Scatter(
      x = results['timestamp'],
      y = results['next-market-price'].astype(float),
      mode = 'lines',
      name = 'Next Market price (usd)'
  )

  trace2 = go.Scatter(
      x = results['timestamp'],
      y = results['prediction'].astype(float),
      mode = 'lines',
      name = 'Predicted next makert price (usd)'
  )

  layout = dict(
      title= ml_model +' predicitons',
      xaxis=dict(
          rangeselector=dict(
              buttons=list([
                  #change the count to desired amount of months.
                  dict(count=1,
                      label='1m',
                      step='month',
                      stepmode='backward'),
                  dict(count=6,
                      label='6m',
                      step='month',
                      stepmode='backward'),
                  dict(count=12,
                      label='1y',
                      step='month',
                      stepmode='backward'),
                  dict(count=36,
                      label='3y',
                      step='month',
                      stepmode='backward'),
                  dict(step='all')
              ])
          ),
          rangeslider=dict(
              visible = True
          ),
          type='date'
      )
  )

  data = [trace1,trace2]
  fig = dict(data=data, layout=layout)
  iplot(fig, filename = ml_model +' predicitons')

# def modelComparison(cv_result, model_info, evaluator_lst):
#     # Calculate mean of all splits on chosen evaluator
#     col_mean_df = cv_result[evaluator_lst].mean().to_frame().T

#     # Extract model info
#     model_info_df = cv_result[model_info][:1]

#     # Concatenate by row
#     comparison_df = pd.concat([model_info_df,col_mean_df], axis=1)

#     return comparison_df

def model_selection(ml_model, param, features_label, target_label):
    if ml_model == "LinearRegression":
        model = LinearRegression(featuresCol=features_label, \
                                    labelCol=target_label, \
                                    maxIter=param['maxIter'], \
                                    regParam=param['regParam'], \
                                    elasticNetParam=param['elasticNetParam'])

    elif ml_model == "GeneralizedLinearRegression":
        model = GeneralizedLinearRegression(featuresCol=features_label, \
                                            labelCol=target_label, \
                                            maxIter=param['maxIter'], \
                                            regParam=param['regParam'])

    elif ml_model == "RandomForestRegressor":
        model = RandomForestRegressor(featuresCol=features_label, \
                                        labelCol=target_label, \
                                        numTrees = param["numTrees"], \
                                        maxDepth = param["maxDepth"])

    elif ml_model == "GBTRegressor":
        model = GBTRegressor(featuresCol=features_label, \
                                labelCol=target_label, \
                                maxIter = param['maxIter'], \
                                maxDepth = param['maxDepth'], \
                                stepSize = param['stepSize'])
    return model

def model_evaluation(target_label, predictions):
    mse_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='mse')
    rmse_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='rmse')
    mae_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='mae')
    r2_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='r2')

    mse = mse_evaluator.evaluate(predictions)
    rmse = rmse_evaluator.evaluate(predictions)
    mae = mae_evaluator.evaluate(predictions)
    r2 = r2_evaluator.evaluate(predictions)

    # Adjusted R-squared
    n = predictions.count()
    p = len(predictions.columns)
    adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)

    results = {'mse':mse, 'rmse':rmse, 'mae':mae, 'r2':r2, 'adj_r2':adj_r2}

    return results

# %% [markdown]
# ## [TOFIX] Simple model functions ❗

# %%
############################
# MODEL TRAIN / VALIDATION #
############################

# Function that create simple models (without hyperparameter tuning) and evaluate them
def model_train_valid_(dataset, params, features, model_type, model_name, features_name, features_label, target_label):
    # Select train and valid data features
    if model_type == "simple":
        dataset = select_features(dataset, features, features_label, target_label)
    elif model_type == "simple_norm" or model_type == "final_validated":
        dataset = select_normalized_features(dataset, features, features_label, target_label)

    # ALL combination of params
    param_lst = [dict(zip(params, param)) for param in product(*params.values())]

    for param in param_lst:
        # Chosen Model
        model = model_selection(model_name, param, features_label, target_label)

        # Split dataset
        train_data, valid_data = dataset_split(dataset)

        # Chain assembler and model in a Pipeline
        pipeline = Pipeline(stages=[model])
        # Train a model and calculate running time
        start = time.time()
        pipeline_model = pipeline.fit(train_data)
        end = time.time()

        # Make predictions
        predictions = pipeline_model.transform(valid_data).select(target_label, "prediction", 'timestamp')

        # Compute validation error by several evaluators
        eval_res = model_evaluation(target_label, predictions)

        # Use dict to store each result
        results = {
            "Model": model_name,
            "Type": model_type,
            "Features": features_name,
            "Parameters": [list(param.values())],
            "MSE": eval_res['mse'],
            "RMSE": eval_res['rmse'],
            "MAE": eval_res['mae'],
            "R2": eval_res['r2'],
            "Adjusted_R2": eval_res['adj_r2'],
            "Time": end - start,
        }

    # Transform dict to pandas dataset
    results_pd = pd.DataFrame(results, index=[0])

    return results_pd, predictions.toPandas()

# %% [markdown]
# ## Simple model

# %%
MODEL_TYPE = "simple"

# %%
# Get default params
params = parameters.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [100], 'regParam': [0.0], 'elasticNetParam': [0.0]}

# %%
# Valid performances with all the features
simple_res_all, simple_pred_all = model_train_valid_(df, params, all_features, MODEL_TYPE, MODEL_NAME, ALL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_all
# Out:
#               Model    Type      Features       Parameters        MSE  \
# 0  LinearRegression  simple  all_features  [100, 0.0, 0.0]  29.236022
#
#        RMSE       MAE        R2  Adjusted_R2      Time
# 0  5.407034  4.381591  0.999966     0.999966  2.040987

# %%
show_results(simple_pred_all, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="71b7b935-d5d0-48e4-bc94-b358d90a4ca5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71b7b935-d5d0-48e4-bc94-b358d90a4ca5")) {                    Plotly.newPlot(                        "71b7b935-d5d0-48e4-bc94-b358d90a4ca5",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-04-24T00:00:00","2023-04-24T00:30:00","2023-04-24T01:00:00","2023-04-24T01:30:00","2023-04-24T02:00:00","2023-04-24T02:30:00","2023-04-24T03:00:00","2023-04-24T03:30:00","2023-04-24T04:00:00","2023-04-24T04:30:00","2023-04-24T05:00:00","2023-04-24T05:30:00","2023-04-24T06:00:00","2023-04-24T06:30:00","2023-04-24T07:00:00","2023-04-24T07:30:00","2023-04-24T08:00:00","2023-04-24T08:30:00","2023-04-24T09:00:00","2023-04-24T09:30:00","2023-04-24T10:00:00","2023-04-24T10:30:00","2023-04-24T11:00:00","2023-04-24T11:30:00","2023-04-24T12:00:00","2023-04-24T12:30:00","2023-04-24T13:00:00","2023-04-24T13:30:00","2023-04-24T14:00:00","2023-04-24T14:30:00","2023-04-24T15:00:00","2023-04-24T15:30:00","2023-04-24T16:00:00","2023-04-24T16:30:00","2023-04-24T17:00:00","2023-04-24T17:30:00","2023-04-24T18:00:00","2023-04-24T18:30:00","2023-04-24T19:00:00","2023-04-24T19:30:00","2023-04-24T20:00:00","2023-04-24T20:30:00","2023-04-24T21:00:00","2023-04-24T21:30:00","2023-04-24T22:00:00","2023-04-24T22:30:00","2023-04-24T23:00:00","2023-04-24T23:30:00","2023-04-25T00:00:00","2023-04-25T00:30:00","2023-04-25T01:00:00","2023-04-25T01:30:00","2023-04-25T02:00:00","2023-04-25T02:30:00","2023-04-25T03:00:00","2023-04-25T03:30:00","2023-04-25T04:00:00","2023-04-25T04:30:00","2023-04-25T05:00:00","2023-04-25T05:30:00","2023-04-25T06:00:00","2023-04-25T06:30:00","2023-04-25T07:00:00","2023-04-25T07:30:00","2023-04-25T08:00:00","2023-04-25T08:30:00","2023-04-25T09:00:00","2023-04-25T09:30:00","2023-04-25T10:00:00","2023-04-25T10:30:00","2023-04-25T11:00:00","2023-04-25T11:30:00","2023-04-25T12:00:00","2023-04-25T12:30:00","2023-04-25T13:00:00","2023-04-25T13:30:00","2023-04-25T14:00:00","2023-04-25T14:30:00","2023-04-25T15:00:00","2023-04-25T15:30:00","2023-04-25T16:00:00","2023-04-25T16:30:00","2023-04-25T17:00:00","2023-04-25T17:30:00","2023-04-25T18:00:00","2023-04-25T18:30:00","2023-04-25T19:00:00","2023-04-25T19:30:00","2023-04-25T20:00:00","2023-04-25T20:30:00","2023-04-25T21:00:00","2023-04-25T21:30:00","2023-04-25T22:00:00","2023-04-25T22:30:00","2023-04-25T23:00:00","2023-04-25T23:30:00","2023-04-26T00:00:00","2023-04-26T00:30:00","2023-04-26T01:00:00","2023-04-26T01:30:00","2023-04-26T02:00:00","2023-04-26T02:30:00","2023-04-26T03:00:00","2023-04-26T03:30:00","2023-04-26T04:00:00","2023-04-26T04:30:00","2023-04-26T05:00:00","2023-04-26T05:30:00","2023-04-26T06:00:00","2023-04-26T06:30:00","2023-04-26T07:00:00","2023-04-26T07:30:00","2023-04-26T08:00:00","2023-04-26T08:30:00","2023-04-26T09:00:00","2023-04-26T09:30:00","2023-04-26T10:00:00","2023-04-26T10:30:00","2023-04-26T11:00:00","2023-04-26T11:30:00","2023-04-26T12:00:00","2023-04-26T12:30:00","2023-04-26T13:00:00","2023-04-26T13:30:00","2023-04-26T14:00:00","2023-04-26T14:30:00","2023-04-26T15:00:00","2023-04-26T15:30:00","2023-04-26T16:00:00","2023-04-26T16:30:00","2023-04-26T17:00:00","2023-04-26T17:30:00","2023-04-26T18:00:00","2023-04-26T18:30:00","2023-04-26T19:00:00","2023-04-26T19:30:00","2023-04-26T20:00:00","2023-04-26T20:30:00","2023-04-26T21:00:00","2023-04-26T21:30:00","2023-04-26T22:00:00","2023-04-26T22:30:00","2023-04-26T23:00:00","2023-04-26T23:30:00","2023-04-27T00:00:00","2023-04-27T00:30:00","2023-04-27T01:00:00","2023-04-27T01:30:00","2023-04-27T02:00:00","2023-04-27T02:30:00","2023-04-27T03:00:00","2023-04-27T03:30:00","2023-04-27T04:00:00","2023-04-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_res_more_rel, simple_pred_more_rel = model_train_valid_(df, params, more_rel_features, MODEL_TYPE, MODEL_NAME, MORE_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_more_rel
# Out:
#               Model    Type           Features       Parameters         MSE  \
# 0  LinearRegression  simple  more_rel_features  [100, 0.0, 0.0]  128.354483
#
#         RMSE       MAE        R2  Adjusted_R2      Time
# 0  11.329364  9.424813  0.999851     0.999851  1.328911

# %%
show_results(simple_pred_more_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ce6dc3ca-de6c-4298-9668-788be933a5d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce6dc3ca-de6c-4298-9668-788be933a5d1")) {                    Plotly.newPlot(                        "ce6dc3ca-de6c-4298-9668-788be933a5d1",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-04-24T00:00:00","2023-04-24T00:30:00","2023-04-24T01:00:00","2023-04-24T01:30:00","2023-04-24T02:00:00","2023-04-24T02:30:00","2023-04-24T03:00:00","2023-04-24T03:30:00","2023-04-24T04:00:00","2023-04-24T04:30:00","2023-04-24T05:00:00","2023-04-24T05:30:00","2023-04-24T06:00:00","2023-04-24T06:30:00","2023-04-24T07:00:00","2023-04-24T07:30:00","2023-04-24T08:00:00","2023-04-24T08:30:00","2023-04-24T09:00:00","2023-04-24T09:30:00","2023-04-24T10:00:00","2023-04-24T10:30:00","2023-04-24T11:00:00","2023-04-24T11:30:00","2023-04-24T12:00:00","2023-04-24T12:30:00","2023-04-24T13:00:00","2023-04-24T13:30:00","2023-04-24T14:00:00","2023-04-24T14:30:00","2023-04-24T15:00:00","2023-04-24T15:30:00","2023-04-24T16:00:00","2023-04-24T16:30:00","2023-04-24T17:00:00","2023-04-24T17:30:00","2023-04-24T18:00:00","2023-04-24T18:30:00","2023-04-24T19:00:00","2023-04-24T19:30:00","2023-04-24T20:00:00","2023-04-24T20:30:00","2023-04-24T21:00:00","2023-04-24T21:30:00","2023-04-24T22:00:00","2023-04-24T22:30:00","2023-04-24T23:00:00","2023-04-24T23:30:00","2023-04-25T00:00:00","2023-04-25T00:30:00","2023-04-25T01:00:00","2023-04-25T01:30:00","2023-04-25T02:00:00","2023-04-25T02:30:00","2023-04-25T03:00:00","2023-04-25T03:30:00","2023-04-25T04:00:00","2023-04-25T04:30:00","2023-04-25T05:00:00","2023-04-25T05:30:00","2023-04-25T06:00:00","2023-04-25T06:30:00","2023-04-25T07:00:00","2023-04-25T07:30:00","2023-04-25T08:00:00","2023-04-25T08:30:00","2023-04-25T09:00:00","2023-04-25T09:30:00","2023-04-25T10:00:00","2023-04-25T10:30:00","2023-04-25T11:00:00","2023-04-25T11:30:00","2023-04-25T12:00:00","2023-04-25T12:30:00","2023-04-25T13:00:00","2023-04-25T13:30:00","2023-04-25T14:00:00","2023-04-25T14:30:00","2023-04-25T15:00:00","2023-04-25T15:30:00","2023-04-25T16:00:00","2023-04-25T16:30:00","2023-04-25T17:00:00","2023-04-25T17:30:00","2023-04-25T18:00:00","2023-04-25T18:30:00","2023-04-25T19:00:00","2023-04-25T19:30:00","2023-04-25T20:00:00","2023-04-25T20:30:00","2023-04-25T21:00:00","2023-04-25T21:30:00","2023-04-25T22:00:00","2023-04-25T22:30:00","2023-04-25T23:00:00","2023-04-25T23:30:00","2023-04-26T00:00:00","2023-04-26T00:30:00","2023-04-26T01:00:00","2023-04-26T01:30:00","2023-04-26T02:00:00","2023-04-26T02:30:00","2023-04-26T03:00:00","2023-04-26T03:30:00","2023-04-26T04:00:00","2023-04-26T04:30:00","2023-04-26T05:00:00","2023-04-26T05:30:00","2023-04-26T06:00:00","2023-04-26T06:30:00","2023-04-26T07:00:00","2023-04-26T07:30:00","2023-04-26T08:00:00","2023-04-26T08:30:00","2023-04-26T09:00:00","2023-04-26T09:30:00","2023-04-26T10:00:00","2023-04-26T10:30:00","2023-04-26T11:00:00","2023-04-26T11:30:00","2023-04-26T12:00:00","2023-04-26T12:30:00","2023-04-26T13:00:00","2023-04-26T13:30:00","2023-04-26T14:00:00","2023-04-26T14:30:00","2023-04-26T15:00:00","2023-04-26T15:30:00","2023-04-26T16:00:00","2023-04-26T16:30:00","2023-04-26T17:00:00","2023-04-26T17:30:00","2023-04-26T18:00:00","2023-04-26T18:30:00","2023-04-26T19:00:00","2023-04-26T19:30:00","2023-04-26T20:00:00","2023-04-26T20:30:00","2023-04-26T21:00:00","2023-04-26T21:30:00","2023-04-26T22:00:00","2023-04-26T22:30:00","2023-04-26T23:00:00","2023-04-26T23:30:00","2023-04-27T00:00:00","2023-04-27T00:30:00","2023-04-27T01:00:00","2023-04-27T01:30:00","2023-04-27T02:00:00","2023-04-27T02:30:00","2023-04-27T03:00:00","2023-04-27T03:30:00","2023-04-27T04:00:00","2023-04-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_res_less_rel, simple_pred_less_rel = model_train_valid_(df, params, less_rel_features, MODEL_TYPE, MODEL_NAME, LESS_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_less_rel
# Out:
#               Model    Type           Features       Parameters           MSE  \
# 0  LinearRegression  simple  less_rel_features  [100, 0.0, 0.0]  6.766071e+08
#
#            RMSE           MAE          R2  Adjusted_R2      Time
# 0  26011.673055  25379.746393 -785.269831  -786.912456  2.340446

# %%
show_results(simple_pred_less_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9764d60f-db51-4b6d-b45b-7755ca69fb94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9764d60f-db51-4b6d-b45b-7755ca69fb94")) {                    Plotly.newPlot(                        "9764d60f-db51-4b6d-b45b-7755ca69fb94",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-04-24T00:00:00","2023-04-24T00:30:00","2023-04-24T01:00:00","2023-04-24T01:30:00","2023-04-24T02:00:00","2023-04-24T02:30:00","2023-04-24T03:00:00","2023-04-24T03:30:00","2023-04-24T04:00:00","2023-04-24T04:30:00","2023-04-24T05:00:00","2023-04-24T05:30:00","2023-04-24T06:00:00","2023-04-24T06:30:00","2023-04-24T07:00:00","2023-04-24T07:30:00","2023-04-24T08:00:00","2023-04-24T08:30:00","2023-04-24T09:00:00","2023-04-24T09:30:00","2023-04-24T10:00:00","2023-04-24T10:30:00","2023-04-24T11:00:00","2023-04-24T11:30:00","2023-04-24T12:00:00","2023-04-24T12:30:00","2023-04-24T13:00:00","2023-04-24T13:30:00","2023-04-24T14:00:00","2023-04-24T14:30:00","2023-04-24T15:00:00","2023-04-24T15:30:00","2023-04-24T16:00:00","2023-04-24T16:30:00","2023-04-24T17:00:00","2023-04-24T17:30:00","2023-04-24T18:00:00","2023-04-24T18:30:00","2023-04-24T19:00:00","2023-04-24T19:30:00","2023-04-24T20:00:00","2023-04-24T20:30:00","2023-04-24T21:00:00","2023-04-24T21:30:00","2023-04-24T22:00:00","2023-04-24T22:30:00","2023-04-24T23:00:00","2023-04-24T23:30:00","2023-04-25T00:00:00","2023-04-25T00:30:00","2023-04-25T01:00:00","2023-04-25T01:30:00","2023-04-25T02:00:00","2023-04-25T02:30:00","2023-04-25T03:00:00","2023-04-25T03:30:00","2023-04-25T04:00:00","2023-04-25T04:30:00","2023-04-25T05:00:00","2023-04-25T05:30:00","2023-04-25T06:00:00","2023-04-25T06:30:00","2023-04-25T07:00:00","2023-04-25T07:30:00","2023-04-25T08:00:00","2023-04-25T08:30:00","2023-04-25T09:00:00","2023-04-25T09:30:00","2023-04-25T10:00:00","2023-04-25T10:30:00","2023-04-25T11:00:00","2023-04-25T11:30:00","2023-04-25T12:00:00","2023-04-25T12:30:00","2023-04-25T13:00:00","2023-04-25T13:30:00","2023-04-25T14:00:00","2023-04-25T14:30:00","2023-04-25T15:00:00","2023-04-25T15:30:00","2023-04-25T16:00:00","2023-04-25T16:30:00","2023-04-25T17:00:00","2023-04-25T17:30:00","2023-04-25T18:00:00","2023-04-25T18:30:00","2023-04-25T19:00:00","2023-04-25T19:30:00","2023-04-25T20:00:00","2023-04-25T20:30:00","2023-04-25T21:00:00","2023-04-25T21:30:00","2023-04-25T22:00:00","2023-04-25T22:30:00","2023-04-25T23:00:00","2023-04-25T23:30:00","2023-04-26T00:00:00","2023-04-26T00:30:00","2023-04-26T01:00:00","2023-04-26T01:30:00","2023-04-26T02:00:00","2023-04-26T02:30:00","2023-04-26T03:00:00","2023-04-26T03:30:00","2023-04-26T04:00:00","2023-04-26T04:30:00","2023-04-26T05:00:00","2023-04-26T05:30:00","2023-04-26T06:00:00","2023-04-26T06:30:00","2023-04-26T07:00:00","2023-04-26T07:30:00","2023-04-26T08:00:00","2023-04-26T08:30:00","2023-04-26T09:00:00","2023-04-26T09:30:00","2023-04-26T10:00:00","2023-04-26T10:30:00","2023-04-26T11:00:00","2023-04-26T11:30:00","2023-04-26T12:00:00","2023-04-26T12:30:00","2023-04-26T13:00:00","2023-04-26T13:30:00","2023-04-26T14:00:00","2023-04-26T14:30:00","2023-04-26T15:00:00","2023-04-26T15:30:00","2023-04-26T16:00:00","2023-04-26T16:30:00","2023-04-26T17:00:00","2023-04-26T17:30:00","2023-04-26T18:00:00","2023-04-26T18:30:00","2023-04-26T19:00:00","2023-04-26T19:30:00","2023-04-26T20:00:00","2023-04-26T20:30:00","2023-04-26T21:00:00","2023-04-26T21:30:00","2023-04-26T22:00:00","2023-04-26T22:30:00","2023-04-26T23:00:00","2023-04-26T23:30:00","2023-04-27T00:00:00","2023-04-27T00:30:00","2023-04-27T01:00:00","2023-04-27T01:30:00","2023-04-27T02:00:00","2023-04-27T02:30:00","2023-04-27T03:00:00","2023-04-27T03:30:00","2023-04-27T04:00:00","2023-04-27T04:3 ...

# %% [markdown]
# ## Simple model w/ data normalization

# %%
MODEL_TYPE = "simple_norm"

# %%
# Valid performances with all the features
simple_norm_res_all, simple_norm_pred_all = model_train_valid_(df, params, all_features, MODEL_TYPE, MODEL_NAME, ALL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_all
# Out:
#               Model         Type      Features       Parameters           MSE  \
# 0  LinearRegression  simple_norm  all_features  [100, 0.0, 0.0]  1.389959e+09
#
#            RMSE           MAE        R2  Adjusted_R2      Time
# 0  37282.156811  35851.425641 -7.372336    -7.373053  2.155105

# %%
show_results(simple_norm_pred_all, MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Valid performances with the corr matrix features
simple_norm_res_more_rel, simple_norm_pred_more_rel = model_train_valid_(df, params, more_rel_features, MODEL_TYPE, MODEL_NAME, MORE_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_more_rel
# Out:
#               Model         Type           Features       Parameters  \
# 0  LinearRegression  simple_norm  more_rel_features  [100, 0.0, 0.0]
#
#             MSE          RMSE          MAE        R2  Adjusted_R2      Time
# 0  1.137579e+08  10665.736198  7933.800274  0.314786     0.314727  1.842914

# %%
show_results(simple_norm_pred_more_rel, MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Valid performances with the corr matrix features
simple_norm_res_less_rel, simple_norm_pred_less_rel = model_train_valid_(df, params, less_rel_features, MODEL_TYPE, MODEL_NAME, LESS_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_less_rel
# Out:
#               Model         Type           Features       Parameters  \
# 0  LinearRegression  simple_norm  less_rel_features  [100, 0.0, 0.0]
#
#             MSE          RMSE           MAE        R2  Adjusted_R2      Time
# 0  6.550647e+08  25594.230853  21953.469488 -2.945743     -2.94608  4.213806

# %%
show_results(simple_norm_pred_less_rel, MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## [TOFIX] Cross validation functions ❗

# %%
####################
# CROSS VALIDATION #
####################

def cross_validation(dataset, features_label, target_label, k_fold=5):
    # Linear regression
    model = LinearRegression(featuresCol=features_label, labelCol=target_label)
    pipeline = Pipeline(stages=[model])

    param_grid = ParamGridBuilder()\
    .addGrid(model.maxIter, [5, 10, 50, 80, 100]) \
    .addGrid(model.regParam, np.arange(0,1,0.2).round(decimals=2)) \
    .addGrid(model.elasticNetParam, np.arange(0,1,0.2).round(decimals=2)) \
    .build()

    cross_val = CrossValidator(estimator=pipeline,
                               estimatorParamMaps=param_grid,
                               evaluator=RegressionEvaluator(labelCol=target_label),
                               numFolds=k_fold,
                               collectSubModels=True
                               )

    # Run cross-validation, and choose the best set of parameters.
    cv_model = cross_val.fit(dataset)

    return cv_model

# %% [markdown]
# ## Cross validation ❗

# %%
CHOSEN_FEATURES = more_rel_features
CHOSEN_FEATURES_LABEL = MORE_REL_FEATURES_NAME

# %%
norm_df = select_normalized_features(df, CHOSEN_FEATURES, FEATURES_LABEL, TARGET_LABEL)

train_data, test_data = dataset_split(norm_df)

# %%
# Execute cross validation with linear regression
cv_models = cross_validation(train_data, FEATURES_LABEL, TARGET_LABEL)

# Summarize average error
for i, avg_rmse in enumerate(cv_models.avgMetrics):
    print("Avg. RMSE computed across k-fold cross validation for model setting #{:d}: {:3f}".format(i+1, avg_rmse))
# Out:
# Avg. RMSE computed across k-fold cross validation for model setting #1: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #2: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #3: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #4: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #5: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #6: 7628.411135
# Avg. RMSE computed across k-fold cross validation for model setting #7: 11616.089962
# Avg. RMSE computed across k-fold cross validation for model setting #8: 11515.869037
# Avg. RMSE computed across k-fold cross validation for model setting #9: 11520.088786
# Avg. RMSE computed across k-fold cross validation for model setting #10: 11520.083447
# Avg. RMSE computed across k-fold cross validation for model setting #11: 7628.809222
# Avg. RMSE computed across k-fold cross validation for model setting #12: 11515.867795
# Avg. RMSE computed across k-fold cross validation for model setting #13: 11520.082285
# Avg. RMSE computed across k-fold cross validation for model setting #14: 11520.071609
# Avg. RMSE computed across k-fold cross validation for model setting #15: 13707.052564
# Avg. RMSE computed across k-fold cross validation for model setting #16: 7629.087013
# Avg. RMSE computed across k-fold cross validation for model setting #17: 11520.086461
# Avg. RMSE computed across k-fold cross validation for model setting #18: 11520.070447
# Avg. RMSE computed across k-fold cross validation for model setting #19: 13706.841599
# Avg. RMSE computed across k-fold cross validation for model setting #20: 13706.886060
# Avg. RMSE computed across k-fold cross validation for model setting #21: 7629.285106
# Avg. RMSE computed across k-fold cross validation for model setting #22: 11520.079961
# Avg. RMSE computed across k-fold cross validation for model setting #23: 13706.601046
# Avg. RMSE computed across k-fold cross validation for model setting #24: 13706.660343
# Avg. RMSE computed across k-fold cross validation for model setting #25: 13706.719494
# Avg. RMSE computed across k-fold cross validation for model setting #26: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #27: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #28: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #29: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #30: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #31: 7628.411135
# Avg. RMSE computed across k-fold cross validation for model setting #32: 9165.895894
# Avg. RMSE computed across k-fold cross validation for model setting #33: 9172.196946
# Avg. RMSE computed across k-fold cross validation for model setting #34: 9256.661641
# Avg. RMSE computed across k-fold cross validation for model setting #35: 9256.697935
# Avg. RMSE computed across k-fold cross validation for model setting #36: 7628.809222
# Avg. RMSE computed across k-fold cross validation for model setting #37: 9172.233139
# Avg. RMSE computed across k-fold cross validation for model setting #38: 9256.624557
# Avg. RMSE computed across k-fold cross validation for model setting #39: 9256.697158
# Avg. RMSE computed across k-fold cross validation for model setting #40: 8986.259852
# Avg. RMSE computed across k-fold cross validation for model setting #41: 7629.087013
# Avg. RMSE computed across k-fold cross validation for model setting #42: 9256.514953
# Avg. RMSE computed across k-fold cross validation for model setting #43: 9256.623837
# Avg. RMSE computed across k-fold cross validation for model setting #44: 9066.440583
# Avg. RMSE computed across k-fold cross validation for model setting #45: 9066.471461
# Avg. RMSE computed across k-fold cross validation for model setting #46: 7629.285106
# Avg. RMSE computed across k-fold cross validation for model setting #47: 9256.477987
# Avg. RMSE computed across k-fold cross validation for model setting #48: 8986.297272
# Avg. RMSE computed across k-fold cross validation for model setting #49: 9066.496575
# Avg. RMSE computed across k-fold cross validation for model setting #50: 9066.537803
# Avg. RMSE computed across k-fold cross validation for model setting #51: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #52: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #53: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #54: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #55: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #56: 7628.411135
# Avg. RMSE computed across k-fold cross validation for model setting #57: 7781.038403
# Avg. RMSE computed across k-fold cross validation for model setting #58: 7804.284364
# Avg. RMSE computed across k-fold cross validation for model setting #59: 7729.952031
# Avg. RMSE computed across k-fold cross validation for model setting #60: 7745.947091
# Avg. RMSE computed across k-fold cross validation for model setting #61: 7628.809222
# Avg. RMSE computed across k-fold cross validation for model setting #62: 7804.211962
# Avg. RMSE computed across k-fold cross validation for model setting #63: 7729.934198
# Avg. RMSE computed across k-fold cross validation for model setting #64: 7745.901309
# Avg. RMSE computed across k-fold cross validation for model setting #65: 7697.202171
# Avg. RMSE computed across k-fold cross validation for model setting #66: 7629.087013
# Avg. RMSE computed across k-fold cross validation for model setting #67: 7729.927492
# Avg. RMSE computed across k-fold cross validation for model setting #68: 7729.913767
# Avg. RMSE computed across k-fold cross validation for model setting #69: 7756.669075
# Avg. RMSE computed across k-fold cross validation for model setting #70: 7756.690745
# Avg. RMSE computed across k-fold cross validation for model setting #71: 7629.285106
# Avg. RMSE computed across k-fold cross validation for model setting #72: 7729.911393
# Avg. RMSE computed across k-fold cross validation for model setting #73: 7697.219394
# Avg. RMSE computed across k-fold cross validation for model setting #74: 7756.716120
# Avg. RMSE computed across k-fold cross validation for model setting #75: 7756.741046
# Avg. RMSE computed across k-fold cross validation for model setting #76: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #77: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #78: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #79: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #80: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #81: 7628.411135
# Avg. RMSE computed across k-fold cross validation for model setting #82: 7669.228683
# Avg. RMSE computed across k-fold cross validation for model setting #83: 7675.561199
# Avg. RMSE computed across k-fold cross validation for model setting #84: 7653.924027
# Avg. RMSE computed across k-fold cross validation for model setting #85: 7654.052461
# Avg. RMSE computed across k-fold cross validation for model setting #86: 7628.809222
# Avg. RMSE computed across k-fold cross validation for model setting #87: 7675.506796
# Avg. RMSE computed across k-fold cross validation for model setting #88: 7653.910303
# Avg. RMSE computed across k-fold cross validation for model setting #89: 7654.008143
# Avg. RMSE computed across k-fold cross validation for model setting #90: 7642.876086
# Avg. RMSE computed across k-fold cross validation for model setting #91: 7629.087013
# Avg. RMSE computed across k-fold cross validation for model setting #92: 7654.351548
# Avg. RMSE computed across k-fold cross validation for model setting #93: 7653.908963
# Avg. RMSE computed across k-fold cross validation for model setting #94: 7655.208455
# Avg. RMSE computed across k-fold cross validation for model setting #95: 7655.193532
# Avg. RMSE computed across k-fold cross validation for model setting #96: 7629.285106
# Avg. RMSE computed across k-fold cross validation for model setting #97: 7654.338452
# Avg. RMSE computed across k-fold cross validation for model setting #98: 7643.167764
# Avg. RMSE computed across k-fold cross validation for model setting #99: 7654.621292
# Avg. RMSE computed across k-fold cross validation for model setting #100: 7654.598127
# Avg. RMSE computed across k-fold cross validation for model setting #101: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #102: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #103: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #104: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #105: 7628.021110
# Avg. RMSE computed across k-fold cross validation for model setting #106: 7628.411135
# Avg. RMSE computed across k-fold cross validation for model setting #107: 7642.390342
# Avg. RMSE computed across k-fold cross validation for model setting #108: 7644.034775
# Avg. RMSE computed across k-fold cross validation for model setting #109: 7636.505833
# Avg. RMSE computed across k-fold cross validation for model setting #110: 7636.383210
# Avg. RMSE computed across k-fold cross validation for model setting #111: 7628.809222
# Avg. RMSE computed across k-fold cross validation for model setting #112: 7643.654697
# Avg. RMSE computed across k-fold cross validation for model setting #113: 7636.303328
# Avg. RMSE computed across k-fold cross validation for model setting #114: 7636.311101
# Avg. RMSE computed across k-fold cross validation for model setting #115: 7635.631532
# Avg. RMSE computed across k-fold cross validation for model setting #116: 7629.087013
# Avg. RMSE computed across k-fold cross validation for model setting #117: 7636.973889
# Avg. RMSE computed across k-fold cross validation for model setting #118: 7636.342344
# Avg. RMSE computed across k-fold cross validation for model setting #119: 7641.847122
# Avg. RMSE computed across k-fold cross validation for model setting #120: 7641.825503
# Avg. RMSE computed across k-fold cross validation for model setting #121: 7629.285106
# Avg. RMSE computed across k-fold cross validation for model setting #122: 7636.964837
# Avg. RMSE computed across k-fold cross validation for model setting #123: 7635.728928
# Avg. RMSE computed across k-fold cross validation for model setting #124: 7640.944565
# Avg. RMSE computed across k-fold cross validation for model setting #125: 7640.969671
# Best parameters:
# aggregationDepth = 2
# elasticNetParam = 0.0
# epsilon = 1.35
# featuresCol = features
# fitIntercept = True
# labelCol = next-market-price
# loss = squaredError
# maxBlockSizeInMB = 0.0
# maxIter = 5
# predictionCol = prediction
# regParam = 0.0
# solver = auto
# standardization = True
# tol = 1e-06

# %%
# Get the best model to extract best hyperparameters
best_model_params = cv_models.bestModel.stages[-1].extractParamMap()
print("Best parameters:")
for param, value in best_model_params.items():
    print(param.name, "=", value)

# %% [markdown]
# ## Validate model ❗

# %%
# Fit a model with best parameters
model = LinearRegression(featuresCol=FEATURES_LABEL, labelCol=TARGET_LABEL, elasticNetParam=0.0, regParam=0.0, maxIter=5)
pipeline = Pipeline(stages=[model])

trained_model = pipeline.fit(train_data)

# %%
# Training set evaluation
training = trained_model.transform(train_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, training)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "trained",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#             MSE         RMSE          MAE        R2  Adjusted_R2
# 0  5.818178e+07  7627.698084  5854.065013  0.782775     0.782766

# %%
show_results(training.toPandas(), MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Testing set evaluation
predictions = trained_model.transform(test_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, predictions)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "predictions",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#             MSE         RMSE          MAE         R2  Adjusted_R2
# 0  1.106620e+07  3326.590039  2595.856104 -11.859782   -11.904621

# %%
show_results(predictions.toPandas(), MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f3d29af6-aa80-40cc-9134-a40eaed103c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3d29af6-aa80-40cc-9134-a40eaed103c0")) {                    Plotly.newPlot(                        "f3d29af6-aa80-40cc-9134-a40eaed103c0",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-04-24T00:00:00","2023-04-24T00:30:00","2023-04-24T01:00:00","2023-04-24T01:30:00","2023-04-24T02:00:00","2023-04-24T02:30:00","2023-04-24T03:00:00","2023-04-24T03:30:00","2023-04-24T04:00:00","2023-04-24T04:30:00","2023-04-24T05:00:00","2023-04-24T05:30:00","2023-04-24T06:00:00","2023-04-24T06:30:00","2023-04-24T07:00:00","2023-04-24T07:30:00","2023-04-24T08:00:00","2023-04-24T08:30:00","2023-04-24T09:00:00","2023-04-24T09:30:00","2023-04-24T10:00:00","2023-04-24T10:30:00","2023-04-24T11:00:00","2023-04-24T11:30:00","2023-04-24T12:00:00","2023-04-24T12:30:00","2023-04-24T13:00:00","2023-04-24T13:30:00","2023-04-24T14:00:00","2023-04-24T14:30:00","2023-04-24T15:00:00","2023-04-24T15:30:00","2023-04-24T16:00:00","2023-04-24T16:30:00","2023-04-24T17:00:00","2023-04-24T17:30:00","2023-04-24T18:00:00","2023-04-24T18:30:00","2023-04-24T19:00:00","2023-04-24T19:30:00","2023-04-24T20:00:00","2023-04-24T20:30:00","2023-04-24T21:00:00","2023-04-24T21:30:00","2023-04-24T22:00:00","2023-04-24T22:30:00","2023-04-24T23:00:00","2023-04-24T23:30:00","2023-04-25T00:00:00","2023-04-25T00:30:00","2023-04-25T01:00:00","2023-04-25T01:30:00","2023-04-25T02:00:00","2023-04-25T02:30:00","2023-04-25T03:00:00","2023-04-25T03:30:00","2023-04-25T04:00:00","2023-04-25T04:30:00","2023-04-25T05:00:00","2023-04-25T05:30:00","2023-04-25T06:00:00","2023-04-25T06:30:00","2023-04-25T07:00:00","2023-04-25T07:30:00","2023-04-25T08:00:00","2023-04-25T08:30:00","2023-04-25T09:00:00","2023-04-25T09:30:00","2023-04-25T10:00:00","2023-04-25T10:30:00","2023-04-25T11:00:00","2023-04-25T11:30:00","2023-04-25T12:00:00","2023-04-25T12:30:00","2023-04-25T13:00:00","2023-04-25T13:30:00","2023-04-25T14:00:00","2023-04-25T14:30:00","2023-04-25T15:00:00","2023-04-25T15:30:00","2023-04-25T16:00:00","2023-04-25T16:30:00","2023-04-25T17:00:00","2023-04-25T17:30:00","2023-04-25T18:00:00","2023-04-25T18:30:00","2023-04-25T19:00:00","2023-04-25T19:30:00","2023-04-25T20:00:00","2023-04-25T20:30:00","2023-04-25T21:00:00","2023-04-25T21:30:00","2023-04-25T22:00:00","2023-04-25T22:30:00","2023-04-25T23:00:00","2023-04-25T23:30:00","2023-04-26T00:00:00","2023-04-26T00:30:00","2023-04-26T01:00:00","2023-04-26T01:30:00","2023-04-26T02:00:00","2023-04-26T02:30:00","2023-04-26T03:00:00","2023-04-26T03:30:00","2023-04-26T04:00:00","2023-04-26T04:30:00","2023-04-26T05:00:00","2023-04-26T05:30:00","2023-04-26T06:00:00","2023-04-26T06:30:00","2023-04-26T07:00:00","2023-04-26T07:30:00","2023-04-26T08:00:00","2023-04-26T08:30:00","2023-04-26T09:00:00","2023-04-26T09:30:00","2023-04-26T10:00:00","2023-04-26T10:30:00","2023-04-26T11:00:00","2023-04-26T11:30:00","2023-04-26T12:00:00","2023-04-26T12:30:00","2023-04-26T13:00:00","2023-04-26T13:30:00","2023-04-26T14:00:00","2023-04-26T14:30:00","2023-04-26T15:00:00","2023-04-26T15:30:00","2023-04-26T16:00:00","2023-04-26T16:30:00","2023-04-26T17:00:00","2023-04-26T17:30:00","2023-04-26T18:00:00","2023-04-26T18:30:00","2023-04-26T19:00:00","2023-04-26T19:30:00","2023-04-26T20:00:00","2023-04-26T20:30:00","2023-04-26T21:00:00","2023-04-26T21:30:00","2023-04-26T22:00:00","2023-04-26T22:30:00","2023-04-26T23:00:00","2023-04-26T23:30:00","2023-04-27T00:00:00","2023-04-27T00:30:00","2023-04-27T01:00:00","2023-04-27T01:30:00","2023-04-27T02:00:00","2023-04-27T02:30:00","2023-04-27T03:00:00","2023-04-27T03:30:00","2023-04-27T04:00:00","2023-04-27T04:3 ...

# %% [markdown]
# ## Train final model ❗

# %%
train_valid_data = select_normalized_features(df, CHOSEN_FEATURES, FEATURES_LABEL, TARGET_LABEL)

# %%
# Fit a model with best parameters
model = LinearRegression(featuresCol=FEATURES_LABEL, labelCol=TARGET_LABEL, elasticNetParam=0.0, regParam=0.0, maxIter=5)
pipeline = Pipeline(stages=[model])

trained_model = pipeline.fit(train_valid_data)

# %%
# Training set evaluation
training = trained_model.transform(train_valid_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, training)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "trained_final",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#             MSE         RMSE          MAE        R2  Adjusted_R2
# 0  5.764963e+07  7592.735531  5824.634389  0.783723     0.783715

# %%
show_results(training.toPandas(), MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Output

# %%
# Save the trained model
lr_model_final.write().overwrite().save(GDRIVE_MODEL)
