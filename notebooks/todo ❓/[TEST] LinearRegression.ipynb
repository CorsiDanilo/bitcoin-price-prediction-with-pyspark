# %% [markdown]
# # **Bitcoin price forecasting - GBTRegressor**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author
# Corsi Danilo - corsi.1742375@studenti.uniroma1.it

# %% [markdown]
# ## Global constants, dependencies, libraries and tools

# %%
# Main constants
GDRIVE_DIR = "/content/drive"
MODEL_NAME = "LinearRegression"
SLOW_OPERATIONS = True

# %%
# Datasets dirs
GDRIVE_DATASET_OUTPUT_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/datasets/output"

# Datasets names
DATASET_TRAIN_VALID_NAME = "bitcoin_blockchain_data_30min_train_valid"

# Datasets paths
GDRIVE_DATASET_TRAIN_VALID  = GDRIVE_DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

# --------------------------------------------- #

# Features dir
GDRIVE_FEATURES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/features"

# Features names
ALL_FEATURES_NAME = "all_features"
MORE_REL_FEATURES_NAME = "more_rel_features"
LESS_REL_FEATURES_NAME = "less_rel_features"

# Features labels
FEATURES_LABEL = "features"
TARGET_LABEL = "next-market-price"

# Features paths
GDRIVE_ALL_FEATURES = GDRIVE_FEATURES_DIR + "/" + ALL_FEATURES_NAME + ".json"
GDRIVE_MORE_REL_FEATURES = GDRIVE_FEATURES_DIR + "/" + MORE_REL_FEATURES_NAME + ".json"
GDRIVE_LESS_REL_FEATURES = GDRIVE_FEATURES_DIR + "/" + LESS_REL_FEATURES_NAME + ".json"

# --------------------------------------------- #

# Model dir
GDRIVE_MODELS_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/models"

# Model path
GDRIVE_MODEL = GDRIVE_MODELS_DIR + "/" + MODEL_NAME

# --------------------------------------------- #

# Utilities dir
GDRIVE_UTILITIES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/utilities"

# %%
# Point Colaboratory to our Google Drive
from google.colab import drive

# Define GDrive paths
drive.mount(GDRIVE_DIR, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Install Spark and related dependencies
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285387 sha256=32d72a9cedcdc10e1e97f6995f360aa79b843bcbb88f1fb0b4941f180aa5e08d
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %% [markdown]
# ## Import files

# %%
import sys
sys.path.append(GDRIVE_UTILITIES_DIR)

from imports import *
import utilities, parameters

importlib.reload(utilities)
importlib.reload(parameters)
# Out:
# <module 'parameters' from '/content/drive/MyDrive/BDC/project/utilities/parameters.py'>

# %% [markdown]
# ## Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '4G').\
                set('spark.driver.memory', '45G').\
                set('spark.driver.maxResultSize', '10G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPriceForecasting").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Loading dataset

# %%
# Load datasets into pyspark dataset objects
df = spark.read.load(GDRIVE_DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
if SLOW_OPERATIONS:
  dataset_info(df)
# Out:
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |          timestamp| id|      market-price|total-bitcoins|         market-cap|  trade-volume|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|        hash-rate|         difficulty|    miners-revenue|transaction-fees-usd|n-unique-addresses|    n-transactions|estimated-transaction-volume-usd|      rate-of-change|        sma-5-days|        sma-7-days|       sma-10-days|       sma-20-days|       sma-50-days|      sma-100-days| next-market-price|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |2016-01-01 00:00:00|  0|            430.89|   1.5029575E7|      6.474139727E9|  2860153.0242|      54604.791735| 0.493407133333333|        1.01155706E8|                   919.2| 697129.166405808|1.03880340815456E11|  1554768.75755142|    8783.06385149973|          263121.0|          124092.0|              5.83462646538702E7| 0.01866292247827417|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|430.97041666666667|
# |2016-01-01 00:30:00|  1|430.97041666666667|1.5029690625E7|6.474671910552083E9|2834859.039425|54606.164985937496|0.4952058123084288|1.0115826085416667E8|       921.4635057471265|697344.3297287727|1.03880340815456E11|1557198.9846382332|    8887.55143320559|       264578.9375|124611.70833333333|             5.818972467025057E7|0.018659440081436607|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|        431.010625|431.05083333333334|
# |2016-01-01 01:00:00|  2|431.05083333333334| 1.502980625E7|6.475204094104167E9| 2809565.05465|   54607.538236875|0.4970044912835246|1.0116081570833333E8|        923.727011494253|697559.4930517374|1.03880340815456E11|1559629.2117250462|    8992.03901491145|        266036.875|125131.41666666667|             5.803318468663094E7| 0.01865595898393746| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333| 431.0508333333333|431.13124999999997|
# +-------------------+---+------------------+--------------+-------------------+--------------+------------------+------------------+--------------------+------------------------+-----------------+-------------------+------------------+--------------------+------------------+------------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 3 rows
#
# Shape: (129600, 25)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- rate-of-change: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# ## Loading features

# %%
# Loading correlation matrix features
with open(GDRIVE_ALL_FEATURES, "r") as f:
    all_features = json.load(f)
print(all_features)
# Out:
# ['market-price', 'total-bitcoins', 'market-cap', 'trade-volume', 'blocks-size', 'avg-block-size', 'n-transactions-total', 'n-transactions-per-block', 'hash-rate', 'difficulty', 'miners-revenue', 'transaction-fees-usd', 'n-unique-addresses', 'n-transactions', 'estimated-transaction-volume-usd', 'rate-of-change', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'sma-20-days', 'sma-50-days', 'sma-100-days']

# %%
# Loading correlation matrix features
with open(GDRIVE_MORE_REL_FEATURES, "r") as f:
    more_rel_features = json.load(f)
print(more_rel_features)
# Out:
# ['market-price', 'market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'n-transactions-total', 'blocks-size', 'sma-100-days', 'total-bitcoins']

# %%
# Loading correlation matrix features
with open(GDRIVE_LESS_REL_FEATURES, "r") as f:
    less_rel_features = json.load(f)
print(less_rel_features)
# Out:
# ['sma-20-days', 'sma-50-days', 'n-unique-addresses', 'difficulty', 'hash-rate', 'avg-block-size', 'transaction-fees-usd', 'trade-volume', 'n-transactions-per-block', 'n-transactions', 'rate-of-change']

# %% [markdown]
# ## [TOFIX] Shared functions ❗

# %%
from itertools import product
from dateutil.relativedelta import relativedelta

##########
# SHARED #
##########

# Return the dataset with the selected features
def select_features(dataset, features, features_label, target_label):
  vectorAssembler = VectorAssembler(inputCols = features, outputCol = features_label)
  dataset = vectorAssembler.transform(dataset).select("timestamp", "id", features_label, target_label)

  return dataset

# Normalized / standardized features selection
def select_normalized_features(dataset, features, features_label, target_label):
    # Assemble the columns into a vector column
    assembler = VectorAssembler(inputCols = features, outputCol = "raw_features")
    df_vector  = assembler.transform(dataset).select("timestamp", "id", "raw_features", target_label)

    # Create a Normalizer instance
    normalizer = Normalizer(inputCol="raw_features", outputCol=features_label)

    # Fit and transform the data
    normalized_data = normalizer.transform(df_vector).select("timestamp", "id", features_label, target_label)

    return normalized_data

def dataset_split(dataset, proportion = 0.9):
    records_num = dataset.count()
    split_point = int(records_num * proportion)

    train_data = dataset.filter(dataset['id'] < split_point)
    valid_data = dataset.filter(dataset['id'] >= split_point)

    return train_data, valid_data

# def dataset_split(dataset):
#     # Retrieve the last value of the column
#     last_value = dataset.agg(last("timestamp")).collect()[0][0]

#     # Sottrai un mese dalla data di partenza
#     split_date = last_value - relativedelta(months=3)

#     # Split the dataset based on the desired date
#     train_data = dataset[dataset['timestamp'] <= split_date]
#     valid_data = dataset[dataset['timestamp'] > split_date]

#     return train_data, valid_data

def show_results(results, ml_model):
  trace1 = go.Scatter(
      x = results['timestamp'],
      y = results['next-market-price'].astype(float),
      mode = 'lines',
      name = 'Next Market price (usd)'
  )

  trace2 = go.Scatter(
      x = results['timestamp'],
      y = results['prediction'].astype(float),
      mode = 'lines',
      name = 'Predicted next makert price (usd)'
  )

  layout = dict(
      title= ml_model +' predicitons',
      xaxis=dict(
          rangeselector=dict(
              buttons=list([
                  #change the count to desired amount of months.
                  dict(count=1,
                      label='1m',
                      step='month',
                      stepmode='backward'),
                  dict(count=6,
                      label='6m',
                      step='month',
                      stepmode='backward'),
                  dict(count=12,
                      label='1y',
                      step='month',
                      stepmode='backward'),
                  dict(count=36,
                      label='3y',
                      step='month',
                      stepmode='backward'),
                  dict(step='all')
              ])
          ),
          rangeslider=dict(
              visible = True
          ),
          type='date'
      )
  )

  data = [trace1,trace2]
  fig = dict(data=data, layout=layout)
  iplot(fig, filename = ml_model +' predicitons')

# def modelComparison(cv_result, model_info, evaluator_lst):
#     # Calculate mean of all splits on chosen evaluator
#     col_mean_df = cv_result[evaluator_lst].mean().to_frame().T

#     # Extract model info
#     model_info_df = cv_result[model_info][:1]

#     # Concatenate by row
#     comparison_df = pd.concat([model_info_df,col_mean_df], axis=1)

#     return comparison_df

def model_selection(model_name, param, features_label, target_label):
    if model_name == "LinearRegression":
        model = LinearRegression(featuresCol=features_label, \
                                    labelCol=target_label, \
                                    maxIter=param['maxIter'], \
                                    regParam=param['regParam'], \
                                    elasticNetParam=param['elasticNetParam'])

    elif model_name == "GeneralizedLinearRegression":
        model = GeneralizedLinearRegression(featuresCol=features_label, \
                                            labelCol=target_label, \
                                            maxIter=param['maxIter'], \
                                            regParam=param['regParam'])

    elif model_name == "RandomForestRegressor":
        model = RandomForestRegressor(featuresCol=features_label, \
                                        labelCol=target_label, \
                                        numTrees = param["numTrees"], \
                                        maxDepth = param["maxDepth"])

    elif model_name == "GBTRegressor":
        model = GBTRegressor(featuresCol=features_label, \
                                labelCol=target_label, \
                                maxIter = param['maxIter'], \
                                maxDepth = param['maxDepth'], \
                                stepSize = param['stepSize'])
    return model

def model_evaluation(target_label, predictions):
    mse_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='mse')
    rmse_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='rmse')
    mae_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='mae')
    r2_evaluator = RegressionEvaluator(labelCol=target_label, predictionCol="prediction", metricName='r2')

    mse = mse_evaluator.evaluate(predictions)
    rmse = rmse_evaluator.evaluate(predictions)
    mae = mae_evaluator.evaluate(predictions)
    r2 = r2_evaluator.evaluate(predictions)

    # Adjusted R-squared
    n = predictions.count()
    p = len(predictions.columns)
    adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)

    results = {'mse':mse, 'rmse':rmse, 'mae':mae, 'r2':r2, 'adj_r2':adj_r2}

    return results

# %% [markdown]
# ## [TOFIX] Simple model functions ❗

# %%
############################
# MODEL TRAIN / VALIDATION #
############################

# Function that create simple models (without hyperparameter tuning) and evaluate them
def model_train_valid(dataset, params, features, model_type, model_name, features_name, features_label, target_label):
    # Select train and valid data features
    if model_type == "simple":
        dataset = select_features(dataset, features, features_label, target_label)
    elif model_type == "simple_norm" or model_type == "final_validated":
        dataset = select_normalized_features(dataset, features, features_label, target_label)

    # ALL combination of params
    param_lst = [dict(zip(params, param)) for param in product(*params.values())]

    for param in param_lst:
        # Chosen Model
        model = model_selection(model_name, param, features_label, target_label)

        # Split dataset
        train_data, valid_data = dataset_split(dataset)

        # Chain assembler and model in a Pipeline
        pipeline = Pipeline(stages=[model])
        # Train a model and calculate running time
        start = time.time()
        pipeline_model = pipeline.fit(train_data)
        end = time.time()

        # Make predictions
        predictions = pipeline_model.transform(valid_data).select(target_label, "prediction", 'timestamp')

        # Compute validation error by several evaluators
        eval_res = model_evaluation(target_label, predictions)

        # Use dict to store each result
        results = {
            "Model": model_name,
            "Type": model_type,
            "Features": features_name,
            "Parameters": [list(param.values())],
            "MSE": eval_res['mse'],
            "RMSE": eval_res['rmse'],
            "MAE": eval_res['mae'],
            "R2": eval_res['r2'],
            "Adjusted_R2": eval_res['adj_r2'],
            "Time": end - start,
        }

    # Transform dict to pandas dataset
    results_pd = pd.DataFrame(results, index=[0])

    return results_pd, predictions.toPandas()

# %% [markdown]
# ## Simple model ❗

# %%
MODEL_TYPE = "simple"

# %%
# Get default params
params = parameters.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'maxIter': [100], 'regParam': [0.0], 'elasticNetParam': [0.0]}

# %%
# Valid performances with all the features
simple_res_all, simple_pred_all = model_train_valid(df, params, all_features, MODEL_TYPE, MODEL_NAME, ALL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_all
# Out:
#               Model    Type      Features       Parameters        MSE  \
# 0  LinearRegression  simple  all_features  [100, 0.0, 0.0]  27.981816
#
#        RMSE       MAE        R2  Adjusted_R2      Time
# 0  5.289784  3.924561  0.999996     0.999996  2.258611

# %%
show_results(simple_pred_all, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2f826f44-9111-4108-a687-52a70832405f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f826f44-9111-4108-a687-52a70832405f")) {                    Plotly.newPlot(                        "2f826f44-9111-4108-a687-52a70832405f",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_res_more_rel, simple_pred_more_rel = model_train_valid(df, params, more_rel_features, MODEL_TYPE, MODEL_NAME, MORE_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_more_rel
# Out:
#               Model    Type           Features       Parameters         MSE  \
# 0  LinearRegression  simple  more_rel_features  [100, 0.0, 0.0]  273.824136
#
#         RMSE        MAE        R2  Adjusted_R2      Time
# 0  16.547632  13.776806  0.999957     0.999957  1.600108

# %%
show_results(simple_pred_more_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="18866de7-9f31-4a66-bcc3-70600b92ae2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18866de7-9f31-4a66-bcc3-70600b92ae2b")) {                    Plotly.newPlot(                        "18866de7-9f31-4a66-bcc3-70600b92ae2b",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_res_less_rel, simple_pred_less_rel = model_train_valid(df, params, less_rel_features, MODEL_TYPE, MODEL_NAME, LESS_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_res_less_rel
# Out:
#               Model    Type           Features       Parameters           MSE  \
# 0  LinearRegression  simple  less_rel_features  [100, 0.0, 0.0]  2.768810e+08
#
#            RMSE           MAE         R2  Adjusted_R2      Time
# 0  16639.740904  12896.784087 -42.094193   -42.124484  1.682067

# %%
show_results(simple_pred_less_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f3a2be37-dd97-4d91-b34b-89d8e5936967" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3a2be37-dd97-4d91-b34b-89d8e5936967")) {                    Plotly.newPlot(                        "f3a2be37-dd97-4d91-b34b-89d8e5936967",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %% [markdown]
# ## Simple model w/ data normalization

# %%
MODEL_TYPE = "simple_norm"

# %%
# Valid performances with all the features
simple_norm_res_all, simple_norm_pred_all = model_train_valid(df, params, all_features, MODEL_TYPE, MODEL_NAME, ALL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_all
# Out:
#               Model         Type      Features       Parameters           MSE  \
# 0  LinearRegression  simple_norm  all_features  [100, 0.0, 0.0]  1.010612e+08
#
#            RMSE          MAE         R2  Adjusted_R2      Time
# 0  10052.922436  9828.497423 -14.729333   -14.740389  3.786674

# %%
show_results(simple_norm_pred_all, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b33c827-41b9-4023-8eda-660f2c97417e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b33c827-41b9-4023-8eda-660f2c97417e")) {                    Plotly.newPlot(                        "1b33c827-41b9-4023-8eda-660f2c97417e",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_norm_res_more_rel, simple_norm_pred_more_rel = model_train_valid(df, params, more_rel_features, MODEL_TYPE, MODEL_NAME, MORE_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_more_rel
# Out:
#               Model         Type           Features       Parameters  \
# 0  LinearRegression  simple_norm  more_rel_features  [100, 0.0, 0.0]
#
#             MSE         RMSE          MAE        R2  Adjusted_R2      Time
# 0  8.653073e+06  2941.610532  2361.208367 -0.346778    -0.347725  1.848652

# %%
show_results(simple_norm_pred_more_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0917d230-b67e-422c-ab8c-8915391ca71f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0917d230-b67e-422c-ab8c-8915391ca71f")) {                    Plotly.newPlot(                        "0917d230-b67e-422c-ab8c-8915391ca71f",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %%
# Valid performances with the corr matrix features
simple_norm_res_less_rel, simple_norm_pred_less_rel = model_train_valid(df, params, less_rel_features, MODEL_TYPE, MODEL_NAME, LESS_REL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
simple_norm_res_less_rel
# Out:
#               Model         Type           Features       Parameters  \
# 0  LinearRegression  simple_norm  less_rel_features  [100, 0.0, 0.0]
#
#             MSE          RMSE           MAE         R2  Adjusted_R2      Time
# 0  1.952197e+08  13972.104954  13514.142908 -29.384305   -29.405662  1.737239

# %%
show_results(simple_norm_pred_less_rel, MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="51c92ce3-8386-41da-99ab-b6b546c6a7f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51c92ce3-8386-41da-99ab-b6b546c6a7f3")) {                    Plotly.newPlot(                        "51c92ce3-8386-41da-99ab-b6b546c6a7f3",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %% [markdown]
# ## [TOFIX] Cross validation functions ❗

# %%
####################
# CROSS VALIDATION #
####################

def cross_validation(dataset, features_label, target_label, k_fold=5):
    # Linear regression
    model = LinearRegression(featuresCol=features_label, labelCol=target_label)
    pipeline = Pipeline(stages=[model])

    param_grid = ParamGridBuilder()\
    .addGrid(model.maxIter, [5, 10, 50, 80, 100]) \
    .addGrid(model.regParam, np.arange(0,1,0.2).round(decimals=2)) \
    .addGrid(model.elasticNetParam, np.arange(0,1,0.2).round(decimals=2)) \
    .build()
    # Linear regression

    cross_val = CrossValidator(estimator=pipeline,
                               estimatorParamMaps=param_grid,
                               evaluator=RegressionEvaluator(labelCol=target_label),
                               numFolds=k_fold,
                               collectSubModels=True
                               )

    # Run cross-validation, and choose the best set of parameters.
    cv_model = cross_val.fit(dataset)

    return cv_model

# %% [markdown]
# ## Cross validation ❗

# %%
CHOSEN_FEATURES = more_rel_features
CHOSEN_FEATURES_LABEL = MORE_REL_FEATURES_NAME

# %%
norm_df = select_normalized_features(df, CHOSEN_FEATURES, FEATURES_LABEL, TARGET_LABEL)

train_data, test_data = dataset_split(norm_df)

# %%
# Execute cross validation with linear regression
cv_models = cross_validation(train_data, FEATURES_LABEL, TARGET_LABEL)

# Summarize average error
for i, avg_rmse in enumerate(cv_models.avgMetrics):
    print("Avg. RMSE computed across k-fold cross validation for model setting #{:d}: {:3f}".format(i+1, avg_rmse))
# Out:
# Avg. RMSE computed across k-fold cross validation for model setting #1: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #2: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #3: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #4: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #5: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #6: 7705.947212
# Avg. RMSE computed across k-fold cross validation for model setting #7: 11724.485191
# Avg. RMSE computed across k-fold cross validation for model setting #8: 11630.485601
# Avg. RMSE computed across k-fold cross validation for model setting #9: 11634.289388
# Avg. RMSE computed across k-fold cross validation for model setting #10: 11634.283908
# Avg. RMSE computed across k-fold cross validation for model setting #11: 7706.068826
# Avg. RMSE computed across k-fold cross validation for model setting #12: 11630.484160
# Avg. RMSE computed across k-fold cross validation for model setting #13: 11634.282557
# Avg. RMSE computed across k-fold cross validation for model setting #14: 11634.271597
# Avg. RMSE computed across k-fold cross validation for model setting #15: 13821.669563
# Avg. RMSE computed across k-fold cross validation for model setting #16: 7706.151417
# Avg. RMSE computed across k-fold cross validation for model setting #17: 11634.286687
# Avg. RMSE computed across k-fold cross validation for model setting #18: 11634.270247
# Avg. RMSE computed across k-fold cross validation for model setting #19: 13821.461988
# Avg. RMSE computed across k-fold cross validation for model setting #20: 13821.504153
# Avg. RMSE computed across k-fold cross validation for model setting #21: 7706.209963
# Avg. RMSE computed across k-fold cross validation for model setting #22: 11634.279856
# Avg. RMSE computed across k-fold cross validation for model setting #23: 13821.226266
# Avg. RMSE computed across k-fold cross validation for model setting #24: 13821.282544
# Avg. RMSE computed across k-fold cross validation for model setting #25: 13821.338711
# Avg. RMSE computed across k-fold cross validation for model setting #26: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #27: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #28: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #29: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #30: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #31: 7705.947212
# Avg. RMSE computed across k-fold cross validation for model setting #32: 9248.046343
# Avg. RMSE computed across k-fold cross validation for model setting #33: 9226.302462
# Avg. RMSE computed across k-fold cross validation for model setting #34: 9182.722316
# Avg. RMSE computed across k-fold cross validation for model setting #35: 9000.156872
# Avg. RMSE computed across k-fold cross validation for model setting #36: 7706.068826
# Avg. RMSE computed across k-fold cross validation for model setting #37: 9226.351761
# Avg. RMSE computed across k-fold cross validation for model setting #38: 9000.168151
# Avg. RMSE computed across k-fold cross validation for model setting #39: 9000.163099
# Avg. RMSE computed across k-fold cross validation for model setting #40: 9069.404458
# Avg. RMSE computed across k-fold cross validation for model setting #41: 7706.151417
# Avg. RMSE computed across k-fold cross validation for model setting #42: 9182.845456
# Avg. RMSE computed across k-fold cross validation for model setting #43: 9000.174439
# Avg. RMSE computed across k-fold cross validation for model setting #44: 9151.409489
# Avg. RMSE computed across k-fold cross validation for model setting #45: 9151.441168
# Avg. RMSE computed across k-fold cross validation for model setting #46: 7706.209963
# Avg. RMSE computed across k-fold cross validation for model setting #47: 9000.190830
# Avg. RMSE computed across k-fold cross validation for model setting #48: 9069.442300
# Avg. RMSE computed across k-fold cross validation for model setting #49: 9151.466127
# Avg. RMSE computed across k-fold cross validation for model setting #50: 9151.508414
# Avg. RMSE computed across k-fold cross validation for model setting #51: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #52: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #53: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #54: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #55: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #56: 7705.947212
# Avg. RMSE computed across k-fold cross validation for model setting #57: 7868.139702
# Avg. RMSE computed across k-fold cross validation for model setting #58: 7840.553084
# Avg. RMSE computed across k-fold cross validation for model setting #59: 7784.656319
# Avg. RMSE computed across k-fold cross validation for model setting #60: 7840.206694
# Avg. RMSE computed across k-fold cross validation for model setting #61: 7706.068826
# Avg. RMSE computed across k-fold cross validation for model setting #62: 7840.555506
# Avg. RMSE computed across k-fold cross validation for model setting #63: 7840.541706
# Avg. RMSE computed across k-fold cross validation for model setting #64: 7825.157629
# Avg. RMSE computed across k-fold cross validation for model setting #65: 7772.902388
# Avg. RMSE computed across k-fold cross validation for model setting #66: 7706.151417
# Avg. RMSE computed across k-fold cross validation for model setting #67: 7782.911108
# Avg. RMSE computed across k-fold cross validation for model setting #68: 7825.181635
# Avg. RMSE computed across k-fold cross validation for model setting #69: 7808.733733
# Avg. RMSE computed across k-fold cross validation for model setting #70: 7808.738528
# Avg. RMSE computed across k-fold cross validation for model setting #71: 7706.209963
# Avg. RMSE computed across k-fold cross validation for model setting #72: 7840.562139
# Avg. RMSE computed across k-fold cross validation for model setting #73: 7769.425088
# Avg. RMSE computed across k-fold cross validation for model setting #74: 7808.773964
# Avg. RMSE computed across k-fold cross validation for model setting #75: 7808.780824
# Avg. RMSE computed across k-fold cross validation for model setting #76: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #77: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #78: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #79: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #80: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #81: 7705.947212
# Avg. RMSE computed across k-fold cross validation for model setting #82: 7752.990185
# Avg. RMSE computed across k-fold cross validation for model setting #83: 7728.164108
# Avg. RMSE computed across k-fold cross validation for model setting #84: 7720.568147
# Avg. RMSE computed across k-fold cross validation for model setting #85: 7744.265319
# Avg. RMSE computed across k-fold cross validation for model setting #86: 7706.068826
# Avg. RMSE computed across k-fold cross validation for model setting #87: 7728.183069
# Avg. RMSE computed across k-fold cross validation for model setting #88: 7743.008442
# Avg. RMSE computed across k-fold cross validation for model setting #89: 7739.390443
# Avg. RMSE computed across k-fold cross validation for model setting #90: 7719.327649
# Avg. RMSE computed across k-fold cross validation for model setting #91: 7706.151417
# Avg. RMSE computed across k-fold cross validation for model setting #92: 7719.678292
# Avg. RMSE computed across k-fold cross validation for model setting #93: 7739.443279
# Avg. RMSE computed across k-fold cross validation for model setting #94: 7726.535921
# Avg. RMSE computed across k-fold cross validation for model setting #95: 7726.570035
# Avg. RMSE computed across k-fold cross validation for model setting #96: 7706.209963
# Avg. RMSE computed across k-fold cross validation for model setting #97: 7742.396972
# Avg. RMSE computed across k-fold cross validation for model setting #98: 7722.650409
# Avg. RMSE computed across k-fold cross validation for model setting #99: 7726.646627
# Avg. RMSE computed across k-fold cross validation for model setting #100: 7726.597790
# Avg. RMSE computed across k-fold cross validation for model setting #101: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #102: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #103: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #104: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #105: 7705.825535
# Avg. RMSE computed across k-fold cross validation for model setting #106: 7705.947212
# Avg. RMSE computed across k-fold cross validation for model setting #107: 7721.342346
# Avg. RMSE computed across k-fold cross validation for model setting #108: 7711.451209
# Avg. RMSE computed across k-fold cross validation for model setting #109: 7713.656341
# Avg. RMSE computed across k-fold cross validation for model setting #110: 7722.881879
# Avg. RMSE computed across k-fold cross validation for model setting #111: 7706.068826
# Avg. RMSE computed across k-fold cross validation for model setting #112: 7711.416492
# Avg. RMSE computed across k-fold cross validation for model setting #113: 7721.912025
# Avg. RMSE computed across k-fold cross validation for model setting #114: 7721.928968
# Avg. RMSE computed across k-fold cross validation for model setting #115: 7712.321911
# Avg. RMSE computed across k-fold cross validation for model setting #116: 7706.151417
# Avg. RMSE computed across k-fold cross validation for model setting #117: 7713.002202
# Avg. RMSE computed across k-fold cross validation for model setting #118: 7722.107163
# Avg. RMSE computed across k-fold cross validation for model setting #119: 7713.921667
# Avg. RMSE computed across k-fold cross validation for model setting #120: 7713.856608
# Avg. RMSE computed across k-fold cross validation for model setting #121: 7706.209963
# Avg. RMSE computed across k-fold cross validation for model setting #122: 7722.018227
# Avg. RMSE computed across k-fold cross validation for model setting #123: 7713.045929
# Avg. RMSE computed across k-fold cross validation for model setting #124: 7713.835471
# Avg. RMSE computed across k-fold cross validation for model setting #125: 7713.839094

# %%
# Get the best model to extract best hyperparameters
best_model_params = cv_models.bestModel.stages[-1].extractParamMap()
print("Best parameters:")
for param, value in best_model_params.items():
    print(param.name, "=", value)
# Out:
# Best parameters:
# aggregationDepth = 2
# elasticNetParam = 0.0
# epsilon = 1.35
# featuresCol = features
# fitIntercept = True
# labelCol = next-market-price
# loss = squaredError
# maxBlockSizeInMB = 0.0
# maxIter = 5
# predictionCol = prediction
# regParam = 0.0
# solver = auto
# standardization = True
# tol = 1e-06

# %% [markdown]
# ## Validate model ❗

# %%
# Fit a model with best parameters
# Linear regression
model = LinearRegression(featuresCol=FEATURES_LABEL, labelCol=TARGET_LABEL, elasticNetParam=0.0, regParam=0.0, maxIter=5)
# Linear regression

pipeline = Pipeline(stages=[model])

trained_model = pipeline.fit(train_data)

# %%
# Training set evaluation
training = trained_model.transform(train_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, training)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "trained",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#               Model     Type           Features           MSE         RMSE  \
# 0  LinearRegression  trained  more_rel_features  5.937123e+07  7705.273102
#
#            MAE        R2  Adjusted_R2
# 0  5927.302645  0.780897     0.780888

# %%
show_results(training.toPandas(), MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Testing set evaluation
predictions = trained_model.transform(test_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, predictions)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "predictions",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#               Model         Type           Features           MSE  \
# 0  LinearRegression  predictions  more_rel_features  8.653073e+06
#
#           RMSE          MAE        R2  Adjusted_R2
# 0  2941.610532  2361.208367 -0.346778    -0.348356

# %%
show_results(predictions.toPandas(), MODEL_NAME)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3165f86d-1465-4135-a873-3fa743327e0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3165f86d-1465-4135-a873-3fa743327e0d")) {                    Plotly.newPlot(                        "3165f86d-1465-4135-a873-3fa743327e0d",                        [{"mode":"lines","name":"Next Market price (usd)","x":["2023-02-24T00:00:00","2023-02-24T00:30:00","2023-02-24T01:00:00","2023-02-24T01:30:00","2023-02-24T02:00:00","2023-02-24T02:30:00","2023-02-24T03:00:00","2023-02-24T03:30:00","2023-02-24T04:00:00","2023-02-24T04:30:00","2023-02-24T05:00:00","2023-02-24T05:30:00","2023-02-24T06:00:00","2023-02-24T06:30:00","2023-02-24T07:00:00","2023-02-24T07:30:00","2023-02-24T08:00:00","2023-02-24T08:30:00","2023-02-24T09:00:00","2023-02-24T09:30:00","2023-02-24T10:00:00","2023-02-24T10:30:00","2023-02-24T11:00:00","2023-02-24T11:30:00","2023-02-24T12:00:00","2023-02-24T12:30:00","2023-02-24T13:00:00","2023-02-24T13:30:00","2023-02-24T14:00:00","2023-02-24T14:30:00","2023-02-24T15:00:00","2023-02-24T15:30:00","2023-02-24T16:00:00","2023-02-24T16:30:00","2023-02-24T17:00:00","2023-02-24T17:30:00","2023-02-24T18:00:00","2023-02-24T18:30:00","2023-02-24T19:00:00","2023-02-24T19:30:00","2023-02-24T20:00:00","2023-02-24T20:30:00","2023-02-24T21:00:00","2023-02-24T21:30:00","2023-02-24T22:00:00","2023-02-24T22:30:00","2023-02-24T23:00:00","2023-02-24T23:30:00","2023-02-25T00:00:00","2023-02-25T00:30:00","2023-02-25T01:00:00","2023-02-25T01:30:00","2023-02-25T02:00:00","2023-02-25T02:30:00","2023-02-25T03:00:00","2023-02-25T03:30:00","2023-02-25T04:00:00","2023-02-25T04:30:00","2023-02-25T05:00:00","2023-02-25T05:30:00","2023-02-25T06:00:00","2023-02-25T06:30:00","2023-02-25T07:00:00","2023-02-25T07:30:00","2023-02-25T08:00:00","2023-02-25T08:30:00","2023-02-25T09:00:00","2023-02-25T09:30:00","2023-02-25T10:00:00","2023-02-25T10:30:00","2023-02-25T11:00:00","2023-02-25T11:30:00","2023-02-25T12:00:00","2023-02-25T12:30:00","2023-02-25T13:00:00","2023-02-25T13:30:00","2023-02-25T14:00:00","2023-02-25T14:30:00","2023-02-25T15:00:00","2023-02-25T15:30:00","2023-02-25T16:00:00","2023-02-25T16:30:00","2023-02-25T17:00:00","2023-02-25T17:30:00","2023-02-25T18:00:00","2023-02-25T18:30:00","2023-02-25T19:00:00","2023-02-25T19:30:00","2023-02-25T20:00:00","2023-02-25T20:30:00","2023-02-25T21:00:00","2023-02-25T21:30:00","2023-02-25T22:00:00","2023-02-25T22:30:00","2023-02-25T23:00:00","2023-02-25T23:30:00","2023-02-26T00:00:00","2023-02-26T00:30:00","2023-02-26T01:00:00","2023-02-26T01:30:00","2023-02-26T02:00:00","2023-02-26T02:30:00","2023-02-26T03:00:00","2023-02-26T03:30:00","2023-02-26T04:00:00","2023-02-26T04:30:00","2023-02-26T05:00:00","2023-02-26T05:30:00","2023-02-26T06:00:00","2023-02-26T06:30:00","2023-02-26T07:00:00","2023-02-26T07:30:00","2023-02-26T08:00:00","2023-02-26T08:30:00","2023-02-26T09:00:00","2023-02-26T09:30:00","2023-02-26T10:00:00","2023-02-26T10:30:00","2023-02-26T11:00:00","2023-02-26T11:30:00","2023-02-26T12:00:00","2023-02-26T12:30:00","2023-02-26T13:00:00","2023-02-26T13:30:00","2023-02-26T14:00:00","2023-02-26T14:30:00","2023-02-26T15:00:00","2023-02-26T15:30:00","2023-02-26T16:00:00","2023-02-26T16:30:00","2023-02-26T17:00:00","2023-02-26T17:30:00","2023-02-26T18:00:00","2023-02-26T18:30:00","2023-02-26T19:00:00","2023-02-26T19:30:00","2023-02-26T20:00:00","2023-02-26T20:30:00","2023-02-26T21:00:00","2023-02-26T21:30:00","2023-02-26T22:00:00","2023-02-26T22:30:00","2023-02-26T23:00:00","2023-02-26T23:30:00","2023-02-27T00:00:00","2023-02-27T00:30:00","2023-02-27T01:00:00","2023-02-27T01:30:00","2023-02-27T02:00:00","2023-02-27T02:30:00","2023-02-27T03:00:00","2023-02-27T03:30:00","2023-02-27T04:00:00","2023-02-27T04:3 ...

# %% [markdown]
# ## Train final model ❗

# %%
train_valid_data = select_normalized_features(df, CHOSEN_FEATURES, FEATURES_LABEL, TARGET_LABEL)

# %%
# Fit a model with best parameters
model = LinearRegression(featuresCol=FEATURES_LABEL, labelCol=TARGET_LABEL, elasticNetParam=0.0, regParam=0.0, maxIter=5)
pipeline = Pipeline(stages=[model])

trained_model = pipeline.fit(train_valid_data)

# %%
# Training set evaluation
training = trained_model.transform(train_valid_data)

# Compute validation error by several evaluators
eval_res = model_evaluation(TARGET_LABEL, training)

# Use dict to store each result
results = {
    "Model": MODEL_NAME,
    "Type": "trained_final",
    "Features": CHOSEN_FEATURES_LABEL,
    "MSE": eval_res['mse'],
    "RMSE": eval_res['rmse'],
    "MAE": eval_res['mae'],
    "R2": eval_res['r2'],
    "Adjusted_R2": eval_res['adj_r2'],
}

# Transform dict to pandas dataset
results_pd = pd.DataFrame(results, index=[0])
results_pd
# Out:
#               Model           Type           Features           MSE  \
# 0  LinearRegression  trained_final  more_rel_features  5.764963e+07
#
#           RMSE          MAE        R2  Adjusted_R2
# 0  7592.735531  5824.634389  0.783723     0.783715

# %%
show_results(training.toPandas(), MODEL_NAME)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Output

# %%
# # Save the trained model
# lr_model_final.write().overwrite().save(GDRIVE_MODEL)
