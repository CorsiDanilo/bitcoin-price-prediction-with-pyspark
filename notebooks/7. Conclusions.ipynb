# %% [markdown]
# # **Bitcoin price forecasting - Conclusions**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author
# Corsi Danilo - corsi.1742375@studenti.uniroma1.it

# %% [markdown]
# ## Global constants, dependencies, libraries and tools

# %%
# GDrive root
GDRIVE_DIR = "/content/drive"

# Dataset
GDRIVE_DATASET_OUTPUT_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/datasets/output"
GDRIVE_DATASET_NAME = "bitcoin_blockchain_data_30min"
GDRIVE_DATASET_NAME_TEST = GDRIVE_DATASET_NAME + "_test"
GDRIVE_DATASET_NAME_EXT_TEST = "/" + GDRIVE_DATASET_NAME_TEST + ".parquet"
GDRIVE_DATASET_TEST = GDRIVE_DATASET_OUTPUT_DIR + GDRIVE_DATASET_NAME_EXT_TEST

# Features
GDRIVE_FEATURES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/features"
GDRIVE_ALL_FEATURES_NAME = "all_features"
GDRIVE_MORE_REL_FEATURES_NAME = "more_rel_features"
GDRIVE_LESS_REL_FEATURES_NAME = "less_rel_features"
GDRIVE_ALL_FEATURES_NAME_EXT = "/" + GDRIVE_ALL_FEATURES_NAME + ".json"
GDRIVE_MORE_REL_FEATURES_NAME_EXT = "/" + GDRIVE_MORE_REL_FEATURES_NAME + ".json"
GDRIVE_LESS_REL_FEATURES_NAME_EXT = "/" + GDRIVE_LESS_REL_FEATURES_NAME + ".json"
GDRIVE_ALL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_ALL_FEATURES_NAME_EXT
GDRIVE_MORE_REL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_MORE_REL_FEATURES_NAME_EXT
GDRIVE_LESS_REL_FEATURES = GDRIVE_FEATURES_DIR + GDRIVE_LESS_REL_FEATURES_NAME_EXT

# Models
PATH_MODELS = "/content/drive/MyDrive/BDC/project/models/"
LR_MODEL_NAME = "LinearRegression"
GLR_MODEL_NAME = "GeneralizedLinearRegression"
RF_MODEL_NAME = "RandomForestRegressor"
GBT_MODEL_NAME = "GBTRegressor"

# Others
JAVA_HOME = "/usr/lib/jvm/java-8-openjdk-amd64"
SLOW_OPERATION = True

# %%
# Point Colaboratory to our Google Drive
from google.colab import drive

# Define GDrive paths
drive.mount(GDRIVE_DIR, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Install Spark and related dependencies
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285388 sha256=3ea8dfc2df35568751cff9fb4138cdc5f7de8b1d8eeba8bdceb3406957665ff0
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %% [markdown]
# ## Import files

# %%
GDRIVE_UTILITIES_DIR = GDRIVE_DIR + "/MyDrive/BDC/project/utilities"

import sys
sys.path.append(GDRIVE_UTILITIES_DIR)

from imports import *

# %% [markdown]
# ## Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '4G').\
                set('spark.driver.memory', '45G').\
                set('spark.driver.maxResultSize', '10G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPriceForecasting").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Loading dataset

# %%
# Load datasets into pyspark dataset objects
df = spark.read.load(GDRIVE_DATASET_TEST,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
if SLOW_OPERATION:
  dataset_info(df)
# Out:
# +-------------------+------+------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |          timestamp|    id|      market-price|      total-bitcoins|          market-cap|        trade-volume|    blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|          hash-rate|        difficulty|      miners-revenue|transaction-fees-usd|n-unique-addresses|   n-transactions|estimated-transaction-volume-usd|      rate-of-change|        sma-5-days|        sma-7-days|       sma-10-days|       sma-20-days|       sma-50-days|      sma-100-days| next-market-price|
# +-------------------+------+------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |2023-04-01 15:30:00|127087| 28470.24979166667|1.9334993880208332E7|5.431791067040364...|1.3695861893379998E8|469794.56551275|1.8538001858381272| 8.196096363541666E8|       2289.372401326302|3.395387044195395E8|4.6843400286277E13| 2.681514645243138E7|   767445.0201397171| 674757.5208333334|333838.8333333333|            1.0936881170820718E9|-0.00107641603279...|20616.695105078026|20362.472876037344|20953.711645950465|33273.821989108896|24160.079006287102|15422.119868280333|28469.943333333333|
# |2023-04-01 16:00:00|127088|28469.943333333333|1.9335016666666668E7|5.430431957041667E11|    1.344060455336E8|  469799.849629|1.8551112858421221| 8.196162853333334E8|      2289.5719718759988|3.399753165555269E8|4.6843400286277E13|2.6848815547784325E7|   763275.9644509932| 673866.6666666666|334296.6666666667|            1.0856229614416554E9|-0.00107642761962...|20617.834514911152|20363.325507080066| 20953.61352731576| 33273.23087364561|24160.419052817128|15422.222532688791|      28469.636875|
# |2023-04-01 16:30:00|127089|      28469.636875|   1.9335039453125E7|5.429072847042969E11|1.3185347213340001E8|469805.13374525| 1.856422385846117|    8.196229343125E8|       2289.771542425695|3.404119286915143E8|4.6843400286277E13| 2.688248464313727E7|   759106.9087622693|       672975.8125|         334754.5|             1.077557805801239E9|-0.00107643920671...|20618.974843482414|20364.178351519276| 20953.51530621422| 33272.63792662699| 24160.75909562614|15422.325193070285|28469.330416666668|
# +-------------------+------+------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 3 rows
#
# Shape: (6689, 25)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- rate-of-change: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# ## [TEST] Cut dataframe ❗

# %%
# # Get the minimum and maximum values of the "Age" column
# min_timestamp = df.agg(min("timestamp")).collect()[0][0]
# max_timestamp = df.agg(max("timestamp")).collect()[0][0]

# # Print the minimum and maximum values
# print("Minimum:", min_timestamp)
# print("Maximum:", max_timestamp)

# from datetime import datetime
# from dateutil.relativedelta import relativedelta

# # Convertire la stringa in un oggetto datetime
# min_timestamp = datetime.strptime(str(min_timestamp), '%Y-%m-%d %H:%M:%S')

# # Aggiungere un mese alla data
# min_timestamp_obj = min_timestamp + relativedelta(months=2)

# # Convertire la nuova data in una stringa nel formato desiderato
# timestamp_to_split = min_timestamp_obj.strftime('%Y-%m-%d %H:%M:%S')

# # Stampare la nuova data
# print(timestamp_to_split)

# # Split the DataFrame based on a date
# df_before_date = df.filter(col("timestamp") < timestamp_to_split)
# df_after_date = df.filter(col("timestamp") >= timestamp_to_split)

# # Show the split DataFrames
# df_before_date.show()
# df_after_date.show()

# df = df_before_date

# %% [markdown]
# ## Load features

# %%
# # Loading correlation matrix features
# with open(GDRIVE_ALL_FEATURES, "r") as f:
#     all_features = json.load(f)
# print(all_features)

# %%
# Loading correlation matrix features
with open(GDRIVE_MORE_REL_FEATURES, "r") as f:
    more_rel_features = json.load(f)
print(more_rel_features)
# Out:
# ['market-price', 'market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'estimated-transaction-volume-usd', 'sma-10-days', 'n-transactions-total', 'blocks-size', 'sma-100-days', 'total-bitcoins']

# %%
# # Loading correlation matrix features
# with open(GDRIVE_LESS_REL_FEATURES, "r") as f:
#     less_rel_features = json.load(f)
# print(less_rel_features)

# %%
# Set the depended variable
TARGET_VAL = 'next-market-price'

# Set the features label
FEATURES_LABEL = "features"

# Features
SELECTED_FEATURES = more_rel_features

# %% [markdown]
# ## Load models

# %%
# Upload the 3 templates saved in Google Drive
lr = PipelineModel.load(PATH_MODELS + LR_MODEL_NAME)
glr = PipelineModel.load(PATH_MODELS + GLR_MODEL_NAME)
rf = PipelineModel.load(PATH_MODELS + RF_MODEL_NAME)
gbt = PipelineModel.load(PATH_MODELS + GBT_MODEL_NAME)

# %% [markdown]
# ## Test models

# %%
# Normalized / standardized features selection
def select_normalized_features(dataset, features, featureCol, labelCol):
    # Assemble the columns into a vector column
    assembler = VectorAssembler(inputCols = features, outputCol = "raw_features")
    df_vector  = assembler.transform(dataset).select("timestamp", "id", "raw_features", labelCol)

    # Create a Normalizer instance
    normalizer = Normalizer(inputCol="raw_features", outputCol=featureCol)

    # Fit and transform the data
    normalized_data = normalizer.transform(df_vector).select("timestamp", "id", featureCol, labelCol)

    return normalized_data

# %%
def evaluate_final_model(dataset, trained_model, features, feature_col, label_col, ml_model):
    # Select train and valid data features
    dataset = select_normalized_features(dataset, features, feature_col, label_col)

    # Make predictions
    predictions = trained_model.transform(dataset)

    # Compute validation error by several evaluators
    rmse_evaluator = RegressionEvaluator(labelCol=label_col, predictionCol="prediction", metricName='rmse')
    mae_evaluator = RegressionEvaluator(labelCol=label_col, predictionCol="prediction", metricName='mae')
    r2_evaluator = RegressionEvaluator(labelCol=label_col, predictionCol="prediction", metricName='r2')
    var_evaluator = RegressionEvaluator(labelCol=label_col, predictionCol="prediction", metricName='var')

    predictions_pd = predictions.select(label_col, "prediction", 'timestamp').toPandas()
    mape = mean_absolute_percentage_error(predictions_pd[label_col], predictions_pd["prediction"])

    rmse = rmse_evaluator.evaluate(predictions)
    mae = mae_evaluator.evaluate(predictions)
    var = var_evaluator.evaluate(predictions)
    r2 = r2_evaluator.evaluate(predictions)
    # Adjusted R-squared
    n = predictions.count()
    p = len(predictions.columns)
    adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)

    # Use dict to store each result
    result = {
        "Model": ml_model,
        "Type": "final",
        "RMSE": rmse,
        "MAPE":mape,
        "MAE": mae,
        "Variance": var,
        "R2": r2,
        "Adjusted_R2": adj_r2,
    }

    # Transform dict to pandas dataset
    result_df = pd.DataFrame(result, index=[0])

    return result_df, predictions_pd

# %%
lr_results, lr_predictions = evaluate_final_model(df, lr, SELECTED_FEATURES, FEATURES_LABEL, TARGET_VAL, LR_MODEL_NAME)
glr_results, glr_predictions = evaluate_final_model(df, glr, SELECTED_FEATURES, FEATURES_LABEL, TARGET_VAL, GLR_MODEL_NAME)
rf_results, rf_predictions = evaluate_final_model(df, rf, SELECTED_FEATURES, FEATURES_LABEL, TARGET_VAL, RF_MODEL_NAME)
gbt_results, gbt_predictions = evaluate_final_model(df, gbt, SELECTED_FEATURES, FEATURES_LABEL, TARGET_VAL, GBT_MODEL_NAME)

# %% [markdown]
# ## Summary

# %%
# Define what model_info and evaluators in the Model Comparison Table
model_info = ['Model','Type']
evaluator_lst = ['RMSE','MAPE','MAE','Variance','R2','Adjusted_R2']

# The the Cross Validation results would like to compare
comparison_lst = [lr_results, glr_results, rf_results, gbt_results]

# %%
def modelComparison(cv_result, model_info, evaluator_lst):
    # Calculate mean of all splits on chosen evaluator
    col_mean_df = cv_result[evaluator_lst].mean().to_frame().T
    # Extract model info
    model_info_df = cv_result[model_info][:1]
    # Concatenate by row
    comparison_df = pd.concat([model_info_df,col_mean_df],axis=1)
    return comparison_df

# %%
def show_results(df, lr_predictions, glr_predictions, rf_predictions, gbt_predictions):
  trace1 = go.Scatter(
      x = df['timestamp'],
      y = df['next-market-price'].astype(float),
      mode = 'lines',
      name = 'Test set'
  )

  trace2 = go.Scatter(
      x = lr_predictions['timestamp'],
      y = lr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Linear Regression predictions'
  )

  trace2 = go.Scatter(
      x = lr_predictions['timestamp'],
      y = lr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Linear Regression predictions'
  )

  trace3 = go.Scatter(
      x = glr_predictions['timestamp'],
      y = glr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Generalized Linear Regression predictions'
  )

  trace4 = go.Scatter(
      x = rf_predictions['timestamp'],
      y = rf_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Random Forest Regressor predictions'
  )

  trace5 = go.Scatter(
      x = gbt_predictions['timestamp'],
      y = gbt_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'GBTRegressor predictions'
  )

  layout = dict(
      title='Test and predictions with Rangeslider',
      xaxis=dict(
          rangeselector=dict(
              buttons=list([
                  #change the count to desired amount of months.
                  dict(count=1,
                      label='1m',
                      step='month',
                      stepmode='backward'),
                  dict(count=6,
                      label='6m',
                      step='month',
                      stepmode='backward'),
                  dict(count=12,
                      label='1y',
                      step='month',
                      stepmode='backward'),
                  dict(count=36,
                      label='3y',
                      step='month',
                      stepmode='backward'),
                  dict(step='all')
              ])
          ),
          rangeslider=dict(
              visible = True
          ),
          type='date'
      )
  )

  data = [trace1,trace2,trace3, trace4, trace5]
  fig = dict(data=data, layout=layout)
  iplot(fig, filename = "Test and predictions with Rangeslider")

# %%
# Show the Comparison Table
pd.concat([modelComparison(cv_result, model_info, evaluator_lst) for cv_result in comparison_lst])
# Out:
#                          Model   Type          RMSE      MAPE           MAE  \
# 0             LinearRegression  final   3184.217982  0.100004   2904.737195
# 0  GeneralizedLinearRegression  final  13245.146391  0.458783  13162.740584
# 0        RandomForestRegressor  final   1133.450036  0.033464    943.381991
# 0                 GBTRegressor  final   2395.442155  0.069721   1967.921379
#
#        Variance         R2  Adjusted_R2
# 0  9.334456e+06  -3.659061    -3.662547
# 0  1.732577e+08 -79.613234   -79.673546
# 0  6.845139e+05   0.409666     0.409225
# 0  8.796038e+06  -1.636721    -1.638694

# %%
show_results(df.toPandas(), lr_predictions, glr_predictions, rf_predictions, gbt_predictions)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="97367e9b-73b2-4a9a-b554-816e9974d1c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97367e9b-73b2-4a9a-b554-816e9974d1c3")) {                    Plotly.newPlot(                        "97367e9b-73b2-4a9a-b554-816e9974d1c3",                        [{"mode":"lines","name":"Test set","x":["2023-04-01T15:30:00","2023-04-01T16:00:00","2023-04-01T16:30:00","2023-04-01T17:00:00","2023-04-01T17:30:00","2023-04-01T18:00:00","2023-04-01T18:30:00","2023-04-01T19:00:00","2023-04-01T19:30:00","2023-04-01T20:00:00","2023-04-01T20:30:00","2023-04-01T21:00:00","2023-04-01T21:30:00","2023-04-01T22:00:00","2023-04-01T22:30:00","2023-04-01T23:00:00","2023-04-01T23:30:00","2023-04-02T00:00:00","2023-04-02T00:30:00","2023-04-02T01:00:00","2023-04-02T01:30:00","2023-04-02T02:00:00","2023-04-02T02:30:00","2023-04-02T03:00:00","2023-04-02T03:30:00","2023-04-02T04:00:00","2023-04-02T04:30:00","2023-04-02T05:00:00","2023-04-02T05:30:00","2023-04-02T06:00:00","2023-04-02T06:30:00","2023-04-02T07:00:00","2023-04-02T07:30:00","2023-04-02T08:00:00","2023-04-02T08:30:00","2023-04-02T09:00:00","2023-04-02T09:30:00","2023-04-02T10:00:00","2023-04-02T10:30:00","2023-04-02T11:00:00","2023-04-02T11:30:00","2023-04-02T12:00:00","2023-04-02T12:30:00","2023-04-02T13:00:00","2023-04-02T13:30:00","2023-04-02T14:00:00","2023-04-02T14:30:00","2023-04-02T15:00:00","2023-04-02T15:30:00","2023-04-02T16:00:00","2023-04-02T16:30:00","2023-04-02T17:00:00","2023-04-02T17:30:00","2023-04-02T18:00:00","2023-04-02T18:30:00","2023-04-02T19:00:00","2023-04-02T19:30:00","2023-04-02T20:00:00","2023-04-02T20:30:00","2023-04-02T21:00:00","2023-04-02T21:30:00","2023-04-02T22:00:00","2023-04-02T22:30:00","2023-04-02T23:00:00","2023-04-02T23:30:00","2023-04-03T00:00:00","2023-04-03T00:30:00","2023-04-03T01:00:00","2023-04-03T01:30:00","2023-04-03T02:00:00","2023-04-03T02:30:00","2023-04-03T03:00:00","2023-04-03T03:30:00","2023-04-03T04:00:00","2023-04-03T04:30:00","2023-04-03T05:00:00","2023-04-03T05:30:00","2023-04-03T06:00:00","2023-04-03T06:30:00","2023-04-03T07:00:00","2023-04-03T07:30:00","2023-04-03T08:00:00","2023-04-03T08:30:00","2023-04-03T09:00:00","2023-04-03T09:30:00","2023-04-03T10:00:00","2023-04-03T10:30:00","2023-04-03T11:00:00","2023-04-03T11:30:00","2023-04-03T12:00:00","2023-04-03T12:30:00","2023-04-03T13:00:00","2023-04-03T13:30:00","2023-04-03T14:00:00","2023-04-03T14:30:00","2023-04-03T15:00:00","2023-04-03T15:30:00","2023-04-03T16:00:00","2023-04-03T16:30:00","2023-04-03T17:00:00","2023-04-03T17:30:00","2023-04-03T18:00:00","2023-04-03T18:30:00","2023-04-03T19:00:00","2023-04-03T19:30:00","2023-04-03T20:00:00","2023-04-03T20:30:00","2023-04-03T21:00:00","2023-04-03T21:30:00","2023-04-03T22:00:00","2023-04-03T22:30:00","2023-04-03T23:00:00","2023-04-03T23:30:00","2023-04-04T00:00:00","2023-04-04T00:30:00","2023-04-04T01:00:00","2023-04-04T01:30:00","2023-04-04T02:00:00","2023-04-04T02:30:00","2023-04-04T03:00:00","2023-04-04T03:30:00","2023-04-04T04:00:00","2023-04-04T04:30:00","2023-04-04T05:00:00","2023-04-04T05:30:00","2023-04-04T06:00:00","2023-04-04T06:30:00","2023-04-04T07:00:00","2023-04-04T07:30:00","2023-04-04T08:00:00","2023-04-04T08:30:00","2023-04-04T09:00:00","2023-04-04T09:30:00","2023-04-04T10:00:00","2023-04-04T10:30:00","2023-04-04T11:00:00","2023-04-04T11:30:00","2023-04-04T12:00:00","2023-04-04T12:30:00","2023-04-04T13:00:00","2023-04-04T13:30:00","2023-04-04T14:00:00","2023-04-04T14:30:00","2023-04-04T15:00:00","2023-04-04T15:30:00","2023-04-04T16:00:00","2023-04-04T16:30:00","2023-04-04T17:00:00","2023-04-04T17:30:00","2023-04-04T18:00:00","2023-04-04T18:30:00","2023-04-04T19:00:00","2023-04-04T19:30:00","2023-04-04T20:00:00","2023-04- ...

# %% [markdown]
# ## Making future forecasting ❗

# %%
# Ri-allena il modello migliore con tutto il dataset
# Crea un dataset che va da oggi ad un anno ad intervalli di mezz'ora❓
# Crea una colonna isFuture(True: dataset nuovo | False: dataset originale)
# Concatena il dataset esistente con quello futuro

# %%
df_pd = df.toPandas()

# %%
# Add one year to the current date
last_timestamp = df_pd['timestamp'].iloc[-1].date()
last_id = df_pd['id'].iloc[-1]

# Print the new date
print(last_timestamp)
print(last_id)
# Out:
# 2023-08-18
# 133775

# %%
# Add one year to the current date
new_date = (last_timestamp + pd.DateOffset(years=1)).date()

# Print the new date
print(new_date)
# Out:
# 2024-08-18

# %%
# Create future dataset
future = pd.date_range(last_timestamp,new_date, freq='30min')
future_df = pd.DataFrame(index=future)

# Generate the IDs based on the length of the dataset
future_df['id'] = range(last_id, last_id + len(future_df))

future_df
# Out:
#                          id
# 2023-08-18 00:00:00  133775
# 2023-08-18 00:30:00  133776
# 2023-08-18 01:00:00  133777
# 2023-08-18 01:30:00  133778
# 2023-08-18 02:00:00  133779
# ...                     ...
# 2024-08-17 22:00:00  151339
# 2024-08-17 22:30:00  151340
# 2024-08-17 23:00:00  151341
# 2024-08-17 23:30:00  151342
# 2024-08-18 00:00:00  151343
#
# [17569 rows x 1 columns]

# %%
df_pd = df_pd.set_index('timestamp')
df_pd
# Out:
#                          id  market-price  total-bitcoins    market-cap  \
# timestamp
# 2023-04-01 15:30:00  127087  28470.249792    1.933499e+07  5.431791e+11
# 2023-04-01 16:00:00  127088  28469.943333    1.933502e+07  5.430432e+11
# 2023-04-01 16:30:00  127089  28469.636875    1.933504e+07  5.429073e+11
# 2023-04-01 17:00:00  127090  28469.330417    1.933506e+07  5.427714e+11
# 2023-04-01 17:30:00  127091  28469.023958    1.933509e+07  5.426355e+11
# ...                     ...           ...             ...           ...
# 2023-08-18 21:30:00  133771  26111.112500    1.946211e+07  5.072502e+11
# 2023-08-18 22:00:00  133772  26098.300000    1.946213e+07  5.073891e+11
# 2023-08-18 22:30:00  133773  26085.487500    1.946215e+07  5.075279e+11
# 2023-08-18 23:00:00  133774  26072.675000    1.946217e+07  5.076668e+11
# 2023-08-18 23:30:00  133775  26059.862500    1.946220e+07  5.078056e+11
#
#                      trade-volume    blocks-size  avg-block-size  \
# timestamp
# 2023-04-01 15:30:00  1.369586e+08  469794.565513        1.853800
# 2023-04-01 16:00:00  1.344060e+08  469799.849629        1.855111
# 2023-04-01 16:30:00  1.318535e+08  469805.133745        1.856422
# 2023-04-01 17:00:00  1.293009e+08  469810.417861        1.857733
# 2023-04-01 17:30:00  1.267483e+08  469815.701978        1.859045
# ...                           ...            ...             ...
# 2023-08-18 21:30:00  1.830140e+08  504581.499297        1.691828
# 2023-08-18 22:00:00  1.799027e+08  504586.224709        1.693243
# 2023-08-18 22:30:00  1.767913e+08  504590.950120        1.694658
# 2023-08-18 23:00:00  1.736800e+08  504595.675532        1.696074
# 2023-08-18 23:30:00  1.705686e+08  504600.400943        1.697489
#
#                      n-transactions-total  n-transactions-per-block  \
# timestamp
# 2023-04-01 15:30:00          8.196096e+08               2289.372401
# 2023-04-01 16:00:00          8.196163e+08               2289.571972
# 2023-04-01 16:30:00          8.196229e+08               2289.771542
# 2023-04-01 17:00:00          8.196296e+08               2289.971113
# 2023-04-01 17:30:00          8.196362e+08               2290.170684
# ...                                   ...                       ...
# 2023-08-18 21:30:00          8.811480e+08               3643.124743
# 2023-08-18 22:00:00          8.811569e+08               3657.042652
# 2023-08-18 22:30:00          8.811657e+08               3670.960560
# 2023-08-18 23:00:00          8.811745e+08               3684.878469
# 2023-08-18 23:30:00          8.811834e+08               3698.796377
#
#                         hash-rate  ...  n-unique-addresses  n-transactions  \
# timestamp                          ...
# 2023-04-01 15:30:00  3.395387e+08  ...       674757.520833   333838.833333
# 2023-04-01 16:00:00  3.399753e+08  ...       673866.666667   334296.666667
# 2023-04-01 16:30:00  3.404119e+08  ...       672975.812500   334754.500000
# 2023-04-01 17:00:00  3.408485e+08  ...       672084.958333   335212.333333
# 2023-04-01 17:30:00  3.412852e+08  ...       671194.104167   335670.166667
# ...                           ...  ...                 ...             ...
# 2023-08-18 21:30:00  3.643419e+08  ...       644542.166667   509720.312500
# 2023-08-18 22:00:00  3.643961e+08  ...       641302.333333   511732.250000
# 2023-08-18 22:30:00  3.644504e+08  ...       638062.500000   513744.187500
# 2023-08-18 23:00:00  3.645046e+08  ...       634822.666667   515756.125000
# 2023-08-18 23:30:00  3.645589e+08  ...       631582.833333   517768.062500
#
#                      estimated-transaction-volume-usd  rate-of-change  \
# timestamp
# 2023-04-01 15:30:00                      1.093688e+09       -0.001076
# 2023-04-01 16:00:00                      1.085623e+09       -0.001076
# 2023-04-01 16:30:00                      1.077558e+09       -0.001076
# 2023-04-01 17:00:00                      1.069493e+09       -0.001076
# 2023-04-01 17:30:00                      1.061427e+09       -0.001076
# ...                                               ...             ...
# 2023-08-18 21:30:00                      1.476158e+09       -0.049069
# 2023-08-18 22:00:00                      1.418873e+09       -0.049093
# 2023-08-18 22:30:00                      1.361587e+09       -0.049117
# 2023-08-18 23:00:00                      1.304301e+09       -0.049141
# 2023-08-18 23:30:00                      1.247015e+09       -0.049166
#
#                        sma-5-days    sma-7-days   sma-10-days   sma-20-days  \
# timestamp
# 2023-04-01 15:30:00  20616.695105  20362.472876  20953.711646  33273.821989
# 2023-04-01 16:00:00  20617.834515  20363.325507  20953.613527  33273.230874
# 2023-04-01 16:30:00  20618.974843  20364.178352  20953.515306  33272.637927
# 2023-04-01 17:00:00  20620.116091  20365.031409  20953.416983  33272.043148
# 2023-04-01 17:30:00  20621.258257  20365.884681  20953.318557  33271.446538
# ...                           ...           ...           ...           ...
# 2023-08-18 21:30:00  28544.973430  27069.836244  24309.023198  27671.972352
# 2023-08-18 22:00:00  28544.685601  27070.185996  24309.501142  27671.122143
# 2023-08-18 22:30:00  28544.394834  27070.531158  24309.978148  27670.271409
# 2023-08-18 23:00:00  28544.101128  27070.871731  24310.454214  27669.420149
# 2023-08-18 23:30:00  28543.804484  27071.207715  24310.929342  27668.568365
#
#                       sma-50-days  sma-100-days
# timestamp
# 2023-04-01 15:30:00  24160.079006  15422.119868
# 2023-04-01 16:00:00  24160.419053  15422.222533
# 2023-04-01 16:30:00  24160.759096  15422.325193
# 2023-04-01 17:00:00  24161.099135  15422.427849
# 2023-04-01 17:30:00  24161.439170  15422.530502
# ...                           ...           ...
# 2023-08-18 21:30:00  26200.579500  16080.595994
# 2023-08-18 22:00:00  26200.774834  16080.670784
# 2023-08-18 22:30:00  26200.970169  16080.745477
# 2023-08-18 23:00:00  26201.165504  16080.820074
# 2023-08-18 23:30:00  26201.360840  16080.894573
#
# [6689 rows x 23 columns]

# %%
# future_df['isFuture'] = True
# test_df_pd['isFuture'] = False
test_and_future = pd.concat([df_pd, future_df])
test_and_future
# Out:
#                          id  market-price  total-bitcoins    market-cap  \
# 2023-04-01 15:30:00  127087  28470.249792    1.933499e+07  5.431791e+11
# 2023-04-01 16:00:00  127088  28469.943333    1.933502e+07  5.430432e+11
# 2023-04-01 16:30:00  127089  28469.636875    1.933504e+07  5.429073e+11
# 2023-04-01 17:00:00  127090  28469.330417    1.933506e+07  5.427714e+11
# 2023-04-01 17:30:00  127091  28469.023958    1.933509e+07  5.426355e+11
# ...                     ...           ...             ...           ...
# 2024-08-17 22:00:00  151339           NaN             NaN           NaN
# 2024-08-17 22:30:00  151340           NaN             NaN           NaN
# 2024-08-17 23:00:00  151341           NaN             NaN           NaN
# 2024-08-17 23:30:00  151342           NaN             NaN           NaN
# 2024-08-18 00:00:00  151343           NaN             NaN           NaN
#
#                      trade-volume    blocks-size  avg-block-size  \
# 2023-04-01 15:30:00  1.369586e+08  469794.565513        1.853800
# 2023-04-01 16:00:00  1.344060e+08  469799.849629        1.855111
# 2023-04-01 16:30:00  1.318535e+08  469805.133745        1.856422
# 2023-04-01 17:00:00  1.293009e+08  469810.417861        1.857733
# 2023-04-01 17:30:00  1.267483e+08  469815.701978        1.859045
# ...                           ...            ...             ...
# 2024-08-17 22:00:00           NaN            NaN             NaN
# 2024-08-17 22:30:00           NaN            NaN             NaN
# 2024-08-17 23:00:00           NaN            NaN             NaN
# 2024-08-17 23:30:00           NaN            NaN             NaN
# 2024-08-18 00:00:00           NaN            NaN             NaN
#
#                      n-transactions-total  n-transactions-per-block  \
# 2023-04-01 15:30:00          8.196096e+08               2289.372401
# 2023-04-01 16:00:00          8.196163e+08               2289.571972
# 2023-04-01 16:30:00          8.196229e+08               2289.771542
# 2023-04-01 17:00:00          8.196296e+08               2289.971113
# 2023-04-01 17:30:00          8.196362e+08               2290.170684
# ...                                   ...                       ...
# 2024-08-17 22:00:00                   NaN                       NaN
# 2024-08-17 22:30:00                   NaN                       NaN
# 2024-08-17 23:00:00                   NaN                       NaN
# 2024-08-17 23:30:00                   NaN                       NaN
# 2024-08-18 00:00:00                   NaN                       NaN
#
#                         hash-rate  ...  n-unique-addresses  n-transactions  \
# 2023-04-01 15:30:00  3.395387e+08  ...       674757.520833   333838.833333
# 2023-04-01 16:00:00  3.399753e+08  ...       673866.666667   334296.666667
# 2023-04-01 16:30:00  3.404119e+08  ...       672975.812500   334754.500000
# 2023-04-01 17:00:00  3.408485e+08  ...       672084.958333   335212.333333
# 2023-04-01 17:30:00  3.412852e+08  ...       671194.104167   335670.166667
# ...                           ...  ...                 ...             ...
# 2024-08-17 22:00:00           NaN  ...                 NaN             NaN
# 2024-08-17 22:30:00           NaN  ...                 NaN             NaN
# 2024-08-17 23:00:00           NaN  ...                 NaN             NaN
# 2024-08-17 23:30:00           NaN  ...                 NaN             NaN
# 2024-08-18 00:00:00           NaN  ...                 NaN             NaN
#
#                      estimated-transaction-volume-usd  rate-of-change  \
# 2023-04-01 15:30:00                      1.093688e+09       -0.001076
# 2023-04-01 16:00:00                      1.085623e+09       -0.001076
# 2023-04-01 16:30:00                      1.077558e+09       -0.001076
# 2023-04-01 17:00:00                      1.069493e+09       -0.001076
# 2023-04-01 17:30:00                      1.061427e+09       -0.001076
# ...                                               ...             ...
# 2024-08-17 22:00:00                               NaN             NaN
# 2024-08-17 22:30:00                               NaN             NaN
# 2024-08-17 23:00:00                               NaN             NaN
# 2024-08-17 23:30:00                               NaN             NaN
# 2024-08-18 00:00:00                               NaN             NaN
#
#                        sma-5-days    sma-7-days   sma-10-days   sma-20-days  \
# 2023-04-01 15:30:00  20616.695105  20362.472876  20953.711646  33273.821989
# 2023-04-01 16:00:00  20617.834515  20363.325507  20953.613527  33273.230874
# 2023-04-01 16:30:00  20618.974843  20364.178352  20953.515306  33272.637927
# 2023-04-01 17:00:00  20620.116091  20365.031409  20953.416983  33272.043148
# 2023-04-01 17:30:00  20621.258257  20365.884681  20953.318557  33271.446538
# ...                           ...           ...           ...           ...
# 2024-08-17 22:00:00           NaN           NaN           NaN           NaN
# 2024-08-17 22:30:00           NaN           NaN           NaN           NaN
# 2024-08-17 23:00:00           NaN           NaN           NaN           NaN
# 2024-08-17 23:30:00           NaN           NaN           NaN           NaN
# 2024-08-18 00:00:00           NaN           NaN           NaN           NaN
#
#                       sma-50-days  sma-100-days
# 2023-04-01 15:30:00  24160.079006  15422.119868
# 2023-04-01 16:00:00  24160.419053  15422.222533
# 2023-04-01 16:30:00  24160.759096  15422.325193
# 2023-04-01 17:00:00  24161.099135  15422.427849
# 2023-04-01 17:30:00  24161.439170  15422.530502
# ...                           ...           ...
# 2024-08-17 22:00:00           NaN           NaN
# 2024-08-17 22:30:00           NaN           NaN
# 2024-08-17 23:00:00           NaN           NaN
# 2024-08-17 23:30:00           NaN           NaN
# 2024-08-18 00:00:00           NaN           NaN
#
# [24258 rows x 23 columns]

# %%
# Convert pandas dataset to PySpark dataset
test_and_future_df = spark.createdataset(test_and_future.reset_index()).withColumn("id", F.row_number().over(Window.orderBy(F.monotonically_increasing_id()))-1).withColumnRenamed("index","timestamp")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-44e0ace8435f> in <cell line: 2>()
#       1 # Convert pandas dataset to PySpark dataset
# ----> 2 test_and_future_df = spark.createdataset(test_and_future.reset_index()).withColumn("id", F.row_number().over(Window.orderBy(F.monotonically_increasing_id()))-1).withColumnRenamed("index","timestamp")
#
# AttributeError: 'SparkSession' object has no attribute 'createdataset'

# %%
# Fill all columns with zeros
test_and_future_df = test_and_future_df.fillna(0)

# %%
def dataset_info(dataset):
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
dataset_info(test_and_future_df)

# %% [markdown]
# ### Test models ❗

# %%
# Raw features selection❗
# # Return the dataset with the selected features
# def select_features(dataset, features, featureCol, labelCol):
#   vectorAssembler = VectorAssembler(
#     inputCols = features,
#     outputCol = featureCol)

#   dataset = vectorAssembler.transform(dataset)
#   dataset = dataset.select(['timestamp','id', featureCol, labelCol])
#   return dataset

# Normalized / standardized features selection❗
def select_features(dataset, features, featureCol, labelCol):
    # Assemble the columns into a vector column
    assembler = VectorAssembler(inputCols=features, outputCol="raw_features")
    df_vector  = assembler.transform(dataset).select("timestamp", "id", "raw_features", labelCol)

    # Normalized
    # Create a Normalizer instance
    normalizer = Normalizer(inputCol="raw_features", outputCol=featureCol)

    # Fit and transform the data
    normalized_data = normalizer.transform(df_vector)

    # Show the normalized data
    # normalized_data.show()

    return normalized_data

# %%
def test_final_model(dataset, trained_model, features, features_label, target_val, ml_model):
  dataset = select_features(dataset, features, features_label, target_val)

  # Make predictions
  predictions = trained_model.transform(dataset)

  results = []

  # Compute validation error by several evaluator
  rmse_evaluator = RegressionEvaluator(labelCol=target_val, predictionCol="prediction", metricName='rmse')
  mae_evaluator = RegressionEvaluator(labelCol=target_val, predictionCol="prediction", metricName='mae')
  r2_evaluator = RegressionEvaluator(labelCol=target_val, predictionCol="prediction", metricName='r2')
  var_evaluator = RegressionEvaluator(labelCol=target_val, predictionCol="prediction", metricName='var')

  predictions_pd = predictions.select(target_val, "prediction").toPandas()
  mape = mean_absolute_percentage_error(predictions_pd[target_val], predictions_pd["prediction"])

  rmse = rmse_evaluator.evaluate(predictions)
  mae = mae_evaluator.evaluate(predictions)
  var = var_evaluator.evaluate(predictions)
  r2 = r2_evaluator.evaluate(predictions)
  # Adjusted R-squared
  n = predictions.count()
  p = len(predictions.columns)
  adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)

  # Use dict to store each result
  result = {
      "Model": ml_model,
      "Type": "trained",
      "RMSE": rmse,
      "MAPE":mape,
      "MAE": mae,
      "Variance": var,
      "R2": r2,
      "Adjusted_R2": adj_r2,
  }

  # Transform dict to pandas dataset
  result_df = pd.DataFrame(result, index=[0])

  return result_df, predictions.toPandas()

# %%
lr_results, lr_predictions = test_final_model(test_and_future_df, lr, more_rel_features, FEATURES_LABEL, TARGET_VAL, LR_MODEL_NAME)
glr_results, glr_predictions = test_final_model(test_and_future_df, glr, more_rel_features, FEATURES_LABEL, TARGET_VAL, GLR_MODEL_NAME)
rf_results, rf_predictions = test_final_model(test_and_future_df, rf, more_rel_features, FEATURES_LABEL, TARGET_VAL, RF_MODEL_NAME)
gbt_results, gbt_predictions = test_final_model(test_and_future_df, gbt, more_rel_features, FEATURES_LABEL, TARGET_VAL, GBT_MODEL_NAME)

# %% [markdown]
# ### Summary ❗

# %%
# Define what model_info and evaluators in the Model Comparison Table
model_info = ['Model','Type']
evaluator_lst = ['RMSE','MAPE','MAE','Variance','R2','Adjusted_R2']

# The the Cross Validation results would like to compare
comparison_lst = [lr_results, glr_results, rf_results, gbt_results]

# %%
def modelComparison(cv_result, model_info, evaluator_lst):
    # Calculate mean of all splits on chosen evaluator
    col_mean_df = cv_result[evaluator_lst].mean().to_frame().T
    # Extract model info
    model_info_df = cv_result[model_info][:1]
    # Concatenate by row
    comparison_df = pd.concat([model_info_df,col_mean_df],axis=1)
    return comparison_df

# %%
def show_results(test_df, lr_predictions, glr_predictions, rf_predictions, gbt_predictions):
  trace1 = go.Scatter(
      x = test_df['timestamp'],
      y = test_df['market-price'].astype(float),
      mode = 'lines',
      name = 'Test set'
  )

  trace2 = go.Scatter(
      x = lr_predictions['timestamp'],
      y = lr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Linear Regression predictions'
  )

  trace2 = go.Scatter(
      x = lr_predictions['timestamp'],
      y = lr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Linear Regression predictions'
  )

  trace3 = go.Scatter(
      x = glr_predictions['timestamp'],
      y = glr_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Generalized Linear Regression predictions'
  )

  trace4 = go.Scatter(
      x = rf_predictions['timestamp'],
      y = rf_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'Random Forest Regressor predictions'
  )

  trace5 = go.Scatter(
      x = gbt_predictions['timestamp'],
      y = gbt_predictions['prediction'].astype(float),
      mode = 'lines',
      name = 'GBTRegressor predictions'
  )

  layout = dict(
      title='Test and predictions with Rangeslider',
      xaxis=dict(
          rangeselector=dict(
              buttons=list([
                  #change the count to desired amount of months.
                  dict(count=1,
                      label='1m',
                      step='month',
                      stepmode='backward'),
                  dict(count=6,
                      label='6m',
                      step='month',
                      stepmode='backward'),
                  dict(count=12,
                      label='1y',
                      step='month',
                      stepmode='backward'),
                  dict(count=36,
                      label='3y',
                      step='month',
                      stepmode='backward'),
                  dict(step='all')
              ])
          ),
          rangeslider=dict(
              visible = True
          ),
          type='date'
      )
  )

  data = [trace1,trace2,trace3, trace4, trace5]
  fig = dict(data=data, layout=layout)
  iplot(fig, filename = "Test and predictions with Rangeslider")

# %%
# Show the Comparison Table
pd.concat([modelComparison(cv_result, model_info, evaluator_lst) for cv_result in comparison_lst])

# %%
show_results(test_and_future_df.toPandas(), lr_predictions, glr_predictions, rf_predictions, gbt_predictions)
