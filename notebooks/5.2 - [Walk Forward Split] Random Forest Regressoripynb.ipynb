# %% [markdown]
# # **Bitcoin price prediction - Random Forest Regressor**
# ### Big Data Computing final project - A.Y. 2022 - 2023
# Prof. Gabriele Tolomei
#
# MSc in Computer Science
#
# La Sapienza, University of Rome
#
# ### Author: Corsi Danilo (1742375) - corsi.1742375@studenti.uniroma1.it
#
#
# ---
#
#
# Description: executing the chosen model, first with default values, then by choosing the best parameters by performing hyperparameter tuning with cross validation and performance evaluation.

# %% [markdown]
# # Global constants, dependencies, libraries and tools

# %%
# Main constants
LOCAL_RUNNING = True
SLOW_OPERATIONS = True # Decide whether or not to use operations that might slow down notebook execution
SPLITTING_METHOD = "walk_forward_splits"
MODEL_NAME = "RandomForestRegressor"
ROOT_DIR = "D:/Documents/Repository/BDC/project" if LOCAL_RUNNING else "/content/drive"

# %%
if not LOCAL_RUNNING: 
    # Point Colaboratory to Google Drive
    from google.colab import drive

    # Define GDrive paths
    drive.mount(ROOT_DIR, force_remount=True)

# %%
# Set main dir
MAIN_DIR = ROOT_DIR + "" if LOCAL_RUNNING else ROOT_DIR + "/MyDrive/BDC/project"

###################
# --- DATASET --- #
###################

# Datasets dirs
DATASET_OUTPUT_DIR = MAIN_DIR + "/datasets/output"

# Datasets names
DATASET_TRAIN_VALID_NAME = "bitcoin_blockchain_data_15min_train_valid"

# Datasets paths
DATASET_TRAIN_VALID  = DATASET_OUTPUT_DIR + "/" + DATASET_TRAIN_VALID_NAME + ".parquet"

####################
# --- FEATURES --- #
####################

# Features dir
FEATURES_DIR = MAIN_DIR + "/features"

# Features labels
FEATURES_LABEL = "features"
TARGET_LABEL = "next-market-price"

# Features names
ALL_FEATURES_NAME = "all_features"
MOST_REL_FEATURES_NAME = "most_rel_features"
LEAST_REL_FEATURES_NAME = "least_rel_features"

# Features paths
ALL_FEATURES = FEATURES_DIR + "/" + ALL_FEATURES_NAME + ".json"
MOST_REL_FEATURES = FEATURES_DIR + "/" + MOST_REL_FEATURES_NAME + ".json"
LEAST_REL_FEATURES = FEATURES_DIR + "/" + LEAST_REL_FEATURES_NAME + ".json"

##################
# --- MODELS --- #
##################

# Model dir
MODELS_DIR = MAIN_DIR + "/models"

# Model path
MODEL = MODELS_DIR + "/" + MODEL_NAME

#####################
# --- UTILITIES --- #
#####################

# Utilities dir
UTILITIES_DIR = MAIN_DIR + "/utilities"

###################
# --- RESULTS --- #
###################

# Results dir
RESULTS_DIR = MAIN_DIR + "/results/" + SPLITTING_METHOD

# Results path
MODEL_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + ".csv"
MODEL_ACCURACY_RESULTS  = RESULTS_DIR + "/" + MODEL_NAME + "_accuracy.csv"

# %%
# Suppression of warnings for better reading
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
if not LOCAL_RUNNING:
    # Install Spark and related dependencies
    # !pip install pyspark
    # !pip install -U -q PyDrive -qq
    # !apt install openjdk-8-jdk-headless -qq

# %% [markdown]
# # Import files

# %%
# Import my files
import sys
sys.path.append(UTILITIES_DIR)

from imports import *
import utilities, parameters

importlib.reload(utilities)
importlib.reload(parameters)
# Out:
# <module 'parameters' from 'D:\\Documents/Repository/BDC/project/utilities\\parameters.py'>

# %% [markdown]
# # Create the pyspark session

# %%
# Create the session
conf = SparkConf().\
                set('spark.ui.port', "4050").\
                set('spark.executor.memory', '12G').\
                set('spark.driver.memory', '12G').\
                set('spark.driver.maxResultSize', '109G').\
                set("spark.kryoserializer.buffer.max", "1G").\
                setAppName("BitcoinPricePrediction").\
                setMaster("local[*]")

# Create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Loading dataset

# %%
# Load train / validation set into pyspark dataset objects
df = spark.read.load(DATASET_TRAIN_VALID,
                         format="parquet",
                         sep=",",
                         inferSchema="true",
                         header="true"
                    )

# %%
def dataset_info(dataset):
  # Print dataset
  dataset.show(3)

  # Get the number of rows
  num_rows = dataset.count()

  # Get the number of columns
  num_columns = len(dataset.columns)

  # Print the shape of the dataset
  print("Shape:", (num_rows, num_columns))

  # Print the schema of the dataset
  dataset.printSchema()

# %%
if SLOW_OPERATIONS:
  dataset_info(df)
# Out:
# +-------------------+---+------------------+--------------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |          timestamp| id|      market-price|      total-bitcoins|          market-cap|        trade-volume|       blocks-size|    avg-block-size|n-transactions-total|n-transactions-per-block|          hash-rate|        difficulty|      miners-revenue|transaction-fees-usd|n-unique-addresses|   n-transactions|estimated-transaction-volume-usd|      rate-of-change|        sma-5-days|        sma-7-days|       sma-10-days|       sma-20-days|       sma-50-days|      sma-100-days| next-market-price|
# +-------------------+---+------------------+--------------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |2019-09-23 00:00:00|  0|          10033.05|          1.795205E7|      1.799872533E11|      5.9501805669E7|     241221.519675|  1.24371952631579|        4.57899079E8|        2527.62280701754| 6.73836536862649E7|1.1890594958796E13|  1.46471837982298E7|     322033.79822979|          544681.0|         288149.0|              8.55073770204309E8|-0.03630397370024685|10029.407604166667|10029.407604166667|10029.407604166667|10029.407604166667|10029.407604166667|10029.407604166667|10029.407604166667|
# |2019-09-23 00:15:00|  1|10029.407604166667|1.7952068619791668E7|1.799313342398437...| 6.013201162194166E7|241222.99548951042| 1.242885136677283|   4.5790207571875E8|       2524.731765304313|6.764841036650151E7|1.1890594958796E13|1.4694820996013507E7|  322519.98085038445| 545225.5104166666|288827.2708333333|             8.788676198815151E8|-0.03631715827184...|    10027.58640625|    10027.58640625|    10027.58640625|    10027.58640625|    10027.58640625|    10027.58640625|10025.765208333332|
# |2019-09-23 00:30:00|  2|10025.765208333332|1.7952087239583332E7|1.798754151796875E11|6.0762217574883334E7|241224.47130402082|1.2420507470387758|    4.579050724375E8|      2521.8407235910863| 6.79131670467381E7|1.1890594958796E13|1.4742458193797214E7|  323006.16347097885| 545770.0208333334|289505.5416666667|             9.026614695587213E8|-0.03633035242341931|10025.765208333332|10025.765208333332|10025.765208333332|10025.765208333332|10025.765208333332|10025.765208333332|     10022.1228125|
# +-------------------+---+------------------+--------------------+--------------------+--------------------+------------------+------------------+--------------------+------------------------+-------------------+------------------+--------------------+--------------------+------------------+-----------------+--------------------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 3 rows
#
# Shape: (131232, 25)
# root
#  |-- timestamp: timestamp_ntz (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- market-price: double (nullable = true)
#  |-- total-bitcoins: double (nullable = true)
#  |-- market-cap: double (nullable = true)
#  |-- trade-volume: double (nullable = true)
#  |-- blocks-size: double (nullable = true)
#  |-- avg-block-size: double (nullable = true)
#  |-- n-transactions-total: double (nullable = true)
#  |-- n-transactions-per-block: double (nullable = true)
#  |-- hash-rate: double (nullable = true)
#  |-- difficulty: double (nullable = true)
#  |-- miners-revenue: double (nullable = true)
#  |-- transaction-fees-usd: double (nullable = true)
#  |-- n-unique-addresses: double (nullable = true)
#  |-- n-transactions: double (nullable = true)
#  |-- estimated-transaction-volume-usd: double (nullable = true)
#  |-- rate-of-change: double (nullable = true)
#  |-- sma-5-days: double (nullable = true)
#  |-- sma-7-days: double (nullable = true)
#  |-- sma-10-days: double (nullable = true)
#  |-- sma-20-days: double (nullable = true)
#  |-- sma-50-days: double (nullable = true)
#  |-- sma-100-days: double (nullable = true)
#  |-- next-market-price: double (nullable = true)

# %% [markdown]
# # Loading features

# %%
# Loading all the features
with open(ALL_FEATURES, "r") as f:
    ALL_FEATURES = json.load(f)
print(ALL_FEATURES)
# Out:
# ['market-price', 'market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'sma-20-days', 'trade-volume', 'sma-100-days', 'n-unique-addresses', 'transaction-fees-usd', 'total-bitcoins', 'n-transactions-total', 'blocks-size', 'sma-50-days', 'hash-rate', 'difficulty', 'avg-block-size', 'n-transactions-per-block', 'n-transactions', 'rate-of-change']

# %%
# Loading the most relevant features
with open(MOST_REL_FEATURES, "r") as f:
    MOST_REL_FEATURES = json.load(f)
print(MOST_REL_FEATURES)
# Out:
# ['market-price', 'market-cap', 'miners-revenue', 'sma-5-days', 'sma-7-days', 'sma-10-days', 'estimated-transaction-volume-usd', 'sma-20-days', 'trade-volume']

# %%
# Loading least relevant features
with open(LEAST_REL_FEATURES, "r") as f:
    LEAST_REL_FEATURES = json.load(f)
print(LEAST_REL_FEATURES)
# Out:
# ['sma-100-days', 'n-unique-addresses', 'transaction-fees-usd', 'total-bitcoins', 'n-transactions-total', 'blocks-size', 'sma-50-days', 'hash-rate', 'difficulty', 'avg-block-size', 'n-transactions-per-block', 'n-transactions', 'rate-of-change']

# %% [markdown]
# # Model train / validation
# In order to train and validate the model I'll try several approaches:
# - **Default without normalization:** Make predictions using the chosen base model
# - **Default with normalization:** Like the previous one but features are normalized
#
# At this point, the features that gave on average the most satisfactory results (for each model) are chosen and proceeded with:
#
# - **Hyperparameter tuning:** Researching the best parameters to use
# - **Cross Validation:** Validate the performance of the model with the chosen parameters
#
# If the final results are satisfactory, the model will be trained on the whole train / validation set and saved to later make predictions on the test set.
#
# ---
#
# For each approach the train / validation set will be split according to the chosen splitting method (in order to figure out which one works best for our problem):
#
# - **Block time series splits:** Involves dividing the time series into blocks of equal length, and then using each block as a separate fold for cross-validation.
#
#     ![block-splits.png](https://drive.google.com/uc?id=1SPT133HO1VdWYZZv6GeknFY3xX3T2tvL)
#
# - **Walk forward time series splits:** Involves using a sliding window approach to create the training and validation sets for each fold. The model is trained on a fixed window of historical data, and then validated on the next observation in the time series. This process is repeated for each subsequent observation, with the window sliding forward one step at a time.
#
#     ![walk-forward-splits.png](https://drive.google.com/uc?id=1SNdq-kjbv4MXtdBj3EOJ2dmQpbbPStJi)
#
# - **Single time series split:** Involves dividing the time series considering as validation set a narrow period of time and as train set everything that happened before this period, in such a way as to best benefit from the trend in the short term.
#
#     ![single-split.png](https://drive.google.com/uc?id=1SODyQLolK4zn9lFGnNaqnMBZrHn3OsVn)

# %%
# Get splitting parameters based on the choosen splitting method
splitting_info = parameters.get_splitting_params(SPLITTING_METHOD)
splitting_info
# Out:
# {'split_type': 'walk_forward_splits',
#  'min_obser': 20000,
#  'sliding_window': 5000}

# %% [markdown]
# ## Default
# The train / validation set will be splitted based on the splitting method chosen so that the model performance can be seen without any tuning by using different features (normalized and non)

# %% [markdown]
# ### Without normalization

# %%
# Define model and features type
MODEL_TYPE = "default"
FEATURES_NORMALIZATION = False

# %%
# Get default parameters
params = parameters.get_defaults_model_params(MODEL_NAME)
params
# Out:
# {'numTrees': [20], 'maxDepth': [5], 'seed': [42]}

# %%
# Make predictions by using all the features
default_res_all, default_pred_all = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, ALL_FEATURES, ALL_FEATURES_NAME, FEATURES_LABEL, TARGET_LABEL)
default_res_all
# Out:
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 1, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 863.590210335848, 'MSE': 745788.0513879142, 'MAE': 740.2523985955457, 'MAPE': 0.07947170083392614, 'R2': 0.019237945829099656, 'Adjusted_R2': 0.01845255079072461, 'Time': 5.477662563323975}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 2, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 424.823714392795, 'MSE': 180475.18831049107, 'MAE': 205.85725374990346, 'MAPE': 0.02008863955203405, 'R2': 0.26037565718844047, 'Adjusted_R2': 0.2597833654224252, 'Time': 2.9910545349121094}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 3, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 641.8495612103931, 'MSE': 411970.8592259741, 'MAE': 569.0525059335273, 'MAPE': 0.04968534180502498, 'R2': -0.21497342673056963, 'Adjusted_R2': -0.21594637842364706, 'Time': 2.1795365810394287}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 4, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 1760.5632154928644, 'MSE': 3099582.8357465737, 'MAE': 1140.6043289188885, 'MAPE': 0.08097881778767065, 'R2': -0.08277296501354225, 'Adjusted_R2': -0.08364005047101064, 'Time': 1.9415068626403809}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 5, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 6636.688045287969, 'MSE': 44045628.21046824, 'MAE': 5314.6728539896785, 'MAPE': 0.23111623981980314, 'R2': -1.7500835388654452, 'Adjusted_R2': -1.752285807965638, 'Time': 1.8539433479309082}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 6, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 13846.578328971913, 'MSE': 191727731.4203546, 'MAE': 11501.440080851564, 'MAPE': 0.26362379263188224, 'R2': -2.472685547917373, 'Adjusted_R2': -2.4754664772850745, 'Time': 1.8931801319122314}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 7, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4227.014037478958, 'MSE': 17867647.673044164, 'MAE': 3620.839229201702, 'MAPE': 0.06471388948184897, 'R2': 0.1685632752198849, 'Adjusted_R2': 0.16789746002486572, 'Time': 1.6131219863891602}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 8, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 6503.283277120874, 'MSE': 42292693.38248002, 'MAE': 5396.967265234241, 'MAPE': 0.133825805730688, 'R2': 0.4457139453744693, 'Adjusted_R2': 0.4452700726580524, 'Time': 1.568751573562622}
# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 9, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 

# {'Model': 'RandomForestRegressor', 'Type': 'default', 'Splitting': 'walk_forward_splits', 'Features': 'all_features', 'Splits': 22, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 2060.5456053800744, 'MSE': 4245848.191851138, 'MAE': 1854.4118562931146, 'MAPE': 0.06805639428714942, 'R2': -3.2520442887381042, 'Adjusted_R2': -3.255449329209566, 'Time': 1.6304094791412354}
#                     Model     Type            Splitting      Features  Splits  \
# 0   RandomForestRegressor  default  walk_forward_splits  all_features       1
# 1   RandomForestRegressor  default  walk_forward_splits  all_features       2
# 2   RandomForestRegressor  default  walk_forward_splits  all_features       3
# 3   RandomForestRegressor  default  walk_forward_splits  all_features       4
# 4   RandomForestRegressor  default  walk_forward_splits  all_features       5
# 5   RandomForestRegressor  default  walk_forward_splits  all_features       6
# 6   RandomForestRegressor  default  walk_forward_splits  all_features       7
# 7   RandomForestRegressor  default  walk_forward_splits  all_features       8
# 8   RandomForestRegressor  default  walk_forward_splits  all_features       9
# 9   RandomForestRegressor  default  walk_forward_splits  all_features      10
# 10  RandomForestRegressor  default  walk_forward_splits  all_features      11
# 11  RandomForestRegressor  default  walk_forward_splits  all_features      12
# 12  RandomForestRegressor  default  walk_forward_splits  all_features      13
# 13  RandomForestRegressor  default  walk_forward_splits  all_features      14
# 14  RandomForestRegressor  default  walk_forward_splits  all_features      15
# 15  RandomForestRegressor  default  walk_forward_splits  all_features      16
# 16  RandomForestRegressor  default  walk_forward_splits  all_features      17
# 17  RandomForestRegressor  default  walk_forward_splits  all_features      18
# 18  RandomForestRegressor  default  walk_forward_splits  all_features      19
# 19  RandomForestRegressor  default  walk_forward_splits  all_features      20
# 20  RandomForestRegressor  default  walk_forward_splits  all_features      21
# 21  RandomForestRegressor  default  walk_forward_splits  all_features      22
#
#    Train&Validation   Parameters          RMSE           MSE           MAE  \
# 0     (20000, 5000)  [20, 5, 42]    863.590210  7.457881e+05    740.252399
# 1     (20000, 5000)  [20, 5, 42]    424.823714  1.804752e+05    205.857254
# 2     (20000, 5000)  [20, 5, 42]    641.849561  4.119709e+05    569.052506
# 3     (20000, 5000)  [20, 5, 42]   1760.563215  3.099583e+06   1140.604329
# 4     (20000, 5000)  [20, 5, 42]   6636.688045  4.404563e+07   5314.672854
# 5     (20000, 5000)  [20, 5, 42]  13846.578329  1.917277e+08  11501.440081
# 6     (20000, 5000)  [20, 5, 42]   4227.014037  1.786765e+07   3620.839229
# 7     (20000, 5000)  [20, 5, 42]   6503.283277  4.229269e+07   5396.967265
# 8     (20000, 5000)  [20, 5, 42]   1796.220297  3.226407e+06   1508.641203
# 9     (20000, 5000)  [20, 5, 42]   2101.928282  4.418103e+06   1760.309241
# 10    (20000, 5000)  [20, 5, 42]   5776.239984  3.336495e+07   4563.613370
# 11    (20000, 5000)  [20, 5, 42]   3838.062210  1.473072e+07   3420.606297
# 12    (20000, 5000)  [20, 5, 42]   3229.178044  1.042759e+07   2681.376077
# 13    (20000, 5000)  [20, 5, 42]    886.660475  7.861668e+05    705.632065
# 14    (20000, 5000)  [20, 5, 42]   6625.985889  4.390369e+07   5369.944447
# 15    (20000, 5000)  [20, 5, 42]   9967.886461  9.935876e+07   9484.785350
# 16    (20000, 5000)  [20, 5, 42]    648.669449  4.207721e+05    536.271596
# 17    (20000, 5000)  [20, 5, 42]    786.038150  6.178560e+05    509.496544
# 18    (20000, 5000)  [20, 5, 42]   1288.107181  1.659220e+06   1240.113712

# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 18, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 8264.23980898037, 'MSE': 68297659.6203359, 'MAE': 7469.505582861343, 'MAPE': 0.3798542771334854, 'R2': -84.65258043791209, 'Adjusted_R2': -84.72117109291743, 'Time': 1.170133113861084}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 19, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 6045.165671243766, 'MSE': 36544027.9927841, 'MAE': 5693.846124839283, 'MAPE': 0.3396848128715107, 'R2': -304.54819681227536, 'Adjusted_R2': -304.79288005296587, 'Time': 1.186011791229248}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 20, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 2266.7427945511004, 'MSE': 5138122.896649333, 'MAE': 2027.3477040605233, 'MAPE': 0.09267748042673071, 'R2': 0.1576907371299292, 'Adjusted_R2': 0.15701621519770093, 'Time': 1.163163185119629}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 21, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 3541.844346096446, 'MSE': 12544661.371975359, 'MAE': 2966.660471426151, 'MAPE': 0.10688350619122457, 'R2': -0.45094285319041805, 'Adjusted_R2': -0.4521047693891691, 'Time': 1.1598711013793945}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 22, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4552.941548456495, 'MSE': 20729276.743661426, 'MAE': 4402.430264641675, 'MAPE': 0.1596590569700696, 'R2': -19.759527614935386, 'Adjusted_R2': -19.77615186127367, 'Time': 1.2286572456359863}
#                     Model          Type            Splitting  \
# 0   RandomForestRegressor  default_norm  walk_forward_splits
# 1   RandomForestRegressor  default_norm  walk_forward_splits
# 2   RandomForestRegressor  default_norm  walk_forward_splits
# 3   RandomForestRegressor  default_norm  walk_forward_splits
# 4   RandomForestRegressor  default_norm  walk_forward_splits
# 5   RandomForestRegressor  default_norm  walk_forward_splits
# 6   RandomForestRegressor  default_norm  walk_forward_splits
# 7   RandomForestRegressor  default_norm  walk_forward_splits
# 8   RandomForestRegressor  default_norm  walk_forward_splits
# 9   RandomForestRegressor  default_norm  walk_forward_splits
# 10  RandomForestRegressor  default_norm  walk_forward_splits
# 11  RandomForestRegressor  default_norm  walk_forward_splits
# 12  RandomForestRegressor  default_norm  walk_forward_splits
# 13  RandomForestRegressor  default_norm  walk_forward_splits
# 14  RandomForestRegressor  default_norm  walk_forward_splits
# 15  RandomForestRegressor  default_norm  walk_forward_splits
# 16  RandomForestRegressor  default_norm  walk_forward_splits
# 17  RandomForestRegressor  default_norm  walk_forward_splits
# 18  RandomForestRegressor  default_norm  walk_forward_splits
# 19  RandomForestRegressor  default_norm  walk_forward_splits
# 20  RandomForestRegressor  default_norm  walk_forward_splits
# 21  RandomForestRegressor  default_norm  walk_forward_splits
#
#              Features  Splits Train&Validation   Parameters          RMSE  \
# 0   most_rel_features       1    (20000, 5000)  [20, 5, 42]    382.499493
# 1   most_rel_features       2    (20000, 5000)  [20, 5, 42]    451.722512
# 2   most_rel_features       3    (20000, 5000)  [20, 5, 42]   1205.661029
# 3   most_rel_features       4    (20000, 5000)  [20, 5, 42]   1981.013981
# 4   most_rel_features       5    (20000, 5000)  [20, 5, 42]   6921.415653
# 5   most_rel_features       6    (20000, 5000)  [20, 5, 42]  14764.156610
# 6   most_rel_features       7    (20000, 5000)  [20, 5, 42]  23029.171058

# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 15, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 10107.761715129629, 'MSE': 102166846.88984025, 'MAE': 8787.117861409208, 'MAPE': 0.2839877760486767, 'R2': -3.914539801301915, 'Adjusted_R2': -3.9184753687103644, 'Time': 1.3716671466827393}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 16, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 17996.26551787396, 'MSE': 323865572.5898193, 'MAE': 16811.579662138975, 'MAPE': 0.7966680083168077, 'R2': -48.64729536481365, 'Adjusted_R2': -48.68705295869939, 'Time': 1.3215336799621582}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 17, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4643.549339447004, 'MSE': 21562550.46787871, 'MAE': 3673.223223540777, 'MAPE': 0.17812803561467314, 'R2': -6.512991097890893, 'Adjusted_R2': -6.519007507178494, 'Time': 1.329265832901001}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 18, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4452.905750898418, 'MSE': 19828369.626384202, 'MAE': 4049.7177276822113, 'MAPE': 0.20948795725595518, 'R2': -23.866899302517755, 'Adjusted_R2': -23.886812735392645, 'Time': 1.3238542079925537}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 19, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4000.4973544673594, 'MSE': 16003979.083100341, 'MAE': 3538.3356943496765, 'MAPE': 0.21176462894168557, 'R2': -132.8108363869535, 'Adjusted_R2': -132.917992211888, 'Time': 1.4045701026916504}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 20, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4066.4533037774395, 'MSE': 16536042.47180245, 'MAE': 3701.216666381818, 'MAPE': 0.16437015147620282, 'R2': -1.710807434032985, 'Adjusted_R2': -1.7129782507969753, 'Time': 1.3859765529632568}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 21, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 4290.696764701349, 'MSE': 18410078.72661862, 'MAE': 3604.1130703305244, 'MAPE': 0.1304831885670428, 'R2': -1.1293497977342382, 'Adjusted_R2': -1.131054982757449, 'Time': 1.3164942264556885}
# {'Model': 'RandomForestRegressor', 'Type': 'default_norm', 'Splitting': 'walk_forward_splits', 'Features': 'least_rel_features', 'Splits': 22, 'Train&Validation': (20000, 5000), 'Parameters': [20, 5, 42], 'RMSE': 2177.5088126261567, 'MSE': 4741544.629064574, 'MAE': 1960.3260186756838, 'MAPE': 0.07194224892503105, 'R2': -3.748464111012125, 'Adjusted_R2': -3.7522666848747974, 'Time': 1.4078905582427979}
#                     Model          Type            Splitting  \
# 0   RandomForestRegressor  default_norm  walk_forward_splits
# 1   RandomForestRegressor  default_norm  walk_forward_splits
# 2   RandomForestRegressor  default_norm  walk_forward_splits
# 3   RandomForestRegressor  default_norm  walk_forward_splits
# 4   RandomForestRegressor  default_norm  walk_forward_splits
# 5   RandomForestRegressor  default_norm  walk_forward_splits
# 6   RandomForestRegressor  default_norm  walk_forward_splits
# 7   RandomForestRegressor  default_norm  walk_forward_splits
# 8   RandomForestRegressor  default_norm  walk_forward_splits
# 9   RandomForestRegressor  default_norm  walk_forward_splits
# 10  RandomForestRegressor  default_norm  walk_forward_splits
# 11  RandomForestRegressor  default_norm  walk_forward_splits
# 12  RandomForestRegressor  default_norm  walk_forward_splits
# 13  RandomForestRegressor  default_norm  walk_forward_splits
# 14  RandomForestRegressor  default_norm  walk_forward_splits
# 15  RandomForestRegressor  default_norm  walk_forward_splits
# 16  RandomForestRegressor  default_norm  walk_forward_splits
# 17  RandomForestRegressor  default_norm  walk_forward_splits
# 18  RandomForestRegressor  default_norm  walk_forward_splits
# 19  RandomForestRegressor  default_norm  walk_forward_splits
# 20  RandomForestRegressor  default_norm  walk_forward_splits
# 21  RandomForestRegressor  default_norm  walk_forward_splits
#
#               Features  Splits Train&Validation   Parameters          RMSE  \
# 0   least_rel_features       1    (20000, 5000)  [20, 5, 42]   1869.271788
# 1   least_rel_features       2    (20000, 5000)  [20, 5, 42]   1181.804861
# 2   least_rel_features       3    (20000, 5000)  [20, 5, 42]   2189.417251
# 3   least_rel_features       4    (20000, 5000)  [20, 5, 42]   2979.407571
# 4   least_rel_features       5    (20000, 5000)  [20, 5, 42]   8944.052083
# 5   least_rel_features       6    (20000, 5000)  [20, 5, 42]  17805.853203
# 6   least_rel_features       7    (20000, 5000)  [20, 5, 42]   8852.049454
# 7   least_rel_features       8    (20000, 5000)  [20, 5, 42]  13007.502262
# 8   least_rel_features       9    (20000, 5000)  [20, 5, 42]   2878.895166
# 9   least_rel_features      10    (20000, 5000)  [20, 5, 42]  12583.396757
# 10  least_rel_features      11    (20000, 5000)  [20, 5, 42]  15457.121639
# 11  least_rel_features      12    (20000, 5000)  [20, 5, 42]   8343.962728
# 12  least_rel_features      13    (20000, 5000)  [20, 5, 42]   8895.979789
# 13  least_rel_features      14    (20000, 5000)  [20, 5, 42]   3096.070839
# 14  least_rel_features      15    (20000, 5000)  [20, 5, 42]  10107.761715
# 15  least_rel_features      16    (20000, 5000)  [20, 5, 42]  17996.265518
# 16  least_rel_features      17    (20000, 5000)  [20, 5, 42]   4643.549339
# 17  least_rel_features      18    (20000, 5000)  [20, 5, 42]   4452.905751
# 18  least_rel_features      19    (20000, 5000)  [20, 5, 42]   4000.497354
# 19  least_rel_features      20    (20000, 5000)  [20, 5, 42]   4066.453304
# 20  least_rel_features      21    (20000, 5000)  [20, 5, 42]   4290.696765
# 21  least_rel_features      22    (20000, 5000)  [20, 5, 42]   2177.508813
#
#              MSE           MAE      MAPE          R2  Adjusted_R2      Time
# 0   3.494177e+06   1667.700363  0.181464   -3.595081    -3.598760  1.243569
# 1   1.396663e+06    925.291473  0.095559   -4.723810    -4.728394  1.335056
# 2   4.793548e+06   2041.056019  0.179638  -13.137003   -13.148324  1.362477
# 3   8.876869e+06   2171.580803  0.159246   -2.100944    -2.103428  1.249236
# 4   7.999607e+07   8259.943536  0.382429   -3.994727    -3.998726  1.356362
# 5   3.170484e+08  16154.437196  0.384284   -4.742567    -4.747166  1.236202
# 6   7.835878e+07   7790.290366  0.139439   -2.646276    -2.649195  1.406424
# 7   1.691951e+08  11672.206956  0.268790   -1.217463    -1.219239  1.257922
# 8   8.288037e+06   2482.909528  0.071597   -0.136883    -0.137793  1.289491
# 9   1.583419e+08  12183.609665  0.259722  -16.372295   -16.386207  1.399391
# 10  2.389226e+08  13336.943603  0.221735   -2.698760    -2.701722  1.301519
# 11  6.962171e+07   6599.387366  0.120238   -1.329789    -1.331655  1.312766
# 12  7.913846e+07   8529.991043  0.213863   -8.884024    -8.891939  1.324060
# 13  9.585655e+06   2448.403226  0.056574   -0.238100    -0.239092  1.359015
# 14  1.021668e+08   8787.117861  0.283988   -3.914540    -3.918475  1.371667
# 15  3.238656e+08  16811.579662  0.796668  -48.647295   -48.687053  1.321534
# 16  2.156255e+07   3673.223224  0.178128   -6.512991    -6.519008  1.329266
# 17  1.982837e+07   4049.717728  0.209488  -23.866899   -23.886813  1.323854
# 18  1.600398e+07   3538.335694  0.211765 -132.810836  -132.917992  1.404570
# 19  1.653604e+07   3701.216666  0.164370   -1.710807    -1.712978  1.385977
# 20  1.841008e+07   3604.113070  0.130483   -1.129350    -1.131055  1.316494
# 21  4.741545e+06   1960.326019  0.071942   -3.748464    -3.752267  1.407891

# %%
# Define model information and evaluators to show
model_info = ['Model', 'Type', 'Splitting', 'Features', 'Parameters']
evaluator_lst = ['RMSE', 'MSE', 'MAE', 'MAPE', 'R2', 'Adjusted_R2', 'Time']

# %%
# Define the results to show
default_comparison_lst = [default_res_all, default_res_most_rel, default_res_least_rel, default_norm_res_all, default_norm_res_most_rel, default_norm_res_least_rel]

# Show the comparison table
default_comparison_lst_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in default_comparison_lst])
default_comparison_lst_df
# Out:
#                    Model          Type            Splitting  \
# 0  RandomForestRegressor       default  walk_forward_splits
# 0  RandomForestRegressor       default  walk_forward_splits
# 0  RandomForestRegressor       default  walk_forward_splits
# 0  RandomForestRegressor  default_norm  walk_forward_splits
# 0  RandomForestRegressor  default_norm  walk_forward_splits
# 0  RandomForestRegressor  default_norm  walk_forward_splits
#
#              Features   Parameters         RMSE           MSE          MAE  \
# 0        all_features  [20, 5, 42]  3633.810289  2.435331e+07  3053.893649
# 0   most_rel_features  [20, 5, 42]  3239.527915  1.902744e+07  2657.261563
# 0  least_rel_features  [20, 5, 42]  6060.488142  5.805877e+07  5312.267269
# 0        all_features  [20, 5, 42]  5190.939166  4.457179e+07  4437.898290
# 0   most_rel_features  [20, 5, 42]  7259.576928  1.089601e+08  6644.448915
# 0  least_rel_features  [20, 5, 42]  7264.564725  7.955332e+07  6472.244594
#
#        MAPE         R2  Adjusted_R2      Time
# 0  0.102658  -1.448513    -1.450474  1.967802
# 0  0.090370  -1.345786    -1.347664  1.333877
# 0  0.171499  -6.748423    -6.754628  1.312483
# 0  0.144396  -4.181290    -4.185439  1.592361
# 0  0.201235 -21.847933   -21.866230  1.215825
# 0  0.217337 -13.098132   -13.109422  1.331579

# %%
# Save the best default model results and predicitons
best_default_results = default_res_most_rel
best_default_predictions = default_pred_most_rel

# %% [markdown]
# ## Tuned
# Once the features and execution method are selected, the model will undergo hyperparameter tuning and cross validation to find the best configuration.

# %% [markdown]
# ### Hyperparameter tuning

# %%
# Select the type of feature to be used
MODEL_TYPE = "hyp_tuning"
CHOSEN_FEATURES = MOST_REL_FEATURES
CHOSEN_FEATURES_LABEL = MOST_REL_FEATURES_NAME
FEATURES_NORMALIZATION = False

# %%
# Get model grid parameters
params = parameters.get_model_grid_params(MODEL_NAME)
params
# Out:
# {'numTrees': [3, 5, 10, 20, 30], 'maxDepth': [3, 5, 10], 'seed': [42]}

# %%
# Perform hyperparameter tuning
hyp_res = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABE

# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 13, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 2697.995388509355, 'MSE': 7279179.116417746, 'MAE': 2404.0720128394655, 'MAPE': 0.06112147247355935, 'R2': 0.09086446907206924, 'Adjusted_R2': 0.09013643261086568, 'Time': 4.042307615280151}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 14, 'Train&Validation': (20000, 5000), 'Parameters': [10, 5, 42], 'RMSE': 721.6766719949725, 'MSE': 520817.2189017391, 'MAE': 549.3911892574063, 'MAPE': 0.013462130928083354, 'R2': 0.9327303261331448, 'Adjusted_R2': 0.9326764565244425, 'Time': 0.71689772605896}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 15, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 6567.135716739808, 'MSE': 43127271.52207967, 'MAE': 5295.712982961671, 'MAPE': 0.17515556115048322, 'R2': -1.0745545044112754, 'Adjusted_R2': -1.076215809319713, 'Time': 3.93391752243042}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 16, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 8077.046748314695, 'MSE': 65238684.174460985, 'MAE': 7694.930775882398, 'MAPE': 0.36683073385037984, 'R2': -9.000829036939365, 'Adjusted_R2': -9.008837708840817, 'Time': 3.533473253250122}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 17, 'Train&Validation': (20000, 5000), 'Parameters': [10, 10, 42], 'RMSE': 417.0820007306779, 'MSE': 173957.39533350524, 'MAE': 343.6616741594274, 'MAPE': 0.016039970295358186, 'R2': 0.9393884149048215, 'Adjusted_R2': 0.9393398770989395, 'Time': 1.5281047821044922}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 18, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 575.0818395684163, 'MSE': 330719.12220139365, 'MAE': 280.8329188629095, 'MAPE': 0.015373903610203653, 'R2': 0.5852427978619039, 'Adjusted_R2': 0.5849106599622937, 'Time': 3.439589738845825}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 19, 'Train&Validation': (20000, 5000), 'Parameters': [5, 10, 42], 'RMSE': 516.3603544771614, 'MSE': 266628.0156757798, 'MAE': 438.37005377529186, 'MAPE': 0.026392077358622514, 'R2': -1.2293029500047457, 'Adjusted_R2': -1.231088177592337, 'Time': 1.0720055103302002}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 20, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 2125.773245042941, 'MSE': 4518911.889340397, 'MAE': 1883.772544663173, 'MAPE': 0.08247266597935354, 'R2': 0.2592000193363839, 'Adjusted_R2': 0.2586067861186353, 'Time': 3.382627487182617}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 21, 'Train&Validation': (20000, 5000), 'Parameters': [5, 10, 42], 'RMSE': 3187.740979757368, 'MSE': 10161692.554024465, 'MAE': 2562.8043631135984, 'MAPE': 0.09191031506556055, 'R2': -0.1753234902392904, 'Adjusted_R2': -0.17626469023147395, 'Time': 1.242262363433838}
# {'Model': 'RandomForestRegressor', 'Type': 'hyp_tuning', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 22, 'Train&Validation': (20000, 5000), 'Parameters': [5, 10, 42], 'RMSE': 375.0049282810618, 'MSE': 140628.6962350843, 'MAE': 311.72536101653577, 'MAPE': 0.01118972503628002, 'R2': 0.8591660799821548, 'Adjusted_R2': 0.8590533000662246, 'Time': 1.0942065715789795}
#                     Model        Type            Splitting           Features  \
# 0   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 1   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 2   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 3   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 4   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 5   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 6   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 7   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 8   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 9   RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 10  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 11  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 12  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 13  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 14  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 15  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 16  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 17  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 18  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 19  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 20  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
# 21  RandomForestRegressor  hyp_tuning  walk_forward_splits  most_rel_features
#
#     Splits Train&Validation    Parameters          RMSE           MSE  \
# 0        1    (20000, 5000)   [3, 10, 42]    262.311103  6.880711e+04
# 1        2    (20000, 5000)   [3, 10, 42]    383.779496  1.472867e+05
# 2        3    (20000, 5000)   [3, 10, 42]    498.648826  2.486507e+05
# 3        4    (20000, 5000)   [3, 10, 42]   1548.579028  2.398097e+06
# 4        5    (20000, 5000)    [3, 5, 42]   6276.097155  3.938940e+07
# 5        6    (20000, 5000)   [5, 10, 42]  10476.955960  1.097666e+08
# 6        7    (20000, 5000)   [3, 10, 42]   3441.612455  1.184470e+07
# 7        8    (20000, 5000)    [5, 3, 42]   6878.742277  4.731710e+07
# 8        9    (20000, 5000)  [20, 10, 42]   1394.442713  1.944470e+06
# 9       10    (20000, 5000)  [30, 10, 42]   1063.556141  1.131152e+06
# 10      11    (20000, 5000)  [20, 10, 42]   3409.124863  1.162213e+07
# 11      12    (20000, 5000)  [20, 10, 42]   1860.975807  3.463231e+06
# 12      13    (20000, 5000)  [30, 10, 42]   2697.995389  7.279179e+06
# 13      14    (20000, 5000)   [10, 5, 42]    721.676672  5.208172e+05
# 14      15    (20000, 5000)  [30, 10, 42]   6567.135717  4.312727e+07
# 15      16    (20000, 5000)  [30, 10, 42]   8077.046748  6.523868e+07
# 16      17    (20000, 5000)  [10, 10, 42]    417.082001  1.739574e+05
# 17      18    (20000, 5000)  [30, 10, 42]    575.081840  3.307191e+05
# 18      19    (20000, 5000)   [5, 10, 42]    516.360354  2.666280e+05
# 19      20    (20000, 5000)  [30, 10, 42]   2125.773245  4.518912e+06
# 20      21    (20000, 5000)   [5, 10, 42]   3187.740980  1.016169e+07
# 21      22    (20000, 5000)   [5, 10, 42]    375.004928  1.406287e+05
#
#             MAE      MAPE        R2  Adjusted_R2      Time
# 0    174.944832  0.019638  0.909514     0.909441  1.091656
# 1    173.974952  0.016826  0.396389     0.395906  1.069073
# 2    434.055877  0.038468  0.266686     0.266099  1.180268
# 3    989.121098  0.070193  0.162276     0.161605  0.978908
# 4   4834.972349  0.207131 -1.459362    -1.461331  0.494623
# 5   7544.215008  0.163469 -0.988157    -0.989750  1.028033
# 6   2632.893608  0.046355  0.448830     0.448388  0.992996
# 7   5379.480904  0.135732  0.379864     0.379368  0.383769
# 8   1097.561446  0.032642  0.733274     0.733060  2.441995
# 9    788.650479  0.017018  0.875897     0.875798  3.658561
# 10  2475.701602  0.041278  0.820078     0.819934  2.543005
# 11  1513.019593  0.030098  0.884108     0.884015  2.497867
# 12  2404.072013  0.061121  0.090864     0.090136  4.042308
# 13   549.391189  0.013462  0.932730     0.932676  0.716898
# 14  5295.712983  0.175156 -1.074555    -1.076216  3.933918
# 15  7694.930776  0.366831 -9.000829    -9.008838  3.533473
# 16   343.661674  0.016040  0.939388     0.939340  1.528105
# 17   280.832919  0.015374  0.585243     0.584911  3.439590
# 18   438.370054  0.026392 -1.229303    -1.231088  1.072006
# 19  1883.772545  0.082473  0.259200     0.258607  3.382627
# 20  2562.804363  0.091910 -0.175323    -0.176265  1.242262
# 21   311.725361  0.011190  0.859166     0.859053  1.094207

# %% [markdown]
# ---
# To select the best parameters to be used in the final model I assign a score to each value in the "Parameters" column based on the following criteria:
# * Calculate the frequency of each unique value in the "Parameters" column.
# * Normalize the frequencies to a scale of 0 to 1, where 1 represents the highest frequency.
# * Calculate the split weight for each value in the "Parameters" column, where a higher split number corresponds to a higher weight.
# * Normalize the split weights to a scale of 0 to 1, where 1 represents the highest split weight.
# * Calculate the RMSE weight for each value in the "Parameters" column, where a lower RMSE value corresponds to a higher weight.
# * Normalize the RMSE weights to a scale of 0 to 1, where 1 represents the highest RMSE weight.
#
# Then calculate the overall score for each value in the "Parameters" column by combining the normalized frequency, split weight, and RMSE weight and take into consideration the parameters that have the highest score.

# %%
# Show parameters score
grouped_scores, best_params = parameters.choose_best_params(hyp_res)
grouped_scores
# Out:
#               Split weight  RMSE weight  Frequency weight  Final score
# Parameters
# (30, 10, 42)      0.696970     0.664238          1.000000     0.462954
# (5, 10, 42)       0.772727     0.652665          0.666667     0.336221
# (20, 10, 42)      0.484848     0.787962          0.500000     0.191021
# (10, 10, 42)      0.772727     0.960191          0.166667     0.123661
# (3, 10, 42)       0.154545     0.882887          0.833333     0.113705
# (10, 5, 42)       0.636364     0.931118          0.166667     0.098755
# (5, 3, 42)        0.363636     0.343441          0.166667     0.020815
# (3, 5, 42)        0.227273     0.400962          0.166667     0.015188

# %%
# Print best parameters
print(f"Best parameters: {best_params}")
# Out:
# Best parameters: (30, 10, 42)

# %% [markdown]
# ### Cross validation

# %%
MODEL_TYPE = "cross_val"

# %%
# Get tuned parameters
params = parameters.get_best_model_params(best_params, MODEL_NAME)
params
# Out:
# {'numTrees': [30], 'maxDepth': [10], 'seed': [42]}

# %%
# Perform cross validation
cv_res, cv_pred = utilities.multiple_splits(df, params, splitting_info, MODEL_NAME, MODEL_TYPE, FEATURES_NORMALIZATION, CHOSEN_FEATURES, CHOSEN_FEATURES_LABEL, FEATURES_LABEL, TARGET_LABEL)
cv_res
# Out:
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 1, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 320.68272014619896, 'MSE': 102837.40700036538, 'MAE': 266.2938609496898, 'MAPE': 0.029003499108288314, 'R2': 0.86476180954148, 'Adjusted_R2': 0.864653510690262, 'Time': 4.199690103530884}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 2, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 489.13799999380393, 'MSE': 239255.98303793854, 'MAE': 314.6874681083824, 'MAPE': 0.03172359710482812, 'R2': 0.01947990261283883, 'Adjusted_R2': 0.01869470133364992, 'Time': 4.208567380905151}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 3, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 521.86565620534, 'MSE': 272343.76312663005, 'MAE': 467.86688974285994, 'MAPE': 0.0415886902596436, 'R2': 0.19681106630612355, 'Adjusted_R2': 0.1961678719648272, 'Time': 3.9090750217437744}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 4, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 1729.4339926927619, 'MSE': 2990941.9350812277, 'MAE': 1127.271506431464, 'MAPE': 0.0800980361200143, 'R2': -0.044821590145115886, 'Adjusted_R2': -0.04565828411119788, 'Time': 4.309117317199707}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 5, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 6304.3007311516685, 'MSE': 39744207.70879947, 'MAE': 4900.214503133572, 'MAPE': 0.21068701353762817, 'R2': -1.4815150975469904, 'Adjusted_R2': -1.4835022968243052, 'Time': 3.4729154109954834}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 6, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 10745.306907777398, 'MSE': 115461620.54232869, 'MAE': 8026.5755592682945, 'MAPE': 0.17647434194680417, 'R2': -1.0913088473225252, 'Adjusted_R2': -1.092983569122183, 'Time': 3.4223198890686035}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 7, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE':

# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 21, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 3303.856721001159, 'MSE': 10915469.23290453, 'MAE': 2608.7900443863027, 'MAPE': 0.09270859792519363, 'R2': -0.2625069424419877, 'Adjusted_R2': -0.26351795901251185, 'Time': 4.0680670738220215}
# {'Model': 'RandomForestRegressor', 'Type': 'cross_val', 'Splitting': 'walk_forward_splits', 'Features': 'most_rel_features', 'Splits': 22, 'Train&Validation': (20000, 5000), 'Parameters': [30, 10, 42], 'RMSE': 794.2992291028183, 'MSE': 630911.2653533315, 'MAE': 673.0239918621273, 'MAPE': 0.024702993322936587, 'R2': 0.3681680264275875, 'Adjusted_R2': 0.3676620548771792, 'Time': 4.006818532943726}
#                     Model       Type            Splitting           Features  \
# 0   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 1   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 2   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 3   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 4   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 5   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 6   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 7   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 8   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 9   RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 10  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 11  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 12  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 13  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 14  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 15  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 16  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 17  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 18  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 19  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 20  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
# 21  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
#
#     Splits Train&Validation    Parameters          RMSE           MSE  \
# 0        1    (20000, 5000)  [30, 10, 42]    320.682720  1.028374e+05
# 1        2    (20000, 5000)  [30, 10, 42]    489.138000  2.392560e+05
# 2        3    (20000, 5000)  [30, 10, 42]    521.865656  2.723438e+05
# 3        4    (20000, 5000)  [30, 10, 42]   1729.433993  2.990942e+06
# 4        5    (20000, 5000)  [30, 10, 42]   6304.300731  3.974421e+07
# 5        6    (20000, 5000)  [30, 10, 42]  10745.306908  1.154616e+08
# 6        7    (20000, 5000)  [30, 10, 42]   3885.204010  1.509481e+07
# 7        8    (20000, 5000)  [30, 10, 42]   7636.423515  5.831496e+07
# 8        9    (20000, 5000)  [30, 10, 42]   1420.376620  2.017470e+06
# 9       10    (20000, 5000)  [30, 10, 42]   1063.556141  1.131152e+06
# 10      11    (20000, 5000)  [30, 10, 42]   4020.120263  1.616137e+07
# 11      12    (20000, 5000)  [30, 10, 42]   2309.440139  5.333514e+06
# 12      13    (20000, 5000)  [30, 10, 42]   2697.995389  7.279179e+06
# 13      14    (20000, 5000)  [30, 10, 42]    876.220138  7.677617e+05
# 14      15    (20000, 5000)  [30, 10, 42]   6567.135717  4.312727e+07
# 15      16    (20000, 5000)  [30, 10, 42]   8077.046748  6.523868e+07
# 16      17    (20000, 5000)  [30, 10, 42]    546.237638  2.983756e+05
# 17      18    (20000, 5000)  [30, 10, 42]    575.081840  3.307191e+05
# 18      19    (20000, 5000)  [30, 10, 42]    813.555906  6.618732e+05
# 19      20    (20000, 5000)  [30, 10, 42]   2125.773245  4.518912e+06
# 20      21    (20000, 5000)  [30, 10, 42]   3303.856721  1.091547e+07
# 21      22    (20000, 5000)  [30, 10, 42]    794.299229  6.309113e+05
#
#             MAE      MAPE        R2  Adjusted_R2      Time
# 0    266.293861  0.029003  0.864762     0.864654  4.199690
# 1    314.687468  0.031724  0.019480     0.018695  4.208567
# 2    467.866890  0.041589  0.196811     0.196168  3.909075
# 3   1127.271506  0.080098 -0.044822    -0.045658  4.309117
# 4   4900.214503  0.210687 -1.481515    -1.483502  3.472915
# 5   8026.575559  0.176474 -1.091309    -1.092984  3.422320
# 6   3289.286367  0.058750  0.297592     0.297029  3.502126
# 7   6543.365356  0.160165  0.235727     0.235115  3.620844
# 8   1068.234982  0.032048  0.723261     0.723039  3.808050
# 9    788.650479  0.017018  0.875897     0.875798  3.788308
# 10  3117.709418  0.052607  0.749806     0.749606  3.869796
# 11  2005.111860  0.038680  0.821522     0.821379  4.396422
# 12  2404.072013  0.061121  0.090864     0.090136  4.199380
# 13   748.638640  0.018218  0.900835     0.900755  4.393130
# 14  5295.712983  0.175156 -1.074555    -1.076216  4.179128
# 15  7694.930776  0.366831 -9.000829    -9.008838  3.774605
# 16   457.682852  0.021923  0.896038     0.895954  3.751328
# 17   280.832919  0.015374  0.585243     0.584911  3.555346
# 18   757.394944  0.045477 -4.533987    -4.538418  3.683845
# 19  1883.772545  0.082473  0.259200     0.258607  3.703772
# 20  2608.790044  0.092709 -0.262507    -0.263518  4.068067
# 21   673.023992  0.024703  0.368168     0.367662  4.006819

# %%
# Define the results to show
tuned_comparison_lst = [cv_res]

# Show the comparison table
tuned_comparison_lst_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in tuned_comparison_lst])
tuned_comparison_lst_df
# Out:
#                    Model       Type            Splitting           Features  \
# 0  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
#
#      Parameters         RMSE           MSE         MAE     MAPE       R2  \
# 0  [30, 10, 42]  3037.411421  1.775607e+07  2487.27818  0.08331 -0.43656
#
#    Adjusted_R2     Time
# 0     -0.43771  3.90103

# %% [markdown]
# # Comparison table
# Visualization of model performance at various stages of train / validation

# %%
# Concatenate final results into Pandas dataset
final_comparison_lst_df = pd.DataFrame(pd.concat([default_comparison_lst_df, tuned_comparison_lst_df], ignore_index=True))
final_comparison_lst_df
# Out:
#                    Model          Type            Splitting  \
# 0  RandomForestRegressor       default  walk_forward_splits
# 1  RandomForestRegressor       default  walk_forward_splits
# 2  RandomForestRegressor       default  walk_forward_splits
# 3  RandomForestRegressor  default_norm  walk_forward_splits
# 4  RandomForestRegressor  default_norm  walk_forward_splits
# 5  RandomForestRegressor  default_norm  walk_forward_splits
# 6  RandomForestRegressor     cross_val  walk_forward_splits
#
#              Features    Parameters         RMSE           MSE          MAE  \
# 0        all_features   [20, 5, 42]  3633.810289  2.435331e+07  3053.893649
# 1   most_rel_features   [20, 5, 42]  3239.527915  1.902744e+07  2657.261563
# 2  least_rel_features   [20, 5, 42]  6060.488142  5.805877e+07  5312.267269
# 3        all_features   [20, 5, 42]  5190.939166  4.457179e+07  4437.898290
# 4   most_rel_features   [20, 5, 42]  7259.576928  1.089601e+08  6644.448915
# 5  least_rel_features   [20, 5, 42]  7264.564725  7.955332e+07  6472.244594
# 6   most_rel_features  [30, 10, 42]  3037.411421  1.775607e+07  2487.278180
#
#        MAPE         R2  Adjusted_R2      Time
# 0  0.102658  -1.448513    -1.450474  1.967802
# 1  0.090370  -1.345786    -1.347664  1.333877
# 2  0.171499  -6.748423    -6.754628  1.312483
# 3  0.144396  -4.181290    -4.185439  1.592361
# 4  0.201235 -21.847933   -21.866230  1.215825
# 5  0.217337 -13.098132   -13.109422  1.331579
# 6  0.083310  -0.436560    -0.437710  3.901030

# %% [markdown]
# # Model accuracy
#
# Since predicting the price accurately is very difficult let's se how good the model is at predicting whether the price will go up or down.
#
# For each row in our predictions let's consider the actual market-price, next-market-price and our predicted next-market-price (prediction).
# We compute whether the current prediction is correct (1) or not (0):
#
# $$
# prediction\_is\_correct
# =
# \begin{cases}
# 0 \text{ if [(market-price > next-market-price) and (market-price < prediction)] or [(market-price < next-market-price) and (market-price > prediction)]} \\
# 1 \text{ if [(market-price > next-market-price) and (market-price > prediction)] or [(market-price < next-market-price) and (market-price < prediction)]}
# \end{cases}
# $$
#
# After that we count the number of correct prediction:
# $$
# correct\_predictions
# =
# \sum_{i=0}^{total\_rows} prediction\_is\_correct
# $$
#
# Finally we compute the percentage of accuracy of the model:
# $$
# \\
# accuracy
# =
# (correct\_predictions / total\_rows)
# * 100
# $$

# %%
# Convert the pandas dataset to a PySpark dataset
best_default_pred_spark = spark.createDataFrame(best_default_predictions)
validated_pred_spark = spark.createDataFrame(cv_pred)

# Compute model accuracy
default_accuracy = utilities.model_accuracy(best_default_pred_spark)
validated_accuracy = utilities.model_accuracy(validated_pred_spark)

# Saving accuracy data into dataframe
accuracy_data = {
    'Model': MODEL_NAME,
    'Features': CHOSEN_FEATURES_LABEL,
    'Splitting': SPLITTING_METHOD,
    'Accuracy (default)': default_accuracy,
    'Accuracy (validated)': validated_accuracy
}
accuracy_data_df = pd.DataFrame(accuracy_data, index=['Model'])

print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (default): {default_accuracy:.2f}%")
print(f"Percentage of correct predictions for {MODEL_NAME} with {CHOSEN_FEATURES_LABEL} and {SPLITTING_METHOD} (validated): {validated_accuracy:.2f}%")
# Out:
# Percentage of correct predictions for RandomForestRegressor with most_rel_features and walk_forward_splits (default): 47.88%
# Percentage of correct predictions for RandomForestRegressor with most_rel_features and walk_forward_splits (validated): 47.89%

# %% [markdown]
# # Saving final results

# %%
# Concatenate default and tuned results
default_tuned_results = [best_default_results, cv_res]
default_tuned_results_df = pd.concat([utilities.model_comparison(results, model_info, evaluator_lst) for results in default_tuned_results])
default_tuned_results_df
# Out:
#                    Model       Type            Splitting           Features  \
# 0  RandomForestRegressor    default  walk_forward_splits  most_rel_features
# 0  RandomForestRegressor  cross_val  walk_forward_splits  most_rel_features
#
#      Parameters         RMSE           MSE          MAE     MAPE        R2  \
# 0   [20, 5, 42]  3239.527915  1.902744e+07  2657.261563  0.09037 -1.345786
# 0  [30, 10, 42]  3037.411421  1.775607e+07  2487.278180  0.08331 -0.436560
#
#    Adjusted_R2      Time
# 0    -1.347664  1.333877
# 0    -0.437710  3.901030

# %%
# Saving default and tuned results
default_tuned_results_df.to_csv(MODEL_RESULTS, index=False)

# %%
# Saving accuracy results
accuracy_data_df.to_csv(MODEL_ACCURACY_RESULTS, index=False)
